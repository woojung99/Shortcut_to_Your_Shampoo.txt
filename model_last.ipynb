# %% [markdown]
# # ABSA Model (최종 버전)
#
# - kykim/electra-kor-base : ACD
# - klue/roberta-base : ASC
# - back translation & stratifiedKFold 적용
# - spacing 적용
# - max_len = 128 로 수정

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.52.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.32.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (2.14.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec>=2021.11.1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.11.1->datasets) (2025.3.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.32.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.18.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (1.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 모듈 import 및 전역 변수 설정

# %%
import json
import os
from tqdm import trange, tqdm
import re
import random

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from torch.optim import AdamW
from torch.amp import autocast, GradScaler
from transformers import AutoModel, AutoConfig, AutoTokenizer
from transformers import get_linear_schedule_with_warmup

from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, precision_score, recall_score
import pandas as pd
import numpy as np
import copy
from collections import Counter

# %%
PADDING_TOKEN = 0
S_OPEN_TOKEN = 1
S_CLOSE_TOKEN = 2

do_eval=True

# 경로 설정
BASE_DIR = '/content/drive/MyDrive/ABSA'
DATA_DIR = os.path.join(BASE_DIR, 'data')
SAVED_MODEL_DIR = os.path.join(BASE_DIR, 'saved_model')
ACD_MODEL_DIR = os.path.join(BASE_DIR, 'saved_model/ACD')
ASC_MODEL_DIR = os.path.join(BASE_DIR, 'saved_model/ASC')
pred_result_DIR = os.path.join(BASE_DIR, 'pred_result')
final_output_DIR = os.path.join(BASE_DIR, 'final_output')

base_data_path = os.path.join(DATA_DIR, 'base_data.jsonl')
converted_base_data_path = os.path.join(DATA_DIR, 'converted_base_data.jsonl')

train_data_path = os.path.join(DATA_DIR, 'train.jsonl')
dev_data_path = os.path.join(DATA_DIR, 'dev.jsonl')
test_data_path = os.path.join(DATA_DIR, 'test.jsonl')

acd_best_model_path = os.path.join(ACD_MODEL_DIR, 'best_model_last.pt')
asc_best_model_path = os.path.join(ASC_MODEL_DIR, 'best_model_last.pt')

raw_data_path = os.path.join(DATA_DIR, 'rawdata_spaced_final.jsonl')
converted_raw_data_path = os.path.join(DATA_DIR, 'converted_raw_data.jsonl')
final_output_path = os.path.join(final_output_DIR, 'final_spaced_output.jsonl')

# 하이퍼파라미터 설정
max_len = 128
batch_size = 16
acd_base_model = 'kykim/electra-kor-base'
asc_base_model = 'klue/roberta-base'
learning_rate = 3e-6
eps = 1e-8
num_train_epochs = 30
dropout_prob = 0.1
label_smoothing = 0.1
max_grad_norm = 1.0
threshold = 0.95

# 속성 카테고리 정의
entity_property_pair = [
    '세정', '자극', '거품', '향', '가격', '머릿결', '탈모', '쿨링'
]

# ACD 라벨 (multi-label classification)
tf_id_to_name = ['False', 'True']
tf_name_to_id = {name: idx for idx, name in enumerate(tf_id_to_name)}

# ASC 라벨 (multi-class classification)
polarity_id_to_name = ['positive', 'negative', 'neutral']
polarity_name_to_id = {name: idx for idx, name in enumerate(polarity_id_to_name)}

# device 정의
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# special_tokens 정의
special_tokens_dict = {
    'additional_special_tokens': [
        '&name&', '&affiliation&',
        '&social-security-num&',
        '&tel-num&', '&card-num&', '&bank-account&',
        '&num&', '&online-account&'
    ]
}

# %% [markdown]
# json 및 jsonl 파일 read, write 함수

# %%
def jsonload(fname, encoding="utf-8"):
    with open(fname, encoding=encoding) as f:
        return json.load(f)

# json 객체를 파일이름으로 깔끔하게 저장
def jsondump(j, fname):
    with open(fname, "w", encoding="UTF8") as f:
        json.dump(j, f, ensure_ascii=False, indent=2)

# jsonl 파일 읽어서 list에 저장
def jsonlload(fname_list, encoding="utf-8"):
    if isinstance(fname_list, str):
        fname_list = [fname_list]

    json_list = []
    for fname in fname_list:
        path = fname if os.path.isfile(fname) else os.path.join(DATA_DIR, fname)
        with open(path, encoding=encoding) as f:
            for line in f:
                json_list.append(json.loads(line))
    return json_list

# list에 담긴 json 객체를 jsonl 파일에 저장
def jsonldump(jlist, fname):
    with open(fname, "w", encoding="utf-8") as f:
        for item in jlist:
            f.write(json.dumps(item, ensure_ascii=False) + "\n")

# jsonl 파일에서 불러온 데이터 분할
def split_jsonl_file(jsonl_path, output_dir, train_ratio=0.7, dev_ratio=0.15, test_ratio=0.15, seed=42):
    with open(jsonl_path, 'r', encoding='utf-8') as f:
        lines = [json.loads(line) for line in f]

    train_data, temp_data = train_test_split(lines, test_size=(1 - train_ratio), random_state=seed)
    dev_data, test_data = train_test_split(temp_data, test_size=test_ratio / (dev_ratio + test_ratio), random_state=seed)

    os.makedirs(output_dir, exist_ok=True)
    jsonldump(train_data, os.path.join(output_dir, 'train.jsonl'))
    jsonldump(dev_data, os.path.join(output_dir, 'dev.jsonl'))
    jsonldump(test_data, os.path.join(output_dir, 'test.jsonl'))

    print(f"데이터 분할 완료: train={len(train_data)}, dev={len(dev_data)}, test={len(test_data)}")

def split_jsonl_file_train_dev_only(jsonl_path, output_dir, train_ratio=0.85, dev_ratio=0.15, seed=42):
    assert abs(train_ratio + dev_ratio - 1.0) < 1e-6, "train과 dev의 비율 합이 1이 되어야 합니다."

    with open(jsonl_path, 'r', encoding='utf-8') as f:
        lines = [json.loads(line) for line in f]

    train_data, dev_data = train_test_split(lines, test_size=dev_ratio, random_state=seed)

    os.makedirs(output_dir, exist_ok=True)
    jsonldump(train_data, os.path.join(output_dir, 'train.jsonl'))
    jsonldump(dev_data, os.path.join(output_dir, 'dev.jsonl'))

    print(f"데이터 분할 완료: train={len(train_data)}, dev={len(dev_data)}")

def ensure_annotation(data):
    for sample in data:
        if not sample.get("annotation") or sample["annotation"] == []:
            sample["annotation"] = [["없음", [None, 0, 0], None]]
    return data

def truncate_left(input_ids, attention_mask, max_len, pad_token_id=0):
    if len(input_ids) > max_len:
        input_ids = input_ids[-max_len:]
        attention_mask = attention_mask[-max_len:]
    else:
        pad_len = max_len - len(input_ids)
        input_ids = input_ids + [pad_token_id] * pad_len
        attention_mask = attention_mask + [0] * pad_len
    return input_ids, attention_mask

def convert_to_absa_format(data):
    converted = []
    sentiment_map = {"긍정": "positive", "부정": "negative", "중립": "neutral"}

    for item in data:
        sentence = item.get("text", "")
        label_list = item.get("entities") or item.get("label") or []
        annos = []

        for label_item in label_list:
            try:
                start, end, full_label = label_item
                word = sentence[start:end]

                if "-" not in full_label:
                    continue

                aspect, sentiment_ko = full_label.split("-")

                if aspect not in entity_property_pair:
                    continue

                polarity = sentiment_map.get(sentiment_ko.strip())
                if polarity is None:
                    continue

                annos.append([aspect, [word, start, end], polarity])
            except Exception:
                continue

        converted.append({
            "sentence_form": sentence,
            "annotation": annos
        })

    return converted

# %%
base_data = jsonlload(base_data_path)
converted_base_data = convert_to_absa_format(base_data)
jsonldump(converted_base_data, converted_base_data_path)
jsonlload(converted_base_data_path)
# Out:
# [{'sentence_form': '바오밥 신제품 나와서 사봤어요 시 카라인이라서 그런지 두피 세정이 잘 되는 느낌이에요',
#   'annotation': [['세정', [' 두피 세정이 잘 되는 느낌이', 29, 45], 'positive']]},
#  {'sentence_form': '이렇게 예쁜 샴푸는 처음 이 야 종류도 다양하고 저는 탈모샴푸로 비컨피던트 구매해 봤는데 감을 때 시원하고 향도 시원해서 여름에 사용하기 참 좋더라구 요 향기 좋고 세정력 좋은 샴푸로 추천합니다',
#   'annotation': [['세정', [' 때 시', 52, 56], 'positive'],
#    ['향', ['하고 향도 시', 57, 64], 'positive'],
#    ['향', ['라구 요 ', 81, 86], 'positive'],
#    ['세정', ['기 좋고 세정력 ', 87, 96], 'positive']]},
#  {'sentence_form': '케이스부터 고급 지네요 지루성 두피염이라 아무거나 못 쓰는 편이라 신중히 고르는 편이예요노모어 오일이 조금 더 비싸서 좋지 않을까 했는데 오일샴푸라 린 언미로 겟했어요 그런데 딱 원하는 제품이네요 뾰루지가 잘 나는 두피인데 염증 완화에 도움을 준데요 합성계면 활성제, 합성 방부제 없고 그 외에도 전제품 EWG 98 프로 이상 유해성분 제외라고 하니 믿고 써봅니다향이 시원한 느낌이고  거품도 잘 나며 개운한 느낌입니다',
#   'annotation': [['향', [' 제외라고 하니 믿고', 187, 198], 'positive'],
#    ['거품', ['써봅니다향이 ', 199, 206], 'positive'],
#    ['세정', ['원한 느낌이고 ', 207, 215], 'positive']]},
#  {'sentence_form': '좋아요.리필팩도 들어 있어서 원플러스 원처럼 구입하게 되서 좋아요.',
#   'annotation': [['가격', ['서 원플러스 원처럼 구입하게 되서 좋', 14, 34], 'positive']]},
#  {'sentence_form': '샴푸를 잘못 구매하면 머리가 떡지거나 거품이 잘 안나거나 샴푸 후 머리가 푸석해져서 몹시 까다로운 편인데 이건 가격도 합리적이고 향도 매우 좋은 로즈향 ?같이 나서 샴푸할 때마다 기분이 너무 좋아요 또 거품도 쫀쫀하게 나 고 하고 나서 세정력도 좋아요! 샴푸 후 푸석거림도 없습니다 영양까지는 모르겠지만 기본으로 적당한 샴푸 찾으시면 무난히 성공합니다',
#   'annotation': [['가격', [' 이건 가격도 합', 58, 67], 'positive'],
#    ['향', ['적이고 향도 ', 68, 75], 'positive'],
#    ['거품', [' 좋아요 또 거', 106, 114], 'positive'],
#    ['세정', [' 고 하고 나서', 123, 131], 'positive'],
#    ['머릿결', ['좋아요! 샴푸 후 ', 137, 147], 'positive']]},
#  {'sentence_form': '거품도 충분히 나 고향도 좋아서 머리 말릴 때 기분 좋아요. 오래 사용할 듯해요~',
#   'annotation': [['거품', ['거품도 충분히 나', 0, 9], 'positive'],
#    ['향', [' 고향도 좋', 9, 15], 'positive']]},
#  {'sentence_form': '이 제품 2번째로 사용하고 있어요!! 2세트라서 하나는 제가 쓰고 하나는 부모님께 드리는데 항상 라벤더 향이나 베이비 로션 같은 향만 쓰다가 달달 상큼한 사과향을 쓰고 향도 은은하게 남으니까 너무 마음에 들어 하셨습니다. 저도 지성 두피라서 오후 되면 두피가 기름이 져서 헤어가 금방 푹 죽어버리는데 이 제품을 꾸준히 사용하고 나서는 아예 지성이 잡히는 건 아니지만 그 래도 기름기가 많이 잡혀서 머리가 그래도 조금이나마 뽀송 뽀송해용!',
#   'annotation': [['향',
#     ['다가 달달 상큼한 사과향을 쓰고 향도 은은하게 남으니까 너무 마음에 들어 ', 76, 117],
#     'positive'],
#    ['세정', ['가 많이 잡혀서 머리가 그래도 조금이', 213, 233], 'positive']]},
#  {'sentence_form': '이 거 요물, 거품도 진짜 많이 나 고 무엇보다 엄청 부드러워요 친규도 부드럽다고 극찬하고 간,',
#   'annotation': [['거품', [' 거품도 진짜 많이 나', 7, 19], 'positive'],
#    ['머릿결', ['청 부드러', 28, 33], 'positive']]},
#  {'sentence_form': '요새 이걸로 쭉 쓰고 있는데 거품도 풍성하고 자극적이지 않아 부담 없이 쓰기 좋아요. 두피가 민감한 편이라 얼마 쓰지도 못하고 버린 샴푸가 좀 되는데 이건 첨 사용할 깨부터 아 신경 써서 만든 샴푸구나 느꼈어요. 가격도 많이 비싸지 않고 패키징도 좋아서 선물하기도 좋고. 샴푸 후에도 머리가 푸석거리지 않고 많이 손상되지 않아 만족해요. 동생도 한 번 써보고 좋아하더라고 요',
#   'annotation': [['거품', [' 거품도 풍', 15, 21], 'positive'],
#    ['자극', [' 자극적이지 않', 24, 32], 'positive'],
#    ['가격', ['어요. 가격도 많이 비', 115, 127], 'positive'],
#    ['머릿결', ['푸 후에도 머리가 푸석거리지 않고 많이 손상되지', 153, 179], 'positive']]},
#  {'sentence_form': '향이 제가 좋아하는 향이라 너무 좋았습니다. 행 구고 난 뒤 향도 너무 좋네요✨',
#   'annotation': [['향', ['제가 좋아하는 향이라', 3, 14], 'positive'],
#    ['향', [' 향도 너무 좋네', 33, 42], 'positive']]},
#  {'sentence_form': '판매자에게 제품비의 일부를 지원받았지만 저의 솔직한 후기입니다.같은 제품으로 한 통 다 써보고 두 번째 사용하게 된 제품입니다.지성 두피용 샴푸인데도 지성 용 샴푸 특유의 머리 감고 난 후에 뻑뻑함이 없어서 좋았어요.트린트먼트를 안하거나 아주 조금 하는 편인데도 빳빳하지 않고 말리고 나면 차분하더라구요. 거품도 잘 나고 향기도 너무 좋아요. 사용하고 히터 틀고 하 루종일 일해도 머리가 답답하거나 떡지는 느낌이 확실히 덜해요. 머리카락에서 은은한 향기도 오래 지속되어서 만족하고 계속 사용 할 것 같아요~!',
#   'annotation': [['머릿결', ['에 뻑뻑함이 없어서 좋았', 105, 118], 'positive'],
#    ['거품', ['요. 거품도 ', 168, 175], 'positive'],
#    ['향', [' 나고 향기도 너무', 176, 186], 'positive'],
#    ['향', [' 머리카락에', 239, 245], 'positive']]},
#  {'sentence_form': '호불호 없이 누구라도 좋아할 향이 아닌가 싶어요 샴푸 살 때면 향을 제일 먼저 보는데 정말 역대급 향이네요 머릿결도 차분하게 유지되고 향 지속력도 좋아요 세정력이 좋은 샴푸로 샴푸 후에 두피가 정말 개운해요',
#   'annotation': [['향', [' 누구라도 좋아할 향이 아닌가 싶어', 6, 25], 'positive'],
#    ['향', ['말 역대급 향이', 49, 57], 'positive'],
#    ['머릿결', ['요 머릿결도 차분하게 유지', 58, 72], 'positive'],
#    ['향', ['고 향 지속력도 좋', 73, 83], 'positive'],
#    ['세정', ['요 세정력이 좋은 ', 84, 94], 'positive'],
#    ['세정', ['에 두피가 정말 개운', 102, 113], 'positive']]},
#  {'sentence_form': '콜라겐 샴푸라서 그런지 사용하고 나면 머릿결이 조금 차분해지는 것 같아서 만족해요.',
#   'annotation': [['머릿결', ['머릿결이 조금 차분해지는 것 같아서 만족해요', 21, 45], 'positive']]},
#  {'sentence_form': '향 지속력은 5시간 정도 ..?.. 하지만 향이 넘 좋아서 샤워할 때 이 샴푸로 머리 감으면 너무 핸복 그 잡채 ..❕향 때문에 산 거지만 탈모 예방 기능성도 있대요 물론 라보에이치는 원래도 샴푸가 유명하긴 하니까 요 ..✨같이 주는 트리트먼트는 사실 안 써봤답니다 호호',
#   'annotation': [['향', [' 향이 넘 좋아', 23, 31], 'positive']]},
#  {'sentence_form': '거품이 잘 나고 세정력이 좋아요 개운한 느낌 ♡ 근지러웠던 두피가 엄청 시원해져 요♡ 머리 결도 좋아진 느낌 ♡ 밤에 향기롭게 잠들 수 있어서 좋네요♡',
#   'annotation': [['거품', ['거품이 잘 나', 0, 7], 'positive'],
#    ['세정', [' 세정력이 좋아', 8, 16], 'positive'],
#    ['머릿결', ['져 요♡ 머리 결도 ', 43, 54], 'positive']]},
#  {'sentence_form': '드라이 샴푸 후기 천자로 써봤어: ⸻바쁜 아침이나 머리 감기 귀찮은 날, 드라이 샴푸는 정말 구세 주 같은 존재다. 나도 처음엔 “그게 정말 효과가 있을까?” 싶어서 반신반의했지만, 직접 써보고 나니 왜 사람들이 극찬하는지 알겠더라. 내가 사용한 제품은 스프레이형으로, 기름기 많은 두피에 뿌리면 기름을 흡수해서 머리가 방금 감은 듯한 느낌을 주는 제품이었다.처 음 사용할 땐 머리카락이 하 얘질까 봐 겁났지만, 적당한 거리에서 가볍게 뿌리고 몇 분 정도 흡수시킨 후 브러시로 빗어 내니 백탁도 거의 없고 볼륨도 살짝 살아났다. 특히 앞머리 부분이나 정수리 근처 기름진 부분에 효과가 좋았다. 냄새도 은은한 향수 느낌이라 기분까지 좋아졌다. 하지만 단점이 없진 않았다. 일단 깨끗하게 감은 머리처럼 완전한 상쾌함은 아니었고 , 손으로 만지면 약간 뻣뻣한 느낌이 남았다. 또 연속해서 2~3일 이상 드라이 샴푸만 쓰면 두피가 막힌 느낌이 들어 결국 제대로 감아줘야 했다. 그리고 흑발 기준으로는 하얗게 남을 수 있으니, 꼼꼼히 털어내는 게 중요하다. 그래도 운동 후나 급하게 외출할 때, 또는 머리 감기 귀찮은 날엔 확실히 유용하다. 단독으로 쓰기보다는 응급용이나 보조용으로 적절하게  활용하면 진짜 꿀템이라는 생각이 들었다. 이제는 파우치에 하나쯤 꼭 챙겨 다니는 필수템이 되어버',
#   'annotation': [['세정', ['정수리 근처 기름진 부분에 ', 308, 323], 'positive'],
#    ['향', ['과가 좋았다. 냄새도 은은한 향수 느낌이라 기분', 324, 350], 'positive'],
#    ['머릿결', ['로 만지면 약간 뻣뻣', 409, 420], 'negative']]},
#  {'sentence_form': '지성 두피인데 잘 씻기고 좋아요 거품도 잘 나 고 세정력이 정말 만족스러워요',
#   'annotation': [['세정', ['잘 씻기고 좋아요', 8, 17], 'positive'],
#    ['거품', ['거품도 잘 나 ', 18, 26], 'positive'],
#    ['세정', [' 세정력이 정말 만족스러워', 27, 41], 'positive']]},
#  {'sentence_form': '퍼퓸 샴푸 중에도 지속력이 좋은 편이에요! 트리트먼트 랑 같이 써서 그런지 몰라도 지속력도 좋은데 자극적이지 않아서 좋았어요. 타사 퍼퓸 샴푸는 쓰고 나면 꼭 이마에 트러블이 생기는데 밀크 바오밥은 성분이 순한 지 트러블이 없더라구요. 거품도 잘 나서 세정력도 우수해요 ㅎㅎ 남동생도 향이 맘에 드는지 써보더니 같이 써도 되냐고 물어보더라구요. 깨끗한 비누향이라 남자가 쓰기에도  무난하고 좋은 거 같아요. 추천합니다 ㅎㅎ',
#   'annotation': [['자극', [' 좋은데 자극적이지 않아서', 50, 64], 'positive'],
#    ['거품', ['이 없더라구요', 123, 130], 'positive'],
#    ['세정', [' 거품도 잘 나서', 131, 140], 'positive'],
#    ['향', ['되냐고 물어보더라구요. 깨끗한 비누향이라 남자가 쓰기에', 180, 210], 'positive']]},
#  {'sentence_form': '세정력이 너무 아쉬워요. 샴푸한 후에도 유분기가 남아 있는 느낌이에요',
#   'annotation': [['세정', ['세정력이 너무 아쉬워요', 0, 12], 'negative'],
#    ['세정', ['유분기가 남아 있는 느낌이에', 22, 37], 'negative']]},
#  {'sentence_form': '은은하고 편안한 향이라 계속 손이 가는 샴푸에요.세정력도 좋아요. 거품이 아주 풍성하게 잘 나요. 스트레스로 인해서 탈모 걱정되는데 여성 맞춤 탈모샴푸라하고 려에서 나온 거라 믿고 쓰고 있어요.',
#   'annotation': [['향', ['은은하고 편안한 향', 0, 10], 'positive'],
#    ['세정', ['세정력도 좋아요', 27, 35], 'positive'],
#    ['거품', [' 거품이 아주 풍성하게 잘 나', 36, 52], 'positive']]},
#  {'sentence_form': '세정력이 좋고 향이 오래 가서 자주 사용하고 있어요.재 구매 할께요',
#   'annotation': [['세정', ['세정력이 좋고', 0, 7], 'positive'],
#    ['향', ['향이 오래 가', 8, 15], 'positive']]},
#  {'sentence_form': '달리프 릴렉싱 샴푸탈 모샴푸라고 해서 탈모가 완전히 좋아지는 건 아닙니다 대신 기존 안 좋은 샴푸 보단(여기서 안 좋다는 건 향 위주나 머릿 결 위주의 샴푸를 말함) 예방 효과는 있어 여 무실리콘 첨가라 안전하고 보통 샴푸는 두피를 씻어주고 트리트먼트 같은 쪽은 머리카락이 죠 두피를 깨끗하게 씻어주니 불필요한 각질이나 먼지들이 제거가 되면서 까끗해져서 머리카락이 잘 올라올 수 있겠죠 하루에 거의 100개 씩은 빠진다고 하니 관리를 잘해죠야 빠진 부분이 듬 성해지지 않겠죠 ㅎㅎ 샴푸제형은 물 같은 제형이예요 좀 주르륵 흐르는 느낌?먼가 약산상폼 클렌징 같은 느낌이더라구 여 깨끗하게 씻어지는 느낌 !! 그래도 거품은 꽤 납니다 ㅎㅎ문지르는 느낌으론 안 나는 거 같지만 실제로 보면 ㅎㅎ 향기는 진짜 정확히 말은 못하겠는데 먼 가 나무 ? 공기 정화?여하튼 깨끗한 냄새나 요 ㅎㅎ',
#   'annotation': [['탈모', ['해서 탈모가 완전히 좋아지는 건', 18, 35], 'neutral'],
#    ['세정', ['예요 좀 주르륵 흐르', 283, 294], 'positive'],
#    ['거품', ['약산상폼 클렌징', 302, 310], 'positive'],
#    ['향', [' 실제로 보면 ', 375, 383], 'positive']]},
#  {'sentence_form': '거품도 잘 나고 지성 두피에 아주 찰떡입니다~!유분도 늦게 올라오는 거 같아요 추천~!',
#   'annotation': [['거품', ['거품도 잘 나', 0, 7], 'positive'],
#    ['세정', ['다~!유분도 늦게 올라오는 ', 23, 38], 'positive']]},
#  {'sentence_form': '헤어플러스 트리트먼트나 에센스 잘 썼어서 샴푸도 구매해봤는데 제형이 꾸덕해서 물을 많이 묻혀야 하고 그럼에도 불구하고 거품 나는 편은 아닌 거 같아요.. 대신 향이 약간 우디향?제 스타일이라 향이 마음에 들고 제 두피에는 기름기가 많지 않은 편이라 괜찮은 거 같아요! 하지만 재 구매 의사는 없을 거 같네요😖',
#   'annotation': [['거품', ['고 거품 나는 편은 아닌 ', 64, 78], 'negative'],
#    ['향', ['스타일이라 향이 ', 101, 110], 'positive']]},
#  {'sentence_form': '행사 덕에 저렴하게 구매해서 만족합니다 비듬에는 살짝 취약한 듯',
#   'annotation': [['가격', [' 저렴하게 구매해', 5, 14], 'positive'],
#    ['세정', [' 비듬에는 살짝 취약한', 21, 33], 'negative']]},
#  {'sentence_form': '너무 만족하고 오래된 브랜드 라 믿고 사용합니다 ~좋아요 거품 짱 많이 나요',
#   'annotation': [['거품', [' 거품 짱 많이 나', 31, 41], 'positive']]},
#  {'sentence_form': '라우쉬 샴푸 중에 젤 가벼운 느낌인 것 같아 요 다른 거랑 번갈아가며 쓰는데 산뜻하고 좋아요',
#   'annotation': [['세정', ['는데 산뜻하고 ', 40, 48], 'positive']]},
#  {'sentence_form': '향도 좋구요, 거품이 잘나요. 부드러운 거품이고 거품을 씻고 나면 헤어가 부드럽기도 하면서 빳 빳해요. 헤어가 건강해진 느낌이에요',
#   'annotation': [['향', ['향도 좋구요', 0, 6], 'positive'],
#    ['거품', ['거품이 잘나요', 8, 15], 'positive'],
#    ['머릿결', [' 부드럽기도 하면서 빳 빳', 40, 54], 'neutral']]},
#  {'sentence_form': '말모 말모 올리브영에서 판매하는 제품들은 거의 인증이 돼서 판매한다고 해도 과 언이 아닌 것 같아요~가성비도 좋고 작은 양으로도 두피 케어가 가능해서 넘 넘 좋아요 다음에도 재구매 의사 있어요!',
#   'annotation': [['가격', ['아요~가성비도', 53, 60], 'positive']]},
#  {'sentence_form': '두피에 자극적이지 않고 머릿결이 헹굴 때도 뻣뻣하지 않아요.',
#   'annotation': [['자극', ['두피에 자극적이지 않고', 0, 12], 'positive'],
#    ['머릿결', ['머릿결이 헹굴 때도 뻣뻣하지 않아', 13, 31], 'positive']]},
#  {'sentence_form': '탈모샴푸는 처음 써보는데 머리카락이 덜 빠지는 것 같아요! 그리고 무엇보다 머릿 결 시 부드러워지고 빗질도 쉬워져서 잘 샀템 중 하나입니다!',
#   'annotation': [['탈모', ['덜 빠지는 것 같아요', 20, 31], 'positive'],
#    ['머릿결', ['머릿 결 시 부드러워', 42, 53], 'positive']]},
#  {'sentence_form': '잦은 탈색과 염색으로 머릿 결과 두피가 많이 상해 있던 찰나, 두피 안티에이징과 모발 강화를 해준다는 샴푸가 있다고 해서 바로 구매했습니다!! 효과와 효능도 매우 궁금했지만 향이 제일 궁금했어요 ㅎㅎ 배송 후 바로 맡아봤는데 생각보다 !! 기대 이상으로 향이 너무 너무 좋더라구 오!!!!!머릿결에서 향수 뿌린 듯한 맑은 꽃향이 은은하게 나서 기분이 좋습니 당 또 두 피를 살짝 시원하게 해줘서 샴푸 후에 굉장히 시원해영! 꾸준히 사용하면 뿌리 볼륨과 모발 밀도가 개선되고 모발 빠짐이 적다고 하니 계속해서 요 걸루 사용해야겠어 용 ㅎㅎ 아주 만족스런 소비였습니다🫶',
#   'annotation': [['향', ['린 듯한 맑은 ', 172, 180], 'positive'],
#    ['세정', ['습니 당 또 두 피를', 197, 208], 'positive']]},
#  {'sentence_form': '머리 감기 귀찮을 때 쓰면 너무 좋아요 단지 향 때문에 무향으로 사야 할 것 같아요…. 하지만 떡진 머리에 짱 좋아요',
#   'annotation': [['향', ['향 때문에 무향으로 사야 할 것 같아', 25, 45], 'negative'],
#    ['세정', [' 떡진 머리에 짱 좋아', 52, 64], 'positive']]},
#  {'sentence_form': '이때까지 사용해봤던 딥 클렌징 샴푸는 정말 두피가 당기도록 건조해져서 두 번 사용하기 사용하기 망설여졌는데 사용 시 세정력도 대단히 좋고 거품도 몽글몽글 풍성하게 잘 나오고 샴푸 후에도 수분감이 넘쳐서 너무 만족스럽네요 거기다 향기도 딱 취향 저격이예요, 무엇보다 두피에 자극이 없이 순하다는 게 너무나 좋아요~사용 후 머릿결도 뻣뻣하지 않다는 점도 베리 나이스!',
#   'annotation': [['세정', ['사용 시 세정력도 대', 60, 71], 'positive'],
#    ['거품', ['히 좋고 거품도 몽글몽글 풍성하게', 72, 90], 'positive'],
#    ['향', ['요 거기다 향기도 딱 취', 121, 134], 'positive'],
#    ['자극', [', 무엇보다 두피에 자극이 없이 순하다는 게', 141, 165], 'positive'],
#    ['머릿결', ['아요~사용 후 머릿결도 뻣뻣하지 않다는 점', 171, 194], 'positive']]},
#  {'sentence_form': '지성 두피의 경우 정말 좋다. 기름기 제거도 잘 되고 시간이 흘렀을 때 기름이 머리에 덜 생긴다. 영양제만 잘 쓰면 좋은 샴푸이다.',
#   'annotation': [['세정', ['기름기 제거도 잘 되고', 17, 29], 'positive'],
#    ['세정', [' 기름이 머리에 덜 생긴', 39, 52], 'positive']]},
#  {'sentence_form': '남편이 지성 두피라 두피에 트러블이 잘 나는 편인데 확실히 지성 두피에 효과 있는 것 같아 요 오래 써본 건 아니라 꾸준히 써보면 더 확실히 알 수 있을 것 같아요~향도 좋고 거품도 잘 나는데 세정력도 좋아서 저와 남편 모두 잘 쓰고 있어요. 삼푸 후에 남편은 트리트먼트를 거의 안하는데 머리 뻣뻣해지지 않고 좋다고 하네요! 꾸준히 써보겠습니다~~"판매자에게 제품비의 일 부를 지원받았지만 저의 솔직한 후기입니다."',
#   'annotation': [['향', [' 같아요~', 87, 92], 'positive'],
#    ['거품', ['도 좋고 거품도', 93, 101], 'positive'],
#    ['세정', ['잘 나는데 세정', 102, 110], 'positive'],
#    ['머릿결', ['거의 안하는데 머리 뻣뻣해지', 153, 168], 'positive']]},
#  {'sentence_form': '일단 바 ㅇ ㅇ 도 블랑쉬랑 향이 똑같다고 해서 궁금해서 구매해봤습니다 냄새는 실제로 제가 그 브랜드의 향수를 갖고 있는데 ㅠ 향이 정말 똑같아서 깜짝 놀랐습니다 일단 좋은 점을 먼저 말해보자면 두피에 별다른 큰 자극들을 느끼지 못했습니다 그리고 냄새가 일단 좋아요 블랑 쉬향이라 깨끗한 고급진 비누 향 냄새가 머리 감는 동안 내내 납니다 거품도 꽤 풍성하고 부 드럽게 잘 올라오는 편인 것 같아 요 그리고 다소 아쉬운 점을 얘기해보자면 두피에 그렇게 큰 청량감과 쿨링이 느껴지진 않았어요 그래서 그런지 정수리 냄새를 잘 잡아주지는 못하는 것 같아 요 그리고 두 번째는 블랑 쉬향이라서 씻고 나와서도 블랑쉬 향이 있었으면 했는데 머리 말리면 향이 다 날아가서 아무 냄새도 나 지 않습니다 이걸 기대했는데 다소 많이 아쉬운 편인 것 같습니다',
#   'annotation': [['자극', ['큰 자극들을 느끼지 못했습', 117, 131], 'positive'],
#    ['향', ['끗한 고급진 비누 향 냄새가 머리 감는 동안 내내', 158, 185], 'positive'],
#    ['거품', ['납니다 거품도 꽤 풍성하고 ', 186, 201], 'positive'],
#    ['쿨링', [' 얘기해보자면 두피에 그렇게 큰 청량감과 쿨링이 ', 237, 264], 'negative'],
#    ['세정', [' 그래서 그런지 정수리 냄새를 잘 잡아주지는', 273, 297], 'negative'],
#    ['향', ['쉬 향이 있었으면 했는데 머리', 338, 354], 'neutral']]},
#  {'sentence_form': '파우디리 향 찐~하게 납니다 라보에이치 초록색 같이 개운하게 감기는 사용감은 아니에 요 라보에이치가 탈모샴푸라서 모발 빠짐이 덜 한 것 같아서 사용하는데 초록새 냄새가 정말 그냥 사쾌한 치약 냄새가 나는 게 별로 좋지 않아서 퍼퓸 샴푸를 샀는데 향이 약하지만 좋은 거 같아 요 나만 가끔씩 맡을 수 있는 은은 한 향이구요 진하지 않아서 두퉁 유발 없어요 이유는 모르겠지만 다른 데 찾아봐도 트리트먼트 랑 붙여서 파는 데는 올리브 영 밖에 없어서 올리브영에서 세일할 때 사 요 트리트먼트만 따로 안 팔아요......샴푸는 따로 팔지만 트리트먼트는 따로 안 팔아 요 트리트먼트가 샴푸보다 용량이 적어서 더 빨리 떨어지는데 따로 안 팔아요.....참고 하시고 페어앤프리지아 블랑쉬앤우디 둘 다 아주 은은하고 누구나 호불호 없이 사용할 만한 향기에 요 특히 진한 것 도 아니고 독한 것도 아니라서 그냥 은은 하기 때문에 딱히 싫을 이유가 없고 둘 다 일단 대중적인 향기가 납니다 감을 때는 향기가 잘 나는데 말리면 그냥 없어요 처음 사용 시 페어앤프리지아 냄새가 정말 안 좋았는데 쓰다 보니까 괜찮아져요 블랑쉬 앤 우디가 첫 사용부터 누구나 좋아할 만한 향입니다 파우더리한 향기고 페어앤 프리지아는 약간 중성적인 냄새요',
#   'annotation': [['세정', ['이 개운하게 감기는 사용감은 아니', 27, 45], 'negative'],
#    ['향', [' 샴푸를 샀는데 향이 약하지', 128, 143], 'positive'],
#    ['향', [' 블랑쉬앤우디 둘 다 아주 은', 373, 389], 'positive'],
#    ['향', [' 좋았는데 쓰다 보니까 괜', 539, 553], 'positive']]},
#  {'sentence_form': '향이 은은 해서 좋아요 거품도 풍성하고 무난하게 사용하기 좋아요',
#   'annotation': [['향', ['향이 은은 해서 좋', 0, 10], 'positive'],
#    ['거품', ['요 거품도 풍성', 11, 19], 'positive']]},
#  {'sentence_form': '재구매했어요!식 초 샴푸라 개운하고 정수리 냄새도 잘 잡아주고 기름도 늦게 올라와 요머릿결도 안 뻣뻣해져서 굿!비건이라 안 살 이유 없어요 ㅎㅎ',
#   'annotation': [['세정', ['수리 냄새도 잘 잡', 21, 31], 'positive']]},
#  {'sentence_form': '향도 좋고 세정력도 좋네 여 로레알 추천합니당',
#   'annotation': [['향', ['향도 좋고', 0, 5], 'positive'],
#    ['세정', ['세정력도 좋네 ', 6, 14], 'positive']]},
#  {'sentence_form': '👉 위낙 유명하다 보니 이게 그렇게 좋아?하고 한 번 사용했는데 두피 케어에 탁월한 효과가 있는 것 같아 그 후론 꾸준히 사용하고 있습니다. 클로란은 두피 모발에 따라 사용할 수 있도록 여러 종류가 있어요. 이번엔 종류별로 구매해봤어요. 저희 가족 모두가 클로란을 즐겨 사용 하고 있습니다 . 👉 거품이 풍성하지는 않지만 그렇다고 해서 세정력이 약한 건 아닙니다. 세 정력 좋고 두피에 자극적이지 않고 지성 두피에 맞는 라인입니다. 쿨링 효과로 두피에 열이 많은 남편에게 잘 맞더라구요~~ 👉 제형이 묽은 편이라 짤 때 흘러내리지 않게 주의해야 해요. 사용 후 머리결이 좀 뻣뻣해지는 감이 있어요. 린스나 트린트먼트를 해주면 좋아요.',
#   'annotation': [['거품', ['. 👉 거품이 풍성하지', 162, 174], 'negative'],
#    ['세정', ['다고 해서 세정력이 약한', 182, 195], 'positive'],
#    ['자극', ['세 정력 좋고 두피에 ', 204, 216], 'positive'],
#    ['머릿결', ['요. 사용 후 머리결이 좀 뻣뻣해지', 306, 325], 'negative']]},
#  {'sentence_form': '밤에 머리를 감는 스타일이라 나이트 버전 샴푸로 구매했는데, 만족스러워요! 우선 두피 세정이 잘 돼서 다음 날 아침에 떡 짐으로 인 한 고민이 없지만 그렇다고 두피에 자극이 가는 샴푸도 아니어서 순하게 두피를 잘 씻어주는 제품이예요! 머리도 한결 부드러워진 것 같아 맘에 들었고, 샴푸 향도 은은한 꽃향이 나서 머리 감으면서도 힐링된 것 같아 요 😆올영세일 맞춰서 사 서 2개에 이 정도 가격이면 가성비 최고라고 생각합니다!',
#   'annotation': [['세정', ['선 두피 세정이 잘 ', 43, 54], 'positive'],
#    ['자극', ['렇다고 두피에 자극이 가는 샴푸도 ', 85, 104], 'positive'],
#    ['자극', ['니어서 순하게 두피를 잘 ', 105, 119], 'positive'],
#    ['머릿결', ['이예요! 머리도 한결 부드러워진 것 같아 맘', 126, 150], 'positive'],
#    ['향', ['들었고, 샴푸 향도 은은한 꽃', 152, 168], 'positive'],
#    ['가격', ['정도 가격이면 가성비 최고', 214, 228], 'positive']]},
#  {'sentence_form': '회사원 A 완도 영상 보고 해당 제품에 관심이 생겼어요 :) 세트로 쓰면 더 효과가 좋을 거 같아서 트리트먼트 랑 같이 구매했어요. 생각보다 향이 강하진 않았는데 은은하게 괜찮은 거 같구 머릿결도 맘에드네요',
#   'annotation': [['향', ['는데 은은하게 괜찮은 ', 88, 100], 'positive'],
#    ['머릿결', [' 같구 머릿결도 맘', 101, 111], 'positive']]},
#  {'sentence_form': '장미향 가득하고 지루성 두피에듀 괜찮은 거 같아 요세정력도 좋아요',
#   'annotation': [['향', ['장미향 가득하고', 0, 8], 'positive'],
#    ['세정', ['아 요세정력도 ', 25, 33], 'positive']]},
#  {'sentence_form': '생각보다 두피가 시원하짇 않앗지만 향이 엄청 진하고 조아 요 머리 감고 난 후 맂스를 해조야 겟어요 ㅠㅠ',
#   'annotation': [['세정', ['두피가 시원하짇 않앗지만', 5, 18], 'negative'],
#    ['향', [' 향이 엄청 진하고 ', 18, 29], 'positive']]},
#  {'sentence_form': '향도 없고 제품력이 무난해서 계속 쓰고 있습니다. 탈모에도 도움 되는 느낌적인 느낌입니다.',
#   'annotation': [['향', ['향도 없고', 0, 5], 'neutral'],
#    ['탈모', ['탈모에도 도움 되는 느낌적인 느낌입니다', 28, 49], 'positive']]},
#  {'sentence_form': '시트러스 향기가 상쾌하고요. 여름에 쓰기 좋은 제품이 에 오.',
#   'annotation': [['향', ['시트러스 향기가 상쾌하고요', 0, 14], 'positive']]},
#  {'sentence_form': '향도 좋고 거품도 풍성합니다~~추천합니다~~|',
#   'annotation': [['향', ['향도 좋', 0, 4], 'positive'],
#    ['거품', [' 거품도 풍성합니', 5, 14], 'positive']]},
#  {'sentence_form': '두피 샴푸에 아주 추천합니 당🤟🤟🤟🤟이번에 올리브영 체험단으로 처음 사용해보았는데요 확실히 두피가 시원하고 상쾌한 것 같아요.. 피부가 워낙 민감 한 편인데도 자극 없이 사용하기 아주 좋아요!!!! 온 가족이 오랫동안 사용할 수 있는 양이라 더더욱 좋아요!!!!! 강추합니 당ㅎㅎㅎㅎㅎㅎ',
#   'annotation': [['세정', ['확실히 두피가 시원하고 상쾌한', 47, 63], 'positive'],
#    ['자극', [' 한 편인데도 자극 없이 사', 81, 96], 'positive'],
#    ['가격', ['!!!! 온 가족이 오랫동안 사용할 수 ', 106, 128], 'positive']]},
#  {'sentence_form': '운동도 하고 여름만 되면 땀이 많은 1인입니다 확실히 두피가 시원하고 사용 후 개운해요 유니폼이 짙은 색이라 비듬이 떨어지면 다 보이는데 각질 떨어지는 것도 거의 안 보이네요. 식초 샴푸라 걱정했는데 식초 냄새 안나요. 향기도 좋고 거품 풍성 해요',
#   'annotation': [['세정', [' 두피가 시원하', 29, 37], 'positive'],
#    ['향', ['. 향기도 ', 121, 127], 'positive'],
#    ['거품', ['고 거품 풍성 ', 128, 136], 'positive']]},
#  {'sentence_form': '거품이 풍성하게 잘 나고 이 거 사용하고 부터 머리 빠지는 양이 줄고 모발에 힘이 생겼어요. 향도 은은하게 나서 좋아요. 모발에 윤기도 나 고 만족스러워요.',
#   'annotation': [['거품', ['거품이 풍성하게 잘 나', 0, 12], 'positive'],
#    ['탈모', ['터 머리 빠지는 양이', 24, 35], 'positive'],
#    ['향', ['요. 향도 은', 49, 56], 'positive']]},
#  {'sentence_form': '처음에 쓰면 샴푸만으로 부드러워진다고 ?감탄하다고 익숙해지면서 감흥 떨어지다가 타샴푸 써보니 왜 좋은지 알겠어요 부드러워요',
#   'annotation': [['머릿결', ['겠어요 부', 59, 64], 'positive']]},
#  {'sentence_form': '피부도 두피도 많이 예민해서 샴푸 한 번 잘못 바꾸면 바로 두피도 뒤집어지고 각질 파티인데..닥터그루트 아쿠아 딥 클린 탈모 증상 완화 샴푸는 3종 히알루론산 스킨케어 성분 함유로 건조함 없이 딥 클렌징 가능하고 풍성하고 쫀쫀한 거품으로 여러 번 펌핑 없이 풍부한 거품으로 세정 가능합니다. 저 자극의 약산성 샴푸로 저처럼 예민하고 민감한 두피, 지성 두피, 탈모가 고민인 분 한테 정말  좋을 것 같아요!" 판매자에게 제품비의 일부를 지원받았지만 저의 솔직한 후기입니다.”',
#   'annotation': [['자극', ['거품으로 세정 가능합', 148, 159], 'positive']]},
#  {'sentence_form': '리뷰대충다는데 얘는 진짜 좋아서 정성 들여서 달고 있음 향이 넘좋음',
#   'annotation': [['향', [' 향이 넘좋', 30, 36], 'positive']]},
#  {'sentence_form': '여러 탈모샴푸 유목민하다가 정착한 유일한 샴푸에 요 거품도 잘 나고 머릿결도 부드럽고 확실히 머리카락 힘도 생겼어요',
#   'annotation': [['거품', ['요 거품도 잘', 27, 34], 'positive'],
#    ['머릿결', ['나고 머릿결도 부', 35, 44], 'positive']]},
#  {'sentence_form': '거품도 잘 나 고 뾰루지도 없고 향기도 좋아서 잘 쓰고 있어요!!',
#   'annotation': [['거품', ['거품도 잘 나 ', 0, 8], 'positive'],
#    ['향', ['고 향기도 좋', 16, 23], 'positive']]},
#  {'sentence_form': '늘 사용하던 거라서 구매했고 향도 좋고 기름기도 잘 잡아주고 급한 날에는 쓰기 편해요',
#   'annotation': [['향', ['고 향도 ', 14, 19], 'positive'],
#    ['세정', ['좋고 기름기도 잘 잡', 19, 30], 'positive']]},
#  {'sentence_form': '위드 비컨 투피 코렉팅 샴푸 잘 받았습니다. 탈모 증상 완화용으로 매우 좋은 것 같습니다. 향도 좋고 조금만 펌핑하여 사용하여도 거품이 충분히 납니다. 잘 사용해 보고 좋은 효과를 기대하겠습니다. 위드 비컨 두피 코렉팅 샴푸 탈모 증상 완화용으로 매우 좋을 것 같습니다.',
#   'annotation': [['향', ['향도 좋고', 51, 56], 'positive'],
#    ['거품', ['거품이 충분히 납니다', 72, 83], 'positive'],
#    ['탈모', [' 탈모 증상 완화용으로 매우 좋을 것 같습니', 125, 149], 'positive']]},
#  {'sentence_form': '너무 잘 쓰고 있어 요데일리 샴푸로 교체! 샴푸 바꾼 뒤로 비듬이 한 번도 안 생겼어요',
#   'annotation': [['세정', ['로 비듬이 한 번도 안 ', 31, 44], 'positive']]},
#  {'sentence_form': '아로마티카 샴푸 처음 쓰는데 넘 좋아요~ 향도 좋고 거품도 잘 나고 고급져요 또 사려구요!',
#   'annotation': [['거품', ['거품도 잘 나', 29, 36], 'positive']]},
#  {'sentence_form': '지성한테 좋다 해서 샀는데 뽀득 뽀득해서 헹궈 낼 때 너무 좋네용 ㅎㅎㅎ',
#   'annotation': [['세정', [' 뽀득 ', 14, 18], 'positive']]},
#  {'sentence_form': '와ㅎ ㅎ 친구가 추천해줘서 한 번 구ㅁㅐ 해봤어요!!! 머리를 안감아서 이 제품을 사는 게 아니라 여러 므로 참 유용하네요 ㅎㅎ 캠핑을 자주 다녀서 씻어도 머리가 금방 찝찝할 때가 있는데 그때 이 제품을 한 번 뿌려주면 . . . 너무 좋은 거에 요 ㅋㅋ ㅋ 물 없이 감는 샴푸 라니.. 왜 그런 말인지 알겠어요 ㅎ 괜히 전세계 판매 1위가 아니군요 기름진 머리를 깔끔 하게 만들어 줄 뿐만 아니라 기 분젛은 상쾌함까지 거기에 깨끗한 헤어스타일을 유지할 수 있도록 도와 줍니다 드라이 샴푸 너무 좋으네요 다음에는 더 큰 용량으로 ㄱㅜ 매할까 합니다ㅏㅎ ㅎ ㅎ',
#   'annotation': [['세정', ['위가 아니군요 기름진 ', 188, 200], 'positive'],
#    ['세정', ['줄 뿐만 아니라', 214, 222], 'positive']]},
#  {'sentence_form': '가격이 너무 사악하지만 세정력도 좋고 떡도 잘 안 져서 이거만 10통째 쓰는 듯..',
#   'annotation': [['가격', ['가격이 너무 사악하지만', 0, 12], 'negative'],
#    ['세정', ['세정력도 좋고 떡도 잘 안 ', 13, 28], 'positive']]},
#  {'sentence_form': '이 제품을 사용 한 지 한 달 정도 돼 가는 거 같은 데 딱히 단점이 눈에 보이지 않는 샴푸인 거 같아 요 일단 쓰면서 제가 올레 머리가 단발이라서 트리트먼트를 잘 하지 않은데 머리가 엄청 건조하다고 느껴지지 않았어요 보통 다른 제품들은 샴푸만 쓰고 나면 머리가 되게 건조한 걸 느껴 볼 수 있는데 이 제품은 어떻게 건조하지 않고 너무 그렇다고 촉촉한 느낌은 아 니에요! 두피 스케일링이 필요할 것 같아서 이 제품을 처음으로 사 봤는데 어 스켈링 이라기 보다는 그냥 새 정력이 좋은 샴푸?인 거 같아 요 아로마티카라는 브랜드가 환경에 되게 신경도 많이 쓰 물었는데 그의 비해서 가격이 그렇게 비싸지 않은 거 같아서 재구매할 것 같습니다 형은 정말 은은하게 허브 향 같은 게 나 구요 잔 향 같은 거는 남지 않습니다 새 일 자주 해줬으면  좋겠어요!! 고민 하시는 분들은 구매 하는 것 추천 드립니다',
#   'annotation': [['머릿결', ['은데 머리가 엄청 건조하다고 느껴지지 않', 96, 118], 'positive'],
#    ['세정', ['는 그냥 새 정력이', 256, 266], 'positive'],
#    ['가격', ['데 그의 비해서 가격이 그렇게 비싸', 314, 333], 'positive'],
#    ['향', ['습니다 형은 정말 은은하게 허브 ', 352, 370], 'positive']]},
#  {'sentence_form': '머리카락이 덜 빠지는 느낌입니다. 샴푸만 하면 빳 빳해서 트리트먼트도 같이 하니 볼륨감도 오래가고 좋더라구요',
#   'annotation': [['탈모', ['머리카락이 덜 빠지는 느낌입니다', 0, 17], 'positive'],
#    ['머릿결', [' 샴푸만 하면 빳 빳', 18, 29], 'negative']]},
#  {'sentence_form': '추천 보고 샀어요 꽃향기 좋고 세정력 좋은 것 같아요 써봐야 효과는 알 수 있을 것 같구요',
#   'annotation': [['향', [' 꽃향기 좋', 9, 15], 'positive'],
#    ['세정', [' 세정력 좋은 것 ', 16, 26], 'positive']]},
#  {'sentence_form': '아직 안 써봤지만 향은 너무 좋아요! 크기가 생각보다 작았지만 잘 쓸게요',
#   'annotation': [['향', [' 향은 너무 좋아', 9, 18], 'positive']]},
#  {'sentence_form': '최근에 탈 색이랑 염색 많이 해서 이 제품 계속 썼는데 탈색했을 때는 확실히 노란끼 많이 잡아주고 쓰다 보면 흰 끼도는 탈 색 모가 되더라구요 그리고 다른 색상 염색했을 때는 확실히 일반 샴푸보다 염색 물 빠짐이 적습니다 그래서 염색을 오래 유자하게 도와 줘요 근데 샴푸의 거품이 다른 샴푸보다는 적은 것 같아서 이점이 좀 아쉽습니다',
#   'annotation': [['거품',
#     [' 유자하게 도와 줘요 근데 샴푸의 거품이 다른 샴푸보', 134, 163],
#     'negative']]},
#  {'sentence_form': '🌱내 돈 내산 리뷰입니다!요즘 여름이라 그런지 지성이 아닌데도 불구하거 땀 때문인지 머리에 유분이 가득한 거 같아서 구매해 봄!향은 은은 한 향이 나는데 생각보다 오래 가서 맘에 듦!샴푸를 조금만 펌핑해도 거품이 풍성해서 긴 머리임에도 불구하고 샴푸를 좀 덜 써도 되서 매우 매우 좋음!특히 유분기가 많이 정리되서 특히 좋음 ! 별 다섯 개! 단점은 가격대가 좀 있는 편인 데 양이 적은 거 같아서 아쉬움 😢😢',
#   'annotation': [['향', ['해 봄!향은 은은 한 향이 나는데 생각보다 오래 가', 67, 95], 'positive'],
#    ['거품', [' 펌핑해도 거품', 109, 117], 'positive'],
#    ['세정', [' 좋음!특히 유분기가 ', 156, 168], 'positive'],
#    ['가격', ['! 별 다섯 개! 단점은 가', 182, 197], 'negative']]},
#  {'sentence_form': '뿌리는데 엄청 시원합니다. 시긴 하네요 다른 드라이 샴푸와 마찬가지로 하얀색 가루가 뿌려지고 열심히 비벼줘야 합니다. 생각보다 유분 제거가 잘 되었어요 향도 괜찮았구요',
#   'annotation': [['세정', ['시원합니다', 8, 13], 'positive'],
#    ['세정', [' 생각보다 유분 제거', 65, 76], 'positive'],
#    ['향', [' 잘 되었어요 ', 77, 85], 'positive']]},
#  {'sentence_form': '몇 번 써보지 않았지만 순하고 부드럽고 좋아요. 두피가 건조한 것 같아 선택했는데 꽤 좋은 듯 해요. 두 가지 타입을 구매했는데 지성 피부에 쓰는 것 하루 수분 타입 하루 이렇게 쓰고 있어요. 좋아요!',
#   'annotation': [['자극', [' 순하고 부드럽고 좋아', 12, 24], 'positive']]},
#  {'sentence_form': '이 거 넘 좋아요. 향도 은은하니 넘 좋고 … 강추합니다. 샴푸',
#   'annotation': [['향', [' 향도 은은하니 넘 좋', 10, 22], 'positive']]},
#  {'sentence_form': '거의 한 달 동안 사용하고 있는데 만족합니다. 거품은 부드럽고, 감고 나면 머릿결 부드러워 져서 좋습니다. 감고 나면 향은 오래가지 않은 편이지만 은은 한 꽃내음 같은 게 좋습니다. 세정력도 좋고 두피에 자극은 거의 없어서 만족합니다.',
#   'annotation': [['거품', [' 거품은 부드럽', 25, 33], 'positive'],
#    ['머릿결', ['면 머릿결 부드러워 져서 좋습', 40, 56], 'positive'],
#    ['향', ['면 향은 오래가지 않은 편이', 64, 79], 'neutral'],
#    ['향', ['만 은은 한 꽃내음 같은 게 ', 80, 96], 'positive'],
#    ['세정', ['니다. 세정력', 98, 105], 'positive'],
#    ['자극', [' 좋고 두피에 자극은 거의 없어서 만', 106, 126], 'positive']]},
#  {'sentence_form': '제형이 쫀쫀하면서도 묵 직해요 시카 성분이 있기 때문에 시카가 안 맞다면 유의하세요! 두피에 자극은 없지만 머릿결이 엄청 부드럽지도 않고 산뜻하고 가볍게 사용할 수 있어요! 세정력은 쏘 쏘두피가 건조하고 건성이면 가렵거나 안 맞을 수 있는데 지 성분들한테 추천해요~',
#   'annotation': [['자극', ['의하세요! 두피에 자', 42, 53], 'positive'],
#    ['머릿결', ['은 없지만 머릿결이 엄청 부드', 54, 70], 'negative'],
#    ['세정', [' 수 있어요!', 89, 96], 'neutral']]},
#  {'sentence_form': '달리프가 여성 브랜드인데 제가 쿨링 샴푸 쓰는데 남편이 너무 더워해서 달리프 쿨링 샴푸 한 번 써보라고 줬는데 남편이 아주 좋다고 난리입니다두피 열도 내려주고 대 만족 인 거 같아 요 거품이 풍성하게 잘 나고 무엇보다 내용물이 투명이라서 깨긋해 여저자극에 탈모 완화 제품이라서 더 좋은 거 같아요',
#   'annotation': [['쿨링', [' 난리입니다두피 열', 72, 82], 'positive'],
#    ['거품', [' 인 거 같아 요 거품', 93, 105], 'positive'],
#    ['자극', [' 투명', 126, 129], 'positive']]},
#  {'sentence_form': '(저는 드라이 샴푸는 처음 써봤다는 거 참고해 주세요) 처음 써보는 거니까 설명서는 당연히 읽어봤어요. 읽어 본 대로 사용했을 때 익숙치 않아서 만족스럽진 않았지만 여러 번 해보니 어떻게 해야 하는지 알 것 같았어요. 몇 번 사용 하니까 편해서 사길 잘 한 것 같다는 생각이 들었어요. 또 유분기 잡는 것도 잘 쓰면 굉장히 보송보송하게 잘 잡아줘요. 그리고 크기도 작아 서 여행 갈 때 하나 챙겨가 기 좋아요(약 12cm 정도). 근데 병에 향 이름이 안 적혀 있어서 향을 구분하기 어려웠는데 좀 불편했어요. 그리고 향은 사람마다 다르겠지만 저는 괜찮았어요. 향도 꽤 오래가는 편이에요. 그래서 저는 이 가격에 만족하는 것 같았어요.',
#   'annotation': [['세정', [' 쓰면 굉장', 173, 179], 'positive'],
#    ['향', ['만 저는 괜찮았어요. 향도', 301, 315], 'positive'],
#    ['가격', ['이에요. 그래서 저는 이', 324, 337], 'positive']]},
#  {'sentence_form': '너무 좋고 하나 더 살 생각이에요! 냄새는 취향이 아니지만... 가격과 용량이 혜자입니다!',
#   'annotation': [['향', ['냄새는 취향이 아니지만', 20, 32], 'negative'],
#    ['가격', ['가격과 용량이 혜자입니다', 36, 49], 'positive']]},
#  {'sentence_form': '두피가 간지럽고 비듬이나 각질로 샴푸를 찾아보던 중 두피에 히 알루론산으로 수분을 보충하고 유칼립투스로 두피를 진정시키고 비듬케어에 효과가 좋다는 후기를 보고 닥터 그루트 아쿠아 샴푸를 구매하였습니다 약산성에 계면활성제도 무첨가 라고 하니 믿고 사용할 수 있을 것 같아 요 또한 탈모 증상도 완화 된다고 하니 저희 부부에게 딱 필요한 샴푸인 것 같아 요 판매자에게 제품비 의 일부를 지원받았지만 저의 솔직한 후기 입니다',
#   'annotation': [['자극', ['니다 ', 109, 112], 'positive'],
#    ['탈모', [' 요 또한 탈모', 150, 158], 'positive']]},
#  {'sentence_form': '이 거 쓰니까 기름기도 줄었고 머리 간지러 움도 덜해요! 그래서 좋은데 벌써 다 써가지구 사야 해요',
#   'annotation': [['세정', ['기름기도 줄었고 머리 간지러 움도 덜', 8, 28], 'positive']]},
#  {'sentence_form': '쎄일 해서 저렴하게 샀어 요 용량이 작아진 듯 그래도 이 제품이 제일 시원하고 풍성해져요',
#   'annotation': [['가격', [' 저렴하게 샀어', 5, 13], 'positive'],
#    ['탈모', ['이 제일 시원하고 ', 34, 44], 'positive']]},
#  {'sentence_form': '감고 나면 시 워어어 어 언~~~~해요!!!! 향도 허브 같은 향이라 제 취향이고 거품도 풍성해서 오랜만에 제대로 된 지성 용 샴푸 만난 것 같아 요ㅠㅠ 그리고 패키지 넘 감성 넘치는 거 아닌가 여,, , 다 쓰고 통 재활용하고 싶을 정도 ㅎ',
#   'annotation': [['향', ['!!! 향도 허브', 22, 31], 'positive'],
#    ['거품', ['취향이고 거품도', 41, 49], 'positive']]},
#  {'sentence_form': '블라인드 테스트에서 팬틴 제품이 좋다고 해서 구매해봤어요 저렴해용',
#   'annotation': [['가격', ['어요 저', 29, 33], 'positive']]},
#  {'sentence_form': '앞머리 사이가 휑해지는 걸 발견하고자 탈모 방지 하고자 구매하게 되었어요 대용량에다가 향도 은은 해서 남녀 모두 호불호 없이 사용 가능해 요 탈모샴푸인데도 소량으로 거품이 많이 나와서 긴 생머리인데도 오래 사용할 거 같아 요 ㅎㅎ추천해요',
#   'annotation': [['향', ['다가 향도 은은 해서 남녀 모두 호불호 없이 사', 45, 71], 'positive'],
#    ['거품', [' 소량으로 거품이 ', 86, 96], 'positive']]},
#  {'sentence_form': '저는 너무 지성이라서 지성들이 사용하는 샴푸나 성분이 안 좋은 샴푸 사용하면 바로 비듬이나 각질이 너무 많이 생기더라구요. 그래서 샴푸 선택이 너무 중요한 편이라 신중히 하는 편인데 후기 글이 좋고 성분도 좋아서 구매해봤어요. 우선은 생각했던 것보다 진짜로 냄새가 너무너무 좋아서..반했어요 향기 대박이에 요 ㅋㅋㅋ 샴푸로 머리 감을 때마다 기 분 좋아요 ㅠ 거품도 잘나 고 투명제형인데 세정력도 좋고 기름지는 것도 없이 너무너무 잘 쓰고 있어요~~~',
#   'annotation': [['향', ['짜로 냄새가 너무너', 141, 151], 'positive'],
#    ['향', ['반했어요 향기 ', 158, 166], 'positive'],
#    ['거품', [' 분 좋아요 ', 192, 199], 'positive'],
#    ['세정', [' 고 투명제형인데 세정력도 좋', 207, 223], 'positive']]},
#  {'sentence_form': '애쉬 블루, 그레이로 솜브레 옴브레 하고 애쉬라 보색 샴푸 필요할 것 같아서 사고 바로 한 달 내내 꾸준히 사용하다가 휴가 때 못 챙겨 가서 2박 3일 내내 일반 샴푸 쓰니까 보색 샴푸 쓰고, 안 쓰고의 차이가 명확히 보임,, 바로 원래 물 빠졌던 색깔로 돌아 옴 ㅜ_ㅜ 오늘 염색하러 갔는데 쌤이 어디 거 쓰냐고 물어볼 정도로 색 유지는 잘 되는데 그레이가  물 빠져서 카키 빛 나가지고 그 부분 좀 열심히 했는데 카키가 다시 그레이로 돌아오지는 않더라구요, , 거기다가 샴푸가 골고루 듣는 게 아니라 어디는 제대로 들고 어디는 안 들고 해서 약간 얼룩 덜룩 해질 수는 있을 듯 그래서 그 다음에 탈색을 할 때 전체적으로 탈색을 한다고 해도 톤이 균일하게 나오지 않아서 토닝은 필수! 토닝하고 탈색 하는 것 같던데 그 러면 머리 진짜 개털될 수도,,?손에도 물들어서 원래 스카이 블루 색상의 젤 네일이 옸는데 물 들어서 좀 진해짐 결론은 애쉬 블루로 염색 하신 분들한테 강 추! 머리 감고 조금 부드러워지기는 하는데 그건 진짜 그냥 머리 감을 때 잠깐 일시적인 것 같아 요 엄청 드라마틱하게 부드러워지고 그런 게 아니라서 극손상모들은 따로 에센스나 트리트먼트는 필수입니당',
#   'annotation': [['머릿결',
#     ['깐 일시적인 것 같아 요 엄청 드라마틱하게 부드', 532, 558],
#     'neutral']]},
#  {'sentence_form': '머리 못 감은 날 볼륨도 줄 수 있으니까 진짜 괜찮은 것 같아요.머리 안 감은 거 티도 안나고 머리 냄새도 잘 잡아주는 것 같아요.',
#   'annotation': [['향', ['냄새도 잘 잡아주는', 56, 66], 'positive']]},
#  {'sentence_form': '염색했는데 너무 노란 끼 돌아서 구매했어요. 가격도 저렴하고 보색 효과도 좋아요!',
#   'annotation': [['가격', [' 가격도 저렴하', 24, 32], 'positive']]},
#  {'sentence_form': '다른 종류 쓰다가 이번에 이 거 구매했는데 나쁘지 않고 거품 많이 생겨서 좋아요',
#   'annotation': [['거품', ['지 않고 거품 많이 ', 26, 37], 'positive']]},
#  {'sentence_form': '바디워시랑 같은 향으로 구매했는데 거품도 풍성하고 두피 자극이 없어 좋은 거 같아요. 다 쓰면 또 같이 구매하려 구요. 강추',
#   'annotation': [['거품', ['거품도 풍성하고', 19, 27], 'positive'],
#    ['자극', ['두피 자극이 없어 좋은', 28, 40], 'positive']]},
#  {'sentence_form': '두피는 극지성에 모발은 극건 성인 완전 수부 지형이에요. 클로란 샴푸 그냥 지성 용 쓰다가 수부지 용 나왔대 서 바꿔봤는데 만족스러워요! 확실히 다른 샴푸로 감을 때 보다 덜 기름지고 감고 나서 상쾌해요.',
#   'annotation': [['세정',
#     [' 확실히 다른 샴푸로 감을 때 보다 덜 기름지고 감고 나서', 76, 108],
#     'positive']]},
#  {'sentence_form': '어릴 때부터 너무 특이하게 머리가 지성이 심했어요 ,, 다른 사람들은 귀찮으면 하루 정도는 머리 감기를 건너뛴다던데 그게 가능하나? 싶을 정도로 극 지성인 머리입니다ㅠㅠ 여름엔 반나절 만에도 떡지는 개노답 머리였어요 그래서 쿨링 샴푸, 지성 샴푸, 천연 샴푸, 샴푸 바 여러 개 사용해보고 있는데 드디어 클로란을 써보네요 처음 나왔을 때만 해도 할인보다는 증정만 껴주고, 가 격대가 꽤나 있는 편이라 펜트하우스 사는 사람들만 쓰는 건 줄 알았는데 성공한 인생이라고 해주십쇼 향..은.. 시트러스라고 해서 라임향, 모히 또 향 같은 걸 생각했는데 약간 ㅋㅋ남동생들 스킨 냄새나 요 아빠..까지는 아니고.. you ng man들의 skin care 냄새 같은.. 근데 향을 중시하는 스타일은 아니라 이건 큰 문제 없었어 요 세정력은 뭐.. 확실히 지성용 두피라 그런지 빨리 떡지거나 하지는 않아요! 샴푸 노답인 거 쓰면 두피에 뾰루지 올라오는데 그렇지도 않고요 그래도 제가 워낙 초극지성이라 매일 감아야 한다는 사실은 변하지 않습니다.. 인생 샴푸 다! 할 정도는 아닌 거 같구 요 다 써보고 또 유목 생활을 할 거 같긴 합니다.. 더 써봐야 알 거 같아 요 (〃⌒▽⌒〃)ゝ',
#   'annotation': [['가격', ['는 증정만 껴주고, 가 격', 197, 211], 'negative']]},
#  {'sentence_form': '가격이 비싸 만큼..향기도 좋고 상품도 좋네용 대박~~~입니다',
#   'annotation': [['가격', ['가격이 비싸', 0, 6], 'negative'],
#    ['향', ['향기도 좋', 11, 16], 'positive']]},
#  {'sentence_form': '만족 만족 대만족이 요ㅠㅠ 시중에 나오는 샴푸들 탈모방지의약품도 아닌데 그거 믿고 계속 쓰다가 요번에 로레알로 염색한 김에 써보고 반해서 그냥 와 장창 주문했어요 재구매 의사 있구요 이것만 쓸거에요 컬도 좋아지고 더군다나 색도 덜 빠지는 거 같구 ㅠ 중요한 건 풍성해 보여요',
#   'annotation': [['머릿결', ['것만 쓸거에요', 103, 110], 'positive']]},
#  {'sentence_form': '남동생이 쓰고 너무 만족해해서 뿌듯했습니다 자극 없고 머릿결도 뻑뻑하지 않고 거품도 딱이라고 세정력도 좋다고 했습니다 재구매의사 있다고 해서 그럼 말 다 했지 생각했어요 추천합니다 주변 지인에게도 좌표 보내줬습니다 머리숱 부자되는 그날까지 함께 해요 머리카락 하나도 너무 소듕하니까 요~~',
#   'annotation': [['자극', ['자극 없', 24, 28], 'positive'],
#    ['머릿결', [' 머릿결도 뻑뻑하지 ', 29, 40], 'neutral'],
#    ['거품', ['고 거품도 딱이', 41, 49], 'positive'],
#    ['세정', ['고 세정력도 좋', 50, 58], 'positive']]},
#  {'sentence_form': '쫀쫀한 제형이어서 많이 펌핑하지 않았는데도 거품이 잘 나서 좋아요. 다만 물로 씻어 헹구면 다시 머릿결이 뻣뻣해져요. 좀 더 써봐야 알 것 같아요.',
#   'annotation': [['거품', ['거품이 잘 나서 좋아요', 24, 36], 'positive'],
#    ['머릿결', [' 다시 머릿결이 뻣뻣해져', 50, 63], 'negative']]},
#  {'sentence_form': '샴푸하고 나면 파우더리한 머스크 향이 나요 *처음엔 향 때문에 썼는데 지금은 샴푸 기능이 좋아 사용합니다. 저는 샴푸를 잘못 쓰면 두피에 가려움을 느낍니다.이 샴푸는 그런 게 없어요~머리 말린 후 두피 쪽 헤어를 만져보면 노폐물이 깔끔하게 제거 된 느낌과 함께 부드러운 머릿결이 느껴져서 좋습니다.',
#   'annotation': [['세정', ['만져보면 노폐물이 깔끔', 119, 131], 'positive'],
#    ['머릿결', ['과 함께 부드러운', 141, 150], 'positive']]},
#  {'sentence_form': '📌 정착템이었지만 여름에는 추천 ❌✅ 장점 몇 년간 사용 중인.. 저는 향에 예민한 편이라 샴푸도 조심히 사용?하는데 이건 참 좋거 등 요 ㅎㅎ✅ 단점 지성 두피는 솔직히 비추합니다 여름 되니까 개기름이 대박.. 약간 개운하지 않았어 여.. 겨울에는 뽀송했지만 , , ㅠ🍯 꿀팁린스 말고!!! 진짜 린스는 말고.. 트리트먼트!!!!!랑 궁합 조음!!',
#   'annotation': [['향',
#     ['는 향에 예민한 편이라 샴푸도 조심히 사용?하는데 이건 참 좋거', 38, 73],
#     'positive'],
#    ['세정', ['박.. 약간 개운', 115, 124], 'negative']]},
#  {'sentence_form': '극지성이라 여름 후 두피에 대한 고민이 많아서 찾아보다 구매하게 됐어요 다른 샴푸로는 아침에 감으면 늦은 오후쯤엔 떡져서 스트레스 받았는데 이건 밤까지 보송보송 유지가 되어 너무 맘에 들어요 패키지도 예뻐서 너무 잘 쓸 거 같아요',
#   'annotation': [['세정', [' 보송보송 유지가 되', 84, 95], 'positive']]},
#  {'sentence_form': '또 구입했어요! 4인 가족이 함께 사용 하니까 금방 쓰게 되네요 ㅋㅋ 제 두피는 복합성인데 가장 마음에 든 점은 두피가 뽀송해지는 점이예 요 ! 오후만 되면 머리에 기름이 잘 지는 편인데.. 그렇다고 또 지성 두피는 아니거든요 ㅠㅠ이 제품을 사용하고 나서는 두피 기름이 확실히 줄어들었어요! 그리고 샴푸 거품도 풍성하게 잘 나 고 향도 시원한 향이라 개운해요 👏🏻👏🏻근데 샴 푸 향은 오래가지 않아 요~ 그리거 제 머리카락은 극 손상모예요.. 이 샴푸는 머릿결을 부드럽게 해줘서 좋아요. 손상 모인데 뻣뻣한 샴푸 사용하면 개털 되는 느낌 아시죠.. 이 샴푸는 그런 거 1도 없이 오히려 부드러워서 추천합니다!',
#   'annotation': [['세정', ['성인데 가장 마음에 든 점은 두피가 뽀송해지는 ', 47, 73], 'positive'],
#    ['세정', ['사용하고 나서는 두피 기름이 확', 135, 152], 'positive'],
#    ['거품', ['! 그리고 샴푸 거품도 ', 161, 174], 'positive'],
#    ['향', ['성하게 잘 나 고 향도 시원', 175, 190], 'positive'],
#    ['머릿결', ['극 손상모예요.. 이 샴푸는 머', 238, 255], 'positive']]},
#  {'sentence_form': '제품 좋은 거 알지만 할인할 때 구매하고 싶어서 이번에 또 구매했아요 ! 은은한 향과 점성력이 약한 데에 비해 풍성한 거품이라 늘 잘 사용합니다! 할인하면 너무 좋아요!',
#   'annotation': [['향', [' 은은한 ', 40, 45], 'positive'],
#    ['거품', [' 풍성한 거', 61, 67], 'positive']]},
#  {'sentence_form': '기름기는 잘 잡아주는 편인데 하얗게 되는 게 심해서 많이 털어줘야 해요 향도 머리 냄새는 잡아주지만 너무 진해서 누가 맡아도 뭐 뿌렸다 생각할 것 같아 요 엄청 좋은 향도 아니라 고 느꼈습니다 전체적으로 아쉬운 제품 ㅠ 휴대용으로는 좋을 것 같네요 다음엔 오리지널로 구매하려 구요',
#   'annotation': [['세정', ['기름기는 잘 잡아주는 편', 0, 13], 'positive'],
#    ['향', [' 향도 머리 냄새는 잡아주지만 너무 진', 39, 60], 'negative'],
#    ['향', ['요 엄청 좋은 향도 아니라 고 느꼈', 85, 104], 'negative']]},
#  {'sentence_form': '신상티켓팅 통해서 저는 샴푸로 받아서 사용해 봤습니다! 사실 샴푸는 보통 쓰는 것만 쓰다 보니까 트린트먼트로 왔으면 좋겠다 싶었는데 하필 샴푸가 와서 좀 아쉬웠거든요..? 아니 근데 이 거 왜 이렇게 좋나요...? 사용해보니 완전 대대 대 만족이라 깜짝 놀란 제품이에요 🥹👍🏻✔️ 일단 제가 가장 만족한 건 볼륨 효과와 향인데요! 제가 샴푸에서 가장 중요하게 생각하는 두가 지거든요. 그걸 충족시키는 샴푸가 거의 없는데 드디어 발견한 그런 기분이에요..🥹제가 완전 심한 파워직 모 생머리라 어떤 샴푸를 쓰면 너무 축 가라앉거나, 정전기가 너무 심하거나, 볼륨 효과가 있으면 향이 별로 고 그런 불만족스러운 제품이 많았거든요. 사실 볼륨 효과와 향 두 가지 전부 갖춘 제품은 찾지를 못해서 그냥 볼륨 효과 포기하고 향만 선택해서 엘라스틴 실크 리페어만 쓰고 있거든 용로레알 제품이라 아무래도 트린트먼트&헤어 오일 이미지가 강해서 이것도 엄청 머릿결 좋은~촤르르한 느낌의 샴푸겠구나 생각했는데 감을 때 부터 왜 볼륨 효과가 있는 건지 느껴지더라구요! 다른 제품은 물로 씻어낼 때 너무 부드러우면 저는 무조건 챡 달라붙는 경우가 많았는데, 이건 아주 살짝 (뻣뻣까진 아니고) 단단히 머릿결이 잡히는 그런 정도 ..!! 그게 딱 느껴지더라구요. 근데 또 너무 기름기 없애면서 뻣뻣한 느낌은 머리 빗을 때도 엉키고 그런 불편스러운 게 있거든요..? 근데 로레알은 말리고 빗을 때 부드러운데 볼륨 효과도 있어서 진짜 신기했어요 ㅠㅠ 라방 때 볼륨 효과가 있다고 하셔서 호기심+기대감이 있었는데 진짜라 너무 좋고 신기했어요,, \U0001fa77감고 말리고 나서 정수리 쪽 보면 뿅 하고 볼륨 효과가 느 껴진답니다..🫢🤍 근데 향은 또 대 박 좋았던.. 진짜 풍부한 플로럴 향인데 호불호 크게 없을 것 같은 플로럴 향이라고 느꼈어요! 제가 향 때문에 엘라스틴 실크 리페어 샴푸만 10년 넘게 쓰고 있는데, 그거만큼 만족스러워서 인생 샴푸 발견한 느낌입니다 🥹다 쓰면 무조건 구매해서 쓸 예정이에요!!!🫶🏻',
#   'annotation': [['세정',
#     ['정도 ..!! 그게 딱 느껴지더라구요. 근데 또 너무 기름기 없애면서 뻣뻣한 느낌은 ', 615, 662],
#     'positive'],
#    ['머릿결', [' 그런 불편스러운 게 있거', 674, 688], 'positive'],
#    ['향', [' 정수리 쪽 보면 뿅', 802, 813], 'positive'],
#    ['향', ['..🫢🤍 근데 향은 또 대 박 좋았던.. 진짜 풍부', 831, 859], 'positive']]},
#  {'sentence_form': '체험단으로 사용해 봤는데 일단 거품이 너무 잘 나서 좋았고요 자극 없이 두피 세정이 잘 돼서 좋았어요 솔직히 개인적으로 선호하는 향은 아니어서 살짝 아쉬웠지만 그래도 향 빼고는 다 너무 만족했어요 체험단 이벤트 진행해 주셔서 좋고 다음에 또 진행하면 좋겠어요~',
#   'annotation': [['거품', ['거품이 너무 잘 나', 17, 27], 'positive'],
#    ['자극', [' 자극 없', 33, 38], 'positive'],
#    ['세정', ['두피 세정이 잘 돼서 좋았어', 40, 55], 'positive'],
#    ['향', [' 개인적으로 선호하는 향은 아니어', 60, 78], 'neutral']]},
#  {'sentence_form': '향도 좋고 바쁜 아침, 늦은 오후에 편하게 잘 사용하고 있습니다',
#   'annotation': [['향', ['향도 좋고', 0, 5], 'positive']]},
#  {'sentence_form': '인생 샴푸! 벌써 몇 번째 재구입 인지도 모를 정도로 떨어지지 않게 쟁여두는 제품입니다.항상 333ml 용량만 쓰다가, 이번에 대용량이 나오고 또 세일까지 하길래 반가운 마음에 구입했어요. 참고로 사진은 평소에 쓰던 333ml와 이번에 구입한 750ml 사이즈 비교입니다. 생각보다 큰 사이즈에 조금 놀랐지만, 저같이 롱 헤어에 숱 많아서 금방 한 통 비우는 사람 은 이렇게 대용량이 좋네요 플라스틱 쓰레기도 줄고.. 이 샴푸는 적게 써도 거품이 풍성하게 나고, 혹시 잘 안 난다면 물을 조금만 더 하면 금새 뭉게 뭉게 피어오르는 거품을 볼 수 있을 거예요. 다른 샴푸들에 비해 뻣뻣해지지도 않으면서 세정력이 약하지도 않아서, 샴푸로서는 최고라고 생각합니다. 단지, 머리카락이 덜 빠지는 건 잘 모르겠어요.. 저한테는 인생 샴푸라 서 앞으로도 계속 구입할 예정이니 제 발 오래오래 판매해 주세요|',
#   'annotation': [['거품', ['적게 써도 거품이 풍', 240, 251], 'positive'],
#    ['머릿결', ['른 샴푸들에 비해 뻣', 314, 325], 'positive'],
#    ['세정', ['해지지도 않으면서 세정력', 326, 339], 'positive'],
#    ['탈모', ['각합니다. 단지, 머리카락이 덜 빠지', 363, 383], 'neutral']]},
#  {'sentence_form': '향이 좋아서 성분이 독할 거라고 생각했는데 예상 외로 순하고 깔끔하게 씻겨요',
#   'annotation': [['향', ['향이 좋아서', 0, 6], 'positive'],
#    ['자극', ['로 순', 28, 31], 'positive'],
#    ['세정', ['고 깔끔하게 씻', 32, 40], 'positive']]},
#  {'sentence_form': '수영으로 인한 푸석함 하루 두 번 아침, 저녁 샴푸를 하다 보니 머릿결이 많이 푸석해지고 빠지는 것 같아서 구매해 보았습니다올리브 영 온라인몰에서 구매해서 당일 받았고 사용해보니 이런 샴푸는 거품이 잘 나 지 않는데 잘 나고 냄새도 저한테는 잘 맞는 것 같아 요닥터 그루트 만족이에요',
#   'annotation': [['거품', ['사용해보니 이런 샴푸는 거품이 잘 나 지', 94, 116], 'positive'],
#    ['향', ['않는데 잘 나고 냄새도 저한테는', 117, 134], 'positive']]},
#  {'sentence_form': '요즘 두피 가려움도 심하고 머리카락 상태도 좋지 않아서 샴푸 바꿔봤는데 괜찮은 듯해요 자극도 없고 맥주 효모 덕분인지 두피도 깔끔하게 씻기네요 ㅎ 잘 써볼게요',
#   'annotation': [['자극', ['요 자극도 ', 46, 52], 'positive'],
#    ['세정', ['피도 깔끔하게 씻', 67, 76], 'positive']]},
#  {'sentence_form': '좀 상쾌한 샴푸 써보고 싶어서 사봤어요 !향도 민트 향 폴폴나 고 샴푸하고 방치해두면 두피 좀 시원해집니다 근데 그 정도가 엄청 심하진 않아요! 거품도 잘 나 고 두피에 자극도 없어서 잘 쓰고 있습니다! 근데 사용 후에 머리가 조금 뻣뻣해 지는 느낌이라 트리트먼트를 같이 써주고 있어요!',
#   'annotation': [['세정', ['두면 두피 좀 시원해', 45, 56], 'positive'],
#    ['거품', ['않아요! 거품도', 76, 84], 'positive'],
#    ['자극', ['잘 나 고 두피에 자', 85, 96], 'positive'],
#    ['머릿결', [' 사용 후에 머리가 조금 뻣뻣', 116, 132], 'negative']]},
#  {'sentence_form': '제품을 써보니 세정력이 좋아요 머리를 감으면서 좀 뻑뻑 한 느낌이 들기는 했는데 머리를 감고 나서는 뻣뻣한 느낌은 없더라구요. 근데 다만 아쉬운 건 거품은 풍성하게 나 진 않았어요 그래도 기름기가 쫘악 씻기는 느낌은 좋았고 향도 달콤하면서도 시원해서 괜찮더라구요. 그리고 머리를 다 말리고 나서는 간지러운 두피가 잠잠해져서 효과가 있구나 라고 생각이 들었어요.개 인적으로 만족스러운 제품이 네요',
#   'annotation': [['세정', ['정력이 좋아요 ', 9, 17], 'positive'],
#    ['머릿결', ['머리를 감고 나서는 뻣뻣한 느낌은 없더라구', 45, 68], 'neutral'],
#    ['거품', ['건 거품은 풍성하게 나 진 않', 81, 97], 'negative'],
#    ['세정', ['래도 기름기가 쫘악 씻기는 느낌은 ', 102, 121], 'positive'],
#    ['향', ['았고 향도 달콤하면서도 시원해서 괜찮더', 122, 143], 'positive'],
#    ['세정', ['서는 간지러운 두피가 잠잠해져서 효과가', 163, 184], 'positive']]},
#  {'sentence_form': '일단 향이 너무너무 제스탈입니다 향 지속력도 오래 가서 좋았어요 ㅎㅎㅎ그리고 거품도 잘 나고 두피에 트러블 없는 걸 보니 순한 거 같아요 그리고 양도 많고!!! 제 인생 샴푸가 되었습니다',
#   'annotation': [['향', ['향이 너무너무 제스탈입니다 향 지속력도 오래 가서 좋았어', 3, 34], 'positive'],
#    ['거품', ['고 거품도 잘', 41, 48], 'positive'],
#    ['자극', [' 보니 순한', 64, 70], 'positive']]},
#  {'sentence_form': '건성 두피인데 탈모 고민이라면 ! 모이세요! # 달리프 릴렉싱 샴푸 ✔️저는 지성 두피인데 사용해보니까 유분감이 많더라구 용 ㅠㅠ 그래서 이건 저희 가족들이 쓰세요! 지성 두피 보단 건성 두피 분들에게 추천 드립니다 ✔️ 제품 특징➡️ 두피에 좋은 천연 성분이 모발 탈락 증상 안화➡️ 특허 받은 한방 추출물로 풍성하고 볼륨 있는 모발로 만들어줍니다➡️ 두피 탄력+ 유수분 밸런스+ 딥 클렌징 + 두피 영양 진정 ☑️ 전체적인 후기 ✔️제형은 흐르는 물제형입니다!✔️향은 약간 시원한 오이 냄새?(호불호 주의) ✔️ 거품 양은 많고 세정력 좋습니다!✔️ 건성 두피에겐 촉촉하지만 지성 두피에겐 유분으로 떡 질 수도 있어요...😭➡️그래서 건성 두피 분들에게 추천 드립니다✔️ 확실히 두피 진정에는 효과는 있는 듯 해요!👎🏻 아쉬운 점 ➡️지성 두피에겐 유분감이 많음 ( 비추..) ➡️ 호불호 갈릴 수 있는 향 (오이 냄새) 🙆🏻\u200d♀️ 이런 분들에게 추천 드려 요✔️ 순한 샴푸 찾으시는 분 ✔️ 중 건성 두피 이 신 분들 ✔️ 순한 탈모샴푸 찾으시는 분',
#   'annotation': [['머릿결', ['안화➡️ 특허 받은 한방 추출물로 풍', 155, 175], 'positive'],
#    ['향', ['☑️ 전체적인 후기 ✔️제형은 흐르는 물', 231, 253], 'neutral'],
#    ['거품', ['입니다!✔️향은', 255, 263], 'positive'],
#    ['세정', ['약간 시원한 오', 264, 272], 'positive'],
#    ['자극', ['질 수도 있어요...😭➡️그래서', 339, 356], 'positive'],
#    ['자극', ['감이 많음', 423, 428], 'positive']]},
#  {'sentence_form': '자신의 두피별로 맞춰 구매하는 샴푸가 있길래 제가 원하는 타입으로 구매했습니다. 저자극으로 각질 케어 용인데 일단 거품도 괜찮고 사용감도 무난했던 제품. 약간 네 가지 타입 중 비컨피던트가 제일 무난한 것 같아요. 잘 맞았고 나중에 린 언미도 한 번 써보고 싶네요. 샴푸용으로 무난하게 맘에 든 제품입니다.',
#   'annotation': [['자극', ['저자극', 45, 48], 'positive'],
#    ['거품', [' 거품도 괜찮', 63, 70], 'neutral']]},
#  {'sentence_form': '탈모샴푸인데 거품도 많이 나고 좋은 것 같아 요뻣빳하지 않아요',
#   'annotation': [['거품', ['거품도 많이 나', 7, 15], 'positive'],
#    ['머릿결', ['아 요뻣빳하지', 23, 30], 'positive']]},
#  {'sentence_form': '잘 사용하고 있어요. 성분도 좋고 샴푸 후에 모발이 부드러워요.',
#   'annotation': [['머릿결', ['모발이 부드러워요', 25, 34], 'positive']]},
#  {'sentence_form': '살짝 되 직함 향 괜찮고 거품 잘 남가성비 좋은 샴푸머리 기름 잘 지는 편이면 추천 안 함',
#   'annotation': [['거품', ['고 거품 잘', 12, 18], 'positive'],
#    ['가격', [' 남가성비 좋은 ', 18, 27], 'positive'],
#    ['세정', ['리 기름 잘 지는 편이면 추천 안', 30, 48], 'neutral']]},
#  {'sentence_form': '한 번 구매하고 선 계속 구매하게 되는 제품이네요. 세척력이 좋고 두피에 자극적이지도 않습니다. 무엇보다 제일 마음에 드는 건 향이 너무 좋아요.',
#   'annotation': [['세정', ['. 세척력이 ', 27, 34], 'positive'],
#    ['자극', ['고 두피에 자극적이지도 않습', 35, 50], 'positive'],
#    ['향', [' 건 향이 너무 ', 68, 77], 'positive']]},
#  {'sentence_form': '우선 민감 지성 두피라서 샴푸를 고를 때 민감한 데 이거 전에는 이니스프리 그린티 민트 샴푸와 아로마티카 로즈마리, 티트리를 썼었어요.이니스프리 샴푸는 성분이 안 좋았고 아로마티카 제품은 성분은 좋은데 쓰다가 보니까 자꾸 석 유 냄새가 나는 듯 해서 결국 이것저것 찾아보다가 세일하는 김에 사용해 보게 되었다가 완잔 반했어요 우선 향은 시원한 민트향이 고 오래 사용해도 석유 냄 새 같은 건 안 나 요머리를 삼일 정도 안 감았다가 감아봐도 한 방에 개운해지고 무엇보다 정수리 냄새가 안 나서 아주 만족한답니다. 클로란 시 트러스와 클로란 피오니와 클로란 석류도 써 봤는데 클로란 민트가 가장 좋아요 샴푸 성분 중에서 멘톨이 들어 있어서 사용 후에 두피에 화한 감이 나는데 아주 심하지는 않고 딱 적당하게 화해서 좋더라구 요 색상은 파란색 그대로 투명하구요 일반 샴푸보다 조금 되직해서 펌프형 용기에 옮겼을 때는 잘 안 나오기도 하더라구요 그래서 이 제품은 기존 용기 그대로 쓰는 게 좋아요 향기는 밤까지 지속되기는 하는데 쿤달보다는 정수리 냄새가 빨리 나는 편이에요 아침에 쓰면, 지성 두피 고 땀이 많이 난다면 밤에는 꿉꿉한 향으로 변하는 편이라서 케바케에 요아 예 정수리 냄새가 산경 쓰일 때는 전 이 거랑 같이 이 브로쉐 모링가 헤어 식초를 같이 써요 그러면 완벽하게 향기로 마무리되고 아주 좋아요.지 성 두피에게 강 추합니다.',
#   'annotation': [['향', ['반했어요 우선', 177, 184], 'positive'],
#    ['세정', ['안 감았다', 234, 239], 'positive']]},
#  {'sentence_form': '헤어 토닉 사용하고 샘플로 받은 샴푸가 맘에 들어서 본품까지 구매하게 됌지 성두피인데 시원하고 뽀득하게 씻김',
#   'annotation': [['세정', ['인데 시원하고 뽀득하게', 45, 57], 'positive']]},
#  {'sentence_form': '제 최애 샴푸에요. 기름기도 잘 잡아주고 무엇보다 정수리 냄새에 좋은 것 같아요. 오후 시 간 되도 그렇게 떡 지지 않고 불쾌한 냄새 안 나서 넘 맘에 들어요',
#   'annotation': [['세정', ['기름기도 잘 잡아주고', 11, 22], 'positive']]},
#  {'sentence_form': '팬틴 거품도 잘 나고 향도 좋아서 재구매했음 ㅎㅎ',
#   'annotation': [['거품', ['거품도 잘 나', 3, 10], 'positive'],
#    ['향', [' 향도 좋아', 11, 17], 'positive']]},
#  {'sentence_form': '쓰면 머릿결이 정갈해져서 좋아요 향도 좋고 가성비 좋은 거 추천 드려요',
#   'annotation': [['머릿결', ['머릿결이 정갈해져서 좋아요', 3, 17], 'positive'],
#    ['향', ['향도 좋고', 18, 23], 'positive'],
#    ['가격', ['가성비 좋은 ', 24, 31], 'positive']]},
#  {'sentence_form': '2년 전에 꾸준히 1년 정도 사용하다가 이번에 재구매하게 되았어요. 돌고 돌아 라우쉬내요. 몇 달 전부터 두피 트러블이 올라오고, 지루성 피부염까지 올라와서 다시 돌아오게 되었어요. 사용해보시면 아시겠지만 두피에 편안한 성분으로 구성된 약 같은 샴푸에요. 뭔가 두피가 개선이 되면서 치료가 되는 느낌이랄까요. 그래서인지 지루성 두피염도 좋아지고 있고, 가려움도  많이 줄었어요. 그리고 성분이 좋은 샴푸들이 대게 거품이 잘 안 나는데요. 이 제품은 라우쉬 라인 중에서도 거품이 잘 나는 편이에요. 그래서 답답하지 않게 세정이 잘 됩니다. 거기에 더해서 뻣뻣하게 세정이 되지 않아서 좋아요. 라우쉬 라인 중에서 두피가 편안하고, 거품이 잘 나는 제품을 찾으신다면 이 콜츠푸드 샴푸를 선택하시면 됩니다. 추천해요.',
#   'annotation': [['자극', ['뭔가 두피가 개선이 되면서 치료가 되는', 143, 164], 'positive'],
#    ['거품', ['중에서도 거품이 잘 나', 258, 270], 'positive'],
#    ['세정', ['하지 않게 세정이', 284, 293], 'positive'],
#    ['머릿결', ['에 더해서 뻣뻣하게 세정이 되지 않', 303, 322], 'positive'],
#    ['자극', ['인 중에서 두피', 335, 343], 'positive'],
#    ['거품', ['편안하고, 거품', 345, 353], 'positive']]},
#  {'sentence_form': '요즘같이 여름에 금방 머리도 떡지고 하는데 간편하게 사용할 수 있는 드라이 샴푸가 있다고 해서 구매해봤어요!! 우선 휴대하기 편해서 외출해서도 잠깐 화장실 가서 톡톡 두들겨주면 기름기를 빠르게 잡아줘서 좋았고 파우더 형식이라 머리카락에 하얗게 남을 줄 알았는데 두들기고 살짝 손으로 털어주면 하얀 끼가 금방 사라져서 좋았습니다~ !!지 성 두피한테는 있으면 굉장히 좋을 만한 제품이에요 :)',
#   'annotation': [['세정', ['겨주면 기름기를 빠르게 잡아줘서', 95, 112], 'positive']]},
#  {'sentence_form': '👨\u200d🔬닥터그루트는 과학입니다👩\u200d🔬 2탄 트리트먼트 트리트먼트는 다 똑같다?아닙니다. 닥터 그루트가 만들면 다릅니다. 올 영 체험단을 통해 닥터 그루트를 처음 만났습니다. 삼푸를 받아서 써봤는데, 한두 번 써보고 그럭저럭 괜찮다고 느꼈고, 일주일 정도 써보니 꽤 좋다고 생각했고, 한 달쯤 쓰니까 가족들이 먼저 머릿결이 좋아지고 머리 숱이 늘어난 걸 알아봤습니다. 그래 서 다 쓰자마자 샴푸와 트리트먼트를 모두 구입했습니다. 윤기가 도는 흰색 크림 제형입니다. 밀도 케어 샴푸처럼 민트향이 납니다. 물을 묻힌 뒤 두피부터 모발까지 문지릅니다. 두피를 제외하고 모발에만 사용하는 트리트먼트도 있는데 이 제품은 두피와 모발에 모두 사용해도 됩니다.두피부터 모발까지 마사지 하듯 문지르면 하얀 크림이 투명하게 바뀝니다. 충분히 마사지한  뒤 물로 쓱쓱 씻어내면 뽀득 뽀득하게 닦입니다. 아무리 닦아내도 미끌거리는 트리트먼트만 써봤는데... 이제라도 이런 제품을 알게 되어 다행입니다.가볍고 개운한 사용감을 가진 트리트먼트를 찾는다면 바로 이 제품을 써보시길 추천합니다.',
#   'annotation': [['머릿결', ['까 가족들이 먼저', 163, 172], 'positive'],
#    ['탈모', ['고 머리 숱이 늘어난 걸 알아봤', 181, 198], 'positive']]},
#  {'sentence_form': '샴푸가 저렴하고 거품이 잘 나서 좋아요 향기로워 요~! 추천합니다',
#   'annotation': [['가격', ['샴푸가 저렴하고', 0, 8], 'positive'],
#    ['거품', ['거품이 잘 나서 좋아', 9, 20], 'positive'],
#    ['향', [' 향기로워', 21, 26], 'positive']]},
#  {'sentence_form': '두피가 지성이라 겨울인데도 저녁만 되면 앞머리가 심하게 갈라져서 구매해봤습니다!!가지고 다니면서 오후에 뿌리려고 작은 사이즈로 구매했는데 한 번 쓰고 방치해 뒀어요...향이 너무너무 별로 가 효과가 좋아도 역해서 기분이 안 좋아지더라구 요 ㅜㅜ향이 또 금방 사라지 지 않고 감을 때까지 지속돼서 더 큰일... 약간 울렁거리는 향에 예민하신 분은 고민해보시는 게 좋을 듯해요!!',
#   'annotation': [['향', ['.향이 너무너무 별', 93, 103], 'negative'],
#    ['향', ['. 약간 울렁', 171, 178], 'negative']]},
#  {'sentence_form': 'ㅠㅠ 다른 드라이 샴푸에 비해 그렇게 효과가 좋지는 않아 여쪼꼬만 놈 휴대하기 편해 보이길래 샀어여..향도 좋고 분사도 잘 됨',
#   'annotation': [['향', [' 샀어여.', 51, 56], 'positive']]},
#  {'sentence_form': '향이 너무 좋아요 그리고 적은 양을 사용해도 거품이 풍성해서 너무나 좋습니다 두피가 예민 한 편인데 예민한 거 치고는 전혀 자극적이지 않아서 너무 사용하기 좋은 것 같아요 오후가 되면 기름이 많이지는데 이걸로 사용하고 나서는 기름 짐도 덜하고 세정력이 아주 좋은 것 같습니다. 너무 만족도가 높아서 후기까지 쓰게 되네요 ㅋ',
#   'annotation': [['향', ['향이 너무 좋아요', 0, 9], 'positive'],
#    ['거품', [' 거품이 풍성해서 너무나 좋습니', 24, 41], 'positive'],
#    ['자극', [' 전혀 자극적이지 않아서 너무 사용하기 좋', 65, 88], 'positive'],
#    ['세정', ['용하고 나서는 기름 짐도 덜하고 세정력이 아', 118, 142], 'positive']]},
#  {'sentence_form': '시원한 허브향ᆢ 제형이 좀 묽지만 머리에 천연 성분이라 자극이 없을 것 같아 중학생 아들과 같이 사용해 요~~',
#   'annotation': [['향', ['시원한 허브', 0, 6], 'positive'],
#    ['자극', ['만 머리에 천연 성분이', 17, 29], 'positive']]},
#  {'sentence_form': '아직 하루밖에 안 써봤지만 거품이 풍성하고 세정력이 좋아요! 비듬 개선에도 효과 있으면 좋겠우요~',
#   'annotation': [['거품', [' 거품이 풍성하', 14, 22], 'positive'],
#    ['세정', [' 세정력이 좋', 23, 30], 'positive']]},
#  {'sentence_form': '출시하자마자 지금까지 몇 통째 구매했는지 모를 정도로 매일 너무 잘 쓰고 있어 용! 어떤 샴푸로 감든 (심지어 두피 전용 샴푸로 감아도) 머리가 항상 가려웠는데 이 샴푸를 쓰고 나서는 가려움증은 물론 뾰루지까지 나 았어요 좀 비싼 감이 있지만 진짜 두피에는 너무 좋은 샴푸에 요 이 거 쓰고 휑했던 가르마가 채워졌어요 두피 볼륨도 잘 생기고..정수리 냄새도 커버 가능합니다 그리고  아무리 두 번 세 번 감아도 머릿결이 엄청 부드러워요!저는 이 샴푸 쓸 땐 트리트먼트를 따로 안 한답니다 그렇다고 유분이 많은 샴푸는 절대 아니에요!!',
#   'annotation': [['세정', ['쓰고 나서는 가려움증은 물론 뾰루지', 96, 115], 'positive'],
#    ['가격', [' 나 았어요 좀', 117, 125], 'negative'],
#    ['머릿결', ['  아무리 두 번 세 번', 212, 225], 'positive']]},
#  {'sentence_form': '나이 들면 기름이 준다는데 왜 늘어나는 거죠 저는..?ㅠ 아침에 머리 감아도 점심이면 슬슬 떡져서 넘 스트레스 받다가 검색 끝에 샀습니다! 양 대비 비싸서 고민했는데 한 번 쓰고 바로 두통 더 쟁였어요.. 이 제 이 거 없음 안 돼ㅠ',
#   'annotation': [['가격', ['니다! 양 대비', 74, 82], 'negative']]},
#  {'sentence_form': '거품이 잘 나서 뽀득 뽀득 잘 씻깁니다. 저렴하고 편해서 아주 좋아요',
#   'annotation': [['거품', ['거품이 잘 나서', 0, 8], 'positive'],
#    ['세정', ['뽀득 뽀득 잘 씻깁니', 9, 20], 'positive'],
#    ['가격', [' 저렴하', 22, 26], 'positive']]},
#  {'sentence_form': '이 거 샴푸 정말 좋네요. 부모님도 쓰시라고 재구매예요. 제가 정말 많은 샴푸들 써봤는데 정말 손에 꼽히는 마음에 드는 샴푸예요. 두피 트러블이 나서 너무 유분이 있어도 안 되고 건조해도 안 되고 예민하거든요. 닥터방기원 랩 샴푸는 제 두피에 딱 맞는 제품이예요. 두피에 자극 없고 씻고 나면 상쾌해요. 이런 제품들이 오래 쓸 수 있는 좋은 제품인 것 같아요.  주변에 소문 내고 다니고 있어요 ㅋㅋ',
#   'annotation': [['자극', ['예요. 두피에 자', 144, 153], 'positive'],
#    ['세정', [' 나면 ', 160, 164], 'positive']]},
#  {'sentence_form': '이번에 탈색하먼 서 알아보다가 구매하게 됐는데 원래 헤어 플러스꺼 에센스를 쓰고 있어서 구매했어요 !! 올리브영 애서도 후기가 제일 많더라구 요 ㅋ 기대했는 ㄷㅔ 역시나 좋더라구 요 !! 보색 샴푸인데 향도 엄청 좋아요 !!! 확실히 컬러가 덜 빠지는 느낌이 들어요! 그리고 감고 나서도 부드러운 느낌이 구영! 탈색 모애는 무조건 보색 샴푸 써야 한다고 하는데 해 어플러스가 가 성비도 좋고 헤어 제품으로 유명하니깐 사용할 이유는 충분한 거 같아요! 그리고 제품 나오는 입구도 스티커로 막아져 있어서 위생적으로 보였어요 향도 좋구 가성비도 젛구 탈색모애게 추천하는 샴푸입니다 ~~~~',
#   'annotation': [['향', ['색 샴푸인데 향도', 106, 115], 'positive'],
#    ['가격', [' 하는데 해 ', 197, 204], 'positive'],
#    ['향', ['져 있어서', 274, 279], 'positive'],
#    ['가격', ['위생적으로 보', 280, 287], 'positive']]},
#  {'sentence_form': '매일 매일 감는 머리에 가성비 좋고 품질도 괜찮은 미장센 추천드려요! ✔️ 향 : 목욕탕 어디선가 맡아본 누군가의 삼푸향! 그냥 나중에 머리 말리고 자고 일어나도 기 분 좋은 잔 향이 남아 있어요! ✔️ 샴푸와 트리트먼트 세트로 같이 쓰고 있어요! 손상보다 극손상이 더 좋은 것 같아서 이것만 계속 쓰고 있어요! 샴푸는 그냥 하루 동안 더러워진 머리를 행구는 용으로 만 생각하고 있어서 아주 아주 만족하구요 ! 가슴까지 오는 긴 머리에 6-7번 펌핑하면 아주 풍부한 거품이 납니다!✔️클리닉을 한 머리에 탈모샴푸 쓰면 클리닉이 빨리 없어진다고 미용사님이 그러셔서 그날 이후로 탈모샴푸는 안 쓰고 있어요! 솔직히 트리트먼트는 어노* 가 더 좋은 것 같은데 올리브영에 있는 샴푸 중엔 이게 제일 무난하고 가성비 좋아요! 세 명이 서 쓰는 데 꽤나 오래 써져요! 다만 발에 떨어트리면 아파 욯ㅎㅎ',
#   'annotation': [['가격', ['가성비 좋고', 13, 19], 'positive'],
#    ['향', [' 기 분 좋은', 90, 97], 'positive'],
#    ['거품', ['7번 펌핑하면 아주 ', 246, 257], 'positive'],
#    ['가격', [' 중엔 이게 ', 377, 384], 'positive']]},
#  {'sentence_form': '요즘 산 후 탈모로 머리 한 번만 감아도 머리카락이 엄청 빠지고 게다가 힘이 없어서 축 처짐이 너무 고민이였는데.여성 전용 탈모샴푸가 출시되었다고 해서 바로 사용을 해보았어요 ㅎ 자극 없이 거품이 참 풍성해서 세정력도 좋았으며 은은한 향도 좋고 트리트먼트를 사용하지 않아도 머리 결도 부드럽네요 ㅎ 뿌리의 볼륨도 살아나고 머리카락이 덜 빠지는 게 확실히 보여서 만족스럽네요ㅎ',
#   'annotation': [['자극', ['을 해보', 90, 94], 'positive'],
#    ['거품', ['어요 ㅎ 자극 없이', 95, 105], 'positive'],
#    ['세정', ['거품이 참 풍성해', 106, 115], 'positive'],
#    ['향', ['서 세정력도 좋았', 115, 124], 'positive'],
#    ['머릿결', ['먼트를 사용하지 않', 140, 150], 'positive'],
#    ['탈모', [' ㅎ 뿌리의 볼륨도 살아나고 머리카락이 덜 빠지', 164, 190], 'positive']]},
#  {'sentence_form': '두피가 시원해지는 느낌 때문에 열감이 쌓였을 때 진정해주기 좋고 무엇보다 거품이 정말 잘 납니다',
#   'annotation': [['쿨링', ['두피가 시원해지는 느낌 때문에 열감이 쌓였을', 0, 24], 'positive'],
#    ['거품', [' 거품이 정말 잘 납니', 40, 52], 'positive']]},
#  {'sentence_form': '😉라보~에이~치 두피쿨링~~ 헤어 샴푸 ~😄👍 요즘 제가 애용하는 헤어 제품입니다~그 이유는~: 1. 헤어를 샴핑하면 뽀득함이 느껴지고 산뜻하고 진짜 말 그대로 두피쿨~링~이 됩니다~😊👍2.저는 헤어 제품에서 샴푸는 거품양을 중요시합니다~ 거품양이 적으면 자꾸 제품 양을 더 사용해서 금방 없어지기 때문입니다~ 이 제품은 조금만 사용해도 거품이 엄청 납니다~ 굿굿 ~!!~😄😊🥰 단점은 요~:1. 성분이 그다지 착하지 않아 요🤣😢 너무 아쉬운 부분입니다~ 성분 많이 보는 편인데..나중에 알았어요~개선되어야 할 부분이라 생각됩니다~😐😀2. 머리카락이 좀 많이 빠지는 느낌, ?입니다~저 말고 우리 언니도 한 번 쓰더니 머리카락이 많이 빠지는 것 같다고 하더라고 오ㅡㅜ 😂😢',
#   'annotation': [['쿨링', [' 두피쿨~링~이 됩니', 89, 100], 'positive'],
#    ['거품', ['이 제품은 조금만 사용해도 거품이 ', 174, 193], 'positive'],
#    ['탈모', ['다~저 말고 우리 언니도 한 번 쓰더', 324, 344], 'negative']]},
#  {'sentence_form': '쿨한 느낌이 있어요 자극별로 없고 엄청 민감한데 삼퓨 조금만 안 맞는 거 쓰면 비듬 생기는데 전혀 안 생기고 찐 저랑 찰떡같이 잘 맞아서 계속해서 쓸 거 같네요!',
#   'annotation': [['자극', ['자극별로 없', 11, 17], 'positive']]},
#  {'sentence_form': '티트리 샴푸 바가 좋아 로즈마리도 골라봤다. 환경 친화적인 제품을 쓴다는 자부심으로 선택한 샴푸바는 만족스럽다. 샴푸 바에 익숙해져 사용하기 전혀 불편한 게 없고 청소년기 아이들도 잘 사용한다. 강추하는 제품이다. 매장에 소량이 있어 진열이 눈에 띄지 않을 수 있으니 관심 있는 분들은 유심히 클렌징 공간을 찾아보길 바란다. 향이 강하지 않고 기능도 적당하다 . 헤어 클렌징에 액상 샴푸와 비교할 때 전혀 문제 없다.',
#   'annotation': [['향', ['. 향이 강하지 ', 180, 189], 'positive']]},
#  {'sentence_form': '항상 쓰던 제품이라 또 구매하여 사용 중입니다. 향도 맘에 들고 좋아요~',
#   'annotation': [['향', [' 향도 맘에 들고 좋', 26, 37], 'positive']]},
#  {'sentence_form': '거품 풍성하고 세정력 좋아요 두피 시원해 요향은 프레쉬 해요',
#   'annotation': [['거품', ['거품 풍성하고', 0, 7], 'positive'],
#    ['세정', ['세정력 좋아요 두피 시원해', 8, 22], 'positive'],
#    ['향', [' 요향은 프레쉬', 22, 30], 'positive']]},
#  {'sentence_form': '미용실 가면 선생님이 놀랄 정도로 두피에 상처 + 진물이 많고, 상처 때문에 특정 부위만 머리카락이 빠지는 부분 탈모로 두피에 주사도 여러 번 맞은 적 있는 여성탈모인입니다ㅠㅠ 여성 맞춤 탈모 전문 샴푸라는 것에 관심을 가지고 상세 설명 읽다가 두피 붉은기, 두피 가려움, 가 늘고 힘 없는 모발 등 등 저에게 해당되는 것이 너무 많아서 홀린 듯이 구매했습니다.일단 좋은 점 은 여타 탈모샴푸와는 다른 게 사용 후 뻣뻣함이 덜하다는 것! 귀찮아서 트린트먼트 안 하면 하루 종일 뻣뻣한 탈모샴푸 사용하다가 이 샴푸 사용 하니까 이런 신세계가 있나!! 탈모샴푸인데도 사용 후 머릿결이 좋습니다. 그런데도 순하고 세정력도 좋아요.순함 + 세정력 좋음 + 사용 후 뻣뻣하지 않음 ... 이게 한 번에 가능했다니! 이 제품 받고 나서 생각보다 작아서 재 구매해야 할지 고민했는데 저는 무조건 재구매할 겁니다.',
#   'annotation': [['머릿결', ['와는 다른 게 사용 ', 219, 230], 'positive'],
#    ['머릿결', ['!! 탈모샴푸인데', 304, 313], 'positive'],
#    ['자극', [' 머릿', 319, 322], 'positive'],
#    ['세정', ['이 좋습니다. ', 323, 331], 'positive']]},
#  {'sentence_form': '상품도 저렴하게 사고 배송도 빠르게 왔는데 다만 포장에 좀 더 신경 써 주시면 좋을 것 같아 요 2개사 서 하나 다 쓰고 펌프만 교환하면 되지만 하나만 샀으면 교환 신청하느라 더 걸렸을 뻔했어요 무게가 있어서 충전재를 양쪽에 넣어주면 좋을 텐데 한쪽만 있어서 완전 깨져서 왓어요',
#   'annotation': [['가격', ['상품도 저렴하게 사고', 0, 11], 'positive']]},
#  {'sentence_form': '향도 시원하고 산뜻하고, 여름에 머리 떡지는데 쓰니까 별로 기름기도 안 생기고 좋아요!',
#   'annotation': [['향', ['향도 시원하고 산뜻하고', 0, 12], 'positive'],
#    ['세정', ['기름기도 안 생기', 33, 42], 'positive']]},
#  {'sentence_form': '탈모샴푸인데도 뻑뻑하지 않고 거품 빵빵하게 잘 나서 너무 좋은 거 같아요~탈모 샴푸의 편견을 깨준 제품 향도 좋고 이거 쓰고 나서 원형 탈모 있던 부분도 많이 작아져서 만족하고 쓰고 있습니 당 아직까진 머리 숱이 적은 편이라 쭉 써주려고 해요',
#   'annotation': [['머릿결', ['뻑뻑하지 않', 8, 14], 'positive'],
#    ['거품', [' 거품 빵빵하게 잘 나', 15, 27], 'positive'],
#    ['향', ['준 제품 ', 53, 58], 'positive'],
#    ['탈모', ['고 나서 원형 탈모 있던 부분', 68, 84], 'positive']]},
#  {'sentence_form': '제꺼 사면서 남편 꺼 샀는데 개운한데 부드럽다고 좋아하네요! 그리고 향이 저는 이게 더 쿨해서 좋아요',
#   'annotation': [['세정', [' 개운한데 부드럽다고 좋아하네', 15, 31], 'positive'],
# ...
#  {'sentence_form': '다른 제품보다 확실히 이 제품으로 씻으면 냄새가 덜 하고 좋아요.',
#   'annotation': [['세정', ['씻으면 냄새가 덜 하고 좋아요', 19, 35], 'positive']]},
#  {'sentence_form': '목욕탕에서 쓰고 있어서 거품 사진을 못 올리겠네요. 하지만 로 레알 헤어 제품은 믿고 쓰는 라인 아니겠습니까~ 향도 거품도 다 만족스럽 구요 두피 자극은 제가 어떤 샴푸를 써도 아무 반응 없는 두피라 잘 모르겠네요 ㅠㅠ 세정력 괜찮습니다 가격이 더 괜찮구요 아주 착한 아이네요',
#   'annotation': [['향', ['까~', 59, 61], 'positive'],
#    ['거품', ['향도 거', 62, 66], 'positive'],
#    ['세정', [' 구요 두피 자극은 제가 어떤 샴푸를 써도 아무 반응 없는 두피라 잘 ', 75, 114], 'neutral'],
#    ['세정', ['요 ㅠㅠ 세정력 ', 118, 127], 'positive'],
#    ['가격', ['찮습니다 가격이 더', 128, 138], 'positive']]},
#  {'sentence_form': '몇 번 안 써봐서 아직 머릿결이 좋아졌다 이런 건 모르겠지만 사용 후 머릿결이 뻣뻣하지 않고 부드러운 게 괜찮은 제품인 것 같아요. 향도 좋구 꾸준히 써보려고 요~!',
#   'annotation': [['머릿결', ['용 후 머릿결이 뻣뻣하지 않고 부드러운 ', 35, 57], 'positive'],
#    ['향', [' 같아요.', 68, 73], 'positive']]},
#  {'sentence_form': '머리카락 끝이 갈라지고 뚝뚝 끊기는 손상모라서 이것저것 케어 제품 사용해야 하는데 트리트먼트 필요 없이 한 가지로 케어가 가능해서 좋아요. 빗질도 잘 되고 부드러워 졌어요. 은은한 향에 쫀쫀하고 풍성한 거품이라 머리 감을 때도 기분 좋아요.',
#   'annotation': [['머릿결', ['되고 부드러워 ', 84, 92], 'positive'],
#    ['향', ['요. 은은한 향에 쫀', 94, 105], 'positive'],
#    ['거품', ['하고 풍성한', 106, 112], 'positive']]},
#  {'sentence_form': '고농축의 꿀제형이라 조금만 펌프해도 거품이 풍성하게 일어나서 머리감을 때 너무 개운하네요.샴푸만 써도 머리결이 부드러워요.단백질 2배 강화 샴푸라 그런가봐요.세척력도 좋고 무엇보다 기 분 좋은 플로럴 향이 나서 머리를 말리고 나서도 은은하게 풍깁니다. 머릿결이 찰랑찰랑 하고 윤기가 맴 돌아요.요즘 머리에 뭐했냐는 질문을 많이 듣네요.',
#   'annotation': [['거품', ['거품이 풍성하게 일어나서', 20, 33], 'positive'],
#    ['세정', ['머리감을 때 너무 개운하', 34, 47], 'positive'],
#    ['머릿결', ['도 머리결이 부드러', 55, 65], 'positive'],
#    ['향', ['엇보다 기 분 좋은 플로', 97, 110], 'positive']]},
#  {'sentence_form': '두피가 개운하고 상쾌해요. 그냥 맡아도 향도 좋고 두피에서도 좋은 향이 나네요.',
#   'annotation': [['세정', ['두피가 개운하고 상쾌해요', 0, 13], 'positive'],
#    ['향', ['도 향도 좋', 20, 26], 'positive']]},
#  {'sentence_form': '일단 전 극지성에 탈모 위협까지 있어서 라우쉬 라인을 전부 다 써보기로 마음 먹었구요 샴푸 자체가 굉장히 순하면서도 진짜 기름기를 쫙 빼주니까 담백하고 이 다음에 두피 토닉도 라우쉬로 마무리 해 주니까 진짜 진짜 좋음! 여러분 모두 강 추템입니다일단 쓰기 전에 전 기획으로 사서 두피 스칼프 팩도 미리미리 해줬구요 그런데 단점이 하나 있다면 머릿결이 다소~~  뻣뻣해진 다 그래서 트리트먼트가 필수 다! 거품이 아주 잘 나는 건 아니에요 그래서 조금 덜어서 물 듬뿍 묻혀서 애벌빨래 하듯이 머리도 애벌샴푸 들어간 다음에 쓰는 게 제일 좋아요! 기획 상품 나오면 앞으로도 쭉 그냥 쓸 것 같아 요 이유는 너무 좋아서 ㅠ 솔직히 이것보다 좋은 거 찾기 힘들 것 같아 요 참고로 전 다ㅂㄴㅅ나 케라ㅅㅌㅈ 다 써봄... 5 샴푸도 여 러 번 바꿔줘야 하는 거 아시죠 다들',
#   'annotation': [['자극', [' 순하면서도', 58, 64], 'positive'],
#    ['세정', [' 기름기를 쫙 빼주니', 67, 78], 'positive'],
#    ['머릿결', ['다면 머릿결이 다소~~  뻣', 188, 203], 'negative'],
#    ['거품', [' 필수 다! 거품이 아주 잘 나는', 219, 237], 'neutral']]},
#  {'sentence_form': '매직셋팅으로 머리가 다 타서 이것저것 사보다 가 구입했어요. 향은 사과 향 같은 늘 맡던 로 레알 특유의 트리트먼트 향이에요. 생각보다 묽지 않아서 샘플 용기가 튜브였으면 좋았을 거 같습니다. 짜기 힘들더라구요. 아침에 트리트먼트 제대로 할 시간이 없어 급하게 이 거 쓰고 샴푸하고 또 이 거 썼는데 부드럽고 괜찮은 거 같아요. 다시 제대로 다시 사용해보고 진짜 개선 됐는지 한 달 후기 남기겠습니다.',
#   'annotation': [['향', [' 향은 사과', 33, 39], 'positive'],
#    ['머릿결', ['거 썼는데 부드럽고 괜찮', 162, 175], 'positive']]},
#  {'sentence_form': '이 샴푸 계속 쓰고 있는데 샴푸는 웬만해서 거기서 거기라고 생각했는데 그래비티는 확실히 달라요 하고 나서 볼륨도 다르고 두피도 시원한 게 두피 트러블도 잘 안나요 앞머리 고데 기 하면 저녁까지 볼륨이 살아 있어요 샴푸 쓰기 전 후 사진 올려봐 용 ㅎㅎ',
#   'annotation': [['자극', ['피 트러블도 잘 안', 78, 88], 'positive']]},
#  {'sentence_form': '예전에 헤어 제품 키트로 샘플 받아보고 마음에 들어서 본품으로 구매해 보았습니다 안 그래도 유명한 제품이더라구요 :) 가격은 할인 쿠폰 이것저것 다 사용해서 10500원 정도에 구매를 했습니다! 향 : 호불호가 갈릴 만한 향이에요 세정력 : 엄청 깨끗하게 씻겨졌단 느낌은 들지 않지만 자극적인 것 같지도 않고 가렵다거나 그러진 않았어요 거품도 풍성해서 한 번  짠 걸로 충분히 해결이 돼 요 근데 샴푸만 했을 땐 머리가 좀 뻣뻣해지는 느낌을 받아서 트리트먼트는 꼭 꼭 해주는 편입니다! 정전기가 잘 일어날 것 같아 요 무난무난한 비건 샴푸라 만족합니다 ㅎㅎ',
#   'annotation': [['향', ['향 : 호불호가 갈릴 만한 향', 109, 125], 'neutral'],
#    ['세정', [' : 엄청 깨끗하게 씻겨졌단 느낌은 들지 ', 132, 155], 'negative'],
#    ['자극', ['만 자극적인 것 같지도 않고 가렵다거나 그러진 않았', 157, 185], 'positive'],
#    ['거품', ['요 거품도 풍성', 186, 194], 'positive'],
#    ['머릿결', ['했을 땐 머리가 좀 뻣뻣해지는 느낌', 226, 245], 'negative']]},
#  {'sentence_form': '향은 크게 없지만 지성 두피에 최강이에 요 주기적으로 구입해서 사용합니다',
#   'annotation': [['향', ['향은 크게 없지만', 0, 9], 'neutral'],
#    ['세정', ['지성 두피에 최강이에 ', 10, 22], 'positive']]},
#  {'sentence_form': '솔직히 향은 진짜 제 스타일 아닌데,, 심지어 감고 나서도 향이 오래 유지되요,, , 트리트먼트를 해도 샴푸 냄새가 잘 나고요, ,, 그런데 머리는 진짜 좀 안 빠지는 것 같아서 샀어요. 라 보에이ㅊ 샴푸 썼는데 다른 것도 사 볼까 해서 산거고 번갈아가며 쓸려고요.',
#   'annotation': [['향', ['향은 진짜 제 스타일 아닌데', 4, 19], 'negative']]},
#  {'sentence_form': '다른 샴푸보다 기름이 덜 올라와서 좋아요! 대신 얼굴에 닿으면 화한 느낌이 들어서 예민한 분은 피하시는 게 좋을 것 같아 요지성 샴푸로 추천합니당',
#   'annotation': [['세정', ['기름이 덜 올라와서 좋아요', 8, 22], 'positive'],
#    ['자극', [' 얼굴에 닿으면 화한 느낌이 들어', 26, 44], 'negative']]},
#  {'sentence_form': '내 인생 샴푸향이 너무너무 제 취향이라서... 계속 쓰게 되네요 진한 향이라 오래 지속되고 넘 넘 좋아 요세일하면 만원도 안 해서 세일 때 쟁이고 있어요',
#   'annotation': [['향', ['푸향이 너무너무 제 취향이', 6, 20], 'positive']]},
#  {'sentence_form': '전 재 구매는 안하려 구요 ㅠ 거품은 잘 나고 향도 괜찮은데 샴푸 후에 넘 바스락 거리고 날려요',
#   'annotation': [['거품', ['요 ㅠ 거품은', 13, 20], 'positive'],
#    ['향', ['잘 나고 향도', 21, 28], 'positive'],
#    ['머릿결', [' 후에 넘 바스락 거', 36, 47], 'negative']]},
#  {'sentence_form': '수 년째 쓰고 있는 비누입니다 굿이 요 순하고 좋아요 굿이 요굿',
#   'annotation': [['자극', [' 요 순하고 ', 19, 26], 'positive']]},
#  {'sentence_form': '믿고 쓰는 방기원 샴푸입니다 ㅎㅎ 오랫동안 쓰고 있는데 두피 자극도 없고 부드러워서 항상 만족이에요 ㅎㅎ',
#   'annotation': [['자극', ['쓰고 있는데 ', 24, 31], 'positive'],
#    ['머릿결', ['두피 자극도 없고 ', 31, 41], 'positive']]},
#  {'sentence_form': '건성보다는 지성에 잘 맞고 지성들은 한 번 쓰면 꼭 이것만 쓰대요.',
#   'annotation': [['세정', ['지성들은 한 번 쓰면 꼭 이것만 쓰대요', 15, 36], 'positive']]},
#  {'sentence_form': '거품도 풍성해서 단발인 저는 한 번 펌핑으로도 충분히 사용할 수 있고 머리 결이 부드러워지는 건 두 말하면 잔소리.. 진짜 머리카락 자르지 마시고 이 샴푸 쓰세요. 강추합니다.',
#   'annotation': [['거품', ['거품도 풍성해서', 0, 8], 'positive'],
#    ['머릿결', ['머리 결이 부드러워지', 39, 50], 'positive']]},
#  {'sentence_form': '맨 처음 로레알을 알게 된 게 어느덧 6년차 헬스장에서 지인이게 추천 받은 샴푸였는데 곱슬에 매번 부시 시한 머리결이 컴플렉스라 항상 1년에 장마철엔 꼭 매직을 하던 저로 레알 샴푸를 알게 되고 곱슬기가 확실히 차분해지면서 갈라짐도 적 고 컨디션에 따라 두세가지 샴푸를 쓰는 데로 레알 향기만큼 참 저녁에 포근한 향기 덕분에 머리 결고 좋고 ~ 대용량 생겼으면 좋겠어요',
#   'annotation': [['향', ['향기만큼 참', 160, 166], 'positive'],
#    ['머릿결', [' 포근한 향기', 170, 177], 'positive']]},
#  {'sentence_form': '액체 샴푸만 20년 이상 써오다가 처음으로 산 고체형 비누샴푸 바 입니다 환경에 대한 문제를 인식하고 기존에 사용하던 샴푸는 큰 플라스틱 통이 재활용 되는 지도 잘 모르겠고, 거품도 너무 심하게 나더라구요 이번에 동구밭 제품을 환경을 생각하면서 구입했어요 종이박스에 간단하게 포장되어 있어서 너무 좋았어요코코넛 펄 프로 만든 비누망에 넣어서 사용 하니 일반 샴푸만큼 거품이  잘 났어 요중 건성용으로 구매했는데 적당히 보송하면서 부드럽게 샴푸를 할 수 있었어 욯ㅎ 비누로 머리를 감으면 뻣뻣할 거라고 생각했는데 그냥 일반 샴푸를 썼을 때랑 비슷해요 생각보다 머리가 더 부드럽고 보송하게 샴푸 잘 되었어요 향도 자극적이지 않고 너무 좋아요 바디워시로 써도 될 만큼 좋은 향이 나요 재구매 벌써 3번 넘게 했네요 다 쓰면 다음에 또 사려 구용 ㅎㅎ',
#   'annotation': [['거품', ['니 일반 샴푸만', 195, 203], 'positive'],
#    ['향', ['부드럽고 보송하게 샴푸 잘 되었어', 318, 336], 'positive'],
#    ['머릿결', ['푸를 썼을 때랑 비슷해요 생각보다 머리가 더 ', 293, 318], 'positive']]},
#  {'sentence_form': '일단 향기가 참 좋네요. 호불호 없을 향이고 거품도 장난 아니예요. 아침에 씻을 때마다 기분이 좋네요~~',
#   'annotation': [['거품', ['거품도 장난 아니예요', 25, 36], 'positive'],
#    ['향', ['호불호 없을 향', 14, 22], 'positive']]},
#  {'sentence_form': '탈모 증상이 완화되기로 유명한 닥터 그루트 제품이라 샀는데, 다른 것 보다도 향이 너무 좋고 머릿결도 부드럽게 유지시켜 주는 것 같아서 매우 만족해요. 특히 남자친구가 머리 감고 나온 날의 저를 너무 좋아해요.',
#   'annotation': [['향', ['도 향이 너무 ', 41, 49], 'positive'],
#    ['머릿결', ['고 머릿결도 부드럽게 ', 50, 62], 'positive']]},
#  {'sentence_form': '거품 잘 나 고 향 괜찮고 무난한 샴푸에요. 무엇보다 가성비가 좋아요',
#   'annotation': [['거품', ['거품 잘 나 ', 0, 7], 'positive'],
#    ['향', [' 향 괜찮', 8, 13], 'positive'],
#    ['가격', [' 가성비가 좋아', 29, 37], 'positive']]},
#  {'sentence_form': '티트리라 두피가 시원해서 좋아요아로마티카 샴푸 맛집 인 건 진짜 인정',
#   'annotation': [['탈모', ['두피가 시원해서 좋아요', 5, 17], 'positive']]},
#  {'sentence_form': '다른 비싼 것보단 전 이 제품이 좋더라구 요향도 마음에 들고 너무 부드러워요',
#   'annotation': [['향', [' 요향도 마음에 ', 22, 31], 'positive'],
#    ['머릿결', ['무 부드러', 35, 40], 'positive']]},
#  {'sentence_form': '거품 풍성합니다. 목욕탕.골프장 가져 다니기 좋아요. 사이즈가 작아서 두 개사 길 너무 잘한 듯요. 무엇보다도 항이 내 스타일입니다,',
#   'annotation': [['거품', ['거품 풍성합니다', 0, 8], 'positive'],
#    ['향', ['다도 항이 내 스타일', 59, 70], 'positive']]},
#  {'sentence_form': '머리가 자주 가렵고 두피가 민감한 편이에요. 닥터 그루트 제품 좋아하는데 자극적이지 않으면서도 세정력 좋은 샴푸 찾다가 평소 애정하는 김지영님이 모델이시길래 바로 구매했습니다. 일단 하늘빛 디자인 너무 이 쁘고, 시원하고 상큼한 향이라 좋아요. 거품도 잘 나고 너무 화하지 않고 상쾌하게 감겨서 좋습니다. 적은 양으로도 거품 풍성하게 나 고 산뜻해서 아침 저녁 언 제 사용해도 좋아요. 두피가 민감한데 자주 가려우신 분들에게 추천 드립니다. 판매자에게 제품비의 일부를 지원받았지만 저의 솔직한 후기입니다.',
#   'annotation': [['향', [', 시원하고 상큼한 향이라 좋', 117, 133], 'positive'],
#    ['거품', ['. 거품도 잘', 135, 142], 'positive'],
#    ['세정', ['않고 상쾌하게 감겨서 좋', 153, 166], 'positive']]},
#  {'sentence_form': '제가 4 통째 쓰는 최 애템입니다 이거 쓰고 머릿결도 좋아지는 게 눈에 보이고 향도 좋아서 쓸 때마다 행복해요',
#   'annotation': [['머릿결', ['고 머릿결도 좋아지', 23, 33], 'positive'],
#    ['향', ['이고 향도 ', 41, 47], 'positive']]},
#  {'sentence_form': '"판매자에게 제품비의 일부를 지원받았지만 저의 솔직한 후기입니다.” 두피가 건조란 편이라 하늘색으로 받아 봤어요 요새 여기 브랜드가 자주 보여서 궁굼했었는데 패키지도 너무 귀엽고 직접 사용해보니 소량만 사용해도 거품도 잘 나고 세라마이드가 함유돼서 그런지 샴푸 후에 건조한 느낌이 덜하고 수분이 채워진 듯한 느낌이었어요 자극 없이 순하고 좋네요 다음에는 토닉이나 다른 제품 도 써보고 싶어요!',
#   'annotation': [['자극', ['느낌이었어요 자', 172, 180], 'positive'],
#    ['거품', ['해도 거품도 ', 115, 122], 'positive']]},
#  {'sentence_form': '건성인 뷴들이 사용하기 좋을 것 같습니닼 향은 너무 좋아요 지성은 조금 떡질 수도 ㅠㅠ',
#   'annotation': [['향', [' 향은 너무 좋아', 22, 31], 'positive'],
#    ['세정', ['지성은 조금 떡질 수', 33, 44], 'negative']]},
#  {'sentence_form': '향도 좋고 머리카락이 뻣뻣해지지 않아요. 두피 샴푸와 번갈아 사용하고 있어 욤',
#   'annotation': [['향', ['향도 좋고', 0, 5], 'positive'],
#    ['머릿결', ['머리카락이 뻣뻣해지지 않아요', 6, 21], 'positive']]},
#  {'sentence_form': '❤ 루톤 여성 두피용 알파에르겐 탈모샴푸 한 달 사용 후기 😙🤗 구매한 이유: 후기가 좋아서 구매했어요 ~!아직 탈모는 없으나 예방 차원으로 사용해보았어요~!🤩 총평 👉 머릿결이 부드러워집니다~향이 좋아요 거품이 풍성하여 조금만 덜어 사용 가능함 👍머리도 안 빠져요~그러나 지성인분들은 기름질 것 같습니다~!🥰향 : 좋은 향입니다 저한테는 요..강하지 않고 ~허브향 사용 후 향이 반나절은 남아 있습 니다~😁😊👍사용하고 난 후 머릿결이 부드러워져서 만족합니다~!😄 탈모 예방 더 써봐야 하지요 😄😊😊 거품양이 아주 풍성해서 좋아요 😊조금 양의 덜어서 사용해도 되서 좋고 마음에 들어 요 👍👍🤗 펌프형이라 사용 편리하니 좋아요케이스도 예쁘고 좋은데..뽀득함이 부족해요 😂😅',
#   'annotation': [['머릿결', ['보았어요~!🤩 총평 👉', 82, 94], 'positive'],
#    ['향', ['머릿결이 부', 95, 101], 'positive'],
#    ['거품', ['드러워집니다~향', 101, 109], 'positive'],
#    ['세정', ['안 빠져요~그러', 143, 151], 'negative']]},
#  {'sentence_form': '거품은 잘 안 나는 거 같아요 유툽 보고 좋다고 해서 세일할 때 저렴하게 구매했습니다',
#   'annotation': [['거품', ['거품은 잘 안 나는 거 같', 0, 14], 'negative'],
#    ['가격', ['할 때 저렴하', 32, 39], 'positive']]},
#  {'sentence_form': '손상 머릿결에 좋다고 느껴졌어요 😁😁 향은 은은한 장미향이 나네요',
#   'annotation': [['향', [' 향은 은은한 장미', 20, 30], 'positive'],
#    ['머릿결', ['손상 머릿결에 좋다', 0, 10], 'positive']]},
#  {'sentence_form': '향 완전 제 취향이에요 시원한 향이라서 완전 좋아요 거품도 풍성해서 좋아요 다음에도 재구매 예정!!',
#   'annotation': [['향', [' 시원한 향이라서 완전 좋아', 12, 27], 'positive'],
#    ['거품', ['요 거품도 풍성', 27, 35], 'positive']]},
#  {'sentence_form': '집에 샴푸 없어서 급하게 샀 능데 무난하게 사용하기 좋아요 향도 괜찮아요',
#   'annotation': [['향', ['요 향도 괜찮', 31, 38], 'positive']]},
#  {'sentence_form': '샴푸칠 하고 나면 두피가 시원해져서 두피 열 내려주고 좋아요',
#   'annotation': [['쿨링', ['두피가 시원해져서 두피 열 내려주고 좋아', 10, 32], 'positive']]},
#  {'sentence_form': '맥주 효모환도 먹고 있는데 샴푸도 맥주 효모가 들어 있는 샴푸를 쓰게 됐네요 생각 외로 향도 좋고 자극 없이 샴푸하기 정말 좋은 거품량까지.. 모두 맘에 들어요~',
#   'annotation': [['향', ['각 외로 ', 44, 49], 'positive'],
#    ['자극', ['도 좋고', 50, 54], 'positive'],
#    ['거품', ['하기 정말 ', 63, 69], 'positive']]},
#  {'sentence_form': '샴푸 후에도 잔 향이 오래 가서 마치 향수를 뿌린 듯한 느낌? 머릿결도 부드러워지고 윤기가 흘러서 요즘 머리 감을 때마다 기분 좋네요 ㅎㅎ',
#   'annotation': [['머릿결', ['? 머릿결도 부드러워', 33, 44], 'positive'],
#    ['향', ['샴푸 후에도 잔 향이 오래 가서 마치 향수를 뿌린 듯한 ', 0, 31], 'positive']]},
#  {'sentence_form': '나인밀라 카밍비어 맥주 효모 샴푸는 진짜 두피 예민한 분들한테 딱 일 것 같아요. 저도 원래 두피가 자주 가렵고 샴푸 잘못 쓰면 뾰루지처럼 뭐 올라오는데, 이건 며칠 써보니까 그런 게 거의 없어서 좋았어요. 맥주 효모 들어갔다고 해서 향이 이 상하지 않을까 걱정했는데 전혀 아니고, 은은한 시원한 허브향? 같은 느낌이라 샴푸하면서 기분까지 상쾌했어요. 거품도 잘  나 고 헹굴 때 머릿결이 뻣뻣하지 않아서 린스 따로 안 써도 괜찮았고요. 머리 말리고 나면 기름기 덜 올라오고 볼륨도 좀 살아있는 느낌이라 확실히 두피에 좋은 성분 쓴 티가 나더라고요. 그리고 비건 샴푸라 그런지 안심하고 매일 쓸 수 있어서 요즘은 이걸로 정착했어요.',
#   'annotation': [['향', ['니고, 은은한 시원한', 154, 165], 'positive'],
#    ['거품', ['요. 거품도 ', 194, 201], 'positive'],
#    ['머릿결', [' 헹굴 때 머릿결이 뻣뻣', 207, 220], 'positive'],
#    ['세정', ['리고 나면 기름기 ', 249, 259], 'positive']]},
#  {'sentence_form': '지성 두피용 샴푸로 최고입니다...보통 아침에 감으면 오후에 기름지고 가렵고 또 저녁에 감으면 다음날 아침에 기름지기 마련이었는데, 이걸 쓰고는 하루 종일 불편하지 않게 됐어요 ㅠㅠㅜ 이* 이 퀄라이징 샴푸가 비싸서 좀 부담스러웠는데 대체품으로 좋은 것 같아요. 향도 은은하고 거품이 너무 적은 것도 아니라서 만족합니다.',
#   'annotation': [['향', ['아요. 향도 ', 143, 150], 'positive'],
#    ['거품', ['은하고 거품이 너무 적은 것도 아니라서 만', 151, 174], 'positive'],
#    ['세정', [' 아침에 기름지기 마련이었는데, 이걸 쓰고는 하루 종일 불편하지 않게 됐', 56, 96], 'positive']]},
#  {'sentence_form': '향이 좋아요머릿결은 워낙 나빠 아직 잘 모르겠지만 특별하게 나쁜 점은 없어요!',
#   'annotation': [['향', ['향이 좋아요', 0, 6], 'positive'],
#    ['머릿결', ['머릿결은 워낙 나빠 아직 잘 모르겠지', 6, 26], 'neutral']]},
#  {'sentence_form': '아보카도 좋아하는데 단백질까지 더 해진 샴푸! 쟁여놔서 아직 안 써봤는데 탈모가 효과 있으면 더 구매할려구요 ! 향은 안심해서 좋네요 보통 일 것 같긴 합니다.',
#   'annotation': [['향', [' ! 향은 안심해서 ', 60, 71], 'positive']]},
#  {'sentence_form': '👍🏻 만족했던 점💬 적당한 거품양, 개운한 세정력 세번째 사진 보시면 물 두 세방울 정도 묻혀 문질러 준 거품양이에 요 거품양이 많이 나 진 않지만 오히려 두피 구석구석 세정해주는 데 더 편해서 아주 만족!💬 은은한 쿨링감과 세정 후 모발 뻣뻣함 X두피 구석구석 씻어준 다음 그대로 2, 3분 방치해주니 은은 한 쿨링감이 느껴졌어요!요 폴리젠은 세정 후 심한 뻣뻣함이  없는 편이라 가끔 트리트먼트 스킵할 때도 있는데 불편함 별로 없었어요!💬 모발 빠짐 확실히 줄어듬 사용 전에는 샴푸 후 고양이 털 뭉치 마냥 머릿카락이 너무 많이 빠졌었는데 사용한 지 3주차 된 요즘은 반절로 많이 줄어들었고 가끔 스트레스 받을 때 아니면 전보다는 많이 안 빠지더라구요!모발 빠짐 때문에 걱정이 신 분들 폴리젠 꼭 써보세요!❗️ 추천하는 대상-모발  빠짐으로 스트레스가 많으신 분들 -부드러운 탈모 샴푸를 선호하시는 분들 🔚 재구매 의사 완전 있어요!닥',
#   'annotation': [['거품', [' 적당한 거품', 10, 17], 'positive'],
#    ['세정', [' 개운한 세정', 19, 26], 'positive'],
#    ['머릿결', ['리젠은 세정 후 심한 ', 189, 201], 'positive'],
#    ['탈모', ['별로 없었어요!💬 모발 ', 238, 251], 'positive']]},
#  {'sentence_form': '민감 두피용에 맞는 제품이고 사용하고 나서도 자극이 없었습니다 꼼꼼하게 신경 써서 샴푸하니까 두피가 많이 좋아졌어요',
#   'annotation': [['자극', ['자극이 없었습니다', 25, 34], 'positive']]},
#  {'sentence_form': '✨️향이 일단 너무 좋았습니다! 사과식초라고는 하지만 상큼한 사과 주스 향이 났어요. 은은하게 남아 있어 좋았어요. ✨️ 세정력 제가 특히 머리가 파워지성인데 제 머리의 유분기를 잘 제거해줬고 꽤 오래 지속되어서 좋았어요. 저는 24시간이 지나지 않아도 좀 머리 냄새가 나는 편이라 스트레스였거든요. ✨️ 거품은 그럭저럭 나는 편이에요!✨️ 아쉬운 점 제가 원래 항상  탈모방지 샴푸를 사용하는데 원래 머리숱 자체가 적은 편이라 조심하고 있거든요. 근데 아무래도 탈모방지 샴푸가 아니라 그런지 요 샴푸를 쓸 때는 머리가 원래 샴푸보다는 아쉬웠던 거 같아요. ✨️ 머리가 뭐 풍성해진다는 리뷰가 있어서 뭐지 했는데 머리가 생각보다 탱글해지고 좀 영양 들어간 느낌? 그랬어요. 살짝 머리 하나 하나가 코팅된 느낌이었어요 다만 가끔 머리가 너 무 윤기가 도니까 잘못 보면 떡져 보일 수도 있겠다는 생각이 들었어요. 하지만 실제로는 머리 윤기가 촤르르 돌았어요. ✨️ 머릿결이 막 엄청 나빠지진 않았으나 단독 사용하기에는 머릿결이 막 좋아히는 편도 아니었어서 트리트먼트 추천합니다.✨️ 총평은 평소 탈모 방지 샴푸를 평소 사용하지 않는 지 성인들에게 추천합니다!도움이 되었다면 도움 눌러주세요 감사합니다 :)',
#   'annotation': [['세정', ['성인데 제 머리의 유분기를 잘', 85, 101], 'positive'],
#    ['거품', ['였거든요. ✨️ 거품은 그럭저', 162, 178], 'neutral'],
#    ['머릿결', ['이 막 엄청 나빠지진 않았으나 단독 ', 485, 505], 'neutral'],
#    ['향', [' 상큼한 사과 주스', 29, 39], 'positive']]},
#  {'sentence_form': '향이 자극적이지 않고 은은 해서 너무 마음에 들어요! 거품도 풍성하고, 세정력도 좋습니다! 역시 믿고 쓰는 라보에이치.',
#   'annotation': [['거품', ['! 거품도 풍성', 28, 36], 'positive'],
#    ['세정', [', 세정력도 좋습', 38, 47], 'positive'],
#    ['향', ['향이 자극적이지 않고 은은 해', 0, 16], 'positive']]},
#  {'sentence_form': '지성 두피 고민 때문에 구매하게 되었는데 너무 만족합니다 세정력 너무 좋고 헹구 고 나면 산뜻해서 개운하게 머리감은 느낌을 느낄 수 있어서 좋았어요 거품도 잘 나는 편이고 향도 인공적으로 독한 편이 아니라서 마음에 듭니다',
#   'annotation': [['세정', ['다 세정력 너무 ', 30, 39], 'positive'],
#    ['거품', ['았어요 거품도 잘 ', 79, 89], 'positive'],
#    ['향', ['편이고 향도 인공적으로 독한 편이 아니라서 마음', 92, 118], 'positive']]},
#  {'sentence_form': '지성 두피라면 사용하기 좋은 아로마티카 두피 세정력 좋아요',
#   'annotation': [['세정', ['세정력 좋아요', 25, 32], 'positive']]},
#  {'sentence_form': '거품도 잘 일어나고 세정력도 좋아서 아주 만족합니다 샴푸 후 퍽퍽하지도 않고 감고 나면 자극적이지 않아 상쾌한 느낌들어 기분 좋네요 두피와 모발에 단백질 영양 팍팍 준다니 열심히 관리 해야겠네요 민감한 피부에도 자극적이지 않아 추청합니다',
#   'annotation': [['거품', ['거품도 잘 일어나', 0, 9], 'positive'],
#    ['세정', [' 세정력도 좋', 10, 17], 'positive'],
#    ['자극', [' 자극적이지 ', 48, 55], 'positive']]},
#  {'sentence_form': '피부과 치료 받으면서 약을 먹고 연고를 얼굴에 바르고 했었는데 얼굴은 깨끗해졌지만 왜인지 모르게 치료 이후로 두피에 트러블도 많이 올라오고 긁으면 피가 나기도 했고, 자고 일어나면 침대 베개에 피딱지들이 떨어져 있기도 했어요 그때 쓰던 샴푸는 탈모에 효과 있는 샴푸였는데 두피에 도움이 전혀 안 되겠다 싶어서 민감, 가려움, 비듬 이런 쪽과 관련된 샴푸를 찾 아서 쓰기 시작했어요 !시간이 많이 지나서 저절로 가라앉은 건지 샴푸덕을 본 건진 모르겠지만 지금은 두피에 트러블도 없고 가려움증도 없어요~ 상품성은 좋지만 한 정 기획이 아니면 가격 부담돼서 못 살 듯 ㅠ..',
#   'annotation': [['자극', ['모르겠지만 지금은 두피에 트러블도 없고 가려움', 247, 272], 'positive'],
#    ['가격', ['기획이 아니면 가격 부', 293, 305], 'negative']]},
#  {'sentence_form': '벌써 세 통 째 재구매예요~ 일단 향은 약간 화한 향이 나요 쓰다 보니 익숙해져서 그러려니 하는데 처음 쓰시는 분들은 이게 무슨 향인 가 하실 수도 있어요! 매일 사용하면 두피나 머릿결에 무리가 있을까봐 저는 2~3일에 한 번 쓰고 평소에는 집에서 사용하는 샴푸로 머리를 감아 줍니다 ㅋㅋㅋ 두피에 자극은 크게 없는 편이고요 세정력은 일반 샴푸랑 비슷한 것  같아 요 거품은 일반 샴푸보다 잘 안 나고요 물을 많이 하든가 아니면 양을 많이 하든가라서 솔직히 가격 대비 좋은 건지는 모르겠어요! ㅠ ㅠ 그리고 사용하고 나면 기름을 빼 줘서 그런 가 머릿결이 뻣뻣해져요 약간 일시적인 느낌이고 바로 컨디셔너나 트리트먼트로 관리해 주면 머릿결은 그대로 돌아옵니다 ㅎㅎ 저는 그래도 재구매 의사 있어요 하고 나면 개운한 느 낌인지라 머리 잘 감았다 하는 느낌이 들거든요',
#   'annotation': [['자극', [' 두피에 자극은 크게 없는 편이고', 162, 180], 'positive'],
#    ['세정', [' 세정력은 일반 샴푸랑 비슷한 것  같아', 181, 203], 'positive'],
#    ['거품', [' 요 거품은 일반 샴푸보다 잘 안 ', 203, 222], 'negative'],
#    ['가격', ['직히 가격 대비 좋은 건지는 모르', 253, 271], 'negative'],
#    ['머릿결', ['런 가 머릿결이 뻣', 302, 312], 'negative'],
#    ['향', ['향은 약간 화한 향이 나', 19, 32], 'positive']]},
#  ...]

# %% [markdown]
# # 데이터 전처리

# %% [markdown]
# - len 200 이하로 자르고 띄어쓰기 수행하는데, 속성 주변 기준으로 리뷰 자르게 되면
#     - truncate_and_spacing 수정 필요

# %%
# 1. 한글, 영어, 숫자, 공백, 직접 정한 허가 특수문자들 이외 공백처리
def clean_review(text):
    allowed_punctuations = "!?.,%+=~&()"
    pattern = rf"[^ㄱ-ㅎㅏ-ㅣ가-힣a-zA-Z0-9\s{re.escape(allowed_punctuations)}]"

    text = re.sub(pattern, ' ', text)

    return text.strip()

# 2. 소괄호 안 부연설명 삭제
def del_bracket(text):
    # 괄호 안 부연설명 제거 (중첩 괄호 포함)
    while re.search(r'\([^()]*\)', text):
        text = re.sub(r'\([^()]*\)', ' ', text)

    # 잔여 괄호 제거
    text = text.replace("(", " ")
    text = text.replace(")", " ")

    return text.strip()

# 3. 의미없는 반복 문자열 축약
# 반복어구
dupchars_pattern = re.compile(r'(.)\1{2,}')
dupsymbols_pattern = re.compile(r'([!?~%+=&])\1{1,}')
# 더블스페이스
doublespace_pattern = re.compile(r'\s+')

def contract_dupchars(text, n = 3):
    if n > 0:
        text = dupchars_pattern.sub('\\1' * n, text)

    text = dupsymbols_pattern.sub('\\1', text)
    text = doublespace_pattern.sub(' ', text)

    return text.strip()

# 4. 협찬 문장 제거
def del_sponsored(text):
    sponsored_pattern = r'''
        (판매자(에게|로부터)|업체로부터|본\s상품\s후기는).{0,70}?
        (후기(입니다|입니다타|에요|입니\s?다)?|
         리뷰(입니다|했습니다|적었습니다|하였습니다|입니다요)?|
         작성하였습니다|기남겨요|기랍니다|흐기입니다|전달합니다|올립니다|것\s?입니다)
        [!.~\s]{0,2}
    '''
    sponsored_pattern = re.compile(sponsored_pattern, flags=re.VERBOSE)
    text = sponsored_pattern.sub(' ', text)

    return text.strip()

# 전처리 종합
def preprocessing(form):
    form = clean_review(form)
    form = del_bracket(form)
    form = contract_dupchars(form)
    form = del_sponsored(form)

    return form

# %% [markdown]
# # 모델 정의
#
# - ACD 를 위한 ky-kim/electra-kor-base
# - ASC 를 위한 klue/roberta-base

# %%
class AttentionPooling(nn.Module):
    def __init__(self, hidden_size):
        super().__init__()
        self.attention = nn.Sequential(
            nn.Linear(hidden_size, hidden_size),
            nn.Tanh(),
            nn.Linear(hidden_size, 1)
        )

    def forward(self, hidden_states, attention_mask):
        scores = self.attention(hidden_states).squeeze(-1)
        scores = scores.masked_fill(attention_mask == 0, -1e4)
        weights = torch.softmax(scores, dim=-1)
        pooled = torch.sum(hidden_states * weights.unsqueeze(-1), dim=1)
        return pooled

class SimpleClassifier(nn.Module):
    def __init__(self, hidden_size, num_labels, dropout_prob=dropout_prob):
        super().__init__()
        self.dense = nn.Linear(hidden_size, hidden_size)
        self.dropout = nn.Dropout(dropout_prob)
        self.norm = nn.LayerNorm(hidden_size)
        self.act = nn.Tanh()
        self.output = nn.Linear(hidden_size, num_labels)

    def forward(self, x):
        x = self.dropout(x)
        x = self.dense(x)
        x = self.norm(x)
        x = self.act(x)
        x = self.dropout(x)
        return self.output(x)

class ABSA_Model(nn.Module):
    def __init__(self, base_model, num_labels, tokenizer_len=None, dropout_prob=dropout_prob):
        super().__init__()

        config = AutoConfig.from_pretrained(base_model)
        self.backbone = AutoModel.from_pretrained(base_model, config=config)

        if tokenizer_len is not None:
            self.backbone.resize_token_embeddings(tokenizer_len)

        self.attn_pool = AttentionPooling(config.hidden_size)
        self.classifier = SimpleClassifier(config.hidden_size, num_labels, dropout_prob)

        self.loss_fn = nn.CrossEntropyLoss(label_smoothing=label_smoothing)

    def forward(self, input_ids, attention_mask, labels=None):
        outputs = self.backbone(
            input_ids=input_ids,
            attention_mask=attention_mask
        )
        hidden_states = outputs.last_hidden_state
        pooled_output = self.attn_pool(hidden_states, attention_mask)
        logits = self.classifier(pooled_output)

        if labels is not None:
            loss = self.loss_fn(logits, labels)
            return loss, logits
        else:
            return None, logits

# %% [markdown]
# # 데이터 파싱 및 tokenization 함수 정의

# %%
def tokenize_and_align_labels(tokenizer, form, annotations, max_len):
    entity_dict = {'input_ids': [], 'attention_mask': [], 'label': []}
    polarity_dict = {'input_ids': [], 'attention_mask': [], 'label': []}

    if not form or not isinstance(form, str):
        return entity_dict, polarity_dict

    pad_token_id = tokenizer.pad_token_id if tokenizer.pad_token_id is not None else 0

    for pair in entity_property_pair:
        matched = False

        encoded = tokenizer(
            form,
            pair,
            padding=False,
            truncation=False,
            return_tensors='pt',
            add_special_tokens=True
        )

        input_ids = encoded['input_ids'][0].tolist()
        attention_mask = encoded['attention_mask'][0].tolist()
        input_ids, attention_mask = truncate_left(input_ids, attention_mask, max_len, pad_token_id)

        for annotation in annotations:
            if len(annotation) < 3:
                continue

            entity_property, _, polarity = annotation
            if polarity == '------------':
                continue

            if entity_property != '없음' and entity_property == pair:
                entity_dict['input_ids'].append(input_ids)
                entity_dict['attention_mask'].append(attention_mask)
                entity_dict['label'].append(tf_name_to_id['True'])

                polarity_id = polarity_name_to_id.get(polarity)
                if polarity_id is not None:
                    polarity_dict['input_ids'].append(input_ids)
                    polarity_dict['attention_mask'].append(attention_mask)
                    polarity_dict['label'].append(polarity_id)

                matched = True
                break

        if not matched:
            entity_dict['input_ids'].append(input_ids)
            entity_dict['attention_mask'].append(attention_mask)
            entity_dict['label'].append(tf_name_to_id['False'])

    return entity_dict, polarity_dict

def get_dataset(raw_data, tokenizer, max_len):
    entity_inputs, entity_masks, entity_labels = [], [], []
    polarity_inputs, polarity_masks, polarity_labels = [], [], []

    for utterance in raw_data:
        form = utterance.get('sentence_form', '')
        form = preprocessing(form)
        if len(form) < 10:
            continue
        annotations = utterance.get('annotation', [])

        entity_dict, polarity_dict = tokenize_and_align_labels(tokenizer, form, annotations, max_len)

        entity_inputs.extend(entity_dict['input_ids'])
        entity_masks.extend(entity_dict['attention_mask'])
        entity_labels.extend(entity_dict['label'])

        polarity_inputs.extend(polarity_dict['input_ids'])
        polarity_masks.extend(polarity_dict['attention_mask'])
        polarity_labels.extend(polarity_dict['label'])

    if not entity_inputs:
        raise ValueError("No entity data found. Check preprocessing or filtering conditions.")
    if not polarity_inputs:
        raise ValueError("No polarity data found. Check preprocessing or filtering conditions.")

    def compute_class_weight(labels, label_size):
        counter = Counter(labels)
        total = sum(counter.values())
        return torch.tensor([
            (total / count) if count > 0 else 0.0
            for i in range(label_size)
            for count in [counter.get(i, 0)]
        ], dtype=torch.float)

    entity_dataset = TensorDataset(
        torch.tensor(entity_inputs, dtype=torch.long),
        torch.tensor(entity_masks, dtype=torch.long),
        torch.tensor(entity_labels, dtype=torch.long)
    )

    polarity_dataset = TensorDataset(
        torch.tensor(polarity_inputs, dtype=torch.long),
        torch.tensor(polarity_masks, dtype=torch.long),
        torch.tensor(polarity_labels, dtype=torch.long)
    )

    entity_weights = compute_class_weight(entity_labels, len(tf_name_to_id))
    polarity_weights = compute_class_weight(polarity_labels, len(polarity_name_to_id))

    return entity_dataset, polarity_dataset, entity_weights, polarity_weights

# %% [markdown]
# - tokenizer = acd_tokenizer or asc_tokenizer 로 task 에 맞게 할당
#
# - return 값 중 필요한 것만 쓰기
#     - 필요 없는 건 _ 로 무시

# %% [markdown]
# # 모델 학습 및 최적화
#
# - 콜백

# %%
def evaluation(y_true, y_pred, label_len):
    count_list = [0] * label_len
    hit_list = [0] * label_len

    for i in range(len(y_true)):
        count_list[y_true[i]] += 1
        if y_true[i] == y_pred[i]:
            hit_list[y_true[i]] += 1

    acc_list = [hit / count if count > 0 else 0 for hit, count in zip(hit_list, count_list)]
    print(f'Accuracy: {sum(hit_list) / sum(count_list):.4f}')
    print(f'Macro Accuracy: {sum(acc_list) / label_len:.4f}')
    print('F1 (per class):', f1_score(y_true, y_pred, average=None))
    print('F1 Micro:', f1_score(y_true, y_pred, average='micro'))
    print('F1 Macro:', f1_score(y_true, y_pred, average='macro'))

scaler = GradScaler()
def train_one_epoch(model, dataloader, optimizer, scheduler, loss_fn):
    model.train()
    total_loss = 0

    for batch in dataloader:
        input_ids, attention_mask, labels = [b.to(device) for b in batch]

        optimizer.zero_grad()
        with autocast(device_type="cuda"):
          loss, logits = model(input_ids, attention_mask, labels)
          loss = loss_fn(logits, labels)

        scaler.scale(loss).backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_grad_norm)
        scaler.step(optimizer)
        scaler.update()
        scheduler.step()

        total_loss += loss.item()

    return total_loss / len(dataloader)

def evaluate_model(model, dataloader):
    model.eval()
    preds, labels = [], []

    with torch.no_grad():
        for batch in dataloader:
            input_ids, attention_mask, label_ids = [t.to(device) for t in batch]
            _, logits = model(input_ids, attention_mask)
            pred = torch.argmax(logits, dim=-1)
            preds.extend(pred.tolist())
            labels.extend(label_ids.tolist())

    macro_f1 = f1_score(labels, preds, average='macro')
    return macro_f1, preds, labels

def get_optimizer_scheduler(model, dataloader):
    no_decay = ['bias', 'gamma', 'beta']
    param_optimizer = list(model.named_parameters())
    grouped_parameters = [
        {'params': [p for n, p in param_optimizer if not any(nd in n for nd in no_decay)], 'weight_decay': 0.01},
        {'params': [p for n, p in param_optimizer if any(nd in n for nd in no_decay)], 'weight_decay': 0.0}
    ]
    optimizer = AdamW(grouped_parameters, lr=learning_rate, eps=eps)
    scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0,
                                                num_training_steps=len(dataloader) * num_train_epochs)
    return optimizer, scheduler

class EarlyStopping:
    def __init__(self, patience=4, mode='max'):
        self.patience = patience
        self.mode = mode
        self.counter = 0
        self.best_score = None
        self.should_stop = False

    def step(self, score):
        if self.best_score is None or \
           (self.mode == 'max' and score > self.best_score) or \
           (self.mode == 'min' and score < self.best_score):
            self.best_score = score
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.should_stop = True

def train_sentiment_analysis(train_data, dev_data):

    print('train_sentiment_analysis START')

    acd_tokenizer = AutoTokenizer.from_pretrained(acd_base_model)
    asc_tokenizer = AutoTokenizer.from_pretrained(asc_base_model)
    acd_tokenizer.add_special_tokens(special_tokens_dict)
    asc_tokenizer.add_special_tokens(special_tokens_dict)

    train_data = ensure_annotation(train_data)
    dev_data = ensure_annotation(dev_data)

    entity_train, _, entity_weights, _ = get_dataset(train_data, acd_tokenizer, max_len)
    _, polarity_train, _, polarity_weights = get_dataset(train_data, asc_tokenizer, max_len)
    entity_dev, _, _, _ = get_dataset(dev_data, acd_tokenizer, max_len)
    _, polarity_dev, _, _ = get_dataset(dev_data, asc_tokenizer, max_len)

    print("Entity Class Weights:")
    for i, (name, weight) in enumerate(zip(tf_id_to_name, entity_weights.tolist())):
        print(f"  - {name} (class {i}): weight = {weight:.4f}")

    print("Polarity Class Weights:")
    for i, (name, weight) in enumerate(zip(polarity_id_to_name, polarity_weights.tolist())):
        print(f"  - {name} (class {i}): weight = {weight:.4f}")

    entity_train_loader = DataLoader(entity_train, shuffle=True, batch_size=batch_size)
    entity_dev_loader = DataLoader(entity_dev, shuffle=False, batch_size=batch_size)
    polarity_train_loader = DataLoader(polarity_train, shuffle=True, batch_size=batch_size)
    polarity_dev_loader = DataLoader(polarity_dev, shuffle=False, batch_size=batch_size)

    entity_model = ABSA_Model(acd_base_model,  len(tf_name_to_id), len(acd_tokenizer)).to(device)
    polarity_model = ABSA_Model(asc_base_model,  len(polarity_name_to_id), len(asc_tokenizer)).to(device)

    entity_loss_fn = torch.nn.CrossEntropyLoss(weight=entity_weights.to(device))
    polarity_loss_fn = torch.nn.CrossEntropyLoss(weight=polarity_weights.to(device))

    entity_opt, entity_sched = get_optimizer_scheduler(entity_model, entity_train_loader)
    polarity_opt, polarity_sched = get_optimizer_scheduler(polarity_model, polarity_train_loader)

    early_stop_entity = EarlyStopping(patience=4, mode='max')
    early_stop_polarity = EarlyStopping(patience=4, mode='max')

    for epoch in trange(num_train_epochs, desc="Epoch"):
        entity_loss = train_one_epoch(entity_model, entity_train_loader, entity_opt, entity_sched, entity_loss_fn)
        print(f"[Entity] Epoch {epoch+1} | Train Loss: {entity_loss:.4f}")

        if do_eval:
            f1, preds, labels = evaluate_model(entity_model, entity_dev_loader)
            print(f"[Entity] Dev F1_macro: {f1:.4f}")
            if f1 > (early_stop_entity.best_score or 0):
                torch.save(entity_model.state_dict(), os.path.join(ACD_MODEL_DIR, 'best_model.pt'))
                print("Saved best entity model")
            early_stop_entity.step(f1)
            if early_stop_entity.should_stop:
                print("Early stopping triggered (Entity)")
                if early_stop_polarity.should_stop:
                  break

        polarity_loss = train_one_epoch(polarity_model, polarity_train_loader, polarity_opt, polarity_sched, polarity_loss_fn)
        print(f"[Polarity] Epoch {epoch+1} | Train Loss: {polarity_loss:.4f}")

        if do_eval:
            f1, preds, labels = evaluate_model(polarity_model, polarity_dev_loader)
            print(f"[Polarity] Dev F1_macro: {f1:.4f}")
            if f1 > (early_stop_polarity.best_score or 0):
                torch.save(polarity_model.state_dict(), os.path.join(ASC_MODEL_DIR, 'best_model.pt'))
                print("Saved best polarity model")
            early_stop_polarity.step(f1)
            if early_stop_polarity.should_stop:
                print("Early stopping triggered (Polarity)")
                if early_stop_entity.should_stop:
                  break

    print("Training complete.")

# %%
split_jsonl_file(
    jsonl_path=converted_base_data_path,
    output_dir=DATA_DIR,
    train_ratio=0.7,
    dev_ratio=0.15,
    test_ratio=0.15
)
# Out:
# 데이터 분할 완료: train=1098, dev=235, test=236

# %%
train_data = jsonlload(train_data_path)
dev_data = jsonlload(dev_data_path)
train_sentiment_analysis(train_data, dev_data)
# Out:
# train_sentiment_analysis START
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/80.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/620 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/344k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/375 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/752k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (624 > 512). Running this sequence through the model will result in indexing errors
# Entity Class Weights:
#   - False (class 0): weight = 1.3846
#   - True (class 1): weight = 3.6000
# Polarity Class Weights:
#   - positive (class 0): weight = 1.1885
#   - negative (class 1): weight = 9.1729
#   - neutral (class 2): weight = 20.1653
# pytorch_model.bin:   0%|          | 0.00/473M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/473M [00:00<?, ?B/s]
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# config.json:   0%|          | 0.00/546 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/443M [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at klue/roberta-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#
# Epoch:   0%|          | 0/20 [00:00<?, ?it/s]
# [Entity] Epoch 1 | Train Loss: 0.6890
# [Entity] Dev F1_macro: 0.5555
# Saved best entity model
# [Polarity] Epoch 1 | Train Loss: 1.0818
# [Polarity] Dev F1_macro: 0.3333
# Epoch:   5%|▌         | 1/20 [01:11<22:43, 71.75s/it]
# Saved best polarity model
# [Entity] Epoch 2 | Train Loss: 0.6335
# [Entity] Dev F1_macro: 0.6972
# Saved best entity model
# [Polarity] Epoch 2 | Train Loss: 1.0008
# [Polarity] Dev F1_macro: 0.4655
# Epoch:  10%|█         | 2/20 [01:55<16:39, 55.55s/it]
# Saved best polarity model
# [Entity] Epoch 3 | Train Loss: 0.3629
# [Entity] Dev F1_macro: 0.9116
# Saved best entity model
# [Polarity] Epoch 3 | Train Loss: 0.9059
# [Polarity] Dev F1_macro: 0.5240
# Epoch:  15%|█▌        | 3/20 [02:41<14:23, 50.79s/it]
# Saved best polarity model
# [Entity] Epoch 4 | Train Loss: 0.2373
# [Entity] Dev F1_macro: 0.9302
# Saved best entity model
# [Polarity] Epoch 4 | Train Loss: 0.8477
# [Polarity] Dev F1_macro: 0.5926
# Epoch:  20%|██        | 4/20 [03:25<12:50, 48.13s/it]
# Saved best polarity model
# [Entity] Epoch 5 | Train Loss: 0.2549
# [Entity] Dev F1_macro: 0.9446
# Saved best entity model
# [Polarity] Epoch 5 | Train Loss: 0.7669
# Epoch:  25%|██▌       | 5/20 [04:08<11:37, 46.49s/it]
# [Polarity] Dev F1_macro: 0.5852
# [Entity] Epoch 6 | Train Loss: 0.3016
# [Entity] Dev F1_macro: 0.9427
# [Polarity] Epoch 6 | Train Loss: 0.7400
# Epoch:  30%|███       | 6/20 [04:50<10:28, 44.89s/it]
# [Polarity] Dev F1_macro: 0.5542
# [Entity] Epoch 7 | Train Loss: 0.3337
# [Entity] Dev F1_macro: 0.9438
# [Polarity] Epoch 7 | Train Loss: 0.6634
# Epoch:  35%|███▌      | 7/20 [05:32<09:29, 43.83s/it]
# [Polarity] Dev F1_macro: 0.5791
# [Entity] Epoch 8 | Train Loss: 0.2923
# [Entity] Dev F1_macro: 0.9384
# [Polarity] Epoch 8 | Train Loss: 0.5587
# Epoch:  40%|████      | 8/20 [06:13<08:37, 43.09s/it]
# [Polarity] Dev F1_macro: 0.5816
# Early stopping triggered (Polarity)
# [Entity] Epoch 9 | Train Loss: 0.2804
# Epoch:  40%|████      | 8/20 [06:47<10:10, 50.89s/it]
# [Entity] Dev F1_macro: 0.9430
# Early stopping triggered (Entity)
# Training complete.

# %% [markdown]
# # 모델 평가

# %% [markdown]
# 학습된 모델을 바탕으로 국어원 데이터 형태를 만드는 방법 예시

# %%
def predict_from_korean_form(acd_tokenizer, asc_tokenizer, acd_best_model, asc_best_model, data, max_len, threshold):
    acd_confidences_all = []
    asc_confidences_all = []

    acd_best_model.eval()
    asc_best_model.eval()

    acd_pad_token_id = acd_tokenizer.pad_token_id
    asc_pad_token_id = asc_tokenizer.pad_token_id

    for sentence in data:
        form = sentence.get('sentence_form', '')
        form = preprocessing(form)
        sentence['annotation'] = []

        if not isinstance(form, str) or not form.strip():
            print(f"Invalid sentence skipped: {form}")
            continue

        for pair in entity_property_pair:
            # ACD 수행
            acd_encoded = acd_tokenizer(
                form,
                pair,
                padding=False,
                truncation=False,
                return_tensors='pt',
                add_special_tokens=True
            )

            acd_input_ids = acd_encoded['input_ids'][0].tolist()
            acd_attention_mask = acd_encoded['attention_mask'][0].tolist()
            acd_input_ids, acd_attention_mask = truncate_left(acd_input_ids, acd_attention_mask, max_len, acd_pad_token_id)

            acd_input_ids = torch.tensor([acd_input_ids]).to(device)
            acd_attention_mask = torch.tensor([acd_attention_mask]).to(device)

            with torch.no_grad():
                _, acd_logits = acd_best_model(acd_input_ids, acd_attention_mask)

            acd_probs = torch.softmax(acd_logits, dim=-1)
            acd_confidence, acd_pred = torch.max(acd_probs, dim=-1)
            acd_pred = acd_pred.item()
            acd_confidence = acd_confidence.item()
            acd_confidences_all.append(acd_confidence)

            if tf_id_to_name[acd_pred] == 'True' and acd_confidence >= threshold:
                # ASC 수행
                asc_encoded = asc_tokenizer(
                    form,
                    pair,
                    padding=False,
                    truncation=False,
                    return_tensors='pt',
                    add_special_tokens=True
                )
                asc_input_ids = asc_encoded['input_ids'][0].tolist()
                asc_attention_mask = asc_encoded['attention_mask'][0].tolist()
                asc_input_ids, asc_attention_mask = truncate_left(asc_input_ids, asc_attention_mask, max_len, asc_pad_token_id)

                asc_input_ids = torch.tensor([asc_input_ids]).to(device)
                asc_attention_mask = torch.tensor([asc_attention_mask]).to(device)

                with torch.no_grad():
                    _, asc_logits = asc_best_model(asc_input_ids, asc_attention_mask)

                asc_probs = torch.softmax(asc_logits, dim=-1)
                asc_confidence, asc_pred = torch.max(asc_probs, dim=-1)
                asc_pred = asc_pred.item()
                asc_confidence = asc_confidence.item()
                asc_confidences_all.append(asc_confidence)

                if 0 <= asc_pred < len(polarity_id_to_name):
                    polarity = polarity_id_to_name[asc_pred]
                else:
                    polarity = "UNKNOWN"

                sentence['annotation'].append([
                    pair,
                    [None, 0, 0],
                    polarity
                ])

        if not sentence['annotation']:
            sentence['annotation'] = [["없음", [None, 0, 0], None]]

    if acd_confidences_all:
        print("Confidence 값 분포 (ACD 단계):")
        print(f"  - max: {max(acd_confidences_all):.4f}")
        print(f"  - min: {min(acd_confidences_all):.4f}")
        print(f"  - mean: {np.mean(acd_confidences_all):.4f}")
        print(f"  - median: {np.median(acd_confidences_all):.4f}")

    if asc_confidences_all:
        print("\nConfidence 값 분포 (ASC 단계):")
        print(f"  - max: {max(asc_confidences_all):.4f}")
        print(f"  - min: {min(asc_confidences_all):.4f}")
        print(f"  - mean: {np.mean(asc_confidences_all):.4f}")
        print(f"  - median: {np.median(asc_confidences_all):.4f}")

    return data

# %% [markdown]
# F1 score 계산 - acd 성능 및 전체 성능 (absa) 에 대한 F1 score 따로 계산

# %%
def evaluation_f1(true_data, pred_data):
    acd_eval = {'tp': 0, 'fp': 0, 'fn': 0}
    absa_eval = {'tp': 0, 'fp': 0, 'fn': 0}

    if len(true_data) != len(pred_data):
        print(f"Warning: Length mismatch (true={len(true_data)}, pred={len(pred_data)})")

    for true_item, pred_item in zip(true_data, pred_data):
        true_annos = true_item.get('annotation', [])
        pred_annos = pred_item.get('annotation', [])

        true_acd_set = set()
        true_absa_set = set()
        for anno in true_annos:
            if len(anno) == 3 and anno[0] != '없음':
                true_acd_set.add(anno[0])
                true_absa_set.add((anno[0], anno[2]))

        pred_acd_set = set()
        pred_absa_set = set()
        for anno in pred_annos:
            if len(anno) == 3 and anno[0] != '없음':
                pred_acd_set.add(anno[0])
                pred_absa_set.add((anno[0], anno[2]))

        acd_eval['tp'] += len(true_acd_set & pred_acd_set)
        acd_eval['fp'] += len(pred_acd_set - true_acd_set)
        acd_eval['fn'] += len(true_acd_set - pred_acd_set)

        absa_eval['tp'] += len(true_absa_set & pred_absa_set)
        absa_eval['fp'] += len(pred_absa_set - true_absa_set)
        absa_eval['fn'] += len(true_absa_set - pred_absa_set)

    def calc_f1(tp, fp, fn):
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0
        f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0.0
        return {
            'Precision': round(precision, 4),
            'Recall': round(recall, 4),
            'F1': round(f1, 4)
        }

    return {
        'ACD result': calc_f1(**acd_eval),
        'entire ABSA result': calc_f1(**absa_eval)
    }

def evaluation_per_aspect(true_data, pred_data):
    aspect_labels = list(set(
        anno[0]
        for sample in true_data
        for anno in sample.get("annotation", [])
        if len(anno) == 3
    ))
    if '없음' not in aspect_labels:
        aspect_labels.append('없음')

    aspect_metrics = {}

    for aspect in sorted(aspect_labels):
        y_true_acd = []
        y_pred_acd = []

        tp = fp = fn = 0

        for true_item, pred_item in zip(true_data, pred_data):
            true_annos = [anno for anno in true_item.get("annotation", []) if len(anno) == 3]
            pred_annos = [anno for anno in pred_item.get("annotation", []) if len(anno) == 3]

            true_aspects_set = set(anno[0] for anno in true_annos)
            pred_aspects_set = set(anno[0] for anno in pred_annos)

            if aspect == '없음':
                y_true_acd.append(1 if len(true_aspects_set - {'없음'}) == 0 else 0)
                y_pred_acd.append(1 if len(pred_aspects_set - {'없음'}) == 0 else 0)
            else:
                y_true_acd.append(1 if aspect in true_aspects_set else 0)
                y_pred_acd.append(1 if aspect in pred_aspects_set else 0)

            if aspect == '없음':
                y_true_absa_set = set((anno[0], anno[2]) for anno in true_annos if anno[0] != '없음')
                y_pred_absa_set = set((anno[0], anno[2]) for anno in pred_annos if anno[0] != '없음')

                y_true_none = len(true_absa_set) == 0
                y_pred_none = len(pred_absa_set) == 0

                if y_true_none and y_pred_none:
                    tp += 1
                elif y_pred_none and not y_true_none:
                    fn += 1
                elif y_true_none and not y_pred_none:
                    fp += 1
                else:
                    pass
            else:
                true_absa_set = set((anno[0], anno[2]) for anno in true_annos if anno[0] == aspect)
                pred_absa_set = set((anno[0], anno[2]) for anno in pred_annos if anno[0] == aspect)

                tp += len(true_absa_set & pred_absa_set)
                fp += len(pred_absa_set - true_absa_set)
                fn += len(true_absa_set - pred_absa_set)

        acd_precision = precision_score(y_true_acd, y_pred_acd, zero_division=0)
        acd_recall = recall_score(y_true_acd, y_pred_acd, zero_division=0)
        acd_f1 = f1_score(y_true_acd, y_pred_acd, zero_division=0)

        absa_precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        absa_recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        absa_f1 = (
            2 * absa_precision * absa_recall / (absa_precision + absa_recall)
            if (absa_precision + absa_recall) > 0 else 0
        )

        aspect_metrics[aspect] = {
            'ACD_Precision': round(acd_precision, 4),
            'ACD_Recall': round(acd_recall, 4),
            'ACD_F1': round(acd_f1, 4),
            'ABSA_Precision': round(absa_precision, 4),
            'ABSA_Recall': round(absa_recall, 4),
            'ABSA_F1': round(absa_f1, 4),
            'Support': sum(y_true_acd)
        }

    return aspect_metrics

# %% [markdown]
# 테스트 데이터에 대한 평가

# %%
def load_model(model_class, path, model_name, label_size, tokenizer_len):
    model = model_class(model_name, label_size, tokenizer_len)
    model.load_state_dict(torch.load(path, map_location=device))
    model.to(device)
    model.eval()
    return model

def pretty_print_result(result_dict, aspect_dict=None):
    print("\nF1 Evaluation Result:")
    for name, metrics in result_dict.items():
        print(f"\n▶ {name}")
        for k, v in metrics.items():
            print(f"   {k}: {v:.4f}")

    if aspect_dict:
        print("\nPer-Aspect Performance:")
        for aspect, metrics in aspect_dict.items():
            print(f"\n - {aspect}")
            for k, v in metrics.items():
                print(f"   {k}: {v}")

def test_sentiment_analysis(test_data, save_path=None):
    print("Starting Sentiment Analysis Test...")

    try:
        acd_tokenizer = AutoTokenizer.from_pretrained(acd_base_model)
        acd_tokenizer.add_special_tokens(special_tokens_dict)
        asc_tokenizer = AutoTokenizer.from_pretrained(asc_base_model)
        asc_tokenizer.add_special_tokens(special_tokens_dict)
    except Exception as e:
        print(f"Tokenizer load error: {e}")
        return

    try:
        test_data = ensure_annotation(test_data)
    except Exception as e:
        print(f"Failed to load test data: {e}")
        return

    try:
        entity_test_data, _, _, _ = get_dataset(test_data, acd_tokenizer, max_len)
        _, polarity_test_data, _, _ = get_dataset(test_data, asc_tokenizer, max_len)
    except Exception as e:
        print(f"Failed to preprocess test data: {e}")
        return

    entity_test_loader = DataLoader(entity_test_data, shuffle=False, batch_size=batch_size)
    polarity_test_loader = DataLoader(polarity_test_data, shuffle=False, batch_size=batch_size)

    try:
        acd_best_model = load_model(ABSA_Model, acd_best_model_path, acd_base_model, len(tf_id_to_name), len(acd_tokenizer))
        asc_best_model = load_model(ABSA_Model, asc_best_model_path, asc_base_model, len(polarity_id_to_name), len(asc_tokenizer))
    except Exception as e:
        print(f"Model load error: {e}")
        return

    acd_best_model.eval()
    asc_best_model.eval()

    acd_total_loss, acd_batches = 0.0, 0
    asc_total_loss, asc_batches = 0.0, 0

    with torch.no_grad():
        for input_ids, attention_mask, labels in entity_test_loader:
            input_ids, attention_mask, labels = input_ids.to(device), attention_mask.to(device), labels.to(device)
            loss, _ = acd_best_model(input_ids, attention_mask, labels)
            acd_total_loss += loss.item()
            acd_batches += 1

        for input_ids, attention_mask, labels in polarity_test_loader:
            input_ids, attention_mask, labels = input_ids.to(device), attention_mask.to(device), labels.to(device)
            loss, _ = asc_best_model(input_ids, attention_mask, labels)
            asc_total_loss += loss.item()
            asc_batches += 1

    pred_data = predict_from_korean_form(acd_tokenizer, asc_tokenizer, acd_best_model, asc_best_model, copy.deepcopy(test_data), max_len, threshold)

    result = evaluation_f1(test_data, pred_data)
    aspect_result = evaluation_per_aspect(test_data, pred_data)

    pretty_print_result(result, aspect_result)

    print("\nAverage Loss:")
    if acd_batches > 0:
        print(f" - ACD Loss: {acd_total_loss / acd_batches:.4f}")
    if asc_batches > 0:
        print(f" - ASC Loss: {asc_total_loss / asc_batches:.4f}")

    save_path = pred_result_DIR
    if save_path:
        try:
            jsondump(pred_data, 'pred_data.jsonl')
            print(f"Saved predictions to {save_path}")
        except Exception as e:
            print(f"Failed to save predictions: {e}")

# %%
test_data = jsonlload(test_data_path)
test_sentiment_analysis(test_data)
# Out:
# Starting Sentiment Analysis Test...
# Some weights of RobertaModel were not initialized from the model checkpoint at klue/roberta-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Confidence 값 분포 (ACD 단계):
#   - max: 0.9999
#   - min: 0.5351
#   - mean: 0.9952
#   - median: 0.9997
#
# Confidence 값 분포 (ASC 단계):
#   - max: 0.9671
#   - min: 0.3570
#   - mean: 0.7467
#   - median: 0.8195
#
# F1 Evaluation Result:
#
# ▶ ACD result
#    Precision: 0.9105
#    Recall: 0.9124
#    F1: 0.9114
#
# ▶ entire ABSA result
#    Precision: 0.7078
#    Recall: 0.7036
#    F1: 0.7056
#
# Per-Aspect Performance:
#
#  - 가격
#    ACD_Precision: 0.92
#    ACD_Recall: 0.9583
#    ACD_F1: 0.9388
#    ABSA_Precision: 0.64
#    ABSA_Recall: 0.6667
#    ABSA_F1: 0.6531
#    Support: 24
#
#  - 거품
#    ACD_Precision: 1.0
#    ACD_Recall: 0.9703
#    ACD_F1: 0.9849
#    ABSA_Precision: 0.7551
#    ABSA_Recall: 0.7327
#    ABSA_F1: 0.7437
#    Support: 101
#
#  - 머릿결
#    ACD_Precision: 0.75
#    ACD_Recall: 0.9808
#    ACD_F1: 0.85
#    ABSA_Precision: 0.5294
#    ABSA_Recall: 0.6923
#    ABSA_F1: 0.6
#    Support: 52
#
#  - 세정
#    ACD_Precision: 0.9035
#    ACD_Recall: 0.8655
#    ACD_F1: 0.8841
#    ABSA_Precision: 0.7632
#    ABSA_Recall: 0.7311
#    ABSA_F1: 0.7468
#    Support: 119
#
#  - 없음
#    ACD_Precision: 0.0
#    ACD_Recall: 0.0
#    ACD_F1: 0.0
#    ABSA_Precision: 0
#    ABSA_Recall: 0
#    ABSA_F1: 0
#    Support: 0
#
#  - 자극
#    ACD_Precision: 0.8684
#    ACD_Recall: 0.825
#    ACD_F1: 0.8462
#    ABSA_Precision: 0.6579
#    ABSA_Recall: 0.6098
#    ABSA_F1: 0.6329
#    Support: 40
#
#  - 쿨링
#    ACD_Precision: 0.8
#    ACD_Recall: 0.8571
#    ACD_F1: 0.8276
#    ABSA_Precision: 0.7333
#    ABSA_Recall: 0.7857
#    ABSA_F1: 0.7586
#    Support: 14
#
#  - 탈모
#    ACD_Precision: 0.8235
#    ACD_Recall: 0.5833
#    ACD_F1: 0.6829
#    ABSA_Precision: 0.7059
#    ABSA_Recall: 0.5
#    ABSA_F1: 0.5854
#    Support: 24
#
#  - 향
#    ACD_Precision: 0.9688
#    ACD_Recall: 0.9688
#    ACD_F1: 0.9688
#    ABSA_Precision: 0.7422
#    ABSA_Recall: 0.7252
#    ABSA_F1: 0.7336
#    Support: 128
#
# Average Loss:
#  - ACD Loss: 0.6290
#  - ASC Loss: 0.7257
# Saved predictions to /content/drive/MyDrive/ABSA/pred_result

# %% [markdown]
# # 증강 데이터 사용

# %%
aug_all_data_path = os.path.join(DATA_DIR, 'aug_all_withko_nn.jsonl')
converted_aug_all_data_path = os.path.join(DATA_DIR, 'converted_aug_all_withko_nn.jsonl')

aug_data = jsonlload(aug_all_data_path)
converted_aug_data = convert_to_absa_format(aug_data)
jsonldump(converted_aug_data, converted_aug_all_data_path)
jsonlload(converted_aug_all_data_path)
# Out:
# [{'sentence_form': '바오밥 신제품 나와서 사봤어요 시카라인이라서 그런지 두피세정이 잘 되는 느낌이에요',
#   'annotation': [['세정', ['두피세정이 잘 되는 느낌이에요', 29, 45], 'positive']]},
#  {'sentence_form': '이렇게 예쁜 샴푸는 처음이야종류도 다양하고 저는 탈모샴푸로 비컨피던트 구매해 봤는데 감을 때 시원하고 향도 시원해서 여름에 사용하기 참좋더라구요 향기 좋고 세정력 좋은 샴푸로 추천합니다',
#   'annotation': [['세정', ['시원하고', 52, 56], 'positive'],
#    ['향', ['향도 시원해서', 57, 64], 'positive'],
#    ['향', ['향기 좋고', 81, 86], 'positive'],
#    ['세정', ['세정력 좋은 샴푸', 87, 96], 'positive']]},
#  {'sentence_form': '케이스부터 고급지네요지루성두피염이라 아무거나 못쓰는 편이라신중히 고르는 편이예요노모어오일이 조금 더 비싸서 좋지 않을까 했는데오일샴푸라 린언미로 겟했어요그런데 딱 원하는 제품이네요뾰루지가 잘 나는 두피인데 염증 완화에 도움을준데요합성계면 활성제, 합성 방부제 없고 그외에도 전제품 EWG 98프로 이상 유해성분 제외라고하니믿고 써봅니다향이 시원한 느낌이고 거품도 잘나며 개운한느낌입니다',
#   'annotation': [['향', ['향이 시원한 느낌이고', 187, 198], 'positive'],
#    ['거품', ['거품도 잘나며', 199, 206], 'positive'],
#    ['세정', ['개운한느낌입니다', 207, 215], 'positive']]},
#  {'sentence_form': '좋아요.리필팩도 들어있어서원플러스 원처럼 구입하게 되서 좋아요.',
#   'annotation': [['가격', ['원플러스 원처럼 구입하게 되서 좋아요', 14, 34], 'positive']]},
#  {'sentence_form': '샴푸를 잘못 구매하면 머리가 떡지거나 거품이 잘안나거나 샴푸후 머리가 푸석해져서 몹시 까다로운편인데이건 가격도 합리적이고 향도 매우좋은 로즈향?같이 나서 샴푸할때마다 기분이 너무 좋아요 또 거품도 쫀쫀하게 나고 하고나서 세정력도 좋아요! 샴푸후 푸석거림도 없습니다영양까지는 모르겠지만 기본으로 적당한 샴푸 찾으시면 무난히 성공합니다',
#   'annotation': [['가격', ['가격도 합리적이고', 58, 67], 'positive'],
#    ['향', ['향도 매우좋은', 68, 75], 'positive'],
#    ['거품', ['거품도 쫀쫀하게', 106, 114], 'positive'],
#    ['세정', ['세정력도 좋아요', 123, 131], 'positive'],
#    ['머릿결', ['푸석거림도 없습니다', 137, 147], 'positive']]},
#  {'sentence_form': '거품도 충분히나고향도 좋아서 머리 말릴때 기분 좋아요.오래 사용할듯해요~',
#   'annotation': [['거품', ['거품도 충분히나고', 0, 9], 'positive'],
#    ['향', ['향도 좋아서', 9, 15], 'positive']]},
#  {'sentence_form': '이 제품 2번째로 사용하고 있어요!! 2세트라서 하나는 제가 쓰고 하나는 부모님께 드리는데 항상 라벤더향이나 베이비로션같은 향만 쓰다가 달달상큼한 사과향을 쓰고 향도 은은하게 남으니까 너무 마음에 들어하셨습니다. 저도 지성두피라서 오후되면 두피가 기름이 져서 헤어가 금방 푹 죽어버리는데 이 제품을 꾸준히 사용하고 나서는 아예 지성이 잡히는건 아니지만 그래도 기름기가 많이 잡혀서 머리가 그래도 조금이나마 뽀송뽀송해용!',
#   'annotation': [['향',
#     ['달달상큼한 사과향을 쓰고 향도 은은하게 남으니까 너무 마음에 들어하셨습니다', 76, 117],
#     'positive'],
#    ['세정', ['머리가 그래도 조금이나마 뽀송뽀송해용', 213, 233], 'positive']]},
#  {'sentence_form': '이거 요물, 거품도 진짜 많이 나고 무엇보다 엄청 부드러워요 친규도 부드럽다고 극찬하고 간,',
#   'annotation': [['거품', ['거품도 진짜 많이 나고', 7, 19], 'positive'],
#    ['머릿결', ['부드러워요', 28, 33], 'positive']]},
#  {'sentence_form': '요새 이걸로 쭉 쓰고있는데 거품도 풍성하고 자극적이지 않아 부담없이 쓰기 좋아요. 두피가 민감한 편이라 얼마 쓰지도 못하고 버린 샴푸가 좀 되는데 이건 첨 사용할깨부터 아 신경써서 만든 샴푸구나 느꼈어요. 가격도 많이 비싸지않고 패키징도 좋아서 선물하기도 좋고. 샴푸후에도 머리가 푸석거리지않고 많이 손상되지않아 만족해요. 동생도 한번 써보고 좋아하더라고요',
#   'annotation': [['거품', ['거품도 풍성', 15, 21], 'positive'],
#    ['자극', ['자극적이지 않아', 24, 32], 'positive'],
#    ['가격', ['가격도 많이 비싸지않고', 115, 127], 'positive'],
#    ['머릿결', ['머리가 푸석거리지않고 많이 손상되지않아 만족해요', 153, 179], 'positive']]},
#  {'sentence_form': '향이 제가 좋아하는 향이라 너무 좋았습니다. 행구고 난 뒤 향도 너무 좋네요✨',
#   'annotation': [['향', ['제가 좋아하는 향이라', 3, 14], 'positive'],
#    ['향', ['향도 너무 좋네요', 33, 42], 'positive']]},
#  {'sentence_form': '판매자에게 제품비의 일부를 지원받았지만 저의 솔직한 후기입니다.같은 제품으로 한 통 다 써보고 두번째 사용하게 된 제품입니다.지성 두피용 샴푸인데도 지성용 샴푸 특유의 머리 감고 난 후에 뻑뻑함이 없어서 좋았어요.트린트먼트를 안하거나 아주 조금 하는 편인데도 빳빳하지 않고 말리고 나면 차분하더라구요.거품도 잘나고 향기도 너무 좋아요.사용하고 히터틀고 하루종일 일해도 머리가 답답하거나 떡지는 느낌이 확실히 덜해요.머리카락에서 은은한 향기도 오래 지속되어서 만족하고 계속 사용 할 것 같아요~!',
#   'annotation': [['머릿결', ['뻑뻑함이 없어서 좋았어요', 105, 118], 'positive'],
#    ['거품', ['거품도 잘나고', 168, 175], 'positive'],
#    ['향', ['향기도 너무 좋아요', 176, 186], 'positive'],
#    ['향', ['은은한 향기', 239, 245], 'positive']]},
#  {'sentence_form': '호불호없이 누구라도 좋아할 향이 아닌가 싶어요 샴푸 살때면 향을 제일 먼저 보는데 정말 역대급 향이네요 머릿결도 차분하게 유지되고 향 지속력도 좋아요 세정력이 좋은 샴푸로 샴푸 후에 두피가 정말 개운해요',
#   'annotation': [['향', ['누구라도 좋아할 향이 아닌가 싶어요', 6, 25], 'positive'],
#    ['향', ['역대급 향이네요', 49, 57], 'positive'],
#    ['머릿결', ['머릿결도 차분하게 유지되고', 58, 72], 'positive'],
#    ['향', ['향 지속력도 좋아요', 73, 83], 'positive'],
#    ['세정', ['세정력이 좋은 샴푸', 84, 94], 'positive'],
#    ['세정', ['두피가 정말 개운해요', 102, 113], 'positive']]},
#  {'sentence_form': '콜라겐 샴푸라서 그런지 사용하고 나면 머릿결이 조금 차분해지는 것 같아서 만족해요.',
#   'annotation': [['머릿결', ['머릿결이 조금 차분해지는 것 같아서 만족해요', 21, 45], 'positive']]},
#  {'sentence_form': '향 지속력은 5시간 정도 ..?..하지만 향이 넘 좋아서 샤워할 때 이 샴푸로 머리 감으면 너무 핸복 그 잡채 ..❕향때문에 산 거지만 탈모예방기능성도 있대요 물론 라보에이치는 원래도 샴푸가 유명하긴 하니까요 ..✨같이 주는 트리트먼트는 사실 안써봤답니다 호호',
#   'annotation': [['향', ['향이 넘 좋아서', 23, 31], 'positive']]},
#  {'sentence_form': '거품이 잘나고 세정력이 좋아요 개운한 느낌♡근지러웠던 두피가 엄청 시원해져요♡머리결도 좋아진 느낌♡밤에 향기롭게 잠들 수 있어서 좋네요♡',
#   'annotation': [['거품', ['거품이 잘나고', 0, 7], 'positive'],
#    ['세정', ['세정력이 좋아요', 8, 16], 'positive'],
#    ['머릿결', ['머리결도 좋아진 느낌', 43, 54], 'positive']]},
#  {'sentence_form': '드라이샴푸 후기 천자로 써봤어:⸻바쁜 아침이나 머리 감기 귀찮은 날, 드라이샴푸는 정말 구세주 같은 존재다. 나도 처음엔 “그게 정말 효과가 있을까?” 싶어서 반신반의했지만, 직접 써보고 나니 왜 사람들이 극찬하는지 알겠더라. 내가 사용한 제품은 스프레이형으로, 기름기 많은 두피에 뿌리면 기름을 흡수해서 머리가 방금 감은 듯한 느낌을 주는 제품이었다.처음 사용할 땐 머리카락이 하얘질까 봐 겁났지만, 적당한 거리에서 가볍게 뿌리고 몇 분 정도 흡수시킨 후 브러시로 빗어내니 백탁도 거의 없고 볼륨도 살짝 살아났다. 특히 앞머리 부분이나 정수리 근처 기름진 부분에 효과가 좋았다. 냄새도 은은한 향수 느낌이라 기분까지 좋아졌다.하지만 단점이 없진 않았다. 일단 깨끗하게 감은 머리처럼 완전한 상쾌함은 아니었고, 손으로 만지면 약간 뻣뻣한 느낌이 남았다. 또 연속해서 2~3일 이상 드라이샴푸만 쓰면 두피가 막힌 느낌이 들어 결국 제대로 감아줘야 했다. 그리고 흑발 기준으로는 하얗게 남을 수 있으니, 꼼꼼히 털어내는 게 중요하다.그래도 운동 후나 급하게 외출할 때, 또는 머리 감기 귀찮은 날엔 확실히 유용하다. 단독으로 쓰기보다는 응급용이나 보조용으로 적절하게 활용하면 진짜 꿀템이라는 생각이 들었다. 이제는 파우치에 하나쯤 꼭 챙겨 다니는 필수템이 되어버',
#   'annotation': [['세정', ['기름진 부분에 효과가 좋았다', 308, 323], 'positive'],
#    ['향', [' 냄새도 은은한 향수 느낌이라 기분까지 좋아졌다', 324, 350], 'positive'],
#    ['머릿결', ['뻣뻣한 느낌이 남았다', 409, 420], 'negative']]},
#  {'sentence_form': '지성 두피인데 잘 씻기고 좋아요 거품도 잘 나고 세정력이 정말 만족스러워요',
#   'annotation': [['세정', ['잘 씻기고 좋아요', 8, 17], 'positive'],
#    ['거품', ['거품도 잘 나고', 18, 26], 'positive'],
#    ['세정', ['세정력이 정말 만족스러워요', 27, 41], 'positive']]},
#  {'sentence_form': '퍼퓸샴푸중에도 지속력이 좋은편이에요! 트리트먼트랑 같이 써서 그런지몰라도 지속력도 좋은데 자극적이지 않아서 좋았어요. 타사 퍼퓸샴푸는 쓰고나면 꼭 이마에 트러블이 생기는데 밀크바오밥은 성분이 순한지 트러블이 없더라구요. 거품도 잘나서 세정력도 우수해요ㅎㅎ 남동생도 향이 맘에드는지 써보더니 같이 써도되냐고 물어보더라구요. 깨끗한 비누향이라 남자가 쓰기에도 무난하고 좋은거같아요. 추천합니다 ㅎㅎ',
#   'annotation': [['자극', ['자극적이지 않아서 좋았어요', 50, 64], 'positive'],
#    ['거품', ['거품도 잘나서', 123, 130], 'positive'],
#    ['세정', ['세정력도 우수해요', 131, 140], 'positive'],
#    ['향', ['깨끗한 비누향이라 남자가 쓰기에도 무난하고 좋은거같아요', 180, 210], 'positive']]},
#  {'sentence_form': '세정력이 너무 아쉬워요. 샴푸한 후에도 유분기가 남아있는 느낌이에요',
#   'annotation': [['세정', ['세정력이 너무 아쉬워요', 0, 12], 'negative'],
#    ['세정', ['유분기가 남아있는 느낌이에요', 22, 37], 'negative']]},
#  {'sentence_form': '은은하고 편안한 향이라 계속 손이 가는 샴푸에요.세정력도 좋아요.거품이 아주 풍성하게 잘 나요.스트레스로 인해서 탈모 걱정되는데 여성맞춤 탈모샴푸라하고 려에서 나온거라 믿고 쓰고 있어요.',
#   'annotation': [['향', ['은은하고 편안한 향', 0, 10], 'positive'],
#    ['세정', ['세정력도 좋아요', 27, 35], 'positive'],
#    ['거품', ['거품이 아주 풍성하게 잘 나요', 36, 52], 'positive']]},
#  {'sentence_form': '세정력이 좋고 향이 오래가서 자주 사용하고 있어요.재구매할께요',
#   'annotation': [['세정', ['세정력이 좋고', 0, 7], 'positive'],
#    ['향', ['향이 오래가서', 8, 15], 'positive']]},
#  {'sentence_form': '달리프 릴렉싱샴푸탈모샴푸라고해서 탈모가 완전히 좋아지는건아닙니다대신 기존 안좋은 샴푸보단(여기서 안좋다는건 향위주나 머릿결위주의샴푸를말함)예방효과는 있어여 무실리콘첨가라 안전하고 보통 샴푸는두피를 씻어주고 트리트먼트같은쪽은 머리카락이죠 두피를 깨끗하게 씻어주니 불필요한각질이나 먼지들이제거가되면서 까끗해져서 머리카락이 잘 올라올수있겠죠하루에 거의 100개씩은 빠진다고하니 관리를 잘해죠야빠진부분이 듬성해지지않겠죠 ㅎㅎ 샴푸제형은 물같은 제형이예요 좀 주르륵 흐르는느낌?먼가 약산상폼클렌징 같은 느낌이더라구여깨끗하게 씻어지는느낌 !! 그래도 거품은 꽤납니다 ㅎㅎ문지르는 느낌으론 안나는거같지만 실제로보면 ㅎㅎ향기는 진짜 정확히말은 못하겠는데 먼가 나무 ? 공기정화?여하튼 깨끗한 냄새나요 ㅎㅎ',
#   'annotation': [['탈모', ['탈모가 완전히 좋아지는건아닙니다', 18, 35], 'neutral'],
#    ['세정', ['깨끗하게 씻어지는느낌', 283, 294], 'positive'],
#    ['거품', ['거품은 꽤납니다', 302, 310], 'positive'],
#    ['향', ['깨끗한 냄새나요', 375, 383], 'positive']]},
#  {'sentence_form': '거품도 잘나고 지성두피에아주 찰떡입니다~!유분도 늦게 올라오는거같아요추천~!',
#   'annotation': [['거품', ['거품도 잘나고', 0, 7], 'positive'],
#    ['세정', ['유분도 늦게 올라오는거같아요', 23, 38], 'positive']]},
#  {'sentence_form': '헤어플러스 트리트먼트나 에센스 잘썼어서 샴푸도 구매해봤는데 제형이 꾸덕해서 물을 많이 묻혀야하고 그럼에도 불구하고 거품나는 편은 아닌거같아요..대신 향이 약간 우디향?제 스타일이라 향이 마음에 들고 제 두피에는 기름기가 많지 않은 편이라 괜찮은거같아요! 하지만 재구매의사는 없을거같네요😖',
#   'annotation': [['거품', ['거품나는 편은 아닌거같아요', 64, 78], 'negative'],
#    ['향', ['향이 마음에 들고', 101, 110], 'positive']]},
#  {'sentence_form': '행사덕에 저렴하게 구매해서 만족합니다 비듬에는 살짝 취약한듯',
#   'annotation': [['가격', ['저렴하게 구매해서', 5, 14], 'positive'],
#    ['세정', ['비듬에는 살짝 취약한듯', 21, 33], 'negative']]},
#  {'sentence_form': '너무 만족하고 오래된 브랜드라 믿고 사용합니다 ~좋아요 거품 짱 많이 나요',
#   'annotation': [['거품', ['거품 짱 많이 나요', 31, 41], 'positive']]},
#  {'sentence_form': '라우쉬 샴푸중에 젤 가벼운 느낌인 것 같아요 다른거랑 번갈아가며 쓰는데 산뜻하고 좋아요',
#   'annotation': [['세정', ['산뜻하고 좋아요', 40, 48], 'positive']]},
#  {'sentence_form': '향도 좋구요, 거품이 잘나요. 부드러운 거품이고 거품을 씻고 나면헤어가 부드럽기도 하면서 빳빳해요.헤어가 건강해진 느낌이에요',
#   'annotation': [['향', ['향도 좋구요', 0, 6], 'positive'],
#    ['거품', ['거품이 잘나요', 8, 15], 'positive'],
#    ['머릿결', ['부드럽기도 하면서 빳빳해요', 40, 54], 'neutral']]},
#  {'sentence_form': '말모말모 올리브영에서 판매하는 제품들은거의 인증이 돼서 판매한다고 해도 과언이 아닌 것 같아요~가성비도 좋고 작은양으로도 두피 케어가 가능해서 넘넘 좋아요다음에도 재구매 의사 있어요!',
#   'annotation': [['가격', ['가성비도 좋고', 53, 60], 'positive']]},
#  {'sentence_form': '두피에 자극적이지 않고 머릿결이 헹굴때도 뻣뻣하지 않아요.',
#   'annotation': [['자극', ['두피에 자극적이지 않고', 0, 12], 'positive'],
#    ['머릿결', ['머릿결이 헹굴때도 뻣뻣하지 않아요', 13, 31], 'positive']]},
#  {'sentence_form': '탈모샴푸는 처음 써보는데 머리카락이 덜 빠지는 것 같아요! 그리고 무엇보다 머릿결시 부드러워지고 빗질도 쉬워져서 잘샀템 중 하나입니다!',
#   'annotation': [['탈모', ['덜 빠지는 것 같아요', 20, 31], 'positive'],
#    ['머릿결', ['머릿결시 부드러워지고', 42, 53], 'positive']]},
#  {'sentence_form': '잦은 탈색과 염색으로 머릿결과 두피가 많이 상해있던 찰나,두피 안티에이징과 모발 강화를 해준다는 샴푸가 있다고 해서 바로 구매했습니다!!효과와 효능도 매우 궁금했지만 향이 제일 궁금했어요 ㅎㅎ배송 후 바로 맡아봤는데 생각보다!! 기대 이상으로 향이 너무 너무 좋더라구오!!!!!머릿결에서 향수 뿌린듯한 맑은 꽃향이 은은하게 나서 기분이 좋습니당 ^^또 두피를 살짝 시원하게 해줘서 샴푸 후에 굉장히 시원해영!꾸준히 사용하면 뿌리볼륨과 모발 밀도가 개선되고 모발빠짐이 적다고 하니 계속해서 요걸루 사용해야겠어용 ㅎㅎ 아주 만족스런 소비였습니다🫶',
#   'annotation': [['향', ['꽃향이 은은하게', 172, 180], 'positive'],
#    ['세정', ['두피를 살짝 시원하게', 197, 208], 'positive']]},
#  {'sentence_form': '머리 감기 귀찮을 때 쓰면 너무 좋아요 단지 향 때문에 무향으로 사야할 것 같아요…. 하지만 떡진 머리에 짱 좋아요',
#   'annotation': [['향', ['향 때문에 무향으로 사야할 것 같아요', 25, 45], 'negative'],
#    ['세정', ['떡진 머리에 짱 좋아요', 52, 64], 'positive']]},
#  {'sentence_form': '이때까지 사용해봤던 딥클렌징 샴푸는 정말 두피가 당기도록 건조해져서 두번사용하기 사용하기 망설여졌는데사용시 세정력도 대단히 좋고 거품도 몽글몽글 풍성하게 잘나오고 샴푸 후에도 수분감이 넘쳐서 너무 만족스럽네요 거기다 향기도 딱 취향저격이예요, 무엇보다 두피에 자극이 없이 순하다는게 너무나 좋아요~사용 후 머릿결도 뻣뻣하지 않다는 점도 베리 나이스!',
#   'annotation': [['세정', ['세정력도 대단히 좋고', 60, 71], 'positive'],
#    ['거품', ['거품도 몽글몽글 풍성하게 잘나오고', 72, 90], 'positive'],
#    ['향', ['향기도 딱 취향저격이예요', 121, 134], 'positive'],
#    ['자극', ['두피에 자극이 없이 순하다는게 너무나 좋아요', 141, 165], 'positive'],
#    ['머릿결', ['머릿결도 뻣뻣하지 않다는 점도 베리 나이스', 171, 194], 'positive']]},
#  {'sentence_form': '지성 두피의 경우 정말 좋다. 기름기 제거도 잘 되고 시간이 흘렀을때 기름이 머리에 덜 생긴다. 영양제만 잘 쓰면 좋은 샴푸이다.',
#   'annotation': [['세정', ['기름기 제거도 잘 되고', 17, 29], 'positive'],
#    ['세정', ['기름이 머리에 덜 생긴다', 39, 52], 'positive']]},
#  {'sentence_form': '남편이 지성두피라 두피에 트러블이 잘나는 편인데 확실히 지성두피에 효과있는 것 같아요^^오래 써본건 아니라 꾸준히 써보면 더 확실히 알 수 있을 것 같아요~향도 좋고 거품도 잘나는데 세정력도 좋아서 저와 남편 모두 잘쓰고 있어요.삼푸 후에 남편은 트리트먼트를 거의 안하는데 머리 뻣뻣해지지 않고 좋다고 하네요!꾸준히 써보겠습니다~~"판매자에게 제품비의 일부를 지원받았지만 저의 솔직한 후기입니다."',
#   'annotation': [['향', ['향도 좋고', 87, 92], 'positive'],
#    ['거품', ['거품도 잘나는데', 93, 101], 'positive'],
#    ['세정', ['세정력도 좋아서', 102, 110], 'positive'],
#    ['머릿결', ['머리 뻣뻣해지지 않고 좋다고', 153, 168], 'positive']]},
#  {'sentence_form': '일단 바 ㅇ ㅇ 도 블랑쉬랑 향이 똑같다고 해서 궁금해서 구매해봤습니다 냄새는 실제로 제가 그 브랜드의 향수를 갖고 있는데ㅠ 향이 정말 똑같아서 깜짝 놀랐습니다 일단 좋은점을 먼저 말해보자면 두피에 별다른 큰 자극들을 느끼지 못했습니다 그리고 냄새가 일단 좋아요 블랑쉬향이라 깨끗한 고급진 비누 향 냄새가 머리감는 동안 내내 납니다 거품도 꽤 풍성하고 부드럽게 잘 올라오는 편인것 같아요 그리고 다소 아쉬운점을 얘기해보자면 두피에그렇게 큰 청량감과 쿨링이 느껴지진 않았어요 그래서 그런지 정수리 냄새를 잘 잡아주지는 못하는것 같아요 그리고 두번째는 블랑쉬향이라서 씻고나와서도 블랑쉬 향이 있었으면 했는데 머리 말리면 향이 다 날아가서 아무 냄새도 나지 않습니다 이걸 기대했는데 다소 많이 아쉬운편인것 같습니다',
#   'annotation': [['자극', ['자극들을 느끼지 못했습니다', 117, 131], 'positive'],
#    ['향', ['고급진 비누 향 냄새가 머리감는 동안 내내 납니다', 158, 185], 'positive'],
#    ['거품', ['거품도 꽤 풍성하고 부드럽게', 186, 201], 'positive'],
#    ['쿨링', ['두피에그렇게 큰 청량감과 쿨링이 느껴지진 않았어요', 237, 264], 'negative'],
#    ['세정', ['정수리 냄새를 잘 잡아주지는 못하는것 같아요', 273, 297], 'negative'],
#    ['향', ['머리 말리면 향이 다 날아가서', 338, 354], 'neutral']]},
#  {'sentence_form': '파우디리향 찐~하게 납니다 라보에이치 초록색같이 개운하게 감기는 사용감은 아니에요 라보에이치가 탈모샴푸라서 모발빠짐이 덜 한것 같아서 사용하는데 초록새 냄새가 정말 그냥 사쾌한 치약냄새가 나는게 별로 좋지않아서 퍼퓸샴푸를 샀는데 향이 약하지만 좋은거 같아요 ^나만^ 가끔씩 맡을수 있는 은은한 향이구요 진하지 않아서 두퉁유발 없어요 이유는 모르겠지만 다른데 찾아봐도 트리트먼트랑 붙여서 파는데는 올리브영 밖에 없어서 올리브영에서 세일할때 사요 트리트먼트만 따로 안팔아요......샴푸는 따로 팔지만 트리트먼트는 따로 안팔아요 트리트먼트가 샴푸보다 용량이 적어서 더 빨리 떨어지는데 따로 안팔아요.....참고하시고 페어앤프리지아 블랑쉬앤우디 둘다 아주 은은하고 누구나 호불호없이 사용할만한 향기에요 특히 진한것도 아니고 독한것도 아니라서 그냥 은은하기 때문에 딱히 싫을이유가 없고 둘다 일단 대중적인 향기가 납니다 감을 때는 향기가 잘 나는데 말리면 그냥 없어요 처음 사용시 페어앤프리지아 냄새가 정말 안좋았는데 쓰다보니까 괜찮아져요 블랑쉬 앤 우디가 첫 사용부터 누구나 좋아할만한 향입니다 파우더리한 향기고 페어앤 프리지아는 약간 중성적인 냄새요',
#   'annotation': [['세정', ['개운하게 감기는 사용감은 아니에요', 27, 45], 'negative'],
#    ['향', ['향이 약하지만 좋은거 같아요', 128, 143], 'positive'],
#    ['향', ['호불호없이 사용할만한 향기에요', 373, 389], 'positive'],
#    ['향', ['누구나 좋아할만한 향입니다', 539, 553], 'positive']]},
#  {'sentence_form': '향이 은은해서좋아요 거품도 풍성하고 무난하게사용하기 좋아요',
#   'annotation': [['향', ['향이 은은해서좋아요', 0, 10], 'positive'],
#    ['거품', ['거품도 풍성하고', 11, 19], 'positive']]},
#  {'sentence_form': '재구매했어요!식초샴푸라 개운하고 정수리냄새도 잘 잡아주고 기름도 늦게 올라와요머릿결도 안 뻣뻣해져서 굿!비건이라 안 살 이유없어요ㅎㅎ',
#   'annotation': [['세정', ['냄새도 잘 잡아주고', 21, 31], 'positive']]},
#  {'sentence_form': '향도 좋고 세정력도 좋네여^^ 로레알 추천합니당',
#   'annotation': [['향', ['향도 좋고', 0, 5], 'positive'],
#    ['세정', ['세정력도 좋네여', 6, 14], 'positive']]},
#  {'sentence_form': '👉  위낙  유명하다보니 이게 그렇게 좋아?하고 한번 사용했는데 두피케어에 탁월한 효과가 있는것 같아 그 후론 꾸준히 사용하고 있습니다. 클로란은 두피 모발에 따라 사용할수있도록 여러종류가 있어요. 이번엔 종류별로 구매해봤어요. 저희 가족 모두가 클로란을 즐겨 사용 하고 있습니다 .👉  거품이 풍성하지는 않지만 그렇다고해서 세정력이 약한건 아닙니다. 세정력 좋고 두피에 자극적이지 않고 지성두피에  맞는 라인입니다. 쿨링 효과로  두피에 열이 많은 남편에게 잘 맞더라구요~~  👉  제형이 묽은 편이라 짤때 흘러내리지 않게 주의해야해요. 사용후 머리결이 좀 뻣뻣해지는 감이 있어요. 린스나 트린트먼트를 해주면 좋아요.',
#   'annotation': [['거품', ['품이 풍성하지는 않지만', 162, 174], 'negative'],
#    ['세정', ['세정력이 약한건 아닙니다', 182, 195], 'positive'],
#    ['자극', ['두피에 자극적이지 않고', 204, 216], 'positive'],
#    ['머릿결', ['머리결이 좀 뻣뻣해지는 감이 있어요', 306, 325], 'negative']]},
#  {'sentence_form': '밤에 머리를 감는 스타일이라 나이트버전 샴푸로 구매했는데, 만족스러워요!우선 두피 세정이 잘 돼서 다음 날 아침에 떡짐으로 인한 고민이 없지만 그렇다고 두피에 자극이 가는 샴푸도 아니어서 순하게 두피를 잘 씻어주는 제품이예요!머리도 한결 부드러워진 것 같아 맘에 들었고, 샴푸 향도 은은한 꽃향이 나서 머리 감으면서도 힐링된 것 같아요😆올영세일 맞춰서 사서 2개에 이 정도 가격이면 가성비 최고라고 생각합니다!',
#   'annotation': [['세정', ['두피 세정이 잘 돼서', 43, 54], 'positive'],
#    ['자극', ['두피에 자극이 가는 샴푸도 아니어서', 85, 104], 'positive'],
#    ['자극', ['순하게 두피를 잘 씻어주는', 105, 119], 'positive'],
#    ['머릿결', ['머리도 한결 부드러워진 것 같아 맘에 들었고', 126, 150], 'positive'],
#    ['향', ['샴푸 향도 은은한 꽃향이 나서', 152, 168], 'positive'],
#    ['가격', ['가성비 최고라고 생각합니다', 214, 228], 'positive']]},
#  {'sentence_form': '회사원 A 완도 영상 보고 해당 제품에 관심이 생겼어요:) 세트로 쓰면 더 효과가 좋을 거같아서 트리트먼트랑 같이 구매했어요. 생각보다 향이 강하진 않았는데 은은하게 괜찮은거 같구 머릿결도 맘에드네요',
#   'annotation': [['향', ['은은하게 괜찮은거 같구', 88, 100], 'positive'],
#    ['머릿결', ['머릿결도 맘에드네요', 101, 111], 'positive']]},
#  {'sentence_form': '장미향 가득하고 지루성 두피에듀 괜찮은거같아요세정력도 좋아요',
#   'annotation': [['향', ['장미향 가득하고', 0, 8], 'positive'],
#    ['세정', ['세정력도 좋아요', 25, 33], 'positive']]},
#  {'sentence_form': '생각보다 두피가 시원하짇 않앗지만향이엄청진하고 조아요머리감고난후 맂스를 해조야겟어요 ㅠㅠ',
#   'annotation': [['세정', ['두피가 시원하짇 않앗지만', 5, 18], 'negative'],
#    ['향', ['향이엄청진하고 조아요', 18, 29], 'positive']]},
#  {'sentence_form': '향도 없고 제품력이 무난해서 계속 쓰고 있습니다. 탈모에도 도움 되는 느낌적인 느낌입니다.',
#   'annotation': [['향', ['향도 없고', 0, 5], 'neutral'],
#    ['탈모', ['탈모에도 도움 되는 느낌적인 느낌입니다', 28, 49], 'positive']]},
#  {'sentence_form': '시트러스 향기가 상쾌하고요. 여름에 쓰기 좋은 제품이에오.',
#   'annotation': [['향', ['시트러스 향기가 상쾌하고요', 0, 14], 'positive']]},
#  {'sentence_form': '향도좋고 거품도 풍성합니다~~추천합니다~~|',
#   'annotation': [['향', ['향도좋고', 0, 4], 'positive'],
#    ['거품', ['거품도 풍성합니다', 5, 14], 'positive']]},
#  {'sentence_form': '두피샴푸에 아주 추천합니당🤟🤟🤟🤟이번에 올리브영체험단으로 처음사용해보았는데요 확실히 두피가 시원하고 상쾌한것같아요.. 피부가 워낙 민감한편인데도 자극없이 사용하기 아주좋아요!!!! 온가족이 오랫동안사용할수있는 양이라 더더욱 좋아요!!!!! 강추합니당ㅎㅎㅎㅎㅎㅎ',
#   'annotation': [['세정', ['두피가 시원하고 상쾌한것같아요', 47, 63], 'positive'],
#    ['자극', ['자극없이 사용하기 아주좋아요', 81, 96], 'positive'],
#    ['가격', ['오랫동안사용할수있는 양이라 더더욱 좋아요', 106, 128], 'positive']]},
#  {'sentence_form': '운동도 하고 여름만 되면 땀이 많은 1인입니다확실히 두피가 시원하고 사용 후 개운해요유니폼이 짙은 색이라 비듬이 떨어지면 다 보이는데 각질 떨어지는 것도 거의 안 보이네요. 식초 샴푸라 걱정했는데 식초 냄새 안나요. 향기도 좋고 거품 풍성 해요',
#   'annotation': [['세정', ['두피가 시원하고', 29, 37], 'positive'],
#    ['향', ['향기도 좋고', 121, 127], 'positive'],
#    ['거품', ['거품 풍성 해요', 128, 136], 'positive']]},
#  {'sentence_form': '거품이 풍성하게 잘나고 이거 사용하고 부터 머리 빠지는양이 줄고 모발에 힘이 생겼어요. 향도 은은하게 나서 좋아요. 모발에 윤기도 나고 만족스러워요.',
#   'annotation': [['거품', ['거품이 풍성하게 잘나고', 0, 12], 'positive'],
#    ['탈모', ['머리 빠지는양이 줄고', 24, 35], 'positive'],
#    ['향', ['향도 은은하게', 49, 56], 'positive']]},
#  {'sentence_form': '처음에 쓰면 샴푸만으로 부드러워진다고?감탄하다고 익숙해지면서 감흥떨어지다가 타샴푸써보니 왜좋은지 알겠어요 부드러워요',
#   'annotation': [['머릿결', ['부드러워요', 59, 64], 'positive']]},
#  {'sentence_form': '피부도 두피도 많이 예민해서샴푸한번 잘못 바꾸면바로 두피도 뒤집어지고 각질파티인데..닥터그루트 아쿠아 딥클린 탈모증상완화샴푸는3종 히알루론산 스킨케어 성분 함유로 건조함 없이 딥클렌징 가능하고풍성하고 쫀쫀한 거품으로 여러번 펌핑없이 풍부한 거품으로 세정 가능합니다.저자극의 약산성 샴푸로저처럼 예민하고 민감한 두피, 지성두피, 탈모가 고민인 분 한테정말 좋을것 같아요!"판매자에게 제품비의 일부를 지원받았지만 저의 솔직한 후기입니다.”',
#   'annotation': [['자극', ['저자극의 약산성 샴푸', 148, 159], 'positive']]},
#  {'sentence_form': '리뷰대충다는데 얘는 진짜 좋아서 정성들여서 달고 있음 향이 넘좋음',
#   'annotation': [['향', ['향이 넘좋음', 30, 36], 'positive']]},
#  {'sentence_form': '여러 탈모샴푸 유목민하다가 정착한 유일한 샴푸에요거품도 잘나고 머릿결도 부드럽고 확실히 머리카락 힘도 생겼어요',
#   'annotation': [['거품', ['거품도 잘나고', 27, 34], 'positive'],
#    ['머릿결', ['머릿결도 부드럽고', 35, 44], 'positive']]},
#  {'sentence_form': '거품도 잘 나고 뾰루지도 없고향기도 좋아서 잘 쓰고 있어요!!',
#   'annotation': [['거품', ['거품도 잘 나고', 0, 8], 'positive'],
#    ['향', ['향기도 좋아서', 16, 23], 'positive']]},
#  {'sentence_form': '늘 사용하던거라서 구매했고향도 좋고기름기도 잘 잡아주고급한날에는 쓰기 편해요',
#   'annotation': [['향', ['향도 좋고', 14, 19], 'positive'],
#    ['세정', ['기름기도 잘 잡아주고', 19, 30], 'positive']]},
#  {'sentence_form': '위드 비컨 투피 코렉팅 샴푸 잘 받았습니다. 탈모 증상 완화용으로 매우 좋은 것 같습니다. 향도 좋고 조금만 펌핑하여 사용하여도 거품이 충분히 납니다. 잘 사용해 보고 좋은 효과를 기대하겠습니다.위드 비컨 두피 코렉팅 샴푸 탈모 증상 완화용으로 매우 좋을 것 같습니다.',
#   'annotation': [['향', ['향도 좋고', 51, 56], 'positive'],
#    ['거품', ['거품이 충분히 납니다', 72, 83], 'positive'],
#    ['탈모', ['탈모 증상 완화용으로 매우 좋을 것 같습니다', 125, 149], 'positive']]},
#  {'sentence_form': '너무 잘 쓰고 있어요데일리 샴푸로 교체!샴푸 바꾼 뒤로 비듬이 한번도 안생겼어요',
#   'annotation': [['세정', ['비듬이 한번도 안생겼어요', 31, 44], 'positive']]},
#  {'sentence_form': '아로마티카 샴푸 처음 쓰는데넘 좋아요~^^향도 좋고 거품도 잘나고 고급져요또  사려구요!',
#   'annotation': [['거품', ['거품도 잘나고', 29, 36], 'positive']]},
#  {'sentence_form': '지성한테 좋다해서 샀는데 뽀득뽀득해서 헹궈낼때 너무 좋네용ㅎㅎㅎ',
#   'annotation': [['세정', ['뽀득뽀득', 14, 18], 'positive']]},
#  {'sentence_form': '와ㅎ ㅎ 친구가 추천해줘서 한번 구ㅁㅐ 해봤어요!!!  머리를 안감아서 이 제품을 사는게 아니라 여러므로 참 유용하네요 ㅎㅎ 캠핑을 자주 다녀서 씻어도 머리가 금방 찝찝할때가 있는데 그때 이 제품을 한번 뿌려주면 . . . 너무 좋은거에요ㅋㅋ ㅋ 물없이 감는 샴푸라니.. 왜 그런 말인지 알겠어요  ㅎ괜히 전세계 판매 1위가 아니군요  기름진 머리를 깔끔하게 만들어 줄 뿐만 아니라 기분젛은 상쾌함까지 거기에 깨끗한 헤어스타일을 유지할 수 있도록 도와 줍니다  드라이샴푸 너무 좋으네요 다음에는 더 큰 용량으로 ㄱㅜ매할까 합니다ㅏㅎ ㅎ ㅎ',
#   'annotation': [['세정', ['기름진 머리를 깔끔하게', 188, 200], 'positive'],
#    ['세정', ['기분젛은 상쾌함', 214, 222], 'positive']]},
#  {'sentence_form': '가격이 너무 사악하지만 세정력도 좋고 떡도 잘안져서 이거만 10통째 쓰는듯..',
#   'annotation': [['가격', ['가격이 너무 사악하지만', 0, 12], 'negative'],
#    ['세정', ['세정력도 좋고 떡도 잘안져서', 13, 28], 'positive']]},
#  {'sentence_form': '이 제품을 사용 한지 한 달 정도 돼 가는 거 같은 데 딱히 단점이 눈에 보이지 않는 샴푸인거 같아요 일단 쓰면서 제가 올레 머리가 단발이라서 트리트먼트를 잘 하지 않은데 머리가 엄청 건조하다고 느껴지지 않았어요 보통 다른 제품들은 샴푸만 쓰고 나면 머리가 되게 건조한 걸 느껴 볼 수 있는데 이제품은 어떻게 건조하지 않고 너무 그렇다고 촉촉한 느낌은 아니에요! 두피 스케일링이 필요할 것 같아서 이 제품을 처음으로 사 봤는데 어 스켈링 이라기 보다는 그냥 새정력이 좋은 샴푸?인거 같아요 아로마티카라는 브랜드가 환경에 되게 신경도 많이쓰 물었는데 그의 비해서 가격이 그렇게 비싸지 않은거 같아서 재구매할 것 같습니다 형은 정말 은은하게 허브향 같은 게 나구요 잔향 같은거는 남지 않습니다 새일 자주 해줬으면 좋겠어요!! 고민 하시는 분들은 구매 하는 것 추천 드립니다',
#   'annotation': [['머릿결', ['머리가 엄청 건조하다고 느껴지지 않았어요', 96, 118], 'positive'],
#    ['세정', ['새정력이 좋은 샴푸', 256, 266], 'positive'],
#    ['가격', ['가격이 그렇게 비싸지 않은거 같아서', 314, 333], 'positive'],
#    ['향', ['은은하게 허브향 같은 게 나구요 ', 352, 370], 'positive']]},
#  {'sentence_form': '머리카락이 덜 빠지는 느낌입니다.샴푸만 하면 빳빳해서 트리트먼트도 같이 하니 볼륨감도 오래가고 좋더라구요',
#   'annotation': [['탈모', ['머리카락이 덜 빠지는 느낌입니다', 0, 17], 'positive'],
#    ['머릿결', ['샴푸만 하면 빳빳해서', 18, 29], 'negative']]},
#  {'sentence_form': '추천 보고 샀어요꽃향기 좋고 세정력 좋은것같아요 써봐야 효과는 알수있을것같구요',
#   'annotation': [['향', ['꽃향기 좋고', 9, 15], 'positive'],
#    ['세정', ['세정력 좋은것같아요', 16, 26], 'positive']]},
#  {'sentence_form': '아직 안써봤지만 향은 너무 좋아요! 크기가 생각보다 작았지만 잘 쓸게요',
#   'annotation': [['향', ['향은 너무 좋아요', 9, 18], 'positive']]},
#  {'sentence_form': '최근에 탈색이랑 염색많이해서 이제품 계속 썼는데 탈색했을때는 확실히 노란끼 많이잡아주고 쓰다보면 흰끼도는 탈색모가 되더라구요그리고 다른색상염색했을때는 확실히 일반샴푸보다 염색물빠짐이 적습니다 그래서 염색을 오래유자하게 도와줘요 근데 샴푸의 거품이 다른샴푸보다는 적은것같아서 이점이 좀아쉽습니다',
#   'annotation': [['거품',
#     ['거품이 다른샴푸보다는 적은것같아서 이점이 좀아쉽습니다', 134, 163],
#     'negative']]},
#  {'sentence_form': '🌱내돈내산 리뷰입니다!요즘 여름이라 그런지 지성이 아닌데도 불구하거 땀 때문인지 머리에 유분이 가득한거 같아서 구매해봄!향은 은은한 향이 나는데 생각보다 오래가서 맘에 듦!샴푸를 조금만 펌핑해도 거품이 풍성해서 긴 머리임에도 불구하고 샴푸를 좀 덜 써도 되서 매우매우 좋음!특히 유분기가 많이 정리되서 특히 좋음! 별 다섯개!단점은 가격대가 좀 있는 편인데 양이 적은거 같아서 아쉬움😢😢',
#   'annotation': [['향', ['향은 은은한 향이 나는데 생각보다 오래가서 맘에 듦', 67, 95], 'positive'],
#    ['거품', ['거품이 풍성해서', 109, 117], 'positive'],
#    ['세정', ['유분기가 많이 정리되서', 156, 168], 'positive'],
#    ['가격', ['단점은 가격대가 좀 있는 편', 182, 197], 'negative']]},
#  {'sentence_form': '뿌리는데 엄청 시원합니다.시긴하네요 다른 드라이샴푸와 마찬가지로 하얀색가루가 뿌려지고 열심히 비벼줘야합니다.생각보다 유분제거가 잘되었어요 향도 괜찮았구요',
#   'annotation': [['세정', ['시원합니다', 8, 13], 'positive'],
#    ['세정', ['유분제거가 잘되었어요', 65, 76], 'positive'],
#    ['향', ['향도 괜찮았구요', 77, 85], 'positive']]},
#  {'sentence_form': '몇번 써보지 않았지만 순하고 부드럽고 좋아요. 두피가 건조한것 같아 선택했는데 꽤 좋은듯 해요. 두가지 타입을 구매했는데 지성피부에 쓰는것 하루 수분 타입 하루 이렇게 쓰고 있어요. 좋아요!^^',
#   'annotation': [['자극', ['순하고 부드럽고 좋아요', 12, 24], 'positive']]},
#  {'sentence_form': '이거 넘 좋아요. 향도 은은하니 넘 좋고… 강추합니다. 샴푸',
#   'annotation': [['향', ['향도 은은하니 넘 좋고', 10, 22], 'positive']]},
#  {'sentence_form': '거의 한달 동안 사용하고 있는데 만족합니다. 거품은 부드럽고, 감고나면 머릿결 부드러워 져서 좋습니다.  감고나면 향은 오래가지 않은 편이지만 은은한 꽃내음 같은게 좋습니다. 세정력도 좋고 두피에 자극은 거의 없어서 만족합니다.',
#   'annotation': [['거품', ['거품은 부드럽고', 25, 33], 'positive'],
#    ['머릿결', ['머릿결 부드러워 져서 좋습니다', 40, 56], 'positive'],
#    ['향', ['향은 오래가지 않은 편이지만', 64, 79], 'neutral'],
#    ['향', ['은은한 꽃내음 같은게 좋습니다', 80, 96], 'positive'],
#    ['세정', ['세정력도 좋고', 98, 105], 'positive'],
#    ['자극', ['두피에 자극은 거의 없어서 만족합니다', 106, 126], 'positive']]},
#  {'sentence_form': '제형이 쫀쫀하면서도 묵직해요시카 성분이있기때문에 시카가 안맞다면 유의하세요!두피에 자극은 없지만 머릿결이 엄청 부드럽지도 않고 산뜻하고 가볍게 사용할수있어요! 세정력은 쏘쏘두피가 건조하고 건성이면 가렵거나 안맞을수 있는데 지성분들한테 추천해요~',
#   'annotation': [['자극', ['두피에 자극은 없지만', 42, 53], 'positive'],
#    ['머릿결', ['머릿결이 엄청 부드럽지도 않고', 54, 70], 'negative'],
#    ['세정', ['세정력은 쏘쏘', 89, 96], 'neutral']]},
#  {'sentence_form': '달리프가 여성브랜드인데 제가 쿨링샴푸 쓰는데남편이 너무 더워해서 달리프 쿨링샴푸 한번 써보라고줬는데 남편이 아주 좋다고 난리입니다두피 열도 내려주고 대만족 인거 같아요거품이 풍성하게 잘나고 무엇보다 내용물이 투명이라서 깨긋해여저자극에 탈모 완화 제품이라서 더 좋은거 같아요',
#   'annotation': [['쿨링', ['두피 열도 내려주고', 72, 82], 'positive'],
#    ['거품', ['거품이 풍성하게 잘나고', 93, 105], 'positive'],
#    ['자극', ['저자극', 126, 129], 'positive']]},
#  {'sentence_form': '(저는 드라이샴푸는 처음 써봤다는 거 참고해주세요)처음 써보는 거니까 설명서는 당연히 읽어봤어요. 읽어본대로 사용했을때 익숙치 않아서 만족스럽진 않았지만 여러번 해보니 어떻게 해야 하는지 알 것 같았어요. 몇 번 사용하니까 편해서 사길 잘 한 것 같다는 생각이 들었어요. 또 유분기 잡는 것도 잘 쓰면 굉장히 보송보송하게 잘 잡아줘요. 그리고 크기도 작아서 여행갈때 하나 챙겨가기 좋아요(약 12cm 정도). 근데 병에 향 이름이 안 적혀 있어서 향을 구분하기 어려웠는데 좀 불편했어요. 그리고 향은 사람마다 다르겠지만 저는 괜찮았어요. 향도 꽤 오래가는 편이에요. 그래서 저는 이 가격에 만족하는 것 같았어요.',
#   'annotation': [['세정', ['보송보송하게', 173, 179], 'positive'],
#    ['향', ['향도 꽤 오래가는 편이에요', 301, 315], 'positive'],
#    ['가격', ['이 가격에 만족하는 것 ', 324, 337], 'positive']]},
#  {'sentence_form': '너무 좋고 하나 더 살 생각이에요! 냄새는 취향이 아니지만... 가격과 용량이 혜자입니다!',
#   'annotation': [['향', ['냄새는 취향이 아니지만', 20, 32], 'negative'],
#    ['가격', ['가격과 용량이 혜자입니다', 36, 49], 'positive']]},
#  {'sentence_form': '두피가 간지럽고 비듬이나 각질로  샴푸를 찾아보던중 두피에 히알루론산으로 수분을 보충하고 유칼립투스로 두피를 진정시키고 비듬케어에 효과가 좋다는 후기를보고 닥터그루트 아쿠아 샴푸를 구매하였습니다 약산성에 계면활성제도 무첨가 라고 하니 믿고 사용할수 있을것 같아요 또한 탈모증상도 완화 된다고 하니 저희 부부에게 딱 필요한 샴푸인것 같아요 판매자에게 제품비의 일부를 지원받았지만 저의 솔직한 후기 입니다',
#   'annotation': [['자극', ['약산성', 109, 112], 'positive'],
#    ['탈모', ['탈모증상도 완화', 150, 158], 'positive']]},
#  {'sentence_form': '이거 쓰니까 기름기도 줄었고 머리 간지러움도 덜해요! 그래서 좋은데 벌써 다 써가지구 사야해요',
#   'annotation': [['세정', ['름기도 줄었고 머리 간지러움도 덜해요', 8, 28], 'positive']]},
#  {'sentence_form': '쎄일해서 저렴하게 샀어요용량이 작아진듯 그래도 이제품이 제일 시원하고 풍성해져요',
#   'annotation': [['가격', ['저렴하게 샀어요', 5, 13], 'positive'],
#    ['탈모', ['시원하고 풍성해져요', 34, 44], 'positive']]},
#  {'sentence_form': '감고나면 시워어어어언~~~~해요!!!! 향도 허브같은 향이라 제 취향이고 거품도 풍성해서 오랜만에 제대로된 지성용 샴푸 만난 것 같아요ㅠㅠ 그리고 패키지 넘 감성넘치는거 아닌가여,,, 다쓰고 통 재활용하고싶을 정도 ㅎ',
#   'annotation': [['향', ['향도 허브같은 향', 22, 31], 'positive'],
#    ['거품', ['거품도 풍성해서', 41, 49], 'positive']]},
#  {'sentence_form': '블라인드테스트에서 팬틴제품이 좋다고해서 구매해봤어요 저렴해용',
#   'annotation': [['가격', ['저렴해용', 29, 33], 'positive']]},
#  {'sentence_form': '앞머리 사이가 휑해지는걸 발견하고자 탈모방지 하고자 구매하게되었어요 대용량에다가 향도 은은해서 남녀 모두호불호 없이 사용가능해요^^탈모샴푸인데도 소량으로 거품이 많이 나와서긴 생머리인데도 오래 사용할거같아요 ㅎㅎ추천해요',
#   'annotation': [['향', ['향도 은은해서 남녀 모두호불호 없이 사용가능해요', 45, 71], 'positive'],
#    ['거품', ['거품이 많이 나와서', 86, 96], 'positive']]},
#  {'sentence_form': '저는 너무 지성이라서 지성들이 사용하는 샴푸나 성분이 안좋은 샴푸 사용하면 바로 비듬이나 각질이 너무많이 생기더라구요. 그래서 샴푸 선택이 너무 중요한 편이라 신중히 하는 편인데 후기글이 좋고 성분도 좋아서 구매해봤어요. 우선은 생각했던것보다 진짜로 냄새가 너무너무좋아서..반했어요 향기 대박이에요 ㅋㅋㅋ 샴푸로 머리 감을 때마다 기분좋아요ㅠ 거품도 잘나고 투명제형인데 세정력도좋고 기름지는것도 없이 너무너무 잘쓰고있어요~~~',
#   'annotation': [['향', ['새가 너무너무좋아서', 141, 151], 'positive'],
#    ['향', ['향기 대박이에요', 158, 166], 'positive'],
#    ['거품', ['거품도 잘나고', 192, 199], 'positive'],
#    ['세정', ['세정력도좋고 기름지는것도 없이', 207, 223], 'positive']]},
#  {'sentence_form': '애쉬 블루,그레이로 솜브레 옴브레 하고 애쉬라 보색 샴푸 필요할 것 같아서 사고 바로 한 달 내내 꾸준히 사용하다가 휴가 때 못 챙겨 가서 2박 3일 내내 일반 샴푸 쓰니까 보색 샴푸 쓰고, 안 쓰고의 차이가 명확히 보임,, 바로 원래 물 빠졌던 색깔로 돌아옴 ㅜ_ㅜ오늘 염색하러 갔는데 쌤이 어디 거 쓰냐고 물어볼 정도로  색 유지는 잘 되는데 그레이가 물 빠져서 카키 빛 나가지고 그 부분 좀 열심히 했는데 카키가 다시 그레이로 돌아오지는 않더라구요,,거기다가 샴푸가 골고루 듣는 게 아니라 어디는 제대로 들고 어디는 안 들고 해서 약간 얼룩 덜룩 해질 수는 있을 듯그래서 그 다음에 탈색을 할 때 전체적으로 탈색을 한다고 해도 톤이 균일하게 나오지 않아서 토닝은 필수! 토닝하고 탈색 하는 것 같던데 그러면 머리 진짜 개털될 수도,,?손에도 물들어서 원래 스카이블루 색상의 젤네일이옸는데 물들어서 좀 진해짐결론은 애쉬 블루로 염색 하신 분들한테 강추! 머리 감고 조금 부드러워지기는 하는데 그건 진짜 그냥 머리 감을 때 잠깐 일시적인 것 같아요 엄청 드라마틱하게 부드러워지고 그런 게 아니라서 극손상모들은 따로 에센스나 트리트먼트는 필수입니당',
#   'annotation': [['머릿결',
#     ['엄청 드라마틱하게 부드러워지고 그런 게 아니라서', 532, 558],
#     'neutral']]},
#  {'sentence_form': '머리 못 감은 날 볼륨도 줄 수 있으니까 진짜 괜찮은 것 같아요.머리 안 감은 거 티도 안나고 머리 냄새도 잘 잡아주는 것 같아요.',
#   'annotation': [['향', ['냄새도 잘 잡아주는', 56, 66], 'positive']]},
#  {'sentence_form': '염색했는데 너무 노란끼 돌아서 구매했어요. 가격도 저렴하고 보색효과도 좋아요!',
#   'annotation': [['가격', ['가격도 저렴하고', 24, 32], 'positive']]},
#  {'sentence_form': '다른종류쓰다가 이번에 이거 구매했는데나쁘지않고 거품많이생겨서 좋아요',
#   'annotation': [['거품', ['거품많이생겨서 좋아요', 26, 37], 'positive']]},
#  {'sentence_form': '바디워시랑 같은 향으로 구매했는데 거품도 풍성하고 두피자극이 없어 좋은거 같아요.다쓰면 또 같이 구매하려구요. 강추',
#   'annotation': [['거품', ['거품도 풍성하고', 19, 27], 'positive'],
#    ['자극', ['두피자극이 없어 좋은거', 28, 40], 'positive']]},
#  {'sentence_form': '두피는 극지성에 모발은 극건성인 완전 수부지형이에요. 클로란 샴푸 그냥 지성용 쓰다가 수부지용 나왔대서 바꿔봤는데 만족스러워요! 확실히 다른 샴푸로 감을 때 보다 덜 기름지고 감고 나서 상쾌해요.',
#   'annotation': [['세정',
#     ['다른 샴푸로 감을 때 보다 덜 기름지고 감고 나서 상쾌해요', 76, 108],
#     'positive']]},
#  {'sentence_form': '어릴때부터 너무 특이하게 머리가 지성이 심했어요 ,,다른 사람들은 귀찮으면 하루정도는 머리감기를 건너뛴다던데 그게 가능하나? 싶을 정도로 극 지성인 머리입니다ㅠㅠ 여름엔 반나절만에도 떡지는 개노답 머리였어요 그래서 쿨링샴푸, 지성샴푸, 천연샴푸, 샴푸바 여러개 사용해보고 있는데 드디어 클로란을 써보네요 처음 나왔을때만 해도 할인보다는 증정만 껴주고, 가격대가 꽤나 있는 편이라 펜트하우스 사는 사람들만 쓰는 건 줄 알았는데^^ 성공한 인생이라고 해주십쇼^^향..은.. 시트러스라고 해서 라임향, 모히또향 같은 걸 생각했는데 약간ㅋㅋ남동생들 스킨 냄새나요 아빠..까지는 아니고.. young man들의 skin care^^ 냄새같은.. 근데 향을 중시하는 스타일은 아니라 이건 큰 문제 없었어요세정력은 뭐..확실히 지성용 두피라 그런지 빨리 떡지거나 하지는 않아요! 샴푸 노답인거 쓰면 두피에 뾰루지 올라오는데 그렇지도 않고요 그래도 제가 워낙 초극지성이라 매일 감아야 한다는 사실은 변하지 않습니다..^^인생샴푸다! 할 정도는 아닌 거 같구요 다 써보고 또 유목생활을 할 거 같긴 합니다.. 더 써봐야 알 거 같아요 (〃⌒▽⌒〃)ゝ',
#   'annotation': [['가격', ['가격대가 꽤나 있는 편이라', 197, 211], 'negative']]},
#  {'sentence_form': '가격이 비싸 만큼..향기도좋고 상품도 좋네용대박~~~입니다',
#   'annotation': [['가격', ['가격이 비싸', 0, 6], 'negative'],
#    ['향', ['향기도좋고', 11, 16], 'positive']]},
#  {'sentence_form': '만족 만족 대만족이요ㅠㅠ시중에 나오는 샴푸들 탈모방지의약품도 아닌데그거 믿고 계속 쓰다가 요번에로레알로 염색한김에 써보고 반해서그냥 와장창 주문했어요 재구매 의사 있구요이것만 쓸거에요 컬도 좋아지고 더군다나색도 덜빠지는거 같구 ㅠ 중요한건 풍성해보여요',
#   'annotation': [['머릿결', ['컬도 좋아지고', 103, 110], 'positive']]},
#  {'sentence_form': '남동생이 쓰고 너무 만족해해서 뿌듯했습니다 자극없고 머릿결도 뻑뻑하지않고 거품도 딱이라고 세정력도 좋다고 했습니다 재구매의사있다고 해서 그럼 말 다했지 생각했어요 추천합니다 주변 지인에게도 좌표보내줬습니다 머리숱 부자되는 그날까지 함께해요 머리카락 하나도 너무 소듕하니까요~~',
#   'annotation': [['자극', ['자극없고', 24, 28], 'positive'],
#    ['머릿결', ['머릿결도 뻑뻑하지않고', 29, 40], 'neutral'],
#    ['거품', ['거품도 딱이라고', 41, 49], 'positive'],
#    ['세정', ['세정력도 좋다고', 50, 58], 'positive']]},
#  {'sentence_form': '쫀쫀한 제형이어서 많이 펌핑하지 않았는데도 거품이 잘 나서 좋아요. 다만 물로 씻어헹구면 다시 머릿결이 뻣뻣해져요. 좀더 써봐야 알 것 같아요.',
#   'annotation': [['거품', ['거품이 잘 나서 좋아요', 24, 36], 'positive'],
#    ['머릿결', ['다시 머릿결이 뻣뻣해져요', 50, 63], 'negative']]},
#  {'sentence_form': '샴푸하고나면 파우더리한 머스크 향이 나요 ^^*처음엔 향때문에 썼는데지금은 샴푸 기능이 좋아 사용합니다.저는 샴푸를 잘못쓰면 두피에 가려움을 느낍니다.이 샴푸는 그런게 없어요~머리 말린 후 두피쪽 헤어를 만져보면 노폐물이 깔끔하게 제거 된 느낌과 함께 부드러운 머릿결이 느껴져서 좋습니다.',
#   'annotation': [['세정', ['노폐물이 깔끔하게 제거', 119, 131], 'positive'],
#    ['머릿결', ['부드러운 머릿결이', 141, 150], 'positive']]},
#  {'sentence_form': '📌 정착템이었지만 여름에는 추천 ❌✅ 장점몇 년간 사용중인.. 저는 향에 예민한 편이라 샴푸도 조심히 사용?하는데 이건 참 좋거등요 ㅎㅎ✅ 단점지성두피는 솔직히 비추합니다 여름되니까 개기름이 대박.. 약간 개운하지 않았어여.. 겨울에는 뽀송했지만 ,, ㅠ🍯 꿀팁린스 말고!!! 진짜 린스는 말고.. 트리트먼트!!!!!랑 궁합 조음!!',
#   'annotation': [['향',
#     ['향에 예민한 편이라 샴푸도 조심히 사용?하는데 이건 참 좋거등요', 38, 73],
#     'positive'],
#    ['세정', ['개운하지 않았어여', 115, 124], 'negative']]},
#  {'sentence_form': '극지성이라 여름 후 두피에 대한 고민이 많아서 찾아보다 구매하게 됐어요다른 샴푸로는 아침에 감으면 늦은 오후쯤엔 떡져서 스트레스 받았는데 이건 밤까지 보송보송 유지가 되어 너무 맘에 들어요패키지도 예뻐서 너무 잘 쓸 거 같아요',
#   'annotation': [['세정', ['보송보송 유지가 되어', 84, 95], 'positive']]},
#  {'sentence_form': '또 구입했어요! 4인 가족이 함께 사용하니까 금방 쓰게되네요ㅋㅋ제 두피는 복합성인데 가장 마음에 든 점은 두피가 뽀송해지는 점이예요^^! 오후만 되면 머리에 기름이 잘 지는편인데..그렇다고 또 지성두피는 아니거든요ㅠㅠ이 제품을 사용하고나서는 두피 기름이 확실히 줄어들었어요! 그리고 샴푸 거품도 풍성하게 잘 나고 향도 시원한 향이라 개운해요👏🏻👏🏻근데 샴푸 향은 오래가지않아요~ 그리거 제 머리카락은 극 손상모예요.. 이 샴푸는 머릿결을 부드럽게 해줘서 좋아요. 손상모인데 뻣뻣한 샴푸 사용하면 개털 되는 느낌 아시죠.. 이샴푸는 그런거1도 없이 오히려 부드러워서 추천합니다!',
#   'annotation': [['세정', ['가장 마음에 든 점은 두피가 뽀송해지는 점이예요', 47, 73], 'positive'],
#    ['세정', ['두피 기름이 확실히 줄어들었어요', 135, 152], 'positive'],
#    ['거품', ['거품도 풍성하게 잘 나고', 161, 174], 'positive'],
#    ['향', ['향도 시원한 향이라 개운해요', 175, 190], 'positive'],
#    ['머릿결', ['는 머릿결을 부드럽게 해줘서 좋', 238, 255], 'positive']]},
#  {'sentence_form': '제품 좋은 거 알지만 할인할 때 구매하고 싶어서 이번에 또 구매했아요! 은은한 향과 점성력이 약한 데에 비해 풍성한 거품이라 늘 잘 사용합니다! 할인하면 너무 좋아요!',
#   'annotation': [['향', ['은은한 향', 40, 45], 'positive'],
#    ['거품', ['풍성한 거품', 61, 67], 'positive']]},
#  {'sentence_form': '기름기는 잘 잡아주는 편인데 하얗게 되는게 심해서 많이 털어줘야 해요 향도 머리 냄새는 잡아주지만 너무 진해서 누가 맡아도 뭐 뿌렸다 생각할 것 같아요 엄청 좋은 향도 아니라고 느꼈습니다 전체적으로 아쉬운 제품ㅠ 휴대용으로는 좋을 것 같네요 다음엔 오리지널로 구매하려구요',
#   'annotation': [['세정', ['기름기는 잘 잡아주는 편', 0, 13], 'positive'],
#    ['향', ['향도 머리 냄새는 잡아주지만 너무 진해', 39, 60], 'negative'],
#    ['향', ['엄청 좋은 향도 아니라고 느꼈습니다', 85, 104], 'negative']]},
#  {'sentence_form': '신상티켓팅 통해서 저는 샴푸로 받아서 사용해 봤습니다!사실 샴푸는 보통 쓰는 것만 쓰다보니까 트린트먼트로 왔으면 좋겠다 싶었는데 하필 샴푸가 와서 좀 아쉬웠거든요..? 아니 근데 이거 왜이렇게 좋나요...? 사용해보니 완전 대대대만족이라 깜짝 놀란 제품이에요🥹👍🏻✔️일단 제가 가장 만족한건 볼륨효과와 향인데요! 제가 샴푸에서 가장 중요하게 생각하는 두가지거든요. 그걸 충족시키는 샴푸가 거의 없는데 드디어 발견한 그런 기분이에요..🥹제가 완전 심한 파워직모 생머리라 어떤 샴푸를 쓰면 너무 축 가라앉거나, 정전기가 너무 심하거나, 볼륨효과가 있으면 향이 별로고 그런 불만족스러운 제품이 많았거든요.사실 볼륨효과와 향 두가지 전부 갖춘 제품은 찾지를 못해서 그냥 볼륨효과 포기하고 향만 선택해서 엘라스틴 실크리페어만 쓰고 있거든용로레알 제품이라 아무래도 트린트먼트&헤어오일 이미지가 강해서 이것도 엄청 머릿결 좋은~촤르르한 느낌의 샴푸겠구나 생각했는데 감을 때 부터 왜 볼륨효과가 있는건지 느껴지더라구요! 다른 제품은 물로 씻어낼 때 너무 부드러우면 저는 무조건 챡 달라붙는 경우가 많았는데, 이건 아주 살짝 (뻣뻣까진 아니고) 단단히 머릿결이 잡히는 그런 정도..!! 그게 딱 느껴지더라구요.근데 또 너무 기름기 없애면서 뻣뻣한 느낌은 머리 빗을 때도 엉키고 그런 불편스러운게 있거든요..? 근데 로레알은 말리고 빗을 때 부드러운데 볼륨효과도 있어서 진짜 신기했어요ㅠㅠ 라방 때 볼륨효과가 있다고 하셔서 호기심+기대감이 있었는데 진짜라 너무 좋고 신기했어요,,\U0001fa77감고 말리고나서 정수리쪽 보면 뿅 하고 볼륨효과가 느껴진답니다..🫢🤍근데 향은 또 대박 좋았던.. 진짜 풍부한 플로럴 향인데 호불호 크게 없을 것 같은 플로럴 향이라고 느꼈어요! 제가 향때문에 엘라스틴 실크리페어 샴푸만 10년 넘게 쓰고 있는데, 그거만큼 만족스러워서 인생샴푸 발견한 느낌입니다🥹다쓰면 무조건 구매해서 쓸 예정이에요!!!🫶🏻',
#   'annotation': [['세정',
#     ['또 너무 기름기 없애면서 뻣뻣한 느낌은 머리 빗을 때도 엉키고 그런 불편스러운게 있거', 615, 662],
#     'positive'],
#    ['머릿결', ['은 말리고 빗을 때 부드러', 674, 688], 'positive'],
#    ['향', ['데 향은 또 대박 좋', 802, 813], 'positive'],
#    ['향', ['데 호불호 크게 없을 것 같은 플로럴 향이라고 느꼈', 831, 859], 'positive']]},
#  {'sentence_form': '체험단으로 사용해 봤는데 일단 거품이 너무 잘나서 좋았고요 자극 없이 두피 세정이 잘 돼서 좋았어요 솔직히 개인적으로 선호하는 향은 아니어서 살짝 아쉬웠지만 그래도 향 빼고는 다 너무 만족했어요 체험단 이벤트 진행해 주셔서 좋고 다음에 또 진행하면 좋겠어요~^^',
#   'annotation': [['거품', ['거품이 너무 잘나서', 17, 27], 'positive'],
#    ['자극', ['자극 없이', 33, 38], 'positive'],
#    ['세정', ['피 세정이 잘 돼서 좋았어요', 40, 55], 'positive'],
#    ['향', ['개인적으로 선호하는 향은 아니어서', 60, 78], 'neutral']]},
#  {'sentence_form': '향도 좋고 바쁜 아침, 늦은 오후에 편하게 잘 사용하고 있습니다',
#   'annotation': [['향', ['향도 좋고', 0, 5], 'positive']]},
#  {'sentence_form': '인생 샴푸! 벌써 몇번째 재구입인지도 모를정도로 떨어지지 않게 쟁여두는 제품입니다.항상 333ml 용량만 쓰다가, 이번에 대용량이 나오고 또 세일까지 하길래 반가운 마음에 구입했어요. 참고로 사진은 평소에 쓰던 333ml와 이번에 구입한 750ml 사이즈 비교입니다. 생각보다 큰 사이즈에 조금 놀랐지만, 저같이 롱헤어에 숱 많아서 금방 한통 비우는 사람은 이렇게 대용량이 좋네요 플라스틱 쓰레기도 줄고.. 이 샴푸는 적게 써도 거품이 풍성하게 나고, 혹시 잘 안난다면 물을 조금만 더하면 금새 뭉게뭉게 피어오르는 거품을 볼 수 있을거예요. 다른 샴푸들에 비해 뻣뻣해지지도 않으면서 세정력이 약하지도 않아서, 샴푸로서는 최고라고 생각합니다. 단지, 머리카락이 덜빠지는 건 잘 모르겠어요.. 저한테는 인생샴푸라서 앞으로도 계속 구입할 예정이니 제발 오래오래 판매해 주세요|',
#   'annotation': [['거품', ['거품이 풍성하게 나고', 240, 251], 'positive'],
#    ['머릿결', ['뻣뻣해지지도 않으면서', 314, 325], 'positive'],
#    ['세정', ['세정력이 약하지도 않아서', 326, 339], 'positive'],
#    ['탈모', ['머리카락이 덜빠지는 건 잘 모르겠어요', 363, 383], 'neutral']]},
#  {'sentence_form': '향이 좋아서 성분이 독할거라고 생각했는데 예상외로 순하고 깔끔하게 씻겨요',
#   'annotation': [['향', ['향이 좋아서', 0, 6], 'positive'],
#    ['자극', ['순하고', 28, 31], 'positive'],
#    ['세정', ['깔끔하게 씻겨요', 32, 40], 'positive']]},
#  {'sentence_form': '수영으로 인한 푸석함하루 두번 아침, 저녁 샴푸를 하다보니 머릿결이 많이 푸석해지고 빠지는것 같아서 구매해 보았습니다올리브영 온라인몰에서 구매해서 당일 받았고사용해보니 이런 샴푸는 거품이 잘 나지 않는데잘나고 냄새도 저한테는 잘맞는것 같아요닥터 그루트 만족이에요',
#   'annotation': [['거품', ['이런 샴푸는 거품이 잘 나지 않는데잘나고', 94, 116], 'positive'],
#    ['향', ['냄새도 저한테는 잘맞는것 같아요', 117, 134], 'positive']]},
#  {'sentence_form': '요즘 두피가려움도 심하고 머리카락 상태도 좋지 않아서 샴푸 바꿔봤는데 괜찮은듯해요 자극도 없고 맥주효모 덕분인지 두피도 깔끔하게 씻기네요 ㅎ 잘써볼게요',
#   'annotation': [['자극', ['자극도 없고', 46, 52], 'positive'],
#    ['세정', ['깔끔하게 씻기네요', 67, 76], 'positive']]},
#  {'sentence_form': '좀 상쾌한 샴푸 써보고 싶어서 사봤어요!향도 민트향 폴폴나고 샴푸하고 방치해두면 두피 좀 시원해집니다근데 그 정도가 엄청 심하진않아요! 거품도 잘 나고 두피에 자극도 없어서 잘 쓰고 있습니다! 근데 사용후에 머리가 조금 뻣뻣해 지는 느낌이라 트리트먼트를 같이 써주고 있어요!',
#   'annotation': [['세정', ['두피 좀 시원해집니다', 45, 56], 'positive'],
#    ['거품', ['거품도 잘 나고', 76, 84], 'positive'],
#    ['자극', ['두피에 자극도 없어서', 85, 96], 'positive'],
#    ['머릿결', ['머리가 조금 뻣뻣해 지는 느낌', 116, 132], 'negative']]},
#  {'sentence_form': '제품을 써보니  세정력이 좋아요 머리를 감으면서 좀 뻑뻑한 느낌이 들기는 했는데 머리를 감고나서는 뻣뻣한 느낌은 없더라구요. 근데 다만 아쉬운건 거품은 풍성하게 나진 않았어요 그래도 기름기가 쫘악 씻기는 느낌은 좋았고 향도 달콤하면서도 시원해서 괜찮더라구요. 그리고 머리를 다 말리고 나서는 간지러운 두피가 잠잠해져서 효과가있구나 라고 생각이 들었어요.개인적으로 만족스러운 제품이네요',
#   'annotation': [['세정', ['세정력이 좋아요', 9, 17], 'positive'],
#    ['머릿결', ['머리를 감고나서는 뻣뻣한 느낌은 없더라구요', 45, 68], 'neutral'],
#    ['거품', ['거품은 풍성하게 나진 않았어요', 81, 97], 'negative'],
#    ['세정', ['기름기가 쫘악 씻기는 느낌은 좋았고', 102, 121], 'positive'],
#    ['향', ['향도 달콤하면서도 시원해서 괜찮더라구요', 122, 143], 'positive'],
#    ['세정', ['간지러운 두피가 잠잠해져서 효과가있구나', 163, 184], 'positive']]},
#  {'sentence_form': '일단 향이 너무너무 제스탈입니다향 지속력도 오래가서 좋았어요 ㅎㅎㅎ그리고 거품도 잘나고 두피에 트러블 없는걸 보니 순한거같아요 그리고 양도 많고!!! 제 인생샴푸가 되었습니다',
#   'annotation': [['향', ['향이 너무너무 제스탈입니다향 지속력도 오래가서 좋았어요 ', 3, 34], 'positive'],
#    ['거품', ['거품도 잘나고', 41, 48], 'positive'],
#    ['자극', ['순한거같아요', 64, 70], 'positive']]},
#  {'sentence_form': '건성 두피인데 탈모고민이라면! 모이세요!#달리프 릴렉싱 샴푸 ✔️저는 지성 두피인데 사용해보니까 유분감이 많더라구용 ㅠㅠ 그래서 이건 저희 가족들이 쓰세요! 지성두피보단 건성 두피분들에게 추천 드립니다 ✔️제품특징➡️두피에 좋은 천연 성분이 모발탈락증상 안화➡️특허받은 한방 추출물로 풍성하고 볼륨있는 모발로 만들어줍니다➡️두피 탄력+ 유수분 밸런스+ 딥클렌징+ 두피 영양 진정☑️전체적인 후기✔️제형은 흐르는 물제형입니다!✔️향은 약간 시원한 오이냄새?(호불호 주의)✔️거품 양은 많고 세정력 좋습니다!✔️건성두피에겐 촉촉하지만 지성두피에겐 유분으로 떡 질수도 있어요...😭➡️그래서 건성 두피분들에게 추천 드립니다✔️확실히 두피진정에는 효과는 있는듯 해요!👎🏻아쉬운 점 ➡️지성 두피에겐 유분감이 많음 (비추..)➡️호불호 갈릴 수 있는 향 (오이냄새)🙆🏻\u200d♀️이런분들에게 추천 드려요✔️순한 샴푸 찾으시는 분✔️중 건성 두피 이신분들 ✔️순한 탈모샴푸 찾으시는 분',
#   'annotation': [['머릿결', ['출물로 풍성하고 볼륨있는 모발로 만들', 155, 175], 'positive'],
#    ['향', ['제형입니다!✔️향은 약간 시원한 오이냄새', 231, 253], 'neutral'],
#    ['거품', ['호불호 주의)✔', 255, 263], 'positive'],
#    ['세정', ['거품 양은 많고', 264, 272], 'positive'],
#    ['자극', ['천 드립니다✔️확실히 두피진정에', 339, 356], 'positive'],
#    ['자극', ['🙆🏻\u200d♀️', 423, 428], 'positive']]},
#  {'sentence_form': '자신의 두피별로 맞춰 구매하는 샴푸가 있길래 제가 원하는 타입으로 구매했습니다. 저자극으로 각질케어 용인데 일단 거품도 괜찮고 사용감도 무난했던 제품. 약간 네가지 타입 중 비컨피던트가 제일 무난한 것 같아요. 잘 맞았고 나중에 린언미도 한번 써보고 싶네요. 샴푸용으로 무난하게 맘에 든 제품입니다.',
#   'annotation': [['자극', ['저자극', 45, 48], 'positive'],
#    ['거품', ['거품도 괜찮고', 63, 70], 'neutral']]},
#  {'sentence_form': '탈모샴푸인데 거품도 많이나고 좋은것 같아요뻣빳하지않아요',
#   'annotation': [['거품', ['거품도 많이나고', 7, 15], 'positive'],
#    ['머릿결', ['뻣빳하지않아요', 23, 30], 'positive']]},
#  {'sentence_form': '잘 사용하고 있어요. 성분도 좋고 샴푸 후에 모발이 부드러워요.',
#   'annotation': [['머릿결', ['모발이 부드러워요', 25, 34], 'positive']]},
#  {'sentence_form': '살짝 되직함향 괜찮고 거품 잘 남가성비 좋은 샴푸머리 기름 잘 지는 편이면 추천 안 함',
#   'annotation': [['거품', ['거품 잘 남', 12, 18], 'positive'],
#    ['가격', ['가성비 좋은 샴푸', 18, 27], 'positive'],
#    ['세정', ['기름 잘 지는 편이면 추천 안 함', 30, 48], 'neutral']]},
#  {'sentence_form': '한 번 구매하고선 계속 구매하게되는 제품이네요. 세척력이 좋고 두피에 자극적이지도 않습니다. 무엇보다 제일 마음에 드는건 향이 너무 좋아요.',
#   'annotation': [['세정', ['세척력이 좋고', 27, 34], 'positive'],
#    ['자극', ['두피에 자극적이지도 않습니다', 35, 50], 'positive'],
#    ['향', ['향이 너무 좋아요', 68, 77], 'positive']]},
#  {'sentence_form': '우선 민감 지성두피라서 샴푸를 고를 때 민감한데이거 전에는 이니스프리 그린티 민트샴푸와아로마티카 로즈마리, 티트리를 썼었어요.이니스프리 샴푸는 성분이 안 좋았고아로마티카 제품은 성분은 좋은데쓰다가 보니까 자꾸 석유 냄새가 나는 듯 해서결국 이것저것 찾아보다가 세일하는 김에사용해 보게 되었다가 완잔 반했어요우선 향은 시원한 민트향이고오래 사용해도 석유 냄새 같은건 안 나요머리를 삼일 정도 안 감았다가 감아봐도한 방에 개운해지고 무엇보다 정수리 냄새가 안 나서 아주 만족한답니다.클로란 시트러스와클로란 피오니와클로란 석류도 써 봤는데클로란 민트가 가장 좋아요샴푸 성분 중에서 멘톨이 들어 있어서사용 후에 두피에 화한 감이 나는데 아주 심하지는 않고 딱 적당하게 화해서 좋더라구요색상은 파란색 그대로 투명하구요일반 샴푸보다 조금 되직해서펌프형 용기에 옮겼을 때는 잘 안 나오기도 하더라구요그래서 이 제품은 기존 용기 그대로 쓰는게 좋아요향기는 밤까지 지속되기는 하는데쿤달보다는 정수리 냄새가 빨리 나는 편이에요아침에 쓰면, 지성두피고 땀이 많이 난다면밤에는 꿉꿉한 향으로 변하는 편이라서 케바케에요아예 정수리 냄새가 산경쓰일때는전 이거랑 같이 이브로쉐 모링가 헤어식초를 같이 써요그러면 완벽하게 향기로 마무리되고 아주 좋아요.지성두피에게 강추합니다.',
#   'annotation': [['향', ['시원한 민트향', 177, 184], 'positive'],
#    ['세정', ['개운해지고', 234, 239], 'positive']]},
#  {'sentence_form': '헤어 토닉 사용하고 샘플로 받은 샴푸가맘에들어서 본품까지 구매하게 됌지성두피인데 시원하고 뽀득하게 씻김',
#   'annotation': [['세정', ['시원하고 뽀득하게 씻김', 45, 57], 'positive']]},
#  {'sentence_form': '제 최애 샴푸에요. 기름기도 잘 잡아주고 무엇보다 정수리 냄새에 좋은것 같아요. 오후 시간 되도 그렇게 떡지지 않고 불쾌한 냄새 안나서 넘 맘에 들어요',
#   'annotation': [['세정', ['기름기도 잘 잡아주고', 11, 22], 'positive']]},
#  {'sentence_form': '팬틴 거품도 잘나고 향도 좋아서 재구매했음ㅎㅎ',
#   'annotation': [['거품', ['거품도 잘나고', 3, 10], 'positive'],
#    ['향', ['향도 좋아서', 11, 17], 'positive']]},
#  {'sentence_form': '쓰면 머릿결이 정갈해져서 좋아요 향도 좋고 가성비 좋은거추천드려요',
#   'annotation': [['머릿결', ['머릿결이 정갈해져서 좋아요', 3, 17], 'positive'],
#    ['향', ['향도 좋고', 18, 23], 'positive'],
#    ['가격', ['가성비 좋은거', 24, 31], 'positive']]},
#  {'sentence_form': '2년 전에 꾸준히 1년 정도 사용하다가  이번에 재구매하게되았어요. 돌고 돌아 라우쉬내요. 몇달전부터 두피 트러블이 올라오고, 지루성 피부염까지 올라와서 다시 돌아오게 되었어요. 사용해보시면 아시겠지만 두피에 편안한 성분으로 구성된 약같은 샴푸에요. 뭔가 두피가 개선이 되면서 치료가 되는 느낌이랄까요. 그래서인지 지루성 두피염도 좋아지고 있고, 가려움도 많이 줄었어요. 그리고 성분이 좋은 샴푸들이 대게 거품이 잘 안나는데요. 이 제품은 라우쉬 라인 중에서도 거품이 잘나는 편이에요. 그래서 답답하지 않게 세정이 잘 됩니다. 거기에 더해서 뻣뻣하게 세정이 되지 않아서 좋아요. 라우쉬 라인 중에서 두피가 편안하고, 거품이 잘 나는 제품을 찾으신다면 이 콜츠푸드 샴푸를 선택하시면 됩니다. 추천해요.',
#   'annotation': [['자극', ['두피가 개선이 되면서 치료가 되는 느낌', 143, 164], 'positive'],
#    ['거품', ['거품이 잘나는 편이에요', 258, 270], 'positive'],
#    ['세정', ['세정이 잘 됩니다', 284, 293], 'positive'],
#    ['머릿결', ['뻣뻣하게 세정이 되지 않아서 좋아요', 303, 322], 'positive'],
#    ['자극', ['두피가 편안하고', 335, 343], 'positive'],
#    ['거품', ['거품이 잘 나는', 345, 353], 'positive']]},
#  {'sentence_form': '요즘같이 여름에 금방 머리도 떡지고 하는데 간편하게 사용할 수 있는 드라이샴푸가 있다고해서 구매해봤어요!!우선 휴대하기 편해서 외출해서도 잠깐 화장실가서 톡톡 두들겨주면 기름기를 빠르게 잡아줘서 좋았고 파우더 형식이라 머리카락에 하얗게 남을줄 알았는데 두들기고 살짝 손으로 털어주면 하얀끼가 금방 사라져서 좋았습니다~!!지성 두피한테는 있으면 굉장히 좋을만한 제품이에요 :)',
#   'annotation': [['세정', ['기름기를 빠르게 잡아줘서 좋았고', 95, 112], 'positive']]},
#  {'sentence_form': '👨\u200d🔬닥터그루트는 과학입니다👩\u200d🔬 2탄 트리트먼트트리트먼트는 다 똑같다?아닙니다. 닥터그루트가 만들면 다릅니다.올영체험단을 통해 닥터그루트를 처음 만났습니다. 삼푸를 받아서 써봤는데, 한두 번 써보고 그럭저럭 괜찮다고 느꼈고, 일주일 정도 써보니 꽤 좋다고 생각했고, 한 달쯤 쓰니까 가족들이 먼저 머릿결이 좋아지고 머리숱이 늘어난 걸 알아봤습니다. 그래서 다 쓰자마자 샴푸와 트리트먼트를 모두 구입했습니다.윤기가 도는 흰색 크림 제형입니다. 밀도케어 샴푸처럼 민트향이 납니다. 물을 묻힌 뒤 두피부터 모발까지 문지릅니다. 두피를 제외하고 모발에만 사용하는 트리트먼트도 있는데 이 제품은 두피와 모발에 모두 사용해도 됩니다.두피부터 모발까지 마사지하듯 문지르면 하얀 크림이 투명하게 바뀝니다. 충분히 마사지한 뒤 물로 쓱쓱 씻어내면 뽀득뽀득하게 닦입니다. 아무리 닦아내도 미끌거리는 트리트먼트만 써봤는데... 이제라도 이런 제품을 알게 되어 다행입니다.가볍고 개운한 사용감을 가진 트리트먼트를 찾는다면 바로 이 제품을 써보시길 추천합니다.',
#   'annotation': [['머릿결', [' 먼저 머릿결이 ', 163, 172], 'positive'],
#    ['탈모', [' 늘어난 걸 알아봤습니다. 그래', 181, 198], 'positive']]},
#  {'sentence_form': '샴푸가 저렴하고 거품이 잘나서 좋아요 향기로워요~! 추천합니다',
#   'annotation': [['가격', ['샴푸가 저렴하고', 0, 8], 'positive'],
#    ['거품', ['거품이 잘나서 좋아요', 9, 20], 'positive'],
#    ['향', ['향기로워요', 21, 26], 'positive']]},
#  {'sentence_form': '두피가 지성이라 겨울인데도 저녁만 되면 앞머리가 심하게 갈라져서 구매해봤습니다!!가지고 다니면서 오후에 뿌리려고 작은 사이즈로 구매했는데 한 번 쓰고 방치해뒀어요...향이 너무너무 별로가 효과가 좋아도 역해서 기분이 안 좋아지더라구요ㅜㅜ향이 또 금방 사라지지 않고 감을 때까지 지속돼서 더 큰일... 약간 울렁거리는 향에 예민하신 분은 고민해보시는게 좋을듯해요!!',
#   'annotation': [['향', ['향이 너무너무 별로', 93, 103], 'negative'],
#    ['향', ['울렁거리는 향', 171, 178], 'negative']]},
#  {'sentence_form': 'ㅠㅠ다른 드라이샴푸에비해 그렇게 효과가 좋지는 않아여쪼꼬만놈 휴대하기 편해보이길래 샀어여..향도 좋고 분사도 잘 됨',
#   'annotation': [['향', ['향도 좋고', 51, 56], 'positive']]},
#  {'sentence_form': '향이 너무 좋아요 그리고 적은양을 사용해도 거품이 풍성해서 너무나 좋습니다 두피가 예민한편인데 예민한거 치고는 전혀 자극적이지않아서 너무 사용하기 좋은것같아요  오후가되면 기름이 많이지는데 이걸로 사용하고나서는 기름짐도 덜하고 세정력이 아주 좋은것같습니다. 너무 만족도가 높아서 후기까지 쓰게되네요 ㅋ',
#   'annotation': [['향', ['향이 너무 좋아요', 0, 9], 'positive'],
#    ['거품', ['거품이 풍성해서 너무나 좋습니다', 24, 41], 'positive'],
#    ['자극', ['자극적이지않아서 너무 사용하기 좋은것같아요', 65, 88], 'positive'],
#    ['세정', ['기름짐도 덜하고 세정력이 아주 좋은것같습니다', 118, 142], 'positive']]},
#  {'sentence_form': '시원한허브향ᆢ제형이좀묽지만머리에천연성분이라자극이없을것같아중학생아들과같이사용해요~~',
#   'annotation': [['향', ['시원한허브향', 0, 6], 'positive'],
#    ['자극', ['천연성분이라자극이없을것', 17, 29], 'positive']]},
#  {'sentence_form': '아직 하루밖에 안써봤지만 거품이 풍성하고 세정력이 좋아요! 비듬개선에도 효과 있으면 좋겠우요~',
#   'annotation': [['거품', ['거품이 풍성하고', 14, 22], 'positive'],
#    ['세정', ['세정력이 좋아', 23, 30], 'positive']]},
#  {'sentence_form': '출시하자마자 지금까지 몇통째 구매했는지 모를정도로매일 너무 잘 쓰고 있어용!어떤 샴푸로 감든 (심지어 두피전용 샴푸로 감아도)머리가 항상 가려웠는데 이 샴푸를 쓰고 나서는 가려움증은 물론 뾰루지까지 나았어요좀 비싼감이 있지만 진짜 두피에는 너무 좋은 샴푸에요이거 쓰고 휑했던 가르마가 채워졌어요두피 볼륨도 잘 생기고..정수리 냄새도 커버 가능합니다그리고 아무리 두번 세번 감아도 머릿결이 엄청 부드러워요!저는 이 샴푸 쓸 땐 트리트먼트를 따로 안한답니다그렇다고 유분이 많은 샴푸는 절대 아니에요!!',
#   'annotation': [['세정', ['가려움증은 물론 뾰루지까지 나았어요', 96, 115], 'positive'],
#    ['가격', ['비싼감이 있지만', 117, 125], 'negative'],
#    ['머릿결', ['머릿결이 엄청 부드러워요', 212, 225], 'positive']]},
#  {'sentence_form': '나이들면 기름이 준다는데 왜 늘어나는 거죠 저는..?ㅠ아침에 머리감아도 점심이면 슬슬 떡져서 넘 스트레스 받다가 검색끝에 샀습니다! 양 대비 비싸서 고민했는데 한번쓰고 바로 두통 더 쟁였어요.. 이제 이거 없음 안돼ㅠ',
#   'annotation': [['가격', ['양 대비 비싸서', 74, 82], 'negative']]},
#  {'sentence_form': '거품이 잘 나서 뽀득뽀득 잘 씻깁니다. 저렴하고 편해서 아주 좋아요',
#   'annotation': [['거품', ['거품이 잘 나서', 0, 8], 'positive'],
#    ['세정', ['뽀득뽀득 잘 씻깁니다', 9, 20], 'positive'],
#    ['가격', ['저렴하고', 22, 26], 'positive']]},
#  {'sentence_form': '이거 샴푸 정말 좋네요. 부모님도 쓰시라고 재구매예요. 제가 정말 많은 샴푸들 써봤는데 정말 손에 꼽히는 마음에 드는 샴푸예요. 두피 트러블이 나서 너무 유분이 있어도 안되고 건조해도 안되고 예민하거든요. 닥터방기원 랩샴푸는 제 두피에 딱 맞는 제품이예요. 두피에 자극 없고 씻고 나면 상쾌해요. 이런 제품들이 오래 쓸 수 있는 좋은 제품인 것 같아요. 주변에 소문내고 다니고 있어요 ㅋㅋ',
#   'annotation': [['자극', ['두피에 자극 없고', 144, 153], 'positive'],
#    ['세정', ['상쾌해요', 160, 164], 'positive']]},
#  {'sentence_form': '이번에 탈색하먼서 알아보다가 구매하게 됐는데 원래 헤어플러스꺼 에센스를 쓰고 있어서 구매했어요 !!올리브영애서도 후기가 제일 많더라구요 ㅋ  기대했는ㄷㅔ 역시나 좋더라구요 !! 보색샴푸인데 향도 엄청 좋아요 !!! 확실히 컬러가 덜 빠지는 느낌이 들어요! 그리고 감고나서도 부드러운 느낌이구영! 탈색모애는 무조건 보색샴푸 써야한다고 하는데 해어플러스가 가성비도 좋고 헤어제품으로 유명하니깐 사용할 이유는 충분한거 같아요!그리고 제품 나오는 입구도 스티커로 막아져 있어서 위생적으로 보였어요 향도 좋구 가성비도 젛구 탈색모애게 추천하는 샴푸입니다 ~~~~',
#   'annotation': [['향', ['향도 엄청 좋아요', 106, 115], 'positive'],
#    ['가격', ['가성비도 좋고', 197, 204], 'positive'],
#    ['향', ['향도 좋구', 274, 279], 'positive'],
#    ['가격', ['가성비도 젛구', 280, 287], 'positive']]},
#  {'sentence_form': '매일 매일 감는 머리에 가성비 좋고 품질도 괜찮은 미장센 추천드려요! ✔️ 향 : 목욕탕 어디선가 맡아본 누군가의 삼푸향! 그냥 나중에 머리 말리고 자고 일어나도 기분좋은 잔향이 남아있어요! ✔️ 샴푸와 트리트먼트 세트로 같이 쓰고 있어요! 손상보다 극손상이 더 좋은것 같아서 이것만 계속 쓰고 있어요! 샴푸는 그냥 하루동안 더러워진 머리를 행구는 용으로만 생각하고 있어서 아주아주 만족하구요 ! 가슴까지 오는 긴머리에 6-7번 펌핑하면 아주 풍부한 거품이 납니다!✔️클리닉을 한 머리에 탈모샴푸 쓰면 클리닉이 빨리 없어진다고 미용사님이 그러셔서 그날이후로 탈모샴푸는 안쓰고 있어요! 솔직히 트리트먼트는 어노* 가 더 좋은것 같은데  올리브영에 있는 샴푸중엔 이게 제일 무난하고 가성비 좋아요! 세명이서 쓰는데 꽤나 오래 써져요! 다만 발에 떨어트리면 아파욯ㅎㅎ',
#   'annotation': [['가격', ['가성비 좋고', 13, 19], 'positive'],
#    ['향', [' 기분좋은 잔', 90, 97], 'positive'],
#    ['거품', ['주 풍부한 거품이 납', 246, 257], 'positive'],
#    ['가격', ['하고 가성비 ', 377, 384], 'positive']]},
#  {'sentence_form': '요즘 산후탈모로 머리한번만 감아도 머리카락이 엄청 빠지고 게다가 힘이 없어서 축처짐이 너무 고민이였는데.여성전용 탈모샴푸가 출시되었다고해서 바로 사용을해보았어요ㅎ자극없이 거품이 참 풍성해서 세정력도 좋았으며은은한 향도 좋고 트리트먼트를 사용하지않아도 머리결도 부드럽네요ㅎ뿌리의 볼륨도 살아나고 머리카락이 덜빠지는게 확실히 보여서 만족스럽네요ㅎ',
#   'annotation': [['자극', ['자극없이', 90, 94], 'positive'],
#    ['거품', ['거품이 참 풍성해서', 95, 105], 'positive'],
#    ['세정', ['세정력도 좋았으며', 106, 115], 'positive'],
#    ['향', ['은은한 향도 좋고', 115, 124], 'positive'],
#    ['머릿결', ['머리결도 부드럽네요', 140, 150], 'positive'],
#    ['탈모', ['머리카락이 덜빠지는게 확실히 보여서 만족스럽네요', 164, 190], 'positive']]},
#  {'sentence_form': '두피가 시원해지는 느낌때문에 열감이 쌓였을 때 진정해주기 좋고 무엇보다 거품이 정말 잘 납니다',
#   'annotation': [['쿨링', ['두피가 시원해지는 느낌때문에 열감이 쌓였을 ', 0, 24], 'positive'],
#    ['거품', ['거품이 정말 잘 납니다', 40, 52], 'positive']]},
#  {'sentence_form': '😉라보~에이~치 두피쿨링~~ 헤어 샴푸 ~😄👍요즘 제가 애용하는 헤어 제품입니다~그이유는~:1. 헤어를 샴핑하면 뽀득함이 느껴지고 산뜻하고 진짜 말그대로 두피쿨~링~이 됩니다~😊👍2.저는 헤어제품에서 샴푸는 거품양을 중요시합니다~  거품양이적으면 자꾸 제품양을 더 사용해서 금방 없어지기때문입니다~  이 제품은 조금만 사용해도 거품이 엄청 납니다~  굿굿~!!~😄😊🥰단점은요~:1. 성분이 그다지 착하지않아요🤣😢너무아쉬운부분입니다~  성분많이보는편인데..나중에 알았어요~개선되어야할부분이라 생각됩니다~😐😀2. 머리카락이 좀 많이 빠지는 느낌,?입니다~저말고 우리언니도 한번쓰더니 머리카락이 많이 빠지는것같다고하더라고오ㅡㅜ 😂😢',
#   'annotation': [['쿨링', ['~링~이 됩니다~😊👍', 89, 100], 'positive'],
#    ['거품', ['조금만 사용해도 거품이 엄청 납니다', 174, 193], 'positive'],
#    ['탈모', ['머리카락이 많이 빠지는것같다고하더라고', 324, 344], 'negative']]},
#  {'sentence_form': '쿨한 느낌이 있어요 자극별로없고 엄청 민감한데 삼퓨 조금만 안맞는거쓰면 비듬생기는데 전혀 안생기고 찐 저랑 찰떡같이 잘맞아서 계속해서 쓸거 같네요!',
#   'annotation': [['자극', ['자극별로없고', 11, 17], 'positive']]},
#  {'sentence_form': '티트리 샴푸바가 좋아 로즈마리도 골라봤다. 환경 친화적인 제품을 쓴다는 자부심으로 선택한 샴푸바는 만족스럽다. 샴푸바에 익숙해져 사용하기 전혀 불편한 게 없고 청소년기 아이들도 잘 사용한다. 강추하는 제품이다. 매장에 소량이 있어 진열이 눈에 띄지 않을 수 있으니 관심 있는 분들은 유심히 클렌징 공간을 찾아보길 바란다. 향이 강하지 않고 기능도 적당하다. 헤어 클렌징에 액상 샴푸와 비교할 때 전혀 문제 없다.',
#   'annotation': [['향', ['향이 강하지 않고', 180, 189], 'positive']]},
#  {'sentence_form': '항상 쓰던 제품이라 또 구매하여 사용중입니다. 향도 맘에들고 좋아요~',
#   'annotation': [['향', ['향도 맘에들고 좋아요', 26, 37], 'positive']]},
#  {'sentence_form': '거품 풍성하고 세정력 좋아요두피 시원해요향은 프레쉬해요',
#   'annotation': [['거품', ['거품 풍성하고', 0, 7], 'positive'],
#    ['세정', ['세정력 좋아요두피 시원해요', 8, 22], 'positive'],
#    ['향', ['향은 프레쉬해요', 22, 30], 'positive']]},
#  {'sentence_form': '미용실가면 선생님이 놀랄정도로 두피에 상처 + 진물이 많고, 상처때문에 특정 부위만 머리카락이 빠지는 부분탈모로 두피에 주사도 여러번 맞은 적 있는 여성탈모인입니다ㅠㅠ여성 맞춤 탈모전문샴푸라는 것에 관심을 가지고 상세설명 읽다가 두피 붉은기, 두피 가려움, 가늘고 힘 없는 모발 등등 저에게 해당되는 것이 너무 많아서 홀린 듯이 구매했습니다.일단 좋은 점은 여타 탈모샴푸와는 다른게 사용 후 뻣뻣함이 덜하다는 것! 귀찮아서 트린트먼트 안하면 하루종일 뻣뻣한 탈모샴푸 사용하다가 이 샴푸 사용하니까 이런 신세계가 있나!! 탈모샴푸인데도 사용 후 머릿결이 좋습니다.그런데도 순하고 세정력도 좋아요.순함 + 세정력 좋음 + 사용 후 뻣뻣하지 않음 ... 이게 한번에 가능했다니!이 제품 받고나서 생각보다 작아서 재구매해야할지 고민했는데 저는 무조건 재구매할겁니다.',
#   'annotation': [['머릿결', ['뻣뻣함이 덜하다는 것', 219, 230], 'positive'],
#    ['머릿결', ['머릿결이 좋습니다', 304, 313], 'positive'],
#    ['자극', ['순하고', 319, 322], 'positive'],
#    ['세정', ['세정력도 좋아요', 323, 331], 'positive']]},
#  {'sentence_form': '상품도 저렴하게 사고 배송도 빠르게 왔는데 다만 포장에 좀 더 신경써 주시면 좋을 것 같아요 2개사서 하나 다쓰고 펌프만 교환하면 되지만 하나만 샀으면 교환신청하느라 더 걸렸을 뻔했어요무게가 있어서 충전재를 양쪽에 넣어주면 좋을텐데 한쪽만 있어서 완전 깨져서 왓어요',
#   'annotation': [['가격', ['상품도 저렴하게 사고', 0, 11], 'positive']]},
#  {'sentence_form': '향도 시원하고 산뜻하고, 여름에 머리 떡지는데 쓰니까 별로 기름기도 안생기고 좋아요!',
#   'annotation': [['향', ['향도 시원하고 산뜻하고', 0, 12], 'positive'],
#    ['세정', ['기름기도 안생기고', 33, 42], 'positive']]},
#  {'sentence_form': '탈모샴푸인데도 뻑뻑하지않고 거품 빵빵하게 잘나서 너무 좋은거같아요~탈모샴푸의 편견을 깨준제품^^향도 좋고 이거쓰고나서 원형탈모있던 부분도 많이 작아져서 만족하고 쓰고있습니당아직까진 머리숱이 적은편이라 쭉 써주려고해요^',
#   'annotation': [['머릿결', ['뻑뻑하지않고', 8, 14], 'positive'],
#    ['거품', ['거품 빵빵하게 잘나서 ', 15, 27], 'positive'],
#    ['향', ['향도 좋고', 53, 58], 'positive'],
#    ['탈모', ['탈모있던 부분도 많이 작아져서', 68, 84], 'positive']]},
#  {'sentence_form': '제꺼 사면서 남편꺼 샀는데 개운한데 부드럽다고 좋아하네요! 그리고 향이 저는 이게 더 쿨해서 좋아요',
#   'annotation': [['세정', ['개운한데 부드럽다고 좋아하네요', 15, 31], 'positive'],
#    ['향', ['향이 저는 이게 더 쿨해서 좋아요', 37, 55], 'positive']]},
#  {'sentence_form': '정말 저의 최애샴푸입니당컨디셔너?도 써봤는데 둘다 좋지만 하나만 쓰라면 샴푸예요.탈모샴푸는 감고나면 머릿결이 뻑뻑한 감이 있는데 이건 안그래요. 깔끔하게 마무리되는 편이고 거품이 풍성해서 부드러워요.지금은 익숙해졌지만 처음에는 뭣모르고 왕창 펌핑했다가 거품땜에 놀랐었어요 (적당히 사용합시다ㅋㅋ)화한 느낌이 강하지 않고 자극도 적으면서 세정력은 좋음여자전용샴푸라 그런지 써본 탈모샴푸 중에선 가장 부드럽고 순하다고 느꼈어요.',
#   'annotation': [['머릿결',
#     ['탈모샴푸는 감고나면 머릿결이 뻑뻑한 감이 있는데 이건 안그래요', 45, 79],
#     'positive'],
#    ['거품', ['거품이 풍성해서 부드러워요', 96, 110], 'positive'],
#    ['자극', ['자극도 적으면서', 179, 187], 'positive'],
#    ['세정', ['세정력은 좋음', 188, 195], 'positive'],
#    ['자극', ['부드럽고 순하다고 느꼈어요', 222, 236], 'positive']]},
#  {'sentence_form': '항상 컨디셔너는 여기 제품 씁니당 향도 좋고 대용량이라 막 쓰기 조아요',
#   'annotation': [['향', ['향도 좋고', 19, 24], 'positive']]},
#  {'sentence_form': '오자마자 바로 사용하고 나서 씁니당향은 거의 무취에 가까운? 근데 사용시 멘솔느낌이 있어서 시원해요 ㅎㅎ 그리고 점도가 제가 좋아하는 점도예요 샴푸가 머리카락이랑 싹 달라붙는 그런느낌 좋습니다',
#   'annotation': [['향', ['향은 거의 무취에 가까운', 19, 32], 'neutral'],
#    ['향', ['멘솔느낌이 있어서 시원해요', 41, 55], 'positive']]},
#  {'sentence_form': '거품도 많이 생기구 향도 괜찮은데 세정력이 너무 아쉬워요 ㅠㅠ',
#   'annotation': [['거품', ['거품도 많이 생기구', 0, 10], 'positive'],
#    ['향', ['향도 괜찮은데', 11, 18], 'neutral'],
#    ['세정', ['세정력이 너무 아쉬워요', 19, 31], 'negative']]},
# ...
#  {'sentence_form': '엄청 유명해서 사봤는데 너무 기대를 한건지그냥 마트에서 사는 샴푸랑 다른점을 잘... 모르겠어요머리에 유분이 있는 편인데 딱히 뭔가 더 보송하다던가 그런건 없구 거품도 뭐.. 그냥 그럭저럭 나구향은좋아요 개인적으로 향이 너무 좋아서재구매하고싶어지는..',
#   'annotation': [['향', ['향은좋아요', 108, 113], 'positive'],
#    ['거품', ['거품도 뭐.. 그냥 그럭저럭', 90, 105], 'neutral'],
#    ['세정', ['뭔가 더 보송하다던가 그런건 없구', 71, 89], 'neutral']]},
#  {'sentence_form': '다른 제품보다 확실히 이 제품으로 씻으면 냄새가 덜 하고 좋아요.',
#   'annotation': [['세정', ['씻으면 냄새가 덜 하고 좋아요', 19, 35], 'positive']]},
#  {'sentence_form': '목욕탕에서 쓰고있어서 거품 사진을 못 올리겠네요. 하지만 로레알 헤어제품은 믿고 쓰는 라인 아니겠습니까~ 향도 거품도 다 만족스럽구요 두피자극은 제가 어떤 샴푸를 써도 아무 반응 없는 두피라 잘 모르겠네요 ㅠㅠ 세정력 괜찮습니다 가격이 더 괜찮구요 아주 착한 아이네요',
#   'annotation': [['향', ['향도', 59, 61], 'positive'],
#    ['거품', ['거품도 ', 62, 66], 'positive'],
#    ['세정', ['두피자극은 제가 어떤 샴푸를 써도 아무 반응 없는 두피라 잘 모르겠네요', 75, 114], 'neutral'],
#    ['세정', ['세정력 괜찮습니다', 118, 127], 'positive'],
#    ['가격', ['가격이 더 괜찮구요', 128, 138], 'positive']]},
#  {'sentence_form': '몇번 안써봐서 아직 머릿결이 좋아졌다 이런건 모르겠지만 사용후 머릿결이 뻣뻣하지 않고 부드러운게 괜찮은 제품인것 같아요. 향도 좋구 꾸준히 써보려고요~!',
#   'annotation': [['머릿결', ['머릿결이 뻣뻣하지 않고 부드러운게 괜찮은', 35, 57], 'positive'],
#    ['향', ['향도 좋구', 68, 73], 'positive']]},
#  {'sentence_form': '머리카락 끝이 갈라지고 뚝뚝 끊기는 손상모라서 이것저것 케어 제품 사용해야 하는데 트리트먼트 필요없이 한가지로 케어가 가능해서 좋아요. 빗질도 잘되고 부드러워 졌어요. 은은한 향에 쫀쫀하고 풍성한 거품이라 머리 감을때도 기분 좋아요.',
#   'annotation': [['머릿결', ['부드러워 졌어요', 84, 92], 'positive'],
#    ['향', ['은은한 향에 쫀쫀하고', 94, 105], 'positive'],
#    ['거품', ['풍성한 거품', 106, 112], 'positive']]},
#  {'sentence_form': '고농축의 꿀제형이라 조금만 펌프해도 거품이 풍성하게 일어나서 머리감을때너무 개운하네요.샴푸만 써도 머리결이 부드러워요.단백질2배 강화샴푸라 그런가봐요.세척력도 좋고 무엇보다 기분좋은 플로럴향이 나서 머리를 말리고 나서도 은은하게 풍깁니다.머릿결이 찰랑찰랑 하고 윤기가 맴돌아요.요즘 머리에 뭐했냐는 질문을 많이 듣네요.',
#   'annotation': [['거품', ['거품이 풍성하게 일어나서', 20, 33], 'positive'],
#    ['세정', ['머리감을때너무 개운하네요', 34, 47], 'positive'],
#    ['머릿결', ['머리결이 부드러워요', 55, 65], 'positive'],
#    ['향', ['기분좋은 플로럴향이 나서', 97, 110], 'positive']]},
#  {'sentence_form': '두피가 개운하고 상쾌해요.그냥 맡아도 향도 좋고 두피에서도 좋은향이 나네요.',
#   'annotation': [['세정', ['두피가 개운하고 상쾌해요', 0, 13], 'positive'],
#    ['향', [' 향도 좋고', 20, 26], 'positive']]},
#  {'sentence_form': '일단 전 극지성에 탈모 위협까지 있어서 라우쉬 라인을 전부 다 써보기로 마음 먹었구요샴푸 자체가 굉장히 순하면서도 진짜 기름기를 쫙 빼주니까 담백하고 이 다음에 두피 토닉도 라우쉬로 마무리 해 주니까 진짜 진짜 좋음! 여러분 모두 강추템입니다일단 쓰기 전에 전 기획으로 사서 두피 스칼프 팩도 미리미리 해줬구요 그런데단점이 하나 있다면 머릿결이 다소~~ 뻣뻣해진다 그래서 트리트먼트가 필수다!거품이 아주 잘 나는 건 아니에요 그래서 조금 덜어서 물 듬뿍 묻혀서 애벌빨래 하듯이 머리도 애벌샴푸 들어간 다음에 쓰는 게 제일 좋아요! 기획 상품 나오면 앞으로도 쭉 그냥 쓸 것 같아요 이유는 너무 좋아서 ㅠ 솔직히 이것보다 좋은 거 찾기 힘들 것 같아요 참고로 전 다ㅂㄴㅅ나 케라ㅅㅌㅈ 다 써봄... 5샴푸도 여러 번 바꿔줘야 하는 거 아시죠 다들',
#   'annotation': [['자극', ['순하면서도 ', 58, 64], 'positive'],
#    ['세정', ['기름기를 쫙 빼주니까', 67, 78], 'positive'],
#    ['머릿결', ['머릿결이 다소~~ 뻣뻣해진다', 188, 203], 'negative'],
#    ['거품', ['거품이 아주 잘 나는 건 아니에요', 219, 237], 'neutral']]},
#  {'sentence_form': '매직셋팅으로 머리가 다 타서 이것저것 사보다가 구입했어요. 향은 사과향 같은 늘 맡던 로레알 특유의 트리트먼트 향이에요. 생각보다 묽지 않아서 샘플 용기가 튜브였으면 좋았을거 같습니다. 짜기 힘들더라구요. 아침에 트리트먼트 제대로 할 시간이 없어 급하게 이거 쓰고 샴푸하고 또 이거 썼는데 부드럽고 괜찮은거 같아요. 다시 제대로 다시 사용해보고 진짜 개선됐는지 한달 후기 남기겠습니다.',
#   'annotation': [['향', ['향은 사과향', 33, 39], 'positive'],
#    ['머릿결', ['부드럽고 괜찮은거 같아요', 162, 175], 'positive']]},
#  {'sentence_form': '이 샴푸 계속 쓰고 있는데 샴푸는 웬만해서 거기서 거기라고 생각했는데 그래비티는 확실히 달라요 하고나서 볼륨도 다르고 두피도 시원한게 두피 트러블도 잘 안나요 앞머리 고데기 하면 저녁까지 볼륨이 살아있어요 샴푸 쓰기 전 후 사진 올려봐용 ㅎㅎ',
#   'annotation': [['자극', ['트러블도 잘 안나요', 78, 88], 'positive']]},
#  {'sentence_form': '예전에 헤어제품 키트로 샘플 받아보고 마음에 들어서 본품으로 구매해 보았습니다 안 그래도 유명한 제품이더라구요 :)가격은 할인쿠폰 이것저것 다 사용해서 10500원 정도에 구매를 했습니다!향 : 호불호가 갈릴 만한  향이에요 세정력 : 엄청 깨끗하게 씻겨졌단 느낌은 들지 않지만  자극적인 것 같지도 않고 가렵다거나 그러진 않았어요 거품도 풍성해서 한번 짠 걸로 충분히 해결이 돼요 근데 샴푸만 했을 땐 머리가 좀 뻣뻣해지는 느낌을 받아서 트리트먼트는 꼭 꼭 해주는 편입니다! 정전기가 잘 일어날 것 같아요 무난무난한 비건샴푸라 만족합니다 ㅎㅎ',
#   'annotation': [['향', ['호불호가 갈릴 만한  향이에요', 109, 125], 'neutral'],
#    ['세정', ['엄청 깨끗하게 씻겨졌단 느낌은 들지 않지만', 132, 155], 'negative'],
#    ['자극', ['자극적인 것 같지도 않고 가렵다거나 그러진 않았어요', 157, 185], 'positive'],
#    ['거품', ['거품도 풍성해서', 186, 194], 'positive'],
#    ['머릿결', ['머리가 좀 뻣뻣해지는 느낌을 받아서', 226, 245], 'negative']]},
#  {'sentence_form': '향은 크게 없지만 지성 두피에 최강이에요 주기적으로 구입해서 사용합니다',
#   'annotation': [['향', ['향은 크게 없지만', 0, 9], 'neutral'],
#    ['세정', ['지성 두피에 최강이에요', 10, 22], 'positive']]},
#  {'sentence_form': '솔직히 향은 진짜 제 스타일 아닌데,,심지어 감고 나서도 향이 오래 유지되요,,,트리트먼트를해도 샴푸냄새가 잘나고요,,,  그런데 머리는 진짜 좀 안빠지는것 같아서 샀어요. 라보에이ㅊ 샴푸 썼는데 다른것도 사볼까해서 산거고 번갈아가며 쓸려고요.',
#   'annotation': [['향', ['향은 진짜 제 스타일 아닌데', 4, 19], 'negative']]},
#  {'sentence_form': '다른 샴푸보다 기름이 덜 올라와서 좋아요!대신 얼굴에 닿으면 화한 느낌이 들어서 예민한 분은 피하시는게 좋을 것 같아요지성샴푸로 추천합니당',
#   'annotation': [['세정', ['기름이 덜 올라와서 좋아요', 8, 22], 'positive'],
#    ['자극', ['얼굴에 닿으면 화한 느낌이 들어서', 26, 44], 'negative']]},
#  {'sentence_form': '내 인생샴푸향이 너무너무 제취향이라서...계속쓰게되네요진한향이라 오래지속되고 넘넘 좋아요세일하면 만원도 안해서세일때 쟁이고있어요',
#   'annotation': [['향', ['향이 너무너무 제취향이라서', 6, 20], 'positive']]},
#  {'sentence_form': '전 재구매는 안하려구요ㅠ거품은 잘나고 향도 괜찮은데 샴푸후에 넘 바스락 거리고 날려요',
#   'annotation': [['거품', ['거품은 잘나고', 13, 20], 'positive'],
#    ['향', ['향도 괜찮은데', 21, 28], 'positive'],
#    ['머릿결', ['바스락 거리고 날려요', 36, 47], 'negative']]},
#  {'sentence_form': '수 년째쓰고 있는 비누입니다 굿이요순하고 좋아요 굿이요굿',
#   'annotation': [['자극', ['순하고 좋아요', 19, 26], 'positive']]},
#  {'sentence_form': '믿고쓰는방기원샴푸입니다 ㅎㅎ오랫동안쓰고있는데두피자극도없고 부드러워서항상만족이에요 ㅎㅎ',
#   'annotation': [['자극', ['두피자극도없고', 24, 31], 'positive'],
#    ['머릿결', [' 부드러워서항상만족', 31, 41], 'positive']]},
#  {'sentence_form': '건성보다는 지성에 잘 맞고 지성들은 한 번 쓰면 꼭 이것만 쓰대요.',
#   'annotation': [['세정', ['지성들은 한 번 쓰면 꼭 이것만 쓰대요', 15, 36], 'positive']]},
#  {'sentence_form': '거품도 풍성해서 단발인 저는 한 번 펌핑으로도 충분히 사용할 수 있고 머리결이 부드러워지는 건 두 말하면 잔소리..진짜 머리카락 자르지 마시고 이 샴푸 쓰세요. 강추합니다.',
#   'annotation': [['거품', ['거품도 풍성해서', 0, 8], 'positive'],
#    ['머릿결', ['머리결이 부드러워지는', 39, 50], 'positive']]},
#  {'sentence_form': '맨 처음 로레알을 알게된게 어느덧 6년차 헬스장에서 지인이게 추천 받은 샴푸였는데곱슬에 매번 부시시한 머리결이 컴플렉스라항상 1년에 장마철엔 꼭 매직을 하던 저로레알샴푸를 알게되고 곱슬기가 확실히 차분해지면서 갈라짐도 적고 컨디션에 따라 두세가지 샴푸를 쓰는데로레알 향기만큼 참 저녁에 포근한 향기 덕분에머리결고 좋고~ 대용량 생겼으면 좋겠어요',
#   'annotation': [['향', ['포근한 향기', 160, 166], 'positive'],
#    ['머릿결', ['머리결고 좋고', 170, 177], 'positive']]},
#  {'sentence_form': '액체샴푸만 20년 이상 써오다가 처음으로 산 고체형 비누샴푸바 입니다환경에 대한 문제를 인식하고기존에 사용하던 샴푸는 큰 플라스틱통이 재활용 되는지도 잘 모르겠고, 거품도 너무 심하게 나더라구요이번에 동구밭 제품을 환경을 생각하면서 구입했어요종이박스에 간단하게 포장되어 있어서 너무 좋았어요코코넛 펄프로 만든 비누망에 넣어서 사용하니 일반 샴푸만큼 거품이 잘 났어요중건성용으로 구매했는데 적당히 보송하면서 부드럽게 샴푸를 할 수 있었어욯ㅎ비누로 머리를 감으면 뻣뻣할거라고 생각했는데그냥 일반 샴푸를 썼을때랑 비슷해요생각보다 머리가 더 부드럽고 보송하게 샴푸 잘 되었어요향도 자극적이지 않고 너무 좋아요바디워시로 써도 될 만큼 좋은 향이 나요재구매 벌써 3번 넘게 했네요다쓰면 다음에 또 사려구용ㅎㅎ',
#   'annotation': [['거품', ['거품이 잘 났어', 195, 203], 'positive'],
#    ['향', ['향도 자극적이지 않고 너무 좋아요', 318, 336], 'positive'],
#    ['머릿결', ['머리가 더 부드럽고 보송하게 샴푸 잘 되었어요', 293, 318], 'positive']]},
#  {'sentence_form': '일단 향기가 참 좋네요. 호불호 없을 향이고 거품도 장난 아니예요. 아침에 씻을때마다 기분이 좋네요~~',
#   'annotation': [['거품', ['거품도 장난 아니예요', 25, 36], 'positive'],
#    ['향', ['호불호 없을 향', 14, 22], 'positive']]},
#  {'sentence_form': '탈모증상이 완화되기로 유명한 닥터그루트 제품이라 샀는데, 다른 것 보다도 향이 너무 좋고 머릿결도 부드럽게 유지시켜 주는 것 같아서 매우 만족해요. 특히 남자친구가 머리 감고 나온 날의 저를 너무 좋아해요.',
#   'annotation': [['향', ['향이 너무 좋고', 41, 49], 'positive'],
#    ['머릿결', ['머릿결도 부드럽게 유지', 50, 62], 'positive']]},
#  {'sentence_form': '거품 잘 나고 향 괜찮고 무난한 샴푸에요. 무엇보다 가성비가 좋아요',
#   'annotation': [['거품', ['거품 잘 나고', 0, 7], 'positive'],
#    ['향', ['향 괜찮고', 8, 13], 'positive'],
#    ['가격', ['가성비가 좋아요', 29, 37], 'positive']]},
#  {'sentence_form': '티트리라 두피가 시원해서 좋아요아로마티카 샴푸 맛집인건 진짜 인정',
#   'annotation': [['탈모', ['두피가 시원해서 좋아요', 5, 17], 'positive']]},
#  {'sentence_form': '다른 비싼것보단 전 이 제품이 좋더라구요향도 마음에 들고 너무 부드러워요',
#   'annotation': [['향', ['향도 마음에 들고', 22, 31], 'positive'],
#    ['머릿결', ['부드러워요', 35, 40], 'positive']]},
#  {'sentence_form': '거품 풍성합니다. 목욕탕.골프장 가져 다니기 좋아요. 사이즈가 작아서 두개사길 너무 잘한듯요. 무엇보다도 항이 내 스타일입니다,',
#   'annotation': [['거품', ['거품 풍성합니다', 0, 8], 'positive'],
#    ['향', ['항이 내 스타일입니다', 59, 70], 'positive']]},
#  {'sentence_form': '머리가 자주 가렵고 두피가 민감한 편이에요. 닥터그루트 제품 좋아하는데 자극적이지 않으면서도 세정력 좋은 샴푸 찾다가 평소 애정하는 김지영님이 모델이시길래 바로 구매했습니다. 일단 하늘빛 디자인 너무 이쁘고, 시원하고 상큼한 향이라 좋아요. 거품도 잘나고 너무 화하지 않고 상쾌하게 감겨서 좋습니다. 적은 양으로도 거품 풍성하게 나고 산뜻해서 아침저녁 언제 사용해도 좋아요. 두피가 민감한데 자주 가려우신 분들에게 추천드립니다.판매자에게 제품비의 일부를 지원받았지만 저의 솔직한 후기입니다.',
#   'annotation': [['향', ['시원하고 상큼한 향이라 좋아요', 117, 133], 'positive'],
#    ['거품', ['거품도 잘나고', 135, 142], 'positive'],
#    ['세정', ['상쾌하게 감겨서 좋습니다', 153, 166], 'positive']]},
#  {'sentence_form': '제가 4통째 쓰는 최애템입니다 이거 쓰고 머릿결도 좋아지는게 눈에 보이고 향도 좋아서 쓸 때마다 행복해요',
#   'annotation': [['머릿결', ['머릿결도 좋아지는게', 23, 33], 'positive'],
#    ['향', ['향도 좋아서', 41, 47], 'positive']]},
#  {'sentence_form': '"판매자에게 제품비의 일부를 지원받았지만 저의 솔직한 후기입니다.”두피가 건조란 편이라 하늘색으로 받아봤어요요새 여기 브랜드가 자주 보여서 궁굼했었는데 패키지도 너무 귀엽고 직접 사용해보니 소량만 사용해도 거품도 잘나고 세라마이드가 함유돼서 그런지 샴푸후에 건조한 느낌이 덜하고 수분이 채워진듯한 느낌이었어요자극없이 순하고 좋네요다음에는 토닉이나 다른제품도 써보고싶어요!',
#   'annotation': [['자극', ['자극없이 순하고', 172, 180], 'positive'],
#    ['거품', ['거품도 잘나고', 115, 122], 'positive']]},
#  {'sentence_form': '건성인뷴들이 사용하기 좋을것같습니닼   향은 너무 좋아요  지성은 조금 떡질수도 ㅠㅠ',
#   'annotation': [['향', ['향은 너무 좋아요', 22, 31], 'positive'],
#    ['세정', ['지성은 조금 떡질수도', 33, 44], 'negative']]},
#  {'sentence_form': '향도 좋고 머리카락이 뻣뻣해지지 않아요. 두피샴푸와 번갈아 사용하고 있어욤',
#   'annotation': [['향', ['향도 좋고', 0, 5], 'positive'],
#    ['머릿결', ['머리카락이 뻣뻣해지지 않아요', 6, 21], 'positive']]},
#  {'sentence_form': '❤루톤 여성 두피용 알파에르겐 탈모샴푸한달사용후기😙🤗구매한 이유:후기가 좋아서 구매했어요 ~!아직 탈모는없으나 예방차원으로 사용해보았어요~!🤩총평👉머릿결이 부드러워집니다~향이 좋아요거품이 풍성하여 조금만 덜어 사용가능함👍머리도 안빠져요~그러나 지성인분들은 기름질것같습니다~!🥰향: 좋은향입니다 저한테는요..강하지않고 ~허브향사용후 향이 반나절은 남아 있습니다~😁😊👍사용하고난후 머릿결이 부드러워져서만족합니다~!😄탈모예방 더 써봐야하지요😄😊😊거품양이 아주 풍성해서좋아요😊조금양의 덜어서 사용해도 되서 좋고 마음에들어요👍👍🤗 펌프형이라 사용편리하니 좋아요케이스도 예쁘고좋은데..뽀득함이 부족해요 😂😅',
#   'annotation': [['머릿결', ['머릿결이 부드러워집니다', 82, 94], 'positive'],
#    ['향', ['향이 좋아요', 95, 101], 'positive'],
#    ['거품', ['거품이 풍성하여', 101, 109], 'positive'],
#    ['세정', ['기름질것같습니다', 143, 151], 'negative']]},
#  {'sentence_form': '거품은 잘 안나는거 같아요유툽 보고 좋다고 해서 세일할때 저렴하게 구매했습니다^^',
#   'annotation': [['거품', ['거품은 잘 안나는거 같아요', 0, 14], 'negative'],
#    ['가격', ['저렴하게 구매', 32, 39], 'positive']]},
#  {'sentence_form': '손상 머릿결에 좋다고 느껴졌어요😁😁 향은 은은한 장미향이 나네요',
#   'annotation': [['향', ['향은 은은한 장미향', 20, 30], 'positive'],
#    ['머릿결', ['손상 머릿결에 좋다', 0, 10], 'positive']]},
#  {'sentence_form': '향 완전 제취향이에요 시원한 향이라서 완전 좋아요거품도 풍성해서 좋아요다음에도 재구매 예정!!',
#   'annotation': [['향', ['시원한 향이라서 완전 좋아요', 12, 27], 'positive'],
#    ['거품', ['거품도 풍성해서', 27, 35], 'positive']]},
#  {'sentence_form': '집에 샴푸없어서 급하게 샀능데 무난하게 사용하기 좋아요 향도 괜찮아요',
#   'annotation': [['향', ['향도 괜찮아요', 31, 38], 'positive']]},
#  {'sentence_form': '샴푸칠 하고 나면 두피가 시원해져서 두피열 내려주고 좋아요',
#   'annotation': [['쿨링', ['두피가 시원해져서 두피열 내려주고 좋아요', 10, 32], 'positive']]},
#  {'sentence_form': '맥주효모환도 먹고 있는데 샴푸도 맥주효모가 들어있는 샴푸를 쓰게 됐네요생각외로 향도 좋고 자극없이 샴푸하기 정말 좋은 거품량까지..모두 맘에 들어요~',
#   'annotation': [['향', ['향도 좋고', 44, 49], 'positive'],
#    ['자극', ['자극없이', 50, 54], 'positive'],
#    ['거품', ['좋은 거품량', 63, 69], 'positive']]},
#  {'sentence_form': '샴푸 후에도 잔향이 오래가서 마치 향수를 뿌린 듯한 느낌? 머릿결도 부드러워지고 윤기가 흘러서 요즘 머리 감을 때마다 기분 좋네요 ㅎㅎ',
#   'annotation': [['머릿결', ['머릿결도 부드러워지고', 33, 44], 'positive'],
#    ['향', ['샴푸 후에도 잔향이 오래가서 마치 향수를 뿌린 듯한 느낌', 0, 31], 'positive']]},
#  {'sentence_form': '나인밀라 카밍비어 맥주효모 샴푸는 진짜 두피 예민한 분들한테 딱일 것 같아요. 저도 원래 두피가 자주 가렵고 샴푸 잘못 쓰면 뾰루지처럼 뭐 올라오는데, 이건 며칠 써보니까 그런 게 거의 없어서 좋았어요. 맥주효모 들어갔다고 해서 향이 이상하지 않을까 걱정했는데 전혀 아니고, 은은한 시원한 허브향? 같은 느낌이라 샴푸하면서 기분까지 상쾌했어요. 거품도 잘 나고 헹굴 때 머릿결이 뻣뻣하지 않아서 린스 따로 안 써도 괜찮았고요. 머리 말리고 나면 기름기 덜 올라오고 볼륨도 좀 살아있는 느낌이라 확실히 두피에 좋은 성분 쓴 티가 나더라고요. 그리고 비건 샴푸라 그런지 안심하고 매일 쓸 수 있어서 요즘은 이걸로 정착했어요.',
#   'annotation': [['향', ['은은한 시원한 허브향', 154, 165], 'positive'],
#    ['거품', ['품도 잘 나고', 194, 201], 'positive'],
#    ['머릿결', ['머릿결이 뻣뻣하지 않아서', 207, 220], 'positive'],
#    ['세정', ['기름기 덜 올라오고', 249, 259], 'positive']]},
#  {'sentence_form': '지성두피용 샴푸로 최고입니다...보통 아침에 감으면 오후에 기름지고 가렵고 또 저녁에 감으면 다음날 아침에 기름지기 마련이었는데, 이걸 쓰고는 하루종일 불편하지 않게 됐어요ㅠㅠㅜ 이* 이퀄라이징 샴푸가 비싸서 좀 부담스러웠는데 대체품으로 좋은 것 같아요. 향도 은은하고 거품이 너무 적은 것도 아니라서 만족합니다.',
#   'annotation': [['향', ['향도 은은하고', 143, 150], 'positive'],
#    ['거품', ['거품이 너무 적은 것도 아니라서 만족합니다', 151, 174], 'positive'],
#    ['세정', ['아침에 기름지기 마련이었는데, 이걸 쓰고는 하루종일 불편하지 않게 됐어요', 56, 96], 'positive']]},
#  {'sentence_form': '향이 좋아요머릿결은 워낙 나빠 아직 잘모르겠지만특별하게 나쁜 점은 없어요!',
#   'annotation': [['향', ['향이 좋아요', 0, 6], 'positive'],
#    ['머릿결', ['머릿결은 워낙 나빠 아직 잘모르겠지만', 6, 26], 'neutral']]},
#  {'sentence_form': '아보카도 좋아하는데 단백질까지 더 해진 샴푸! 쟁여놔서 아직 안써봤는데 탈모가 효과있으면 더 구매할려구요! 향은 안심해서 좋네요 보통일 것 같긴합니다.',
#   'annotation': [['향', ['향은 안심해서 좋네요', 60, 71], 'positive']]},
#  {'sentence_form': '👍🏻 만족했던 점💬 적당한 거품양, 개운한 세정력세번째 사진 보시면 물 두 세방울 정도 묻혀 문질러준 거품양이에요거품양이 많이 나진 않지만 오히려 두피 구석구석 세정해주는데 더 편해서 아주 만족!💬 은은한 쿨링감과 세정 후 모발 뻣뻣함 X두피 구석구석 씻어준 다음 그대로 2,3분 방치해주니 은은한 쿨링감이 느껴졌어요!요 폴리젠은 세정 후 심한 뻣뻣함이 없는 편이라 가끔 트리트먼트 스킵할 때도 있는데 불편함 별로 없었어요!💬 모발 빠짐 확실히 줄어듬사용 전에는 샴푸 후 고양이 털뭉치마냥 머릿카락이 너무 많이 빠졌었는데 사용한지 3주차 된 요즘은 반절로 많이 줄어들었고 가끔 스트레스 받을 때 아니면 전보다는 많이 안빠지더라구요!모발 빠짐 때문에 걱정이신 분들 폴리젠 꼭 써보세요!❗️ 추천하는 대상-모발 빠짐으로 스트레스가 많으신 분들-부드러운 탈모샴푸를 선호하시는 분들🔚 재구매 의사 완전 있어요!닥',
#   'annotation': [['거품', [' 적당한 거품', 10, 17], 'positive'],
#    ['세정', [' 개운한 세정', 19, 26], 'positive'],
#    ['머릿결', [' 심한 뻣뻣함이 없는 ', 189, 201], 'positive'],
#    ['탈모', [' 모발 빠짐 확실히 줄어', 238, 251], 'positive']]},
#  {'sentence_form': '민감 두피용에 맞는 제품이고 사용하고 나서도 자극이 없었습니다꼼꼼하게 신경써서 샴푸하니까 두피가 많이 좋아졌어요',
#   'annotation': [['자극', ['자극이 없었습니다', 25, 34], 'positive']]},
#  {'sentence_form': '✨️향이 일단 너무 좋았습니다! 사과식초라고는 하지만 상큼한 사과주스 향이 났어요. 은은하게 남아있어 좋았어요.✨️세정력 제가 특히 머리가 파워지성인데 제 머리의 유분기를 잘 제거해줬고 꽤 오래 지속되어서 좋았어요. 저는 24시간이 지나지 않아도 좀 머리 냄새가 나는 편이라 스트레스였거든요.✨️거품은 그럭저럭 나는 편이에요!✨️아쉬운점 제가 원래 항상 탈모방지 샴푸를 사용하는데 원래 머리숱자체가 적은 편이라 조심하고 있거든요. 근데 아무래도 탈모방지샴푸가 아니라 그런지 요 샴푸를 쓸 때는 머리가 원래 샴푸보다는 아쉬웠던거 같아요.✨️머리가 뭐 풍성해진다는 리뷰가 있어서 뭐지 했는데 머리가 생각보다 탱글해지고 좀 영양들어간 느낌? 그랬어요. 살짝 머리 하나하나가 코팅된 느낌이었어요 다만 가끔 머리가 너무 윤기가 도니까 잘못보면 떡져보일수도 있겠다는 생각이 들었어요. 하지만 실제로는 머리 윤기가 촤르르 돌았어요. ✨️머릿결이 막 엄청 나빠지진 않았으나 단독 사용하기에는 머릿결이 막 좋아히는 편도 아니었어서 트리트먼트 추천합니다.✨️총평은 평소 탈모방지 샴푸를 평소 사용하지 않는 지성인들에게 추천합니다!도움이 되었다면 도움 눌러주세요 감사합니다 :)',
#   'annotation': [['세정', ['제 머리의 유분기를 잘 제거해', 85, 101], 'positive'],
#    ['거품', ['.✨️거품은 그럭저럭 나는 편', 162, 178], 'neutral'],
#    ['머릿결', ['용하기에는 머릿결이 막 좋아히는 편도', 485, 505], 'neutral'],
#    ['향', [' 상큼한 사과주스 ', 29, 39], 'positive']]},
#  {'sentence_form': '향이 자극적이지 않고 은은해서 너무 마음에 들어요!거품도 풍성하고, 세정력도 좋습니다!역시 믿고 쓰는 라보에이치. ^^',
#   'annotation': [['거품', ['거품도 풍성하고', 28, 36], 'positive'],
#    ['세정', ['세정력도 좋습니다', 38, 47], 'positive'],
#    ['향', ['향이 자극적이지 않고 은은해서', 0, 16], 'positive']]},
#  {'sentence_form': '지성 두피 고민때문에 구매하게 되었는데 너무 만족합니다세정력 너무 좋고 헹구고 나면 산뜻해서 개운하게 머리감은 느낌을 느낄 수 있어서 좋았어요거품도 잘 나는 편이고 향도 인공적으로 독한편이 아니라서 마음에 듭니다',
#   'annotation': [['세정', ['세정력 너무 좋고', 30, 39], 'positive'],
#    ['거품', ['거품도 잘 나는 편', 79, 89], 'positive'],
#    ['향', ['향도 인공적으로 독한편이 아니라서 마음에 듭니다', 92, 118], 'positive']]},
#  {'sentence_form': '지성 두피라면 사용하기 좋은 아로마티카 두피 세정력 좋아요',
#   'annotation': [['세정', ['세정력 좋아요', 25, 32], 'positive']]},
#  {'sentence_form': '거품도 잘일어나고 세정력도좋아서  아주만족합니다   샴푸후 퍽퍽하지도않고   감고나면 자극적이지않아 상쾌한느낌들어  기분좋네요  두피와모발에 단백질영양 팍팍준다니 열심히 관리 해야겠네요  민감한피부에도자극적이지않아 추청합니다',
#   'annotation': [['거품', ['거품도 잘일어나고', 0, 9], 'positive'],
#    ['세정', ['세정력도좋아서', 10, 17], 'positive'],
#    ['자극', ['자극적이지않아', 48, 55], 'positive']]},
#  {'sentence_form': '피부과 치료 받으면서 약을 먹고 연고를 얼굴에 바르고 했었는데얼굴은 깨끗해졌지만 왜인지 모르게 치료 이후로 두피에 트러블도 많이 올라오고 긁으면 피가 나기도 했고, 자고 일어나면 침대 베개에 피딱지들이 떨어져 있기도 했어요 그때 쓰던 샴푸는 탈모에 효과 있는 샴푸였는데 두피에 도움이 전혀 안 되겠다 싶어서 민감, 가려움, 비듬 이런쪽과 관련된 샴푸를 찾아서 쓰기 시작했어요!시간이 많이 지나서 저절로 가라앉은건지 샴푸덕을 본건진 모르겠지만 지금은 두피에 트러블도 없고 가려움증도 없어요~ 상품성은 좋지만 한정기획이 아니면 가격 부담돼서 못 살듯 ㅠ..',
#   'annotation': [['자극', ['지금은 두피에 트러블도 없고 가려움증도 없어요', 247, 272], 'positive'],
#    ['가격', ['가격 부담돼서 못 살듯', 293, 305], 'negative']]},
#  {'sentence_form': '벌써 세 통 째 재구매예요~ 일단 향은 약간 화한 향이 나요 쓰다 보니 익숙해져서 그러려니 하는데 처음 쓰시는 분들은 이게 무슨 향인가 하실 수도 있어요! 매일 사용하면 두피나 머릿결에 무리가 있을까봐 저는 2~3일에 한 번 쓰고 평소에는 집에서 사용하는 샴푸로 머리를 감아 줍니다 ㅋㅋㅋ 두피에 자극은 크게 없는 편이고요 세정력은 일반 샴푸랑 비슷한 것 같아요 거품은 일반 샴푸보다 잘 안 나고요 물을 많이 하든가 아니면 양을 많이 하든가라서 솔직히 가격 대비 좋은 건지는 모르겠어요! ㅠ ㅠ 그리고 사용하고 나면 기름을 빼 줘서 그런가 머릿결이 뻣뻣해져요 약간 일시적인 느낌이고 바로 컨디셔너나 트리트먼트로 관리해 주면 머릿결은 그대로 돌아옵니다 ㅎㅎ 저는 그래도 재구매 의사 있어요 하고 나면 개운한 느낌인지라 머리 잘 감았다 하는 느낌이 들거든요',
#   'annotation': [['자극', ['두피에 자극은 크게 없는 편이고요', 162, 180], 'positive'],
#    ['세정', ['세정력은 일반 샴푸랑 비슷한 것 같아요 ', 181, 203], 'positive'],
#    ['거품', ['거품은 일반 샴푸보다 잘 안 나고요', 203, 222], 'negative'],
#    ['가격', ['가격 대비 좋은 건지는 모르겠어요', 253, 271], 'negative'],
#    ['머릿결', ['머릿결이 뻣뻣해져요', 302, 312], 'negative'],
#    ['향', ['향은 약간 화한 향이 나', 19, 32], 'positive']]},
#  ...]

# %%
split_jsonl_file_train_dev_only(
    jsonl_path=converted_aug_all_data_path,
    output_dir=DATA_DIR,
    train_ratio=0.9,
    dev_ratio=0.1
)
# Out:
# 데이터 분할 완료: train=2367, dev=264

# %%
train_data = jsonlload(train_data_path)
dev_data = jsonlload(dev_data_path)
train_sentiment_analysis(train_data, dev_data)
# Out:
# train_sentiment_analysis START
# Token indices sequence length is longer than the specified maximum sequence length for this model (630 > 512). Running this sequence through the model will result in indexing errors
# Entity Class Weights:
#   - False (class 0): weight = 1.2977
#   - True (class 1): weight = 4.3593
# Polarity Class Weights:
#   - positive (class 0): weight = 1.6535
#   - negative (class 1): weight = 3.8054
#   - neutral (class 2): weight = 7.5513
# Some weights of RobertaModel were not initialized from the model checkpoint at klue/roberta-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch:   0%|          | 0/30 [00:00<?, ?it/s]
# [Entity] Epoch 1 | Train Loss: 0.5967
# [Entity] Dev F1_macro: 0.8385
# Saved best entity model
# [Polarity] Epoch 1 | Train Loss: 0.8240
# [Polarity] Dev F1_macro: 0.6154
# Epoch:   3%|▎         | 1/30 [01:30<43:42, 90.44s/it]
# Saved best polarity model
# [Entity] Epoch 2 | Train Loss: 0.3177
# [Entity] Dev F1_macro: 0.8771
# Saved best entity model
# [Polarity] Epoch 2 | Train Loss: 0.6805
# [Polarity] Dev F1_macro: 0.7110
# Epoch:   7%|▋         | 2/30 [03:01<42:20, 90.74s/it]
# Saved best polarity model
# [Entity] Epoch 3 | Train Loss: 0.2815
# [Entity] Dev F1_macro: 0.8827
# Saved best entity model
# [Polarity] Epoch 3 | Train Loss: 0.6076
# [Polarity] Dev F1_macro: 0.7236
# Epoch:  10%|█         | 3/30 [04:32<40:52, 90.83s/it]
# Saved best polarity model
# [Entity] Epoch 4 | Train Loss: 0.2734
# [Entity] Dev F1_macro: 0.8962
# Saved best entity model
# [Polarity] Epoch 4 | Train Loss: 0.5730
# [Polarity] Dev F1_macro: 0.7390
# Epoch:  13%|█▎        | 4/30 [06:03<39:22, 90.86s/it]
# Saved best polarity model
# [Entity] Epoch 5 | Train Loss: 0.2923
# [Entity] Dev F1_macro: 0.9009
# Saved best entity model
# [Polarity] Epoch 5 | Train Loss: 0.5138
# [Polarity] Dev F1_macro: 0.7454
# Epoch:  17%|█▋        | 5/30 [07:34<37:53, 90.93s/it]
# Saved best polarity model
# [Entity] Epoch 6 | Train Loss: 0.3673
# [Entity] Dev F1_macro: 0.9109
# Saved best entity model
# [Polarity] Epoch 6 | Train Loss: 0.4807
# [Polarity] Dev F1_macro: 0.7721
# Epoch:  20%|██        | 6/30 [09:05<36:24, 91.00s/it]
# Saved best polarity model
# [Entity] Epoch 7 | Train Loss: 0.4547
# [Entity] Dev F1_macro: 0.9133
# Saved best entity model
# [Polarity] Epoch 7 | Train Loss: 0.4112
# [Polarity] Dev F1_macro: 0.7952
# Epoch:  23%|██▎       | 7/30 [10:36<34:57, 91.18s/it]
# Saved best polarity model
# [Entity] Epoch 8 | Train Loss: 0.4789
# [Entity] Dev F1_macro: 0.9160
# Saved best entity model
# [Polarity] Epoch 8 | Train Loss: 0.3675
# [Polarity] Dev F1_macro: 0.7954
# Epoch:  27%|██▋       | 8/30 [12:08<33:30, 91.39s/it]
# Saved best polarity model
# [Entity] Epoch 9 | Train Loss: 0.4099
# [Entity] Dev F1_macro: 0.9143
# [Polarity] Epoch 9 | Train Loss: 0.3368
# [Polarity] Dev F1_macro: 0.8225
# Epoch:  30%|███       | 9/30 [13:33<31:18, 89.45s/it]
# Saved best polarity model
# [Entity] Epoch 10 | Train Loss: 0.3606
# [Entity] Dev F1_macro: 0.9223
# Saved best entity model
# [Polarity] Epoch 10 | Train Loss: 0.2604
# [Polarity] Dev F1_macro: 0.8250
# Epoch:  33%|███▎      | 10/30 [15:05<29:58, 89.94s/it]
# Saved best polarity model
# [Entity] Epoch 11 | Train Loss: 0.3514
# [Entity] Dev F1_macro: 0.9225
# Saved best entity model
# [Polarity] Epoch 11 | Train Loss: 0.2350
# Epoch:  37%|███▋      | 11/30 [16:30<28:01, 88.50s/it]
# [Polarity] Dev F1_macro: 0.8126
# [Entity] Epoch 12 | Train Loss: 0.3508
# [Entity] Dev F1_macro: 0.9216
# [Polarity] Epoch 12 | Train Loss: 0.2145
# [Polarity] Dev F1_macro: 0.8479
# Epoch:  40%|████      | 12/30 [17:54<26:11, 87.29s/it]
# Saved best polarity model
# [Entity] Epoch 13 | Train Loss: 0.3395
# [Entity] Dev F1_macro: 0.9205
# [Polarity] Epoch 13 | Train Loss: 0.2091
# Epoch:  43%|████▎     | 13/30 [19:18<24:25, 86.20s/it]
# [Polarity] Dev F1_macro: 0.8326
# [Entity] Epoch 14 | Train Loss: 0.3058
# [Entity] Dev F1_macro: 0.9211
# [Polarity] Epoch 14 | Train Loss: 0.1960
# [Polarity] Dev F1_macro: 0.8639
# Epoch:  47%|████▋     | 14/30 [20:42<22:50, 85.64s/it]
# Saved best polarity model
# [Entity] Epoch 15 | Train Loss: 0.2659
# [Entity] Dev F1_macro: 0.9162
# Early stopping triggered (Entity)
# [Polarity] Epoch 15 | Train Loss: 0.1950
# Epoch:  50%|█████     | 15/30 [22:06<21:15, 85.05s/it]
# [Polarity] Dev F1_macro: 0.8620
# [Entity] Epoch 16 | Train Loss: 0.2518
# [Entity] Dev F1_macro: 0.9287
# Saved best entity model
# Early stopping triggered (Entity)
# [Polarity] Epoch 16 | Train Loss: 0.1654
# Epoch:  53%|█████▎    | 16/30 [23:31<19:48, 84.88s/it]
# [Polarity] Dev F1_macro: 0.8622
# [Entity] Epoch 17 | Train Loss: 0.2547
# [Entity] Dev F1_macro: 0.9231
# Early stopping triggered (Entity)
# [Polarity] Epoch 17 | Train Loss: 0.1577
# [Polarity] Dev F1_macro: 0.8639
# Epoch:  57%|█████▋    | 17/30 [24:55<18:22, 84.83s/it]
# Saved best polarity model
# [Entity] Epoch 18 | Train Loss: 0.2537
# [Entity] Dev F1_macro: 0.9243
# Early stopping triggered (Entity)
# [Polarity] Epoch 18 | Train Loss: 0.2022
# Epoch:  60%|██████    | 18/30 [26:19<16:54, 84.52s/it]
# [Polarity] Dev F1_macro: 0.8602
# [Entity] Epoch 19 | Train Loss: 0.2256
# [Entity] Dev F1_macro: 0.9255
# Early stopping triggered (Entity)
# [Polarity] Epoch 19 | Train Loss: 0.1803
# [Polarity] Dev F1_macro: 0.8663
# Epoch:  63%|██████▎   | 19/30 [27:44<15:29, 84.54s/it]
# Saved best polarity model
# [Entity] Epoch 20 | Train Loss: 0.2159
# [Entity] Dev F1_macro: 0.9279
# Early stopping triggered (Entity)
# [Polarity] Epoch 20 | Train Loss: 0.2034
# [Polarity] Dev F1_macro: 0.8721
# Epoch:  67%|██████▋   | 20/30 [29:09<14:07, 84.72s/it]
# Saved best polarity model
# [Entity] Epoch 21 | Train Loss: 0.2254
# [Entity] Dev F1_macro: 0.9304
# Saved best entity model
# Early stopping triggered (Entity)
# [Polarity] Epoch 21 | Train Loss: 0.2057
# Epoch:  70%|███████   | 21/30 [30:34<12:43, 84.87s/it]
# [Polarity] Dev F1_macro: 0.8713
# [Entity] Epoch 22 | Train Loss: 0.2145
# [Entity] Dev F1_macro: 0.9266
# Early stopping triggered (Entity)
# [Polarity] Epoch 22 | Train Loss: 0.2119
# [Polarity] Dev F1_macro: 0.8773
# Epoch:  73%|███████▎  | 22/30 [31:59<11:18, 84.84s/it]
# Saved best polarity model
# [Entity] Epoch 23 | Train Loss: 0.2018
# [Entity] Dev F1_macro: 0.9296
# Early stopping triggered (Entity)
# [Polarity] Epoch 23 | Train Loss: 0.1735
# Epoch:  77%|███████▋  | 23/30 [33:23<09:51, 84.54s/it]
# [Polarity] Dev F1_macro: 0.8725
# [Entity] Epoch 24 | Train Loss: 0.2187
# [Entity] Dev F1_macro: 0.9287
# Early stopping triggered (Entity)
# [Polarity] Epoch 24 | Train Loss: 0.1931
# [Polarity] Dev F1_macro: 0.8882
# Epoch:  80%|████████  | 24/30 [34:47<08:27, 84.56s/it]
# Saved best polarity model
# [Entity] Epoch 25 | Train Loss: 0.2070
# [Entity] Dev F1_macro: 0.9282
# Early stopping triggered (Entity)
# [Polarity] Epoch 25 | Train Loss: 0.1725
# Epoch:  83%|████████▎ | 25/30 [36:11<07:01, 84.34s/it]
# [Polarity] Dev F1_macro: 0.8777
# [Entity] Epoch 26 | Train Loss: 0.1862
# [Entity] Dev F1_macro: 0.9307
# Saved best entity model
# Early stopping triggered (Entity)
# [Polarity] Epoch 26 | Train Loss: 0.1681
# Epoch:  87%|████████▋ | 26/30 [37:36<05:38, 84.56s/it]
# [Polarity] Dev F1_macro: 0.8777
# [Entity] Epoch 27 | Train Loss: 0.1955
# [Entity] Dev F1_macro: 0.9264
# Early stopping triggered (Entity)
# [Polarity] Epoch 27 | Train Loss: 0.2020
# Epoch:  90%|█████████ | 27/30 [39:00<04:13, 84.45s/it]
# [Polarity] Dev F1_macro: 0.8764
# [Entity] Epoch 28 | Train Loss: 0.1901
# [Entity] Dev F1_macro: 0.9300
# Early stopping triggered (Entity)
# [Polarity] Epoch 28 | Train Loss: 0.1719
# Epoch:  90%|█████████ | 27/30 [40:24<04:29, 89.78s/it]
# [Polarity] Dev F1_macro: 0.8662
# Early stopping triggered (Polarity)
# Training complete.

# %%
test_data = jsonlload(test_data_path)
test_sentiment_analysis(test_data)
# Out:
# Starting Sentiment Analysis Test...
# Some weights of RobertaModel were not initialized from the model checkpoint at klue/roberta-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Confidence 값 분포 (ACD 단계):
#   - max: 1.0000
#   - min: 0.7700
#   - mean: 0.9999
#   - median: 1.0000
#
# Confidence 값 분포 (ASC 단계):
#   - max: 1.0000
#   - min: 0.5777
#   - mean: 0.9967
#   - median: 1.0000
#
# F1 Evaluation Result:
#
# ▶ ACD result
#    Precision: 0.9722
#    Recall: 0.9741
#    F1: 0.9731
#
# ▶ entire ABSA result
#    Precision: 0.9443
#    Recall: 0.9387
#    F1: 0.9415
#
# Per-Aspect Performance:
#
#  - 가격
#    ACD_Precision: 1.0
#    ACD_Recall: 0.9583
#    ACD_F1: 0.9787
#    ABSA_Precision: 0.9565
#    ABSA_Recall: 0.9167
#    ABSA_F1: 0.9362
#    Support: 24
#
#  - 거품
#    ACD_Precision: 1.0
#    ACD_Recall: 0.9901
#    ACD_F1: 0.995
#    ABSA_Precision: 0.98
#    ABSA_Recall: 0.9703
#    ABSA_F1: 0.9751
#    Support: 101
#
#  - 머릿결
#    ACD_Precision: 0.963
#    ACD_Recall: 1.0
#    ACD_F1: 0.9811
#    ABSA_Precision: 0.9074
#    ABSA_Recall: 0.9423
#    ABSA_F1: 0.9245
#    Support: 52
#
#  - 세정
#    ACD_Precision: 0.9746
#    ACD_Recall: 0.9664
#    ACD_F1: 0.9705
#    ABSA_Precision: 0.9661
#    ABSA_Recall: 0.958
#    ABSA_F1: 0.962
#    Support: 119
#
#  - 없음
#    ACD_Precision: 0.0
#    ACD_Recall: 0.0
#    ACD_F1: 0.0
#    ABSA_Precision: 0
#    ABSA_Recall: 0
#    ABSA_F1: 0
#    Support: 0
#
#  - 자극
#    ACD_Precision: 0.9268
#    ACD_Recall: 0.95
#    ACD_F1: 0.9383
#    ABSA_Precision: 0.9024
#    ABSA_Recall: 0.9024
#    ABSA_F1: 0.9024
#    Support: 40
#
#  - 쿨링
#    ACD_Precision: 1.0
#    ACD_Recall: 1.0
#    ACD_F1: 1.0
#    ABSA_Precision: 1.0
#    ABSA_Recall: 1.0
#    ABSA_F1: 1.0
#    Support: 14
#
#  - 탈모
#    ACD_Precision: 0.9091
#    ACD_Recall: 0.8333
#    ACD_F1: 0.8696
#    ABSA_Precision: 0.8636
#    ABSA_Recall: 0.7917
#    ABSA_F1: 0.8261
#    Support: 24
#
#  - 향
#    ACD_Precision: 0.9695
#    ACD_Recall: 0.9922
#    ACD_F1: 0.9807
#    ABSA_Precision: 0.9313
#    ABSA_Recall: 0.9313
#    ABSA_F1: 0.9313
#    Support: 128
#
# Average Loss:
#  - ACD Loss: 0.8687
#  - ASC Loss: 1.0650
# Saved predictions to /content/drive/MyDrive/ABSA/pred_result

# %% [markdown]
# # StratifiedKFold 적용

# %%
# !pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Downloading scikit_learn-1.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 129.2 MB/s eta 0:00:00
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.7.0 which is incompatible.
# Successfully installed scikit-learn-1.7.0

# %%
import sklearn
from sklearn.model_selection import StratifiedKFold, KFold

# %%
def set_seed(seedNum, device='cpu'):
    torch.manual_seed(seedNum)
    np.random.seed(seedNum)
    random.seed(seedNum)
    if device == 'cuda' and torch.cuda.is_available():
        torch.cuda.manual_seed(seedNum)
        torch.cuda.manual_seed_all(seedNum)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

def custom_stratified_KFold(file_list, n_splits, which_k):
    data = jsonlload(file_list)
    labels = []

    for d in data:
        annotation = d.get("annotation", [])
        if not annotation:
            labels.append(0)
            continue
        max_idx = max(entity_property_pair.index(anno[0]) for anno in annotation if anno[0] in entity_property_pair)
        labels.append(max_idx)

    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=1)

    for n_iter, (train_idx, test_idx) in enumerate(skf.split(data, labels), 1):
        if n_iter == which_k:
            print(f'CustomStratifiedKFold - {n_iter}/{n_splits}')
            train_data = [data[i] for i in train_idx]
            test_data = [data[i] for i in test_idx]

            save_path = os.path.join(DATA_DIR, f"{n_iter}Fold.jsonl")
            jsondump(test_data, save_path)

            return train_data, test_data

set_seed(1, device)

# input_file_list = ["train.jsonl", "dev.jsonl", "temp_aug.jsonl"]
input_file_list = ["train.jsonl", "dev.jsonl"]

# %%
train_data, dev_data = custom_stratified_KFold(input_file_list, 3, 1)
# Out:
# CustomStratifiedKFold - 1/3

# %%
train_sentiment_analysis(train_data, dev_data)
# Out:
# train_sentiment_analysis START
# Token indices sequence length is longer than the specified maximum sequence length for this model (630 > 512). Running this sequence through the model will result in indexing errors
# Entity Class Weights:
#   - False (class 0): weight = 1.3015
#   - True (class 1): weight = 4.3166
# Polarity Class Weights:
#   - positive (class 0): weight = 1.6432
#   - negative (class 1): weight = 3.9215
#   - neutral (class 2): weight = 7.3296
# Some weights of RobertaModel were not initialized from the model checkpoint at klue/roberta-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch:   0%|          | 0/30 [00:00<?, ?it/s]
# [Entity] Epoch 1 | Train Loss: 0.5538
# [Entity] Dev F1_macro: 0.8450
# Saved best entity model
# [Polarity] Epoch 1 | Train Loss: 0.8188
# [Polarity] Dev F1_macro: 0.6428
# Epoch:   3%|▎         | 1/30 [01:14<36:13, 74.95s/it]
# Saved best polarity model
# [Entity] Epoch 2 | Train Loss: 0.3282
# [Entity] Dev F1_macro: 0.8642
# Saved best entity model
# [Polarity] Epoch 2 | Train Loss: 0.6707
# [Polarity] Dev F1_macro: 0.6861
# Epoch:   7%|▋         | 2/30 [02:37<36:56, 79.17s/it]
# Saved best polarity model
# [Entity] Epoch 3 | Train Loss: 0.2954
# [Entity] Dev F1_macro: 0.8720
# Saved best entity model
# [Polarity] Epoch 3 | Train Loss: 0.6112
# [Polarity] Dev F1_macro: 0.7061
# Epoch:  10%|█         | 3/30 [03:59<36:22, 80.83s/it]
# Saved best polarity model
# [Entity] Epoch 4 | Train Loss: 0.2761
# [Entity] Dev F1_macro: 0.8753
# Saved best entity model
# [Polarity] Epoch 4 | Train Loss: 0.5459
# [Polarity] Dev F1_macro: 0.7170
# Epoch:  13%|█▎        | 4/30 [05:22<35:21, 81.60s/it]
# Saved best polarity model
# [Entity] Epoch 5 | Train Loss: 0.2657
# [Entity] Dev F1_macro: 0.8858
# Saved best entity model
# [Polarity] Epoch 5 | Train Loss: 0.5136
# [Polarity] Dev F1_macro: 0.7225
# Epoch:  17%|█▋        | 5/30 [06:45<34:08, 81.96s/it]
# Saved best polarity model
# [Entity] Epoch 6 | Train Loss: 0.2534
# [Entity] Dev F1_macro: 0.8881
# Saved best entity model
# [Polarity] Epoch 6 | Train Loss: 0.4641
# [Polarity] Dev F1_macro: 0.7324
# Epoch:  20%|██        | 6/30 [08:07<32:50, 82.11s/it]
# Saved best polarity model
# [Entity] Epoch 7 | Train Loss: 0.2668
# [Entity] Dev F1_macro: 0.8951
# Saved best entity model
# [Polarity] Epoch 7 | Train Loss: 0.4483
# [Polarity] Dev F1_macro: 0.7349
# Epoch:  23%|██▎       | 7/30 [09:30<31:32, 82.27s/it]
# Saved best polarity model
# [Entity] Epoch 8 | Train Loss: 0.2634
# [Entity] Dev F1_macro: 0.8969
# Saved best entity model
# [Polarity] Epoch 8 | Train Loss: 0.4311
# Epoch:  27%|██▋       | 8/30 [10:45<29:21, 80.05s/it]
# [Polarity] Dev F1_macro: 0.7349
# [Entity] Epoch 9 | Train Loss: 0.2885
# [Entity] Dev F1_macro: 0.8985
# Saved best entity model
# [Polarity] Epoch 9 | Train Loss: 0.4225
# [Polarity] Dev F1_macro: 0.7444
# Epoch:  30%|███       | 9/30 [12:07<28:13, 80.64s/it]
# Saved best polarity model
# [Entity] Epoch 10 | Train Loss: 0.3410
# [Entity] Dev F1_macro: 0.9009
# Saved best entity model
# [Polarity] Epoch 10 | Train Loss: 0.4106
# [Polarity] Dev F1_macro: 0.7485
# Epoch:  33%|███▎      | 10/30 [13:29<27:01, 81.09s/it]
# Saved best polarity model
# [Entity] Epoch 11 | Train Loss: 0.3878
# [Entity] Dev F1_macro: 0.9032
# Saved best entity model
# [Polarity] Epoch 11 | Train Loss: 0.4037
# [Polarity] Dev F1_macro: 0.7503
# Epoch:  37%|███▋      | 11/30 [14:54<26:00, 82.14s/it]
# Saved best polarity model
# [Entity] Epoch 12 | Train Loss: 0.4496
# [Entity] Dev F1_macro: 0.8999
# [Polarity] Epoch 12 | Train Loss: 0.4185
# Epoch:  40%|████      | 12/30 [16:07<23:52, 79.58s/it]
# [Polarity] Dev F1_macro: 0.7341
# [Entity] Epoch 13 | Train Loss: 0.3929
# [Entity] Dev F1_macro: 0.9095
# Saved best entity model
# [Polarity] Epoch 13 | Train Loss: 0.3933
# [Polarity] Dev F1_macro: 0.7586
# Epoch:  43%|████▎     | 13/30 [17:29<22:42, 80.17s/it]
# Saved best polarity model
# [Entity] Epoch 14 | Train Loss: 0.3777
# [Entity] Dev F1_macro: 0.9094
# [Polarity] Epoch 14 | Train Loss: 0.3531
# [Polarity] Dev F1_macro: 0.7754
# Epoch:  47%|████▋     | 14/30 [18:44<20:56, 78.52s/it]
# Saved best polarity model
# [Entity] Epoch 15 | Train Loss: 0.3689
# [Entity] Dev F1_macro: 0.9110
# Saved best entity model
# [Polarity] Epoch 15 | Train Loss: 0.3135
# Epoch:  50%|█████     | 15/30 [19:59<19:21, 77.45s/it]
# [Polarity] Dev F1_macro: 0.7723
# [Entity] Epoch 16 | Train Loss: 0.3451
# [Entity] Dev F1_macro: 0.9108
# [Polarity] Epoch 16 | Train Loss: 0.3111
# [Polarity] Dev F1_macro: 0.7806
# Epoch:  53%|█████▎    | 16/30 [21:13<17:53, 76.67s/it]
# Saved best polarity model
# [Entity] Epoch 17 | Train Loss: 0.3610
# [Entity] Dev F1_macro: 0.9126
# Saved best entity model
# [Polarity] Epoch 17 | Train Loss: 0.3158
# [Polarity] Dev F1_macro: 0.7829
# Epoch:  57%|█████▋    | 17/30 [22:35<16:57, 78.29s/it]
# Saved best polarity model
# [Entity] Epoch 18 | Train Loss: 0.3096
# [Entity] Dev F1_macro: 0.9119
# [Polarity] Epoch 18 | Train Loss: 0.2720
# [Polarity] Dev F1_macro: 0.7840
# Epoch:  60%|██████    | 18/30 [23:50<15:25, 77.11s/it]
# Saved best polarity model
# [Entity] Epoch 19 | Train Loss: 0.2754
# [Entity] Dev F1_macro: 0.9134
# Saved best entity model
# [Polarity] Epoch 19 | Train Loss: 0.2297
# [Polarity] Dev F1_macro: 0.8002
# Epoch:  63%|██████▎   | 19/30 [25:10<14:19, 78.12s/it]
# Saved best polarity model
# [Entity] Epoch 20 | Train Loss: 0.2981
# [Entity] Dev F1_macro: 0.9136
# Saved best entity model
# [Polarity] Epoch 20 | Train Loss: 0.2399
# [Polarity] Dev F1_macro: 0.8107
# Epoch:  67%|██████▋   | 20/30 [26:32<13:12, 79.28s/it]
# Saved best polarity model
# [Entity] Epoch 21 | Train Loss: 0.2636
# [Entity] Dev F1_macro: 0.9129
# [Polarity] Epoch 21 | Train Loss: 0.2080
# Epoch:  70%|███████   | 21/30 [27:47<11:40, 77.83s/it]
# [Polarity] Dev F1_macro: 0.8104
# [Entity] Epoch 22 | Train Loss: 0.2629
# [Entity] Dev F1_macro: 0.9137
# Saved best entity model
# [Polarity] Epoch 22 | Train Loss: 0.1815
# [Polarity] Dev F1_macro: 0.8254
# Epoch:  73%|███████▎  | 22/30 [29:08<10:31, 78.99s/it]
# Saved best polarity model
# [Entity] Epoch 23 | Train Loss: 0.2841
# [Entity] Dev F1_macro: 0.9145
# Saved best entity model
# [Polarity] Epoch 23 | Train Loss: 0.2009
# Epoch:  77%|███████▋  | 23/30 [30:23<09:04, 77.81s/it]
# [Polarity] Dev F1_macro: 0.8236
# [Entity] Epoch 24 | Train Loss: 0.2563
# [Entity] Dev F1_macro: 0.9176
# Saved best entity model
# [Polarity] Epoch 24 | Train Loss: 0.1693
# [Polarity] Dev F1_macro: 0.8259
# Epoch:  80%|████████  | 24/30 [31:46<07:54, 79.12s/it]
# Saved best polarity model
# [Entity] Epoch 25 | Train Loss: 0.2231
# [Entity] Dev F1_macro: 0.9178
# Saved best entity model
# [Polarity] Epoch 25 | Train Loss: 0.1391
# [Polarity] Dev F1_macro: 0.8339
# Epoch:  83%|████████▎ | 25/30 [33:09<06:41, 80.26s/it]
# Saved best polarity model
# [Entity] Epoch 26 | Train Loss: 0.2331
# [Entity] Dev F1_macro: 0.9160
# [Polarity] Epoch 26 | Train Loss: 0.1527
# Epoch:  87%|████████▋ | 26/30 [34:23<05:13, 78.50s/it]
# [Polarity] Dev F1_macro: 0.8310
# [Entity] Epoch 27 | Train Loss: 0.2435
# [Entity] Dev F1_macro: 0.9164
# [Polarity] Epoch 27 | Train Loss: 0.1421
# [Polarity] Dev F1_macro: 0.8347
# Epoch:  90%|█████████ | 27/30 [35:37<03:51, 77.22s/it]
# Saved best polarity model
# [Entity] Epoch 28 | Train Loss: 0.2473
# [Entity] Dev F1_macro: 0.9160
# [Polarity] Epoch 28 | Train Loss: 0.1554
# Epoch:  93%|█████████▎| 28/30 [36:51<02:32, 76.12s/it]
# [Polarity] Dev F1_macro: 0.8307
# [Entity] Epoch 29 | Train Loss: 0.2207
# [Entity] Dev F1_macro: 0.9157
# Early stopping triggered (Entity)
# [Polarity] Epoch 29 | Train Loss: 0.1518
# Epoch:  97%|█████████▋| 29/30 [38:04<01:15, 75.29s/it]
# [Polarity] Dev F1_macro: 0.8303
# [Entity] Epoch 30 | Train Loss: 0.2287
# [Entity] Dev F1_macro: 0.9166
# Early stopping triggered (Entity)
# [Polarity] Epoch 30 | Train Loss: 0.1360
# Epoch: 100%|██████████| 30/30 [39:17<00:00, 78.59s/it]
# [Polarity] Dev F1_macro: 0.8303
# Training complete.

# %%
test_data = jsonlload(test_data_path)
test_sentiment_analysis(test_data)
# Out:
# Starting Sentiment Analysis Test...
# Some weights of RobertaModel were not initialized from the model checkpoint at klue/roberta-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Confidence 값 분포 (ACD 단계):
#   - max: 1.0000
#   - min: 0.6027
#   - mean: 0.9993
#   - median: 1.0000
#
# Confidence 값 분포 (ASC 단계):
#   - max: 0.9996
#   - min: 0.4095
#   - mean: 0.9644
#   - median: 0.9988
#
# F1 Evaluation Result:
#
# ▶ ACD result
#    Precision: 0.9464
#    Recall: 0.9502
#    F1: 0.9483
#
# ▶ entire ABSA result
#    Precision: 0.8889
#    Recall: 0.8854
#    F1: 0.8871
#
# Per-Aspect Performance:
#
#  - 가격
#    ACD_Precision: 0.92
#    ACD_Recall: 0.9583
#    ACD_F1: 0.9388
#    ABSA_Precision: 0.8
#    ABSA_Recall: 0.8333
#    ABSA_F1: 0.8163
#    Support: 24
#
#  - 거품
#    ACD_Precision: 1.0
#    ACD_Recall: 0.9901
#    ACD_F1: 0.995
#    ABSA_Precision: 0.96
#    ABSA_Recall: 0.9505
#    ABSA_F1: 0.9552
#    Support: 101
#
#  - 머릿결
#    ACD_Precision: 0.8947
#    ACD_Recall: 0.9808
#    ACD_F1: 0.9358
#    ABSA_Precision: 0.8421
#    ABSA_Recall: 0.9231
#    ABSA_F1: 0.8807
#    Support: 52
#
#  - 세정
#    ACD_Precision: 0.9316
#    ACD_Recall: 0.916
#    ACD_F1: 0.9237
#    ABSA_Precision: 0.8718
#    ABSA_Recall: 0.8571
#    ABSA_F1: 0.8644
#    Support: 119
#
#  - 없음
#    ACD_Precision: 0.0
#    ACD_Recall: 0.0
#    ACD_F1: 0.0
#    ABSA_Precision: 0
#    ABSA_Recall: 0
#    ABSA_F1: 0
#    Support: 0
#
#  - 자극
#    ACD_Precision: 0.9474
#    ACD_Recall: 0.9
#    ACD_F1: 0.9231
#    ABSA_Precision: 0.8684
#    ABSA_Recall: 0.8049
#    ABSA_F1: 0.8354
#    Support: 40
#
#  - 쿨링
#    ACD_Precision: 0.8667
#    ACD_Recall: 0.9286
#    ACD_F1: 0.8966
#    ABSA_Precision: 0.8667
#    ABSA_Recall: 0.9286
#    ABSA_F1: 0.8966
#    Support: 14
#
#  - 탈모
#    ACD_Precision: 0.8696
#    ACD_Recall: 0.8333
#    ACD_F1: 0.8511
#    ABSA_Precision: 0.8261
#    ABSA_Recall: 0.7917
#    ABSA_F1: 0.8085
#    Support: 24
#
#  - 향
#    ACD_Precision: 0.969
#    ACD_Recall: 0.9766
#    ACD_F1: 0.9728
#    ABSA_Precision: 0.907
#    ABSA_Recall: 0.8931
#    ABSA_F1: 0.9
#    Support: 128
#
# Average Loss:
#  - ACD Loss: 0.8687
#  - ASC Loss: 0.6594
# Saved predictions to /content/drive/MyDrive/ABSA/pred_result

# %%
train_data, dev_data = custom_stratified_KFold(input_file_list, 3, 2)
# Out:
# CustomStratifiedKFold - 2/3

# %%
train_sentiment_analysis(train_data, dev_data)
# Out:
# train_sentiment_analysis START
# Token indices sequence length is longer than the specified maximum sequence length for this model (630 > 512). Running this sequence through the model will result in indexing errors
# Entity Class Weights:
#   - False (class 0): weight = 1.2942
#   - True (class 1): weight = 4.3990
# Polarity Class Weights:
#   - positive (class 0): weight = 1.6674
#   - negative (class 1): weight = 3.8134
#   - neutral (class 2): weight = 7.2455
# Some weights of RobertaModel were not initialized from the model checkpoint at klue/roberta-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch:   0%|          | 0/30 [00:00<?, ?it/s]
# [Entity] Epoch 1 | Train Loss: 0.5487
# [Entity] Dev F1_macro: 0.8647
# Saved best entity model
# [Polarity] Epoch 1 | Train Loss: 0.8715
# [Polarity] Dev F1_macro: 0.6527
# Epoch:   3%|▎         | 1/30 [01:21<39:29, 81.70s/it]
# Saved best polarity model
# [Entity] Epoch 2 | Train Loss: 0.3296
# [Entity] Dev F1_macro: 0.8710
# Saved best entity model
# [Polarity] Epoch 2 | Train Loss: 0.6959
# [Polarity] Dev F1_macro: 0.6908
# Epoch:   7%|▋         | 2/30 [02:44<38:28, 82.46s/it]
# Saved best polarity model
# [Entity] Epoch 3 | Train Loss: 0.3119
# [Entity] Dev F1_macro: 0.8703
# [Polarity] Epoch 3 | Train Loss: 0.6127
# [Polarity] Dev F1_macro: 0.7375
# Epoch:  10%|█         | 3/30 [03:59<35:27, 78.79s/it]
# Saved best polarity model
# [Entity] Epoch 4 | Train Loss: 0.2791
# [Entity] Dev F1_macro: 0.9014
# Saved best entity model
# [Polarity] Epoch 4 | Train Loss: 0.5409
# Epoch:  13%|█▎        | 4/30 [05:14<33:29, 77.29s/it]
# [Polarity] Dev F1_macro: 0.7216
# [Entity] Epoch 5 | Train Loss: 0.2709
# [Entity] Dev F1_macro: 0.9045
# Saved best entity model
# [Polarity] Epoch 5 | Train Loss: 0.4826
# [Polarity] Dev F1_macro: 0.7591
# Epoch:  17%|█▋        | 5/30 [06:36<32:55, 79.02s/it]
# Saved best polarity model
# [Entity] Epoch 6 | Train Loss: 0.2667
# [Entity] Dev F1_macro: 0.9094
# Saved best entity model
# [Polarity] Epoch 6 | Train Loss: 0.4223
# [Polarity] Dev F1_macro: 0.7706
# Epoch:  20%|██        | 6/30 [07:58<32:06, 80.27s/it]
# Saved best polarity model
# [Entity] Epoch 7 | Train Loss: 0.2758
# [Entity] Dev F1_macro: 0.9129
# Saved best entity model
# [Polarity] Epoch 7 | Train Loss: 0.3945
# Epoch:  23%|██▎       | 7/30 [09:13<30:05, 78.51s/it]
# [Polarity] Dev F1_macro: 0.7694
# [Entity] Epoch 8 | Train Loss: 0.3136
# [Entity] Dev F1_macro: 0.9149
# Saved best entity model
# [Polarity] Epoch 8 | Train Loss: 0.3900
# [Polarity] Dev F1_macro: 0.7721
# Epoch:  27%|██▋       | 8/30 [10:35<29:12, 79.64s/it]
# Saved best polarity model
# [Entity] Epoch 9 | Train Loss: 0.4379
# [Entity] Dev F1_macro: 0.9195
# Saved best entity model
# [Polarity] Epoch 9 | Train Loss: 0.3483
# [Polarity] Dev F1_macro: 0.7997
# Epoch:  30%|███       | 9/30 [11:58<28:12, 80.60s/it]
# Saved best polarity model
# [Entity] Epoch 10 | Train Loss: 0.4490
# [Entity] Dev F1_macro: 0.9217
# Saved best entity model
# [Polarity] Epoch 10 | Train Loss: 0.3333
# [Polarity] Dev F1_macro: 0.8293
# Epoch:  33%|███▎      | 10/30 [13:20<27:02, 81.11s/it]
# Saved best polarity model
# [Entity] Epoch 11 | Train Loss: 0.4554
# [Entity] Dev F1_macro: 0.9211
# [Polarity] Epoch 11 | Train Loss: 0.3101
# [Polarity] Dev F1_macro: 0.8318
# Epoch:  37%|███▋      | 11/30 [14:35<25:04, 79.20s/it]
# Saved best polarity model
# [Entity] Epoch 12 | Train Loss: 0.3926
# [Entity] Dev F1_macro: 0.9241
# Saved best entity model
# [Polarity] Epoch 12 | Train Loss: 0.2897
# [Polarity] Dev F1_macro: 0.8462
# Epoch:  40%|████      | 12/30 [15:58<24:04, 80.25s/it]
# Saved best polarity model
# [Entity] Epoch 13 | Train Loss: 0.3222
# [Entity] Dev F1_macro: 0.9271
# Saved best entity model
# [Polarity] Epoch 13 | Train Loss: 0.2324
# [Polarity] Dev F1_macro: 0.8644
# Epoch:  43%|████▎     | 13/30 [17:20<22:56, 80.95s/it]
# Saved best polarity model
# [Entity] Epoch 14 | Train Loss: 0.3114
# [Entity] Dev F1_macro: 0.9274
# Saved best entity model
# [Polarity] Epoch 14 | Train Loss: 0.1615
# [Polarity] Dev F1_macro: 0.8663
# Epoch:  47%|████▋     | 14/30 [18:43<21:44, 81.56s/it]
# Saved best polarity model
# [Entity] Epoch 15 | Train Loss: 0.2884
# [Entity] Dev F1_macro: 0.9272
# [Polarity] Epoch 15 | Train Loss: 0.1534
# [Polarity] Dev F1_macro: 0.8705
# Epoch:  50%|█████     | 15/30 [19:58<19:54, 79.62s/it]
# Saved best polarity model
# [Entity] Epoch 16 | Train Loss: 0.2855
# [Entity] Dev F1_macro: 0.9265
# [Polarity] Epoch 16 | Train Loss: 0.1382
# [Polarity] Dev F1_macro: 0.8731
# Epoch:  53%|█████▎    | 16/30 [21:13<18:14, 78.16s/it]
# Saved best polarity model
# [Entity] Epoch 17 | Train Loss: 0.2770
# [Entity] Dev F1_macro: 0.9270
# [Polarity] Epoch 17 | Train Loss: 0.1518
# [Polarity] Dev F1_macro: 0.8733
# Epoch:  57%|█████▋    | 17/30 [22:28<16:43, 77.21s/it]
# Saved best polarity model
# [Entity] Epoch 18 | Train Loss: 0.2794
# [Entity] Dev F1_macro: 0.9286
# Saved best entity model
# [Polarity] Epoch 18 | Train Loss: 0.1389
# [Polarity] Dev F1_macro: 0.8865
# Epoch:  60%|██████    | 18/30 [23:51<15:45, 78.80s/it]
# Saved best polarity model
# [Entity] Epoch 19 | Train Loss: 0.2544
# [Entity] Dev F1_macro: 0.9291
# Saved best entity model
# [Polarity] Epoch 19 | Train Loss: 0.1166
# Epoch:  63%|██████▎   | 19/30 [25:06<14:14, 77.66s/it]
# [Polarity] Dev F1_macro: 0.8815
# [Entity] Epoch 20 | Train Loss: 0.2535
# [Entity] Dev F1_macro: 0.9270
# [Polarity] Epoch 20 | Train Loss: 0.1270
# Epoch:  67%|██████▋   | 20/30 [26:20<12:45, 76.58s/it]
# [Polarity] Dev F1_macro: 0.8813
# [Entity] Epoch 21 | Train Loss: 0.2377
# [Entity] Dev F1_macro: 0.9283
# [Polarity] Epoch 21 | Train Loss: 0.1401
# [Polarity] Dev F1_macro: 0.8872
# Epoch:  70%|███████   | 21/30 [27:34<11:22, 75.85s/it]
# Saved best polarity model
# [Entity] Epoch 22 | Train Loss: 0.2401
# [Entity] Dev F1_macro: 0.9301
# Saved best entity model
# [Polarity] Epoch 22 | Train Loss: 0.1226
# Epoch:  73%|███████▎  | 22/30 [28:49<10:04, 75.56s/it]
# [Polarity] Dev F1_macro: 0.8754
# [Entity] Epoch 23 | Train Loss: 0.2341
# [Entity] Dev F1_macro: 0.9291
# [Polarity] Epoch 23 | Train Loss: 0.1246
# Epoch:  77%|███████▋  | 23/30 [30:03<08:45, 75.02s/it]
# [Polarity] Dev F1_macro: 0.8759
# [Entity] Epoch 24 | Train Loss: 0.2127
# [Entity] Dev F1_macro: 0.9300
# [Polarity] Epoch 24 | Train Loss: 0.1501
# Epoch:  80%|████████  | 24/30 [31:16<07:27, 74.53s/it]
# [Polarity] Dev F1_macro: 0.8774
# [Entity] Epoch 25 | Train Loss: 0.2068
# [Entity] Dev F1_macro: 0.9298
# [Polarity] Epoch 25 | Train Loss: 0.1420
# Epoch:  83%|████████▎ | 25/30 [32:29<06:10, 74.17s/it]
# [Polarity] Dev F1_macro: 0.8832
# Early stopping triggered (Polarity)
# [Entity] Epoch 26 | Train Loss: 0.2064
# Epoch:  83%|████████▎ | 25/30 [33:30<06:42, 80.43s/it]
# [Entity] Dev F1_macro: 0.9292
# Early stopping triggered (Entity)
# Training complete.

# %%
test_data = jsonlload(test_data_path)
test_sentiment_analysis(test_data)
# Out:
# Starting Sentiment Analysis Test...
# Some weights of RobertaModel were not initialized from the model checkpoint at klue/roberta-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Confidence 값 분포 (ACD 단계):
#   - max: 1.0000
#   - min: 0.5060
#   - mean: 0.9993
#   - median: 1.0000
#
# Confidence 값 분포 (ASC 단계):
#   - max: 1.0000
#   - min: 0.5086
#   - mean: 0.9900
#   - median: 0.9999
#
# F1 Evaluation Result:
#
# ▶ ACD result
#    Precision: 0.9660
#    Recall: 0.9622
#    F1: 0.9641
#
# ▶ entire ABSA result
#    Precision: 0.9300
#    Recall: 0.9190
#    F1: 0.9245
#
# Per-Aspect Performance:
#
#  - 가격
#    ACD_Precision: 0.9583
#    ACD_Recall: 0.9583
#    ACD_F1: 0.9583
#    ABSA_Precision: 0.9167
#    ABSA_Recall: 0.9167
#    ABSA_F1: 0.9167
#    Support: 24
#
#  - 거품
#    ACD_Precision: 1.0
#    ACD_Recall: 0.9901
#    ACD_F1: 0.995
#    ABSA_Precision: 0.97
#    ABSA_Recall: 0.9604
#    ABSA_F1: 0.9652
#    Support: 101
#
#  - 머릿결
#    ACD_Precision: 0.9091
#    ACD_Recall: 0.9615
#    ACD_F1: 0.9346
#    ABSA_Precision: 0.8727
#    ABSA_Recall: 0.9231
#    ABSA_F1: 0.8972
#    Support: 52
#
#  - 세정
#    ACD_Precision: 0.9661
#    ACD_Recall: 0.958
#    ACD_F1: 0.962
#    ABSA_Precision: 0.9322
#    ABSA_Recall: 0.9244
#    ABSA_F1: 0.9283
#    Support: 119
#
#  - 없음
#    ACD_Precision: 0.0
#    ACD_Recall: 0.0
#    ACD_F1: 0.0
#    ABSA_Precision: 0
#    ABSA_Recall: 0
#    ABSA_F1: 0
#    Support: 0
#
#  - 자극
#    ACD_Precision: 0.9268
#    ACD_Recall: 0.95
#    ACD_F1: 0.9383
#    ABSA_Precision: 0.8537
#    ABSA_Recall: 0.8537
#    ABSA_F1: 0.8537
#    Support: 40
#
#  - 쿨링
#    ACD_Precision: 0.8667
#    ACD_Recall: 0.9286
#    ACD_F1: 0.8966
#    ABSA_Precision: 0.8
#    ABSA_Recall: 0.8571
#    ABSA_F1: 0.8276
#    Support: 14
#
#  - 탈모
#    ACD_Precision: 1.0
#    ACD_Recall: 0.8333
#    ACD_F1: 0.9091
#    ABSA_Precision: 0.95
#    ABSA_Recall: 0.7917
#    ABSA_F1: 0.8636
#    Support: 24
#
#  - 향
#    ACD_Precision: 0.9843
#    ACD_Recall: 0.9766
#    ACD_F1: 0.9804
#    ABSA_Precision: 0.9606
#    ABSA_Recall: 0.9313
#    ABSA_F1: 0.9457
#    Support: 128
#
# Average Loss:
#  - ACD Loss: 0.8130
#  - ASC Loss: 0.8948
# Saved predictions to /content/drive/MyDrive/ABSA/pred_result

# %%
train_data, dev_data = custom_stratified_KFold(input_file_list, 3, 3)
# Out:
# CustomStratifiedKFold - 3/3

# %%
train_sentiment_analysis(train_data, dev_data)
# Out:
# train_sentiment_analysis START
# Token indices sequence length is longer than the specified maximum sequence length for this model (630 > 512). Running this sequence through the model will result in indexing errors
# Entity Class Weights:
#   - False (class 0): weight = 1.2986
#   - True (class 1): weight = 4.3485
# Polarity Class Weights:
#   - positive (class 0): weight = 1.6590
#   - negative (class 1): weight = 3.7500
#   - neutral (class 2): weight = 7.6603
# Some weights of RobertaModel were not initialized from the model checkpoint at klue/roberta-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch:   0%|          | 0/30 [00:00<?, ?it/s]
# [Entity] Epoch 1 | Train Loss: 0.5300
# [Entity] Dev F1_macro: 0.8494
# Saved best entity model
# [Polarity] Epoch 1 | Train Loss: 0.8637
# [Polarity] Dev F1_macro: 0.6143
# Epoch:   3%|▎         | 1/30 [01:21<39:32, 81.81s/it]
# Saved best polarity model
# [Entity] Epoch 2 | Train Loss: 0.3234
# [Entity] Dev F1_macro: 0.8640
# Saved best entity model
# [Polarity] Epoch 2 | Train Loss: 0.7051
# [Polarity] Dev F1_macro: 0.6407
# Epoch:   7%|▋         | 2/30 [02:44<38:29, 82.48s/it]
# Saved best polarity model
# [Entity] Epoch 3 | Train Loss: 0.3053
# [Entity] Dev F1_macro: 0.8746
# Saved best entity model
# [Polarity] Epoch 3 | Train Loss: 0.6304
# [Polarity] Dev F1_macro: 0.6815
# Epoch:  10%|█         | 3/30 [04:05<36:41, 81.54s/it]
# Saved best polarity model
# [Entity] Epoch 4 | Train Loss: 0.2760
# [Entity] Dev F1_macro: 0.8770
# Saved best entity model
# [Polarity] Epoch 4 | Train Loss: 0.5950
# [Polarity] Dev F1_macro: 0.6978
# Epoch:  13%|█▎        | 4/30 [05:28<35:40, 82.32s/it]
# Saved best polarity model
# [Entity] Epoch 5 | Train Loss: 0.2737
# [Entity] Dev F1_macro: 0.8840
# Saved best entity model
# [Polarity] Epoch 5 | Train Loss: 0.5494
# [Polarity] Dev F1_macro: 0.7027
# Epoch:  17%|█▋        | 5/30 [06:51<34:19, 82.40s/it]
# Saved best polarity model
# [Entity] Epoch 6 | Train Loss: 0.2717
# [Entity] Dev F1_macro: 0.8977
# Saved best entity model
# [Polarity] Epoch 6 | Train Loss: 0.5275
# [Polarity] Dev F1_macro: 0.7133
# Epoch:  20%|██        | 6/30 [08:13<32:59, 82.48s/it]
# Saved best polarity model
# [Entity] Epoch 7 | Train Loss: 0.2862
# [Entity] Dev F1_macro: 0.9054
# Saved best entity model
# [Polarity] Epoch 7 | Train Loss: 0.5086
# [Polarity] Dev F1_macro: 0.7358
# Epoch:  23%|██▎       | 7/30 [09:35<31:29, 82.15s/it]
# Saved best polarity model
# [Entity] Epoch 8 | Train Loss: 0.3188
# [Entity] Dev F1_macro: 0.9082
# Saved best entity model
# [Polarity] Epoch 8 | Train Loss: 0.4867
# [Polarity] Dev F1_macro: 0.7436
# Epoch:  27%|██▋       | 8/30 [10:57<30:07, 82.14s/it]
# Saved best polarity model
# [Entity] Epoch 9 | Train Loss: 0.3615
# [Entity] Dev F1_macro: 0.9103
# Saved best entity model
# [Polarity] Epoch 9 | Train Loss: 0.4082
# Epoch:  30%|███       | 9/30 [12:11<27:53, 79.71s/it]
# [Polarity] Dev F1_macro: 0.7412
# [Entity] Epoch 10 | Train Loss: 0.4448
# [Entity] Dev F1_macro: 0.9141
# Saved best entity model
# [Polarity] Epoch 10 | Train Loss: 0.3828
# [Polarity] Dev F1_macro: 0.7552
# Epoch:  33%|███▎      | 10/30 [13:34<26:50, 80.50s/it]
# Saved best polarity model
# [Entity] Epoch 11 | Train Loss: 0.4594
# [Entity] Dev F1_macro: 0.9158
# Saved best entity model
# [Polarity] Epoch 11 | Train Loss: 0.3731
# [Polarity] Dev F1_macro: 0.7764
# Epoch:  37%|███▋      | 11/30 [14:56<25:41, 81.12s/it]
# Saved best polarity model
# [Entity] Epoch 12 | Train Loss: 0.4314
# [Entity] Dev F1_macro: 0.9134
# [Polarity] Epoch 12 | Train Loss: 0.3438
# Epoch:  40%|████      | 12/30 [16:10<23:40, 78.90s/it]
# [Polarity] Dev F1_macro: 0.7634
# [Entity] Epoch 13 | Train Loss: 0.4155
# [Entity] Dev F1_macro: 0.9177
# Saved best entity model
# [Polarity] Epoch 13 | Train Loss: 0.2873
# [Polarity] Dev F1_macro: 0.7991
# Epoch:  43%|████▎     | 13/30 [17:32<22:37, 79.83s/it]
# Saved best polarity model
# [Entity] Epoch 14 | Train Loss: 0.3750
# [Entity] Dev F1_macro: 0.9183
# Saved best entity model
# [Polarity] Epoch 14 | Train Loss: 0.2922
# [Polarity] Dev F1_macro: 0.8154
# Epoch:  47%|████▋     | 14/30 [18:55<21:31, 80.71s/it]
# Saved best polarity model
# [Entity] Epoch 15 | Train Loss: 0.3368
# [Entity] Dev F1_macro: 0.9178
# [Polarity] Epoch 15 | Train Loss: 0.2527
# Epoch:  50%|█████     | 15/30 [20:08<19:39, 78.61s/it]
# [Polarity] Dev F1_macro: 0.8111
# [Entity] Epoch 16 | Train Loss: 0.3028
# [Entity] Dev F1_macro: 0.9188
# Saved best entity model
# [Polarity] Epoch 16 | Train Loss: 0.1993
# [Polarity] Dev F1_macro: 0.8242
# Epoch:  53%|█████▎    | 16/30 [21:30<18:34, 79.60s/it]
# Saved best polarity model
# [Entity] Epoch 17 | Train Loss: 0.3059
# [Entity] Dev F1_macro: 0.9191
# Saved best entity model
# [Polarity] Epoch 17 | Train Loss: 0.2105
# [Polarity] Dev F1_macro: 0.8361
# Epoch:  57%|█████▋    | 17/30 [22:53<17:25, 80.43s/it]
# Saved best polarity model
# [Entity] Epoch 18 | Train Loss: 0.2972
# [Entity] Dev F1_macro: 0.9209
# Saved best entity model
# [Polarity] Epoch 18 | Train Loss: 0.1949
# Epoch:  60%|██████    | 18/30 [24:08<15:45, 78.82s/it]
# [Polarity] Dev F1_macro: 0.8351
# [Entity] Epoch 19 | Train Loss: 0.2875
# [Entity] Dev F1_macro: 0.9210
# Saved best entity model
# [Polarity] Epoch 19 | Train Loss: 0.1755
# [Polarity] Dev F1_macro: 0.8471
# Epoch:  63%|██████▎   | 19/30 [25:29<14:36, 79.64s/it]
# Saved best polarity model
# [Entity] Epoch 20 | Train Loss: 0.2779
# [Entity] Dev F1_macro: 0.9206
# [Polarity] Epoch 20 | Train Loss: 0.1655
# [Polarity] Dev F1_macro: 0.8495
# Epoch:  67%|██████▋   | 20/30 [26:45<13:03, 78.32s/it]
# Saved best polarity model
# [Entity] Epoch 21 | Train Loss: 0.2712
# [Entity] Dev F1_macro: 0.9201
# [Polarity] Epoch 21 | Train Loss: 0.1607
# Epoch:  70%|███████   | 21/30 [27:58<11:33, 77.01s/it]
# [Polarity] Dev F1_macro: 0.8439
# [Entity] Epoch 22 | Train Loss: 0.2577
# [Entity] Dev F1_macro: 0.9176
# [Polarity] Epoch 22 | Train Loss: 0.1728
# Epoch:  73%|███████▎  | 22/30 [29:12<10:07, 75.93s/it]
# [Polarity] Dev F1_macro: 0.8394
# [Entity] Epoch 23 | Train Loss: 0.2492
# [Entity] Dev F1_macro: 0.9204
# Early stopping triggered (Entity)
# [Polarity] Epoch 23 | Train Loss: 0.1873
# Epoch:  77%|███████▋  | 23/30 [30:25<08:46, 75.16s/it]
# [Polarity] Dev F1_macro: 0.8443
# [Entity] Epoch 24 | Train Loss: 0.2306
# [Entity] Dev F1_macro: 0.9191
# Early stopping triggered (Entity)
# [Polarity] Epoch 24 | Train Loss: 0.1629
# [Polarity] Dev F1_macro: 0.8526
# Epoch:  80%|████████  | 24/30 [31:39<07:28, 74.82s/it]
# Saved best polarity model
# [Entity] Epoch 25 | Train Loss: 0.2366
# [Entity] Dev F1_macro: 0.9200
# Early stopping triggered (Entity)
# [Polarity] Epoch 25 | Train Loss: 0.2034
# Epoch:  83%|████████▎ | 25/30 [32:53<06:12, 74.56s/it]
# [Polarity] Dev F1_macro: 0.8498
# [Entity] Epoch 26 | Train Loss: 0.2467
# [Entity] Dev F1_macro: 0.9209
# Early stopping triggered (Entity)
# [Polarity] Epoch 26 | Train Loss: 0.1971
# Epoch:  87%|████████▋ | 26/30 [34:06<04:56, 74.14s/it]
# [Polarity] Dev F1_macro: 0.8448
# [Entity] Epoch 27 | Train Loss: 0.2550
# [Entity] Dev F1_macro: 0.9201
# Early stopping triggered (Entity)
# [Polarity] Epoch 27 | Train Loss: 0.1641
# Epoch:  90%|█████████ | 27/30 [35:20<03:41, 73.91s/it]
# [Polarity] Dev F1_macro: 0.8506
# [Entity] Epoch 28 | Train Loss: 0.2382
# [Entity] Dev F1_macro: 0.9202
# Early stopping triggered (Entity)
# [Polarity] Epoch 28 | Train Loss: 0.1917
# Epoch:  90%|█████████ | 27/30 [36:33<04:03, 81.24s/it]
# [Polarity] Dev F1_macro: 0.8483
# Early stopping triggered (Polarity)
# Training complete.

# %%
test_data = jsonlload(test_data_path)
test_sentiment_analysis(test_data)
# Out:
# Starting Sentiment Analysis Test...
# Some weights of RobertaModel were not initialized from the model checkpoint at klue/roberta-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Confidence 값 분포 (ACD 단계):
#   - max: 1.0000
#   - min: 0.6067
#   - mean: 0.9991
#   - median: 1.0000
#
# Confidence 값 분포 (ASC 단계):
#   - max: 0.9999
#   - min: 0.5312
#   - mean: 0.9889
#   - median: 0.9999
#
# F1 Evaluation Result:
#
# ▶ ACD result
#    Precision: 0.9557
#    Recall: 0.9462
#    F1: 0.9510
#
# ▶ entire ABSA result
#    Precision: 0.9115
#    Recall: 0.8953
#    F1: 0.9033
#
# Per-Aspect Performance:
#
#  - 가격
#    ACD_Precision: 1.0
#    ACD_Recall: 0.9583
#    ACD_F1: 0.9787
#    ABSA_Precision: 0.9565
#    ABSA_Recall: 0.9167
#    ABSA_F1: 0.9362
#    Support: 24
#
#  - 거품
#    ACD_Precision: 0.9899
#    ACD_Recall: 0.9703
#    ACD_F1: 0.98
#    ABSA_Precision: 0.9394
#    ABSA_Recall: 0.9208
#    ABSA_F1: 0.93
#    Support: 101
#
#  - 머릿결
#    ACD_Precision: 0.8793
#    ACD_Recall: 0.9808
#    ACD_F1: 0.9273
#    ABSA_Precision: 0.7759
#    ABSA_Recall: 0.8654
#    ABSA_F1: 0.8182
#    Support: 52
#
#  - 세정
#    ACD_Precision: 0.9558
#    ACD_Recall: 0.9076
#    ACD_F1: 0.931
#    ABSA_Precision: 0.9558
#    ABSA_Recall: 0.9076
#    ABSA_F1: 0.931
#    Support: 119
#
#  - 없음
#    ACD_Precision: 0.0
#    ACD_Recall: 0.0
#    ACD_F1: 0.0
#    ABSA_Precision: 0
#    ABSA_Recall: 0
#    ABSA_F1: 0
#    Support: 0
#
#  - 자극
#    ACD_Precision: 0.9268
#    ACD_Recall: 0.95
#    ACD_F1: 0.9383
#    ABSA_Precision: 0.878
#    ABSA_Recall: 0.878
#    ABSA_F1: 0.878
#    Support: 40
#
#  - 쿨링
#    ACD_Precision: 1.0
#    ACD_Recall: 0.8571
#    ACD_F1: 0.9231
#    ABSA_Precision: 1.0
#    ABSA_Recall: 0.8571
#    ABSA_F1: 0.9231
#    Support: 14
#
#  - 탈모
#    ACD_Precision: 0.8571
#    ACD_Recall: 0.75
#    ACD_F1: 0.8
#    ABSA_Precision: 0.7619
#    ABSA_Recall: 0.6667
#    ABSA_F1: 0.7111
#    Support: 24
#
#  - 향
#    ACD_Precision: 0.9769
#    ACD_Recall: 0.9922
#    ACD_F1: 0.9845
#    ABSA_Precision: 0.9308
#    ABSA_Recall: 0.9237
#    ABSA_F1: 0.9272
#    Support: 128
#
# Average Loss:
#  - ACD Loss: 0.9070
#  - ASC Loss: 0.9003
# Saved predictions to /content/drive/MyDrive/ABSA/pred_result

# %% [markdown]
# # 라벨링

# %%
def label_raw_data_with_trained_model(
    raw_data,
    acd_best_model_path,
    asc_best_model_path,
    model_class,
    acd_tokenizer_name,
    asc_tokenizer_name,
    tf_id_to_name,
    polarity_id_to_name,
    special_tokens_dict,
    entity_property_pair,
    max_len,
    threshold,
    save_path
):
    print("Starting Labeling with Raw Data...")

    try:
        acd_tokenizer = AutoTokenizer.from_pretrained(acd_base_model)
        acd_tokenizer.add_special_tokens(special_tokens_dict)
        asc_tokenizer = AutoTokenizer.from_pretrained(asc_base_model)
        asc_tokenizer.add_special_tokens(special_tokens_dict)
    except Exception as e:
        print(f"Tokenizer load error: {e}")
        return

    try:
        acd_best_model = load_model(ABSA_Model, acd_best_model_path, acd_base_model, len(tf_id_to_name), len(acd_tokenizer))
        asc_best_model = load_model(ABSA_Model, asc_best_model_path, asc_base_model, len(polarity_id_to_name), len(asc_tokenizer))
    except Exception as e:
        print(f"Model load error: {e}")
        return

    def predict_on_raw_data(data):
        acd_best_model.eval()
        asc_best_model.eval()
        results = copy.deepcopy(data)

        acd_pad_token_id = acd_tokenizer.pad_token_id
        asc_pad_token_id = asc_tokenizer.pad_token_id

        for idx, sentence in enumerate(tqdm(results, desc="라벨링 진행")):
            form = sentence.get('리뷰', '')
            form = preprocessing(form)
            sentence['annotation'] = []

            if not isinstance(form, str) or not form.strip():
                print(f"Invalid sentence skipped: {form}")
                continue

            for pair in entity_property_pair:
                # ACD 수행
                acd_encoded = acd_tokenizer(
                    form,
                    pair,
                    padding=False,
                    truncation=False,
                    return_tensors='pt',
                    add_special_tokens=True
                )

                acd_input_ids = acd_encoded['input_ids'][0].tolist()
                acd_attention_mask = acd_encoded['attention_mask'][0].tolist()
                acd_input_ids, acd_attention_mask = truncate_left(acd_input_ids, acd_attention_mask, max_len, acd_pad_token_id)

                acd_input_ids = torch.tensor([acd_input_ids]).to(device)
                acd_attention_mask = torch.tensor([acd_attention_mask]).to(device)

                with torch.no_grad():
                    _, acd_logits = acd_best_model(acd_input_ids, acd_attention_mask)

                acd_probs = torch.softmax(acd_logits, dim=-1)
                acd_confidence, acd_pred = torch.max(acd_probs, dim=-1)
                acd_pred = acd_pred.item()
                acd_confidence = acd_confidence.item()

                if tf_id_to_name[acd_pred] == 'True' and acd_confidence >= threshold:
                    # ASC 수행
                    asc_encoded = asc_tokenizer(
                        form,
                        pair,
                        padding=False,
                        truncation=False,
                        return_tensors='pt',
                        add_special_tokens=True
                    )
                    asc_input_ids = asc_encoded['input_ids'][0].tolist()
                    asc_attention_mask = asc_encoded['attention_mask'][0].tolist()
                    asc_input_ids, asc_attention_mask = truncate_left(asc_input_ids, asc_attention_mask, max_len, asc_pad_token_id)

                    asc_input_ids = torch.tensor([asc_input_ids]).to(device)
                    asc_attention_mask = torch.tensor([asc_attention_mask]).to(device)

                    with torch.no_grad():
                        _, asc_logits = asc_best_model(asc_input_ids, asc_attention_mask)

                    asc_probs = torch.softmax(asc_logits, dim=-1)
                    asc_confidence, asc_pred = torch.max(asc_probs, dim=-1)
                    asc_pred = asc_pred.item()
                    asc_confidence = asc_confidence.item()

                    if 0 <= asc_pred < len(polarity_id_to_name):
                        polarity = polarity_id_to_name[asc_pred]
                    else:
                        polarity = "UNKNOWN"

                    sentence['annotation'].append([
                        pair,
                        [None, 0, 0],
                        polarity
                    ])

            if not sentence['annotation']:
                sentence['annotation'] = [["없음", [None, 0, 0], None]]

        return results

    labeled_raw_data = predict_on_raw_data(raw_data)

    if save_path:
        try:
            jsondump(labeled_raw_data, final_output_path)
            print(f"Saved final outputs to {save_path}")
        except Exception as e:
            print(f"Failed to save final outputs: {e}")

    return labeled_raw_data

# %%
jsonlload(raw_data_path)
# Out:
# [{'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': '용자입니다',
#   '작성일자': '2025.05.19',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '일주일째 쓰는 중인데 좋은 거 같기도 하고 아닌 것 같기도 하고 한 달 뒤 후기로..ㄹ'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': '레몽몽',
#   '작성일자': '2025.04.28',
#   '별점': '5점만점에 4점',
#   '사용현황': '',
#   '세정력': '보통이에요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '거품이나 향은 무난한데 새치 커버력이 홍보 대비 좀 아쉽네요'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'k202401158****',
#   '작성일자': '2025.05.16',
#   '별점': '5점만점에 5점',
#   '사용현황': '재구매',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '얼마 전에 구매했는데 쿠폰이 있어서 또 구매했어요 미리 쟁여 둘려 구요'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'k202401158****',
#   '작성일자': '2025.05.10',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '염색 하지 않고 몇 년째 계속 사용하고 있어요 남편 덕분에 알게 되어서 지금까지 같이 쓰고 있어요~'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'sweetvio****',
#   '작성일자': '2025.05.06',
#   '별점': '5점만점에 5점',
#   '사용현황': '한달이상사용',
#   '세정력': '보통이에요',
#   '자극도': '보통이에요',
#   '거품': '보통이에요',
#   '향': '보통이에요',
#   '리뷰': '남편 40대 되고 흰 머리가 많아 이걸 사줬는데 그레이 정도는 되는 것 같아요'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': '운영자',
#   '작성일자': '2025.04.29',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '모다모다는 사랑입니다. 친구들에게 추천하고 싶어요! 가격이 합리적이라 더 만족스러워요.'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'puln****',
#   '작성일자': '2025.04.04',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '항성 사용하고 있어요굿 몇 년째 모다모다샴푸만 사용해 요항성 사용하고 있어요굿 몇 년째 모다모다샴푸만 사용해요'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'iren****',
#   '작성일자': '2025.04.05',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '흰머리가 많지 않은 경우 염색 대신 좋아요. 계속 사용하고 있어요.'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'sweetvio****',
#   '작성일자': '2025.03.29',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '보통이에요',
#   '자극도': '보통이에요',
#   '거품': '보통이에요',
#   '향': '보통이에요',
#   '리뷰': '남편 흰머리가 넘 많이 보여서 샀는데 회색 정도는 나오는 것 같아 요 신기하네용'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': '사야마야',
#   '작성일자': '2025.04.15',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '보통이에요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '흰 머리를 완벽하게 커버하긴 어렵지만, 어느 정도 감당하며 지 내겠다 하면 좋은 선택지가 될 수 있을 것 같아요.머리 색이 깔끔하게 동일한 톤으로 변화되는 것은 아니라서, 그 점도 어느 정도 감당하겠다 하면 불만 없이 쓸 수 있는 제품입니다.'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': '정현꽁뜌',
#   '작성일자': '2025.04.20',
#   '별점': '5점만점에 4점',
#   '사용현황': '한달이상사용',
#   '세정력': '아주 만족해요',
#   '자극도': '보통이에요',
#   '거품': '거품이 풍성해요',
#   '향': '보통이에요',
#   '리뷰': '새치 커버에 효과가 좋습니다 다음번 도 또 살 예정입니다 흰머리지긋지긋'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': '호두멍멍',
#   '작성일자': '2024.04.29',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '새치나 흰 머리는 남 얘기로만 생각하고 살았던 지난 날..지난 주 미용실에 가니 선생님께서 오잉 뒤쪽에 흰 머리가 많이 나셨네요? 하시더라구요 평소 보이지 않아 챙기지 못했던 내 뒤통수에게 미안한 마음이 들어 새치 케어 제품을 검색했습죠. 염색을 하기에는 아직 이르다 싶었고 염색할 때 마다 느끼는 눈 따가움을 피하고 싶어 모다모다 시도 해봤어요 현재 3주차에 접어들 었습니다! 거품 내고 3분 방치 설명서가 시키는 대로 잘 따라 하고 있습니다 제가 또 말은 잘 듣거든요. 어쨌든 3주차부터 겉으로 보이던 새치가 갈색으로 조금씩 변하는 느낌? 이에요. 원래는 뒤 통수에 보면 흰색으로 뿅 튀어나와서 눈에 띄던 새치 친구가 주변 머리 색과 서서히 비슷해져 가는???? 뭐 야 리뷰를 쓰다 보니까 신기하네요? 회사에도 쓰고 계신 분들이 있어서 얘기  들어보니 2-3달 열심히 쓰고 어느 정도 색 변화가 만족스럽다~싶으면 하루씩 번 갈아 쓰기도 하시고.. 거품 내기 전 샴푸 액상을 바르고 기다리시는 분들도 계시고..뭐랄까 민간요법들이 많더라구 요 나름 재밌는 것 같기도 하고 ㅎㅎ 지금까진 만족해요 6주차까지 열심히 써보겠습니다!'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'maxwell****',
#   '작성일자': '2025.04.03',
#   '별점': '5점만점에 1점',
#   '사용현황': '',
#   '세정력': '다소 아쉬워요',
#   '자극도': '자극이 느껴져요',
#   '거품': '거품이 적어요',
#   '향': '다소 아쉬워요',
#   '리뷰': '진물이 나서 딱 쟁이가 됩니다 1세대 쓰고 나름 만족해 3세대 쓰니 부작용으로 고생 중. 어떤 유해 성분이 첨가됐길래 이런가. 건조한 날씨 탓인가 사무실 히터 탓인가 했는데 잠시 안 쓰다 다시 쓰기 시작하니 바로 두피이 딱 쟁이가 생김. 못 믿을 모다모다'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': '운수대톨',
#   '작성일자': '2024.03.31',
#   '별점': '5점만점에 5점',
#   '사용현황': '한달이상사용',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '전 모델보다는 염색도 잘 되고 모발도 부드러워요. 손톱 물드는 것도 덜 하네요. 잘 쓸께 요~'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': '운수대톨',
#   '작성일자': '2024.02.29',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '2세대라 훨씬 좋네요. 노란색 전 모델보다 모발도 부드럽고 향도 좋아요. 효과도 좋구요. 잘 쓸게요 7~~'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'recognit****',
#   '작성일자': '2025.05.20',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '보통이에요',
#   '자극도': '자극없이 순해요',
#   '거품': '보통이에요',
#   '향': '보통이에요',
#   '리뷰': '아빠가 1세대 상품부터 몇 년째 꾸준히 쓰고 계셔요. 자극 없이 흰 머리 커버가 되니 좋어하셔서 올리브영에서 기획상품으로 종종 사드려요'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': '식물킹',
#   '작성일자': '2024.04.18',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '향이 좋아지고 머리 감고 나서 이 전 제품보다 머릿결이 더 부드럽네요 사용감이 더 좋아진 게 느껴져요'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'hwang****',
#   '작성일자': '2024.04.14',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '저번에 샴푸 하나만 사 서 썼는데 너무 만족해서 그냥 2개 세트로 사 버렸어요 ㅠ 사람마다 뭐 의견이 다르지만 저랑 우리 부모님은 진짜 대 만족하면서 쓰고 있어 용 특히 엄마가 염색에서 벗어났다고 진짜 좋아하세요 캬캬캬 사실 염색할 때마다 알러지나서 엄청 힘들어 하셨거든요 2개 세트사서 더 좋아하심 ㅋㅋㅋㅋ 써보니까 저랑 부모님이랑 약간 색이 변하는 속도가 좀 다르 긴 한데 결국은 다 색이 변하니까 꾸준하게 쓰는 게 중요한 거 같아요! 엄마는 엄청 빨리 되는데 저는 조금 더 걸려 용 ㅋㅋㅋㅋ 유튜브에 보니까 뿌리 부분에 좀 바르고 기다리라고 해가지고 저도 그 방법 써보니 대 만족! ㅋㅋㅋㅋㅋ 염색약은 아니니까 바로 안 되는 사람들은 이 방법 추천 ㅋㅋ 거품도 풍성하게 나 고 가끔 샴푸 잘못 쓰면 가려울 때가 있는데 저는 사실 두피가  민감하지 않아서 그런 건 전혀 못 느꼈어요 샴푸 바뀌고 드라이 할 때 머리가 잘 살아서 그 점도 엄청 만족스러워요! 아 그리고 하나 제안하면 저처럼 가족들하고 같이 쓰는 사람들을 위해 3개 세트도 있으면 좋겠고 사은품 좀 많이 주세요!!!!'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': '머리빗',
#   '작성일자': '2024.03.23',
#   '별점': '5점만점에 5점',
#   '사용현황': '한달이상사용',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '꼭 꼭 머리에 도 포 후 기다려주셔야 해요!안 그러면 효과가 없더라구요ㅠ저는 머리에 발라놓고 몸을 씻으면 시간이 맞더라구 요 ㅎㅎ 흰머리가 완전 검정색이 되지는 않고 갈색이 되는데 티도 잘 안 나 고 염색보다 훨씬 편리해요!두피에도 무리가 덜 가구요'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'icha****',
#   '작성일자': '2025.05.06',
#   '별점': '5점만점에 4점',
#   '사용현황': '',
#   '세정력': '보통이에요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '보통이에요',
#   '리뷰': '완전 염색은 아니지만 만족합니다. 향이 더 개선되면 좋겠습니다'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'tnqls****',
#   '작성일자': '2025.05.02',
#   '별점': '5점만점에 5점',
#   '사용현황': '재구매',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '세정력이 좋고 두피에 자극 없이 세정력이 좋아요 만족합니다'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'onya****',
#   '작성일자': '2025.04.30',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '남편이 이 젶무을 너무 좋아해요. 따로 염색을 하지 않아도 머리 감을 면서 동시에 염색이 된다면서 아주 간편하대요.정말 꾸준히 쓰고 있는 걸로 봐서는 정말 만족해하는 거 같아요.'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'choi****',
#   '작성일자': '2025.04.24',
#   '별점': '5점만점에 5점',
#   '사용현황': '재구매',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '거품이 부드럽고 풍성해서 샴푸하면서 마사지하기 딱 좋고 헹굴 때 잔여감이 없어요.'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'choi****',
#   '작성일자': '2025.04.24',
#   '별점': '5점만점에 5점',
#   '사용현황': '한달이상사용',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '정수리 냄새가 신경 쓰였는데, 이 제품은 하루 종일 뽀송한 향이 유지돼서 너무 좋아요.'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'hana27',
#   '작성일자': '2024.07.31',
#   '별점': '5점만점에 5점',
#   '사용현황': '한달이상사용',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '어마는 이 제품이 꽤 적합하다고 느꼈다. 그리고 다시 사겠습니다 ❤️'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'hana27',
#   '작성일자': '2024.06.03',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '아주 좋은 제품이에요. 다시 여러 번 사 서 친구들에게도 소개시켜줄 게 ❤️'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'puln****',
#   '작성일자': '2025.04.14',
#   '별점': '5점만점에 5점',
#   '사용현황': '재구매',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '몇 년째 모다모다샴푸만 사용해 요새로 업그레이 되었다니 써보고 후기 남길께요'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'danieljang',
#   '작성일자': '2024.04.15',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '꾸준하게 사용해오던 제품인데 이번에 더블기획 할인행사 중이여서 구매했습니다!!! 찐 사용자로써 팁 하나 드리고 갈께요.. 저희 가족 모두 이렇게 사용하는데 효과를 보고 있어요!! ㅎ팁. 3분 방치에서 조금 더 찐 ~ 한 검은색을 원하는 우리 가족들은 10분 방치! (다이소에서 샤워캡 1,000원짜리로 하나 구매해서 같이 써요!!) 이렇게 하면 색이 더 찐하고  빠르게 올라오더라구요! 사용하는데 아침보다는 저녁을 추천 드려 요 ~ ㅎ'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'gasmon****',
#   '작성일자': '2024.04.16',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '3개월 전에 올리브 영 통해서 한통 써보고 특가로 이번엔 2개 패키지 구매했습니다. 한 통 쓸 때 저희 마미가 이 좋은 걸 너만 쟁겨놓고 쓴다고 해서. 이번엔 효도(?)할 겸 2개 구매했습니다. 저희 가족은 염색약에 알러지 반응이 너무 심해 미용실은 커녕 셀프 염색도 못하는 집이였는데 모다모다 출시 이후 저희 가족은 유레카를 외쳤네요 저도 이 제 마흔이 다 되어 가 다 보니  새치 가 듬성듬성 나는 편이라 모다모다 샴푸를 쓰는 데 저는 사용 후 바로 갈변되기 보다는 서 서희 자연갈색으로 변하면서 기존 제 머리색과 비슷하게 변하더라구 요 저희 엄마는 완전 그레이 색이셔서 사용 후 바로 갈색이 올라오는 속도가 엄청 빠르시더라구요 아마도 개인차가 있어서 그런 거 같아 여 기존 댓글 보면 잘 안 된다는 의견도 있는데 저희 어머니 팁을 설명드리면  샴푸 하고 3분 동안 헤어캡을 쓰고 기다린 다음에 세척을 하시더라구요 그러면 누구보다 빠르게 남들보다 빠르게 되신다고 ㅎㅎ 사용감은 정말 린스 없이도 부들부들 거리는 게 다른 샴푸는 못 쓰겠더라구요, 드라이하면 보들 보들 하고 볼륨도 살아나서 정말 만족하면서 쓰고 있네요 향도 기존 버전 보다 더 은은한 꽃향이라 좋구요~~ 손상 모 샴푸도 함께 쓰고 있는데 이제 품도 얼른 올영에서 판매 해주셨음 좋겠습니다.'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'mamzziz****',
#   '작성일자': '2024.04.15',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '우선 용기가 너무 귀엽네요 뭔가 깔끔하고 고급 지면서 귀여운 ㅎ 모다모다는 워낙 유명해서 나온 제품들은 한 번씩은 다 써봤는데 이번 제로 그레이는 사용하자마자 그 차이가 확 느껴졌습니다. 우선 향이 ㅎ 많이 좋아졌고 뻣뻣한 감도 많이 사라졌어요 부들부들 ~ 샴푸액도 색상이 고급지다 고 해야 하나 (사진에 고급진 색상이 안담김 ㅜ ) 마냥 새까맣지 않고 반투명한  갈색에 묽지 않아서 그런지 머리에 거품도 잘 나고 뭔가 쫀쫀한 느낌 ㅎ 지금 받자마자 5일 정도를 계속 쓰고 있는데 새치가 색이 아직 변하기는 이른 거 같고... 전체적인 머리 색의 명암이 어두워졌다고 나 해야 할까요? 흠 한 달 정도 쓰면 눈에 띌 정도로 색이 어 두 월 질꺼 같은 기대감 뿜뿜 쓰면 쓸수록 어두워진다고 하니 ㅋ 인 내심을 가지고 쭈욱~ 써보겠습니다.'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'wlgu****',
#   '작성일자': '2024.03.12',
#   '별점': '5점만점에 4점',
#   '사용현황': '',
#   '세정력': '보통이에요',
#   '자극도': '보통이에요',
#   '거품': '보통이에요',
#   '향': '보통이에요',
#   '리뷰': '앞 전의 삼푸보다도 업그레이 되었다기에 앞전의 삼푸가 남아 있는데 구매했어요~회사를 믿기에 ᆢ숱이 있어 미리 삼푸로 머리를 감고 샤워하면서 젤 나중에 헹구어 줍니다~세치가 워낙 많아 금방은 해결은 안 되지만 염색보다 나을 거 같아 계속 구매할 겁니다!'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'useongc****',
#   '작성일자': '2025.04.19',
#   '별점': '5점만점에 5점',
#   '사용현황': '한달이상사용',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '감을 때마다 풍성한 거품 덕분에 샴푸 시간이 즐거워졌어요~'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'tnqls****',
#   '작성일자': '2025.04.19',
#   '별점': '5점만점에 5점',
#   '사용현황': '재구매',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '빗질할 때 머리카락이 안 끊기고 술술 풀려요.자극도 없어요'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'tnqls****',
#   '작성일자': '2025.04.19',
#   '별점': '5점만점에 5점',
#   '사용현황': '한달이상사용',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '염색하는 것 보다 머릿결에 부담이 덜 되서 좋은 것 같고 만족합니다'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'zhz****',
#   '작성일자': '2025.04.15',
#   '별점': '5점만점에 5점',
#   '사용현황': '재구매',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '너무 유분감 있지 않으면서도 충분한 보습력이 느껴져서 균형감이 좋아요.'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'zhz****',
#   '작성일자': '2025.04.15',
#   '별점': '5점만점에 5점',
#   '사용현황': '한달이상사용',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '은은한 향이 기분 좋고, 성분도 순해서 예민한 날에도 문제 없이 사용할 수 있어요.'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'anes****',
#   '작성일자': '2025.04.13',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '보통이에요',
#   '거품': '거품이 풍성해요',
#   '향': '보통이에요',
#   '리뷰': '50대 후반입니다 흰머리가 많아서 염색할까 하다 모다모다샴푸 사용하고 만족해서 4년째 사용 중입니다~~굿!!'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'twi****',
#   '작성일자': '2025.02.11',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '보통이에요',
#   '향': '아주 만족해요',
#   '리뷰': '모다모다 블랙 샴푸 꾸준히 사용 중입니다. 미장원에 가서 오래 앉아 있는 것을 귀찮아 하는 편이라 미장원 가지 않고 집에서 샴푸만 해도 흰 머리가 어느 정도 커버되는 것에 아주 만족하고 있습니다. 그래서 행사하길래 다른 물품 구매하면서 미리 쟁여 놓습니다. 염색만큼 진하게 색이 나오는 것은 아니 기 때문에 크게 효과가 있나 싶었는데 사용하다 사용을 중지해 보 니 흰 머리가 엄청 도드라지더라구요. 나름 흰머리가 은은한 갈색으로 코팅 되어 눈에 덜 띄도록 해 주고 있었어요. 그 이후로 열심히 사용 중입니다.'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'k33****',
#   '작성일자': '2024.04.11',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '보통이에요',
#   '리뷰': '처음에 지인 추천으로 구매했는데 쓰다 보니 머리카락도 힘이 생기고 약간 중독성 있게 쓰게 되요 ㅋ 두피 유분 정도에 따라 중간 중간 다른 샴푸 한 번씩. 쓰긴 하지만 거품도 쫀쫀하고 풍성해서 세정력도 나쁘지 않고 향도 처음보다 좋아졌어요. ㅋ 배송도 빠르고 만족합니다'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'part****',
#   '작성일자': '2025.03.03',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '보통이에요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '보통이에요',
#   '리뷰': '가격대는 조금 있고 드라마틱한 변화를 기대할 수는 없지만 그래도 탈모 등 두피에 좋은 것 같아요 꾸준히 사용하고 있습니다'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'minjeong****',
#   '작성일자': '2024.07.14',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '보통이에요',
#   '자극도': '보통이에요',
#   '거품': '보통이에요',
#   '향': '보통이에요',
#   '리뷰': '아빠 드리려고 주문했어요 너무 편하다고 하시더라구요 추천합니다'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'kwakkw****',
#   '작성일자': '2024.06.25',
#   '별점': '5점만점에 4점',
#   '사용현황': '',
#   '세정력': '보통이에요',
#   '자극도': '보통이에요',
#   '거품': '보통이에요',
#   '향': '보통이에요',
#   '리뷰': '10번 이상 계속 사용했는데도 별로 색이 변하지 않네요 두통이나 샀는데 아쉽네요.'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'kj****',
#   '작성일자': '2024.06.17',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '업그레이드 됐다고 해서 또 사용해봤는데 기존 제품이랑 별 차이는 못 느끼겠다는..뻣뻣해 짐을 해결했다는 데 여전히 샴푸 후 트리트먼트 없이는 안 되고 염색도 그다지..염색을 좀 늦춰주는 정도로 만족하며 쓰고 있어요'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'kanar****',
#   '작성일자': '2024.05.06',
#   '별점': '5점만점에 4점',
#   '사용현황': '',
#   '세정력': '보통이에요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '보통이에요',
#   '리뷰': '드라마틱하게 새치 커버가 되진 않아요.. 거품은 소량만 사용해서 엄청 풍성하고 쫀득해요. 두피 자극 전혀 없어요'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'ai****',
#   '작성일자': '2024.04.25',
#   '별점': '5점만점에 1점',
#   '사용현황': '',
#   '세정력': '다소 아쉬워요',
#   '자극도': '보통이에요',
#   '거품': '거품이 풍성해요',
#   '향': '보통이에요',
#   '리뷰': '전 한 달 써봐도 효과 하나도 없어서 별로라 안 쓰는데 남편은 올라오는 머리에선 흰 머리가 줄었다고 하네요 5만원 넘는 샴프를 팔면서 샘플도 없다는 게 참 별로에 요 전 재 구매 의사 없어요'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'aatj****',
#   '작성일자': '2024.04.19',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '두피가 깨끗하게 씻기고 머릿결이 훨씬 부드러워지는 느낌이에요 거품도 잘나 구 향도 너무 좋습니다 새치가 많아서 한 달에 한 번은 염색을 했었는데 모다모다 제품을 사용하고 나서는 자연스럽게 새치 커버가 되니까 꾸준히 사용하고 있어요!'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'nin****',
#   '작성일자': '2024.04.12',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '보통이에요',
#   '리뷰': '남편이랑 잘 쓰고 있습니다 아무래도 이런 류의 샴푸에서 창시자 격이다 보니 믿음이 가 고 효과가 좋네요'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'e642****',
#   '작성일자': '2024.04.01',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '재구매합니다. 미용실 염색은 머리에 부담이 많아서요. 속도는 느리지만 자연스럽게 염색되는 것 같아요.'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'gml****',
#   '작성일자': '2024.02.25',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '보통이에요',
#   '거품': '거품이 풍성해요',
#   '향': '보통이에요',
#   '리뷰': '40~50일에 한 번씩 염색하는 데 머리도 빠지고 귀찮기도 해서 지인의 소개로 샀네요 두 번 감았는 데 흰머리가 옅어졌어요 대박입니다 우선 트리트먼 쓰지 않는데도 부드럽네요 다 쓰면 재 구매 하렵니다'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'xvivie****',
#   '작성일자': '2024.02.09',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '보통이에요',
#   '거품': '거품이 풍성해요',
#   '향': '보통이에요',
#   '리뷰': '두 개 할인이라 구매했어요 4주째 사용 중인데 아직은 아쉬운 효과? 2달 꾸준히 써보려구요'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': 'bgi****',
#   '작성일자': '2024.01.22',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '거품이 잘 나 고 향도 좋습니다. 지속적으로 사용하면 새치에도 좋은 것 같습니다'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': '노랑발챙이',
#   '작성일자': '2025.02.08',
#   '별점': '5점만점에 5점',
#   '사용현황': '한달이상사용',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '모다모다 사용하면서 염색약은 사용하지 않아 요 자연스러운 샤치 커버 가능'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': '집돌이집순이',
#   '작성일자': '2025.01.31',
#   '별점': '5점만점에 3점',
#   '사용현황': '한달이상사용',
#   '세정력': '아주 만족해요',
#   '자극도': '보통이에요',
#   '거품': '거품이 풍성해요',
#   '향': '보통이에요',
#   '리뷰': '아빠가 꾸준히 사용 중이신 제품인데 이거.. 리뉴얼 되고 나서는 갈 변 효과가 많이 줄어들었나 봐요 아빠가 아쉬워하시네요.'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': '노랑발챙이',
#   '작성일자': '2025.01.02',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '보통이에요',
#   '리뷰': '머리 감고 15분 정도 방치 하면 훨씬 더 오래 가는 거 같아요. 번거롭게 염색 하는 것보다는 편합니다.'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': '집돌이집순이',
#   '작성일자': '2024.10.24',
#   '별점': '5점만점에 4점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '세정력도 거품도 다 만족하는데.. 그런데 이 전 버전보다 뭔가 새치 커버력은 떨어지는 것 같습니다. 아빠가 같은 모다모다 맞냐 고 물어보셨어요 ㅠㅠ'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': '스틱콘버터',
#   '작성일자': '2024.05.22',
#   '별점': '5점만점에 5점',
#   '사용현황': '한달이상사용',
#   '세정력': '아주 만족해요',
#   '자극도': '보통이에요',
#   '거품': '거품이 풍성해요',
#   '향': '보통이에요',
#   '리뷰': '아빠가 꾸준히 사용하시는 제품이라 구매했습니다 행사 많이 해주 새용'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': '장비',
#   '작성일자': '2024.05.13',
#   '별점': '5점만점에 4점',
#   '사용현황': '한달이상사용',
#   '세정력': '아주 만족해요',
#   '자극도': '보통이에요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '매일 저녁 사용하고 있는데 새치 커버는 안 쓸 때보다 나은 건 같은데 드라마틱한 효과는 아직 이네요'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': '소보소보',
#   '작성일자': '2024.04.25',
#   '별점': '5점만점에 5점',
#   '사용현황': '한달이상사용',
#   '세정력': '보통이에요',
#   '자극도': '보통이에요',
#   '거품': '보통이에요',
#   '향': '보통이에요',
#   '리뷰': '선물했어요 올영선물하기 기능 편하고 조아요굿굿입니다지인 챙겨주기 좋은'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': '스틱콘버터',
#   '작성일자': '2024.04.19',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '보통이에요',
#   '자극도': '보통이에요',
#   '거품': '보통이에요',
#   '향': '보통이에요',
#   '리뷰': '아빠가 항상 사용하시는 제품인데 기획세트 가격이 좋아서 구매했어요'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': '장비',
#   '작성일자': '2024.04.13',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '향도 그렇고 손톱에 물드는 정도도 훨씬 개선되어서 좋습니다.'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': '돌멩수',
#   '작성일자': '2024.03.29',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '보통이에요',
#   '자극도': '보통이에요',
#   '거품': '보통이에요',
#   '향': '보통이에요',
#   '리뷰': '아빠가 항상 사용하시는데 따로 새치 염색 필요 없어 좋아요! 재구매 템입니당'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': '소보소보',
#   '작성일자': '2024.03.18',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '보통이에요',
#   '자극도': '보통이에요',
#   '거품': '보통이에요',
#   '향': '보통이에요',
#   '리뷰': '지인이 골라서 선물해줬어요 모다모다 이슈 있었던 것 같은데.없어졌나봐 유?'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': '고민은배송만늦출뿐',
#   '작성일자': '2024.03.09',
#   '별점': '5점만점에 4점',
#   '사용현황': '',
#   '세정력': '보통이에요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '보통이에요',
#   '리뷰': '확실히 이 전 단종된 버전보다 염색이 안 되는 편이에 요 아부지가 쓰시는데 눈으로 확연히 보이게 다릅니다 그래도 꾸준히 써봐야 죠 속도가 이 전 같지 않을 뿐 염색이 되는 거라면요 이것도 사람마다 피드백이 다른 것 같아서 요ㅎㅎ'},
#  {'제품명': '모다모다 제로그레이 블랙샴푸10 더블기획 (300g+300g)',
#   '브랜드': '모다모다',
#   '원가': '78,000\n원',
#   '판매가': '48,280\n원',
#   '리뷰수': '145',
#   '평균별점': '4.6',
#   '5점비율': '78%',
#   '4점비율': '13%',
#   '3점비율': '6%',
#   '2점비율': '1%',
#   '1점비율': '3%',
#   '세정력/아주만족해요': '68%',
#   '세정력/보통이에요': '30%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '74%',
#   '자극도/보통이에요': '22%',
#   '자극도/자극이느껴져요': '4%',
#   '거품/거품이풍성해요': '68%',
#   '거품/보통이에요': '30%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '60%',
#   '향/보통이에요': '36%',
#   '향/다소아쉬워요': '4%',
#   '작성자': '머리빗',
#   '작성일자': '2024.02.18',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
# ...
#  {'제품명': '라보에이치 두피쿨링&노세범샴푸 탈모증상완화 750ml+100ml 한정기획 / 단품',
#   '브랜드': '라보에이치',
#   '원가': '36,000\n원',
#   '판매가': '25,900\n원 ~',
#   '리뷰수': '4,204',
#   '평균별점': '4.7',
#   '5점비율': '80%',
#   '4점비율': '12%',
#   '3점비율': '5%',
#   '2점비율': '1%',
#   '1점비율': '1%',
#   '세정력/아주만족해요': '67%',
#   '세정력/보통이에요': '31%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '51%',
#   '자극도/보통이에요': '44%',
#   '자극도/자극이느껴져요': '5%',
#   '거품/거품이풍성해요': '67%',
#   '거품/보통이에요': '31%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '52%',
#   '향/보통이에요': '43%',
#   '향/다소아쉬워요': '5%',
#   '작성자': 'cka****',
#   '작성일자': '2025.03.19',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '보통이에요',
#   '자극도': '자극없이 순해요',
#   '거품': '보통이에요',
#   '향': '보통이에요',
#   '리뷰': '아이 말로는 쉬원 한 느낌은 없다네요.열이 많은 아이라 쿨링으로 알아본 건데 아이한테는 쿨링감이 느껴지지 않나 봐요'},
#  {'제품명': '라보에이치 두피쿨링&노세범샴푸 탈모증상완화 750ml+100ml 한정기획 / 단품',
#   '브랜드': '라보에이치',
#   '원가': '36,000\n원',
#   '판매가': '25,900\n원 ~',
#   '리뷰수': '4,204',
#   '평균별점': '4.7',
#   '5점비율': '80%',
#   '4점비율': '12%',
#   '3점비율': '5%',
#   '2점비율': '1%',
#   '1점비율': '1%',
#   '세정력/아주만족해요': '67%',
#   '세정력/보통이에요': '31%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '51%',
#   '자극도/보통이에요': '44%',
#   '자극도/자극이느껴져요': '5%',
#   '거품/거품이풍성해요': '67%',
#   '거품/보통이에요': '31%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '52%',
#   '향/보통이에요': '43%',
#   '향/다소아쉬워요': '5%',
#   '작성자': 'lina****',
#   '작성일자': '2025.03.08',
#   '별점': '5점만점에 4점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '세정력도 만족합니다~거품 양도 만족합니다~샴푸 향도 만족합니다~!!!'},
#  {'제품명': '라보에이치 두피쿨링&노세범샴푸 탈모증상완화 750ml+100ml 한정기획 / 단품',
#   '브랜드': '라보에이치',
#   '원가': '36,000\n원',
#   '판매가': '25,900\n원 ~',
#   '리뷰수': '4,204',
#   '평균별점': '4.7',
#   '5점비율': '80%',
#   '4점비율': '12%',
#   '3점비율': '5%',
#   '2점비율': '1%',
#   '1점비율': '1%',
#   '세정력/아주만족해요': '67%',
#   '세정력/보통이에요': '31%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '51%',
#   '자극도/보통이에요': '44%',
#   '자극도/자극이느껴져요': '5%',
#   '거품/거품이풍성해요': '67%',
#   '거품/보통이에요': '31%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '52%',
#   '향/보통이에요': '43%',
#   '향/다소아쉬워요': '5%',
#   '작성자': 'hskim****',
#   '작성일자': '2025.03.07',
#   '별점': '5점만점에 4점',
#   '사용현황': '',
#   '세정력': '보통이에요',
#   '자극도': '보통이에요',
#   '거품': '보통이에요',
#   '향': '보통이에요',
#   '리뷰': '라보에이치 기본 제품 사용 중인데 친구 추천으로 사용해보려고요. 한 달 사용해보고 후기 남길게요.'},
#  {'제품명': '라보에이치 두피쿨링&노세범샴푸 탈모증상완화 750ml+100ml 한정기획 / 단품',
#   '브랜드': '라보에이치',
#   '원가': '36,000\n원',
#   '판매가': '25,900\n원 ~',
#   '리뷰수': '4,204',
#   '평균별점': '4.7',
#   '5점비율': '80%',
#   '4점비율': '12%',
#   '3점비율': '5%',
#   '2점비율': '1%',
#   '1점비율': '1%',
#   '세정력/아주만족해요': '67%',
#   '세정력/보통이에요': '31%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '51%',
#   '자극도/보통이에요': '44%',
#   '자극도/자극이느껴져요': '5%',
#   '거품/거품이풍성해요': '67%',
#   '거품/보통이에요': '31%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '52%',
#   '향/보통이에요': '43%',
#   '향/다소아쉬워요': '5%',
#   '작성자': 'tpflal****',
#   '작성일자': '2025.01.08',
#   '별점': '5점만점에 3점',
#   '사용현황': '재구매',
#   '세정력': '보통이에요',
#   '자극도': '보통이에요',
#   '거품': '보통이에요',
#   '향': '보통이에요',
#   '리뷰': '머리 기름도 많고 워낙 지성이랑 좋은 탈모샴푸 찾다가 이 제 정착했어요. 계속 재구매 하고 있습니다.'},
#  {'제품명': '라보에이치 두피쿨링&노세범샴푸 탈모증상완화 750ml+100ml 한정기획 / 단품',
#   '브랜드': '라보에이치',
#   '원가': '36,000\n원',
#   '판매가': '25,900\n원 ~',
#   '리뷰수': '4,204',
#   '평균별점': '4.7',
#   '5점비율': '80%',
#   '4점비율': '12%',
#   '3점비율': '5%',
#   '2점비율': '1%',
#   '1점비율': '1%',
#   '세정력/아주만족해요': '67%',
#   '세정력/보통이에요': '31%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '51%',
#   '자극도/보통이에요': '44%',
#   '자극도/자극이느껴져요': '5%',
#   '거품/거품이풍성해요': '67%',
#   '거품/보통이에요': '31%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '52%',
#   '향/보통이에요': '43%',
#   '향/다소아쉬워요': '5%',
#   '작성자': 'advanc****',
#   '작성일자': '2025.01.06',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '빠른 배송으로 잘 받았습니다.라보에이치 탈모 증상 완화 샴푸 두피 강화 노세범 재구매했어요.'},
#  {'제품명': '라보에이치 두피쿨링&노세범샴푸 탈모증상완화 750ml+100ml 한정기획 / 단품',
#   '브랜드': '라보에이치',
#   '원가': '36,000\n원',
#   '판매가': '25,900\n원 ~',
#   '리뷰수': '4,204',
#   '평균별점': '4.7',
#   '5점비율': '80%',
#   '4점비율': '12%',
#   '3점비율': '5%',
#   '2점비율': '1%',
#   '1점비율': '1%',
#   '세정력/아주만족해요': '67%',
#   '세정력/보통이에요': '31%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '51%',
#   '자극도/보통이에요': '44%',
#   '자극도/자극이느껴져요': '5%',
#   '거품/거품이풍성해요': '67%',
#   '거품/보통이에요': '31%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '52%',
#   '향/보통이에요': '43%',
#   '향/다소아쉬워요': '5%',
#   '작성자': 'ks63****',
#   '작성일자': '2024.12.13',
#   '별점': '5점만점에 5점',
#   '사용현황': '재구매',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '재구매해서 쭈욱 쓰고 있어 요 거품 잘 나고 머리카락이 더 좋아진 것 같아요'},
#  {'제품명': '라보에이치 두피쿨링&노세범샴푸 탈모증상완화 750ml+100ml 한정기획 / 단품',
#   '브랜드': '라보에이치',
#   '원가': '36,000\n원',
#   '판매가': '25,900\n원 ~',
#   '리뷰수': '4,204',
#   '평균별점': '4.7',
#   '5점비율': '80%',
#   '4점비율': '12%',
#   '3점비율': '5%',
#   '2점비율': '1%',
#   '1점비율': '1%',
#   '세정력/아주만족해요': '67%',
#   '세정력/보통이에요': '31%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '51%',
#   '자극도/보통이에요': '44%',
#   '자극도/자극이느껴져요': '5%',
#   '거품/거품이풍성해요': '67%',
#   '거품/보통이에요': '31%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '52%',
#   '향/보통이에요': '43%',
#   '향/다소아쉬워요': '5%',
#   '작성자': 'jo****',
#   '작성일자': '2024.11.26',
#   '별점': '5점만점에 5점',
#   '사용현황': '한달이상사용',
#   '세정력': '보통이에요',
#   '자극도': '보통이에요',
#   '거품': '보통이에요',
#   '향': '보통이에요',
#   '리뷰': '좋다고 해서 사봤는데 초록색이랑 비교 해보기 위해 다른 것도 써봐야겠어요'},
#  {'제품명': '라보에이치 두피쿨링&노세범샴푸 탈모증상완화 750ml+100ml 한정기획 / 단품',
#   '브랜드': '라보에이치',
#   '원가': '36,000\n원',
#   '판매가': '25,900\n원 ~',
#   '리뷰수': '4,204',
#   '평균별점': '4.7',
#   '5점비율': '80%',
#   '4점비율': '12%',
#   '3점비율': '5%',
#   '2점비율': '1%',
#   '1점비율': '1%',
#   '세정력/아주만족해요': '67%',
#   '세정력/보통이에요': '31%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '51%',
#   '자극도/보통이에요': '44%',
#   '자극도/자극이느껴져요': '5%',
#   '거품/거품이풍성해요': '67%',
#   '거품/보통이에요': '31%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '52%',
#   '향/보통이에요': '43%',
#   '향/다소아쉬워요': '5%',
#   '작성자': 's647****',
#   '작성일자': '2024.11.11',
#   '별점': '5점만점에 5점',
#   '사용현황': '한달이상사용',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '여라 개 구매 햇어요 기름기 제거 잘되서 좋아요 여름엔 필수입니다'},
#  {'제품명': '라보에이치 두피쿨링&노세범샴푸 탈모증상완화 750ml+100ml 한정기획 / 단품',
#   '브랜드': '라보에이치',
#   '원가': '36,000\n원',
#   '판매가': '25,900\n원 ~',
#   '리뷰수': '4,204',
#   '평균별점': '4.7',
#   '5점비율': '80%',
#   '4점비율': '12%',
#   '3점비율': '5%',
#   '2점비율': '1%',
#   '1점비율': '1%',
#   '세정력/아주만족해요': '67%',
#   '세정력/보통이에요': '31%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '51%',
#   '자극도/보통이에요': '44%',
#   '자극도/자극이느껴져요': '5%',
#   '거품/거품이풍성해요': '67%',
#   '거품/보통이에요': '31%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '52%',
#   '향/보통이에요': '43%',
#   '향/다소아쉬워요': '5%',
#   '작성자': 'jo****',
#   '작성일자': '2024.10.17',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '보통이에요',
#   '자극도': '보통이에요',
#   '거품': '보통이에요',
#   '향': '보통이에요',
#   '리뷰': '많이들 좋다고 해서 구매했습니다. 아직까지는 잘 모르겠어요'},
#  {'제품명': '라보에이치 두피쿨링&노세범샴푸 탈모증상완화 750ml+100ml 한정기획 / 단품',
#   '브랜드': '라보에이치',
#   '원가': '36,000\n원',
#   '판매가': '25,900\n원 ~',
#   '리뷰수': '4,204',
#   '평균별점': '4.7',
#   '5점비율': '80%',
#   '4점비율': '12%',
#   '3점비율': '5%',
#   '2점비율': '1%',
#   '1점비율': '1%',
#   '세정력/아주만족해요': '67%',
#   '세정력/보통이에요': '31%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '51%',
#   '자극도/보통이에요': '44%',
#   '자극도/자극이느껴져요': '5%',
#   '거품/거품이풍성해요': '67%',
#   '거품/보통이에요': '31%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '52%',
#   '향/보통이에요': '43%',
#   '향/다소아쉬워요': '5%',
#   '작성자': 'yhym****',
#   '작성일자': '2024.08.27',
#   '별점': '5점만점에 5점',
#   '사용현황': '한달이상사용',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '풍성하구 너무 조아용 🤍🤘감사합니 당 꾸준히 잘 쓰고 있어요😏'},
#  {'제품명': '라보에이치 두피쿨링&노세범샴푸 탈모증상완화 750ml+100ml 한정기획 / 단품',
#   '브랜드': '라보에이치',
#   '원가': '36,000\n원',
#   '판매가': '25,900\n원 ~',
#   '리뷰수': '4,204',
#   '평균별점': '4.7',
#   '5점비율': '80%',
#   '4점비율': '12%',
#   '3점비율': '5%',
#   '2점비율': '1%',
#   '1점비율': '1%',
#   '세정력/아주만족해요': '67%',
#   '세정력/보통이에요': '31%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '51%',
#   '자극도/보통이에요': '44%',
#   '자극도/자극이느껴져요': '5%',
#   '거품/거품이풍성해요': '67%',
#   '거품/보통이에요': '31%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '52%',
#   '향/보통이에요': '43%',
#   '향/다소아쉬워요': '5%',
#   '작성자': 'wkdtnrud****',
#   '작성일자': '2024.08.18',
#   '별점': '5점만점에 5점',
#   '사용현황': '한달이상사용',
#   '세정력': '보통이에요',
#   '자극도': '보통이에요',
#   '거품': '보통이에요',
#   '향': '보통이에요',
#   '리뷰': '올리브영에서 처음 구매해봤는데 생각보다 거품도 잘 나고 괜찮은 것 같아요!'},
#  {'제품명': '라보에이치 두피쿨링&노세범샴푸 탈모증상완화 750ml+100ml 한정기획 / 단품',
#   '브랜드': '라보에이치',
#   '원가': '36,000\n원',
#   '판매가': '25,900\n원 ~',
#   '리뷰수': '4,204',
#   '평균별점': '4.7',
#   '5점비율': '80%',
#   '4점비율': '12%',
#   '3점비율': '5%',
#   '2점비율': '1%',
#   '1점비율': '1%',
#   '세정력/아주만족해요': '67%',
#   '세정력/보통이에요': '31%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '51%',
#   '자극도/보통이에요': '44%',
#   '자극도/자극이느껴져요': '5%',
#   '거품/거품이풍성해요': '67%',
#   '거품/보통이에요': '31%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '52%',
#   '향/보통이에요': '43%',
#   '향/다소아쉬워요': '5%',
#   '작성자': 'youngsik****',
#   '작성일자': '2024.08.18',
#   '별점': '5점만점에 5점',
#   '사용현황': '한달이상사용',
#   '세정력': '보통이에요',
#   '자극도': '보통이에요',
#   '거품': '보통이에요',
#   '향': '보통이에요',
#   '리뷰': '(셩!) 우리 시아버님 탈모 증상이 사라지고 있어서 너무 좋으시대요'},
#  {'제품명': '라보에이치 두피쿨링&노세범샴푸 탈모증상완화 750ml+100ml 한정기획 / 단품',
#   '브랜드': '라보에이치',
#   '원가': '36,000\n원',
#   '판매가': '25,900\n원 ~',
#   '리뷰수': '4,204',
#   '평균별점': '4.7',
#   '5점비율': '80%',
#   '4점비율': '12%',
#   '3점비율': '5%',
#   '2점비율': '1%',
#   '1점비율': '1%',
#   '세정력/아주만족해요': '67%',
#   '세정력/보통이에요': '31%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '51%',
#   '자극도/보통이에요': '44%',
#   '자극도/자극이느껴져요': '5%',
#   '거품/거품이풍성해요': '67%',
#   '거품/보통이에요': '31%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '52%',
#   '향/보통이에요': '43%',
#   '향/다소아쉬워요': '5%',
#   '작성자': 'ktca****',
#   '작성일자': '2024.08.11',
#   '별점': '5점만점에 1점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '세정력이 좋고 향도 오래 가서 머리 감을 때마다 기분이 좋습니다. 매일 쓰는 제품은 역시 좋은 걸 사용해야 한다는 교훈을 준달까요.'},
#  {'제품명': '라보에이치 두피쿨링&노세범샴푸 탈모증상완화 750ml+100ml 한정기획 / 단품',
#   '브랜드': '라보에이치',
#   '원가': '36,000\n원',
#   '판매가': '25,900\n원 ~',
#   '리뷰수': '4,204',
#   '평균별점': '4.7',
#   '5점비율': '80%',
#   '4점비율': '12%',
#   '3점비율': '5%',
#   '2점비율': '1%',
#   '1점비율': '1%',
#   '세정력/아주만족해요': '67%',
#   '세정력/보통이에요': '31%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '51%',
#   '자극도/보통이에요': '44%',
#   '자극도/자극이느껴져요': '5%',
#   '거품/거품이풍성해요': '67%',
#   '거품/보통이에요': '31%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '52%',
#   '향/보통이에요': '43%',
#   '향/다소아쉬워요': '5%',
#   '작성자': 's647****',
#   '작성일자': '2024.08.03',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '항상 쓰던 두피 샴푸 리뉴얼 되서 구매했어요 더 써보고 추가 구매할게요 ㅎ'},
#  {'제품명': '라보에이치 두피쿨링&노세범샴푸 탈모증상완화 750ml+100ml 한정기획 / 단품',
#   '브랜드': '라보에이치',
#   '원가': '36,000\n원',
#   '판매가': '25,900\n원 ~',
#   '리뷰수': '4,204',
#   '평균별점': '4.7',
#   '5점비율': '80%',
#   '4점비율': '12%',
#   '3점비율': '5%',
#   '2점비율': '1%',
#   '1점비율': '1%',
#   '세정력/아주만족해요': '67%',
#   '세정력/보통이에요': '31%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '51%',
#   '자극도/보통이에요': '44%',
#   '자극도/자극이느껴져요': '5%',
#   '거품/거품이풍성해요': '67%',
#   '거품/보통이에요': '31%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '52%',
#   '향/보통이에요': '43%',
#   '향/다소아쉬워요': '5%',
#   '작성자': 'kredpul****',
#   '작성일자': '2024.08.02',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '보통이에요',
#   '자극도': '보통이에요',
#   '거품': '보통이에요',
#   '향': '보통이에요',
#   '리뷰': '라보에이치는 유명하죠 ㅋ 가성비 조아서 여름 에 쓰길 괜찬으 거 같아 요 ㅋ 진정 효과짱'},
#  {'제품명': '라보에이치 두피쿨링&노세범샴푸 탈모증상완화 750ml+100ml 한정기획 / 단품',
#   '브랜드': '라보에이치',
#   '원가': '36,000\n원',
#   '판매가': '25,900\n원 ~',
#   '리뷰수': '4,204',
#   '평균별점': '4.7',
#   '5점비율': '80%',
#   '4점비율': '12%',
#   '3점비율': '5%',
#   '2점비율': '1%',
#   '1점비율': '1%',
#   '세정력/아주만족해요': '67%',
#   '세정력/보통이에요': '31%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '51%',
#   '자극도/보통이에요': '44%',
#   '자극도/자극이느껴져요': '5%',
#   '거품/거품이풍성해요': '67%',
#   '거품/보통이에요': '31%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '52%',
#   '향/보통이에요': '43%',
#   '향/다소아쉬워요': '5%',
#   '작성자': 'tldtld****',
#   '작성일자': '2024.08.01',
#   '별점': '5점만점에 4점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '시원하고 거품 잘 나고 순해요. 여름에 쓰기 좋아요.두피 자극도 없네요'},
#  {'제품명': '라보에이치 두피쿨링&노세범샴푸 탈모증상완화 750ml+100ml 한정기획 / 단품',
#   '브랜드': '라보에이치',
#   '원가': '36,000\n원',
#   '판매가': '25,900\n원 ~',
#   '리뷰수': '4,204',
#   '평균별점': '4.7',
#   '5점비율': '80%',
#   '4점비율': '12%',
#   '3점비율': '5%',
#   '2점비율': '1%',
#   '1점비율': '1%',
#   '세정력/아주만족해요': '67%',
#   '세정력/보통이에요': '31%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '51%',
#   '자극도/보통이에요': '44%',
#   '자극도/자극이느껴져요': '5%',
#   '거품/거품이풍성해요': '67%',
#   '거품/보통이에요': '31%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '52%',
#   '향/보통이에요': '43%',
#   '향/다소아쉬워요': '5%',
#   '작성자': 'xylito****',
#   '작성일자': '2024.07.28',
#   '별점': '5점만점에 5점',
#   '사용현황': '한달이상사용',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '초록색 펌프(두피 강화)인 제품보다 이 제품이 세정력이 더 좋은 것 같습니다. 샴푸 후에 머리가 더 뻣뻣한 느낌이 긴 합니다. 트리트먼트를 꼭 같이 하길 추천 드립니다.'},
#  {'제품명': '라보에이치 두피쿨링&노세범샴푸 탈모증상완화 750ml+100ml 한정기획 / 단품',
#   '브랜드': '라보에이치',
#   '원가': '36,000\n원',
#   '판매가': '25,900\n원 ~',
#   '리뷰수': '4,204',
#   '평균별점': '4.7',
#   '5점비율': '80%',
#   '4점비율': '12%',
#   '3점비율': '5%',
#   '2점비율': '1%',
#   '1점비율': '1%',
#   '세정력/아주만족해요': '67%',
#   '세정력/보통이에요': '31%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '51%',
#   '자극도/보통이에요': '44%',
#   '자극도/자극이느껴져요': '5%',
#   '거품/거품이풍성해요': '67%',
#   '거품/보통이에요': '31%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '52%',
#   '향/보통이에요': '43%',
#   '향/다소아쉬워요': '5%',
#   '작성자': 'teo****',
#   '작성일자': '2024.07.28',
#   '별점': '5점만점에 4점',
#   '사용현황': '한달이상사용',
#   '세정력': '아주 만족해요',
#   '자극도': '보통이에요',
#   '거품': '거품이 풍성해요',
#   '향': '보통이에요',
#   '리뷰': '거품도 잘 나고 세정력도 좋은데 노세 범용이라 저한테는 안 맞는 거 같아 아쉬워요! 지 성분들이 쓰기에 좋은 거 같아요! 기름기가 쫙 빠져서인지 살짝 뻣뻣해지는 감이 있어요ㅠ'},
#  {'제품명': '라보에이치 두피쿨링&노세범샴푸 탈모증상완화 750ml+100ml 한정기획 / 단품',
#   '브랜드': '라보에이치',
#   '원가': '36,000\n원',
#   '판매가': '25,900\n원 ~',
#   '리뷰수': '4,204',
#   '평균별점': '4.7',
#   '5점비율': '80%',
#   '4점비율': '12%',
#   '3점비율': '5%',
#   '2점비율': '1%',
#   '1점비율': '1%',
#   '세정력/아주만족해요': '67%',
#   '세정력/보통이에요': '31%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '51%',
#   '자극도/보통이에요': '44%',
#   '자극도/자극이느껴져요': '5%',
#   '거품/거품이풍성해요': '67%',
#   '거품/보통이에요': '31%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '52%',
#   '향/보통이에요': '43%',
#   '향/다소아쉬워요': '5%',
#   '작성자': 'itogg****',
#   '작성일자': '2024.07.27',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '보통이에요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '리뷰가 좋아서 밑져야 본전으로 구매해봤는데 세정력도 좋고 민트 향도 시원해서 좋아요'},
#  {'제품명': '라보에이치 두피쿨링&노세범샴푸 탈모증상완화 750ml+100ml 한정기획 / 단품',
#   '브랜드': '라보에이치',
#   '원가': '36,000\n원',
#   '판매가': '25,900\n원 ~',
#   '리뷰수': '4,204',
#   '평균별점': '4.7',
#   '5점비율': '80%',
#   '4점비율': '12%',
#   '3점비율': '5%',
#   '2점비율': '1%',
#   '1점비율': '1%',
#   '세정력/아주만족해요': '67%',
#   '세정력/보통이에요': '31%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '51%',
#   '자극도/보통이에요': '44%',
#   '자극도/자극이느껴져요': '5%',
#   '거품/거품이풍성해요': '67%',
#   '거품/보통이에요': '31%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '52%',
#   '향/보통이에요': '43%',
#   '향/다소아쉬워요': '5%',
#   '작성자': 'ybl8****',
#   '작성일자': '2024.07.23',
#   '별점': '5점만점에 4점',
#   '사용현황': '한달이상사용',
#   '세정력': '보통이에요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '노세범 샴푸 인데 그렇게 기름기 많이 잡아주는 거 같진 않아 요 아침에 감으면 저녁 쯤이면 다시 기름기 조금 올라와요. 뻑뻑해서 린스나 트리트먼트도 꼭 써야 돼요!'},
#  {'제품명': '라보에이치 두피쿨링&노세범샴푸 탈모증상완화 750ml+100ml 한정기획 / 단품',
#   '브랜드': '라보에이치',
#   '원가': '36,000\n원',
#   '판매가': '25,900\n원 ~',
#   '리뷰수': '4,204',
#   '평균별점': '4.7',
#   '5점비율': '80%',
#   '4점비율': '12%',
#   '3점비율': '5%',
#   '2점비율': '1%',
#   '1점비율': '1%',
#   '세정력/아주만족해요': '67%',
#   '세정력/보통이에요': '31%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '51%',
#   '자극도/보통이에요': '44%',
#   '자극도/자극이느껴져요': '5%',
#   '거품/거품이풍성해요': '67%',
#   '거품/보통이에요': '31%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '52%',
#   '향/보통이에요': '43%',
#   '향/다소아쉬워요': '5%',
#   '작성자': 'qpqp****',
#   '작성일자': '2024.07.21',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '여름이라서 머리 좀 더 기름이 잘 생기는 것 같아서 좀 시원한 제품으로 사봤는데 머리 감으면서 거품도 잘 나 고 두피 완전 시원해요 !! 스케일링 되는 기분 !!'},
#  {'제품명': '라보에이치 두피쿨링&노세범샴푸 탈모증상완화 750ml+100ml 한정기획 / 단품',
#   '브랜드': '라보에이치',
#   '원가': '36,000\n원',
#   '판매가': '25,900\n원 ~',
#   '리뷰수': '4,204',
#   '평균별점': '4.7',
#   '5점비율': '80%',
#   '4점비율': '12%',
#   '3점비율': '5%',
#   '2점비율': '1%',
#   '1점비율': '1%',
#   '세정력/아주만족해요': '67%',
#   '세정력/보통이에요': '31%',
#   '세정력/다소아쉬워요': '2%',
#   '자극도/자극없이순해요': '51%',
#   '자극도/보통이에요': '44%',
#   '자극도/자극이느껴져요': '5%',
#   '거품/거품이풍성해요': '67%',
#   '거품/보통이에요': '31%',
#   '거품/거품이적어요': '2%',
#   '향/아주만족해요': '52%',
#   '향/보통이에요': '43%',
#   '향/다소아쉬워요': '5%',
#   '작성자': 'zard****',
#   '작성일자': '2024.07.20',
#   '별점': '5점만점에 5점',
#   '사용현황': '',
#   '세정력': '아주 만족해요',
#   '자극도': '자극없이 순해요',
#   '거품': '거품이 풍성해요',
#   '향': '아주 만족해요',
#   '리뷰': '향도 좋고 거품도 풍부하고 전체적으로 만족합니다~~ 추천!!'},
#  ...]

# %%
raw_data = jsonlload(raw_data_path)
len(raw_data)
# Out:
# 181908

# %%
labeled = label_raw_data_with_trained_model(
    raw_data=jsonlload(raw_data_path),
    acd_best_model_path=acd_best_model_path,
    asc_best_model_path=asc_best_model_path,
    model_class=ABSA_Model,
    acd_tokenizer_name=acd_base_model,
    asc_tokenizer_name=asc_base_model,
    tf_id_to_name=tf_id_to_name,
    polarity_id_to_name=polarity_id_to_name,
    special_tokens_dict=special_tokens_dict,
    entity_property_pair=entity_property_pair,
    max_len=max_len,
    threshold=threshold,
    save_path=final_output_DIR
)
# Out:
# Starting Labeling with Raw Data...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/80.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/620 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/344k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/375 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/752k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/473M [00:00<?, ?B/s]
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# model.safetensors:   0%|          | 0.00/473M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/546 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/443M [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at klue/roberta-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 라벨링 진행:   1%|          | 1407/181908 [02:25<5:57:29,  8.42it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (517 > 512). Running this sequence through the model will result in indexing errors
# 라벨링 진행:   2%|▏         | 2879/181908 [04:53<5:28:10,  9.09it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (539 > 512). Running this sequence through the model will result in indexing errors
# 라벨링 진행: 100%|██████████| 181908/181908 [5:16:33<00:00,  9.58it/s]
# Saved final outputs to /content/drive/MyDrive/ABSA/f_final_output
